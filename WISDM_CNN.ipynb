# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 19:49:12

# %% [markdown]
# # **Load the WISDM Dataset**

# %%
file_path ='/content/drive/MyDrive/WISDM/WISDM_ar_v1.1_cleaned.txt'
model_save_path = '/content/drive/MyDrive/WISDM/WISDM-CNN.hdf5'


colnames = ['users', 'activity', 'timestamp', 'x-axis', 'y-axis', 'z-axis']
dataset = pd.read_csv(file_path, names=colnames)
dataset = dataset.dropna()

# Further data cleaning of the database: convert the 'x-axis', 'y-axis', 'z-axis' to numeric values by removing and ; or ,
for axis in ['x-axis', 'y-axis', 'z-axis']:
    dataset[axis] = dataset[axis].astype(str).str.replace(';', '').astype(np.float32)

n_time_step = 128
step = 64
n_feature = 3
segments = []
labels = []

for i in range(0, len(dataset) - n_time_step, step):
    x = dataset['x-axis'].values[i: i + n_time_step]
    y = dataset['y-axis'].values[i: i + n_time_step]
    z = dataset['z-axis'].values[i: i + n_time_step]
    segment_labels = dataset['activity'][i: i + n_time_step]
    # Use pandas to find the most frequent label
    label = segment_labels.value_counts().idxmax()
    segments.append([x, y, z])
    labels.append(label)

reshaped_segments = np.asarray(segments, dtype=np.float32).reshape(-1, n_time_step, n_feature)
labels = np.asarray(pd.get_dummies(labels), dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(reshaped_segments, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class CNNAttentionModel:

    def __init__(self, kernel_size, learning_rate, batch_size):
        self.model = None
        self.kernel_size = kernel_size
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def CNN_Attention(self, input_forward, input_backward, kernel_size):
        # 1D-CNN layers with different kernels
        conv1_forward = Conv1D(128, kernel_size, activation='relu', padding='same')(input_forward)
        conv1_backward = Conv1D(128, kernel_size, activation='relu', padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

        # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

        # Dropout
        model = Dropout(0.2)(model)

        # Additional Conv1D layers
        model = Conv1D(128, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//2, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//4, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # Layer Normalization
        model = LayerNormalization()(model)

        # Extra CNN layer for demonstration
        model = Conv1D(128//8, kernel_size, activation='relu', padding='same')(model)

        # Attention layer
        output = Attention(8)(model)

        return output

    def create_model(self, kernel_size, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)

        model1 = self.CNN_Attention(input_1_forward, input_1_backward_flipped, kernel_size)

        output = Dropout(0.2)(model1)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )


    def fit(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data):
        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history




    def score(self, X, y):
        loss, accuracy = self.model.evaluate(X, y, verbose=0)
        return accuracy


    def get_params(self, deep=True):
        return {
            'kernel_size': self.kernel_size,
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Train and Test The Model**

# %%
best_params = {
    'learning_rate': 0.0001,
    'kernel_size': 5,
    'batch_size': 32
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = CNNAttentionModel(kernel_size=best_params['kernel_size'],
                               learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit(
    X=[
        x_train_final,
        np.flip(x_train_final, axis=1)
    ],
    y=y_train_final,
    kernel_size=best_params['kernel_size'],
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final,
            np.flip(x_val_final, axis=1)
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([X_test, np.flip(X_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([X_test, np.flip(X_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics
average_accuracy = np.mean(history.history['accuracy'])
best_accuracy = np.max(history.history['accuracy'])
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'],
                  index=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 344/344 [==============================] - ETA: 0s - loss: 1.1121 - accuracy: 0.5967
# Epoch 1: val_accuracy improved from -inf to 0.77021, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 21s 22ms/step - loss: 1.1121 - accuracy: 0.5967 - val_loss: 0.6173 - val_accuracy: 0.7702
# Epoch 2/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.7214 - accuracy: 0.7463
# Epoch 2: val_accuracy improved from 0.77021 to 0.84523, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 13ms/step - loss: 0.7221 - accuracy: 0.7462 - val_loss: 0.4299 - val_accuracy: 0.8452
# Epoch 3/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.5732 - accuracy: 0.7980
# Epoch 3: val_accuracy improved from 0.84523 to 0.87800, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.5733 - accuracy: 0.7980 - val_loss: 0.3644 - val_accuracy: 0.8780
# Epoch 4/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.4717 - accuracy: 0.8345
# Epoch 4: val_accuracy improved from 0.87800 to 0.90386, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.4726 - accuracy: 0.8339 - val_loss: 0.2851 - val_accuracy: 0.9039
# Epoch 5/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.4024 - accuracy: 0.8599
# Epoch 5: val_accuracy improved from 0.90386 to 0.91369, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 13ms/step - loss: 0.4026 - accuracy: 0.8597 - val_loss: 0.2504 - val_accuracy: 0.9137
# Epoch 6/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.3645 - accuracy: 0.8714
# Epoch 6: val_accuracy did not improve from 0.91369
# 344/344 [==============================] - 5s 15ms/step - loss: 0.3643 - accuracy: 0.8716 - val_loss: 0.2584 - val_accuracy: 0.9119
# Epoch 7/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.3228 - accuracy: 0.8878
# Epoch 7: val_accuracy improved from 0.91369 to 0.94355, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 16ms/step - loss: 0.3229 - accuracy: 0.8877 - val_loss: 0.1986 - val_accuracy: 0.9436
# Epoch 8/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.3026 - accuracy: 0.8996
# Epoch 8: val_accuracy improved from 0.94355 to 0.94683, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 13ms/step - loss: 0.3018 - accuracy: 0.8998 - val_loss: 0.1863 - val_accuracy: 0.9468
# Epoch 9/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.9043
# Epoch 9: val_accuracy improved from 0.94683 to 0.94792, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 16ms/step - loss: 0.2845 - accuracy: 0.9046 - val_loss: 0.1789 - val_accuracy: 0.9479
# Epoch 10/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2675 - accuracy: 0.9128
# Epoch 10: val_accuracy did not improve from 0.94792
# 344/344 [==============================] - 5s 16ms/step - loss: 0.2678 - accuracy: 0.9128 - val_loss: 0.1796 - val_accuracy: 0.9468
# Epoch 11/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9150
# Epoch 11: val_accuracy improved from 0.94792 to 0.95157, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 21ms/step - loss: 0.2493 - accuracy: 0.9150 - val_loss: 0.1720 - val_accuracy: 0.9516
# Epoch 12/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9258
# Epoch 12: val_accuracy improved from 0.95157 to 0.95266, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.2257 - accuracy: 0.9258 - val_loss: 0.1579 - val_accuracy: 0.9527
# Epoch 13/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2176 - accuracy: 0.9278
# Epoch 13: val_accuracy improved from 0.95266 to 0.95484, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2176 - accuracy: 0.9279 - val_loss: 0.1555 - val_accuracy: 0.9548
# Epoch 14/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9292
# Epoch 14: val_accuracy did not improve from 0.95484
# 344/344 [==============================] - 6s 19ms/step - loss: 0.2155 - accuracy: 0.9293 - val_loss: 0.1569 - val_accuracy: 0.9523
# Epoch 15/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9272
# Epoch 15: val_accuracy did not improve from 0.95484
# 344/344 [==============================] - 5s 14ms/step - loss: 0.2053 - accuracy: 0.9271 - val_loss: 0.1531 - val_accuracy: 0.9501
# Epoch 16/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9335
# Epoch 16: val_accuracy did not improve from 0.95484
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1975 - accuracy: 0.9332 - val_loss: 0.1422 - val_accuracy: 0.9512
# Epoch 17/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1852 - accuracy: 0.9371
# Epoch 17: val_accuracy improved from 0.95484 to 0.95630, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1851 - accuracy: 0.9372 - val_loss: 0.1426 - val_accuracy: 0.9563
# Epoch 18/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.1809 - accuracy: 0.9397
# Epoch 18: val_accuracy improved from 0.95630 to 0.95921, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1800 - accuracy: 0.9401 - val_loss: 0.1358 - val_accuracy: 0.9592
# Epoch 19/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9454
# Epoch 19: val_accuracy did not improve from 0.95921
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1679 - accuracy: 0.9454 - val_loss: 0.1378 - val_accuracy: 0.9585
# Epoch 20/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1665 - accuracy: 0.9423
# Epoch 20: val_accuracy improved from 0.95921 to 0.95958, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1662 - accuracy: 0.9425 - val_loss: 0.1429 - val_accuracy: 0.9596
# Epoch 21/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9456
# Epoch 21: val_accuracy did not improve from 0.95958
# 344/344 [==============================] - 5s 13ms/step - loss: 0.1634 - accuracy: 0.9454 - val_loss: 0.1645 - val_accuracy: 0.9516
# Epoch 22/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1613 - accuracy: 0.9482
# Epoch 22: val_accuracy did not improve from 0.95958
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1610 - accuracy: 0.9481 - val_loss: 0.1388 - val_accuracy: 0.9592
# Epoch 23/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1467 - accuracy: 0.9514
# Epoch 23: val_accuracy improved from 0.95958 to 0.96031, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1467 - accuracy: 0.9514 - val_loss: 0.1289 - val_accuracy: 0.9603
# Epoch 24/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1464 - accuracy: 0.9525
# Epoch 24: val_accuracy improved from 0.96031 to 0.96213, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1469 - accuracy: 0.9523 - val_loss: 0.1186 - val_accuracy: 0.9621
# Epoch 25/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1432 - accuracy: 0.9538
# Epoch 25: val_accuracy improved from 0.96213 to 0.96395, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1432 - accuracy: 0.9538 - val_loss: 0.1162 - val_accuracy: 0.9639
# Epoch 26/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1335 - accuracy: 0.9579
# Epoch 26: val_accuracy improved from 0.96395 to 0.96431, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1336 - accuracy: 0.9577 - val_loss: 0.1171 - val_accuracy: 0.9643
# Epoch 27/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1307 - accuracy: 0.9583
# Epoch 27: val_accuracy did not improve from 0.96431
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1308 - accuracy: 0.9583 - val_loss: 0.1475 - val_accuracy: 0.9512
# Epoch 28/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9562
# Epoch 28: val_accuracy did not improve from 0.96431
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1319 - accuracy: 0.9562 - val_loss: 0.1169 - val_accuracy: 0.9636
# Epoch 29/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1245 - accuracy: 0.9566
# Epoch 29: val_accuracy improved from 0.96431 to 0.96504, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1252 - accuracy: 0.9564 - val_loss: 0.1092 - val_accuracy: 0.9650
# Epoch 30/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9601
# Epoch 30: val_accuracy improved from 0.96504 to 0.96795, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1215 - accuracy: 0.9603 - val_loss: 0.1153 - val_accuracy: 0.9680
# Epoch 31/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9622
# Epoch 31: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1206 - accuracy: 0.9621 - val_loss: 0.1101 - val_accuracy: 0.9661
# Epoch 32/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9644
# Epoch 32: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1107 - accuracy: 0.9646 - val_loss: 0.1302 - val_accuracy: 0.9621
# Epoch 33/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.9646
# Epoch 33: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1131 - accuracy: 0.9646 - val_loss: 0.1200 - val_accuracy: 0.9650
# Epoch 34/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9648
# Epoch 34: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 5s 13ms/step - loss: 0.1086 - accuracy: 0.9648 - val_loss: 0.1173 - val_accuracy: 0.9654
# Epoch 35/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9646
# Epoch 35: val_accuracy improved from 0.96795 to 0.96868, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1114 - accuracy: 0.9646 - val_loss: 0.1134 - val_accuracy: 0.9687
# Epoch 36/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9688
# Epoch 36: val_accuracy did not improve from 0.96868
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0993 - accuracy: 0.9688 - val_loss: 0.1403 - val_accuracy: 0.9618
# Epoch 37/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.1109 - accuracy: 0.9637
# Epoch 37: val_accuracy did not improve from 0.96868
# 344/344 [==============================] - 4s 13ms/step - loss: 0.1106 - accuracy: 0.9638 - val_loss: 0.1224 - val_accuracy: 0.9625
# Epoch 38/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9673
# Epoch 38: val_accuracy did not improve from 0.96868
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1015 - accuracy: 0.9673 - val_loss: 0.1190 - val_accuracy: 0.9650
# Epoch 39/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0983 - accuracy: 0.9692
# Epoch 39: val_accuracy did not improve from 0.96868
# 344/344 [==============================] - 5s 15ms/step - loss: 0.0986 - accuracy: 0.9690 - val_loss: 0.1178 - val_accuracy: 0.9683
# Epoch 40/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9672
# Epoch 40: val_accuracy improved from 0.96868 to 0.97196, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 14ms/step - loss: 0.1052 - accuracy: 0.9671 - val_loss: 0.1100 - val_accuracy: 0.9720
# Epoch 41/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0921 - accuracy: 0.9720
# Epoch 41: val_accuracy did not improve from 0.97196
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0922 - accuracy: 0.9720 - val_loss: 0.1046 - val_accuracy: 0.9698
# Epoch 42/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9688
# Epoch 42: val_accuracy did not improve from 0.97196
# 344/344 [==============================] - 5s 16ms/step - loss: 0.0946 - accuracy: 0.9689 - val_loss: 0.1100 - val_accuracy: 0.9676
# Epoch 43/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0910 - accuracy: 0.9707
# Epoch 43: val_accuracy did not improve from 0.97196
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0910 - accuracy: 0.9706 - val_loss: 0.1074 - val_accuracy: 0.9709
# Epoch 44/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0888 - accuracy: 0.9693
# Epoch 44: val_accuracy did not improve from 0.97196
# 344/344 [==============================] - 5s 15ms/step - loss: 0.0888 - accuracy: 0.9693 - val_loss: 0.1092 - val_accuracy: 0.9694
# Epoch 45/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9731
# Epoch 45: val_accuracy improved from 0.97196 to 0.97305, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 5s 16ms/step - loss: 0.0843 - accuracy: 0.9731 - val_loss: 0.1209 - val_accuracy: 0.9731
# Epoch 46/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9735
# Epoch 46: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0879 - accuracy: 0.9735 - val_loss: 0.1532 - val_accuracy: 0.9574
# Epoch 47/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0899 - accuracy: 0.9721
# Epoch 47: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0900 - accuracy: 0.9721 - val_loss: 0.1152 - val_accuracy: 0.9698
# Epoch 48/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.0843 - accuracy: 0.9717
# Epoch 48: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0840 - accuracy: 0.9719 - val_loss: 0.1258 - val_accuracy: 0.9694
# Epoch 49/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9748
# Epoch 49: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0790 - accuracy: 0.9748 - val_loss: 0.1247 - val_accuracy: 0.9705
# Epoch 50/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9747
# Epoch 50: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 16ms/step - loss: 0.0793 - accuracy: 0.9747 - val_loss: 0.1150 - val_accuracy: 0.9665
# Epoch 51/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9740
# Epoch 51: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0795 - accuracy: 0.9740 - val_loss: 0.1371 - val_accuracy: 0.9621
# Epoch 52/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0844 - accuracy: 0.9708
# Epoch 52: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0847 - accuracy: 0.9707 - val_loss: 0.1285 - val_accuracy: 0.9676
# Epoch 53/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9759
# Epoch 53: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 21ms/step - loss: 0.0735 - accuracy: 0.9759 - val_loss: 0.1217 - val_accuracy: 0.9723
# Epoch 54/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9783
# Epoch 54: val_accuracy improved from 0.97305 to 0.97342, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0671 - accuracy: 0.9782 - val_loss: 0.1061 - val_accuracy: 0.9734
# Epoch 55/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9756
# Epoch 55: val_accuracy did not improve from 0.97342
# 344/344 [==============================] - 5s 15ms/step - loss: 0.0762 - accuracy: 0.9756 - val_loss: 0.1406 - val_accuracy: 0.9694
# Epoch 56/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0764 - accuracy: 0.9737
# Epoch 56: val_accuracy improved from 0.97342 to 0.97597, saving model to /content/drive/MyDrive/WISDM/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0762 - accuracy: 0.9738 - val_loss: 0.1121 - val_accuracy: 0.9760
# Epoch 57/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.0709 - accuracy: 0.9767
# Epoch 57: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 0.1470 - val_accuracy: 0.9705
# Epoch 58/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9779
# Epoch 58: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 16ms/step - loss: 0.0703 - accuracy: 0.9780 - val_loss: 0.1229 - val_accuracy: 0.9687
# Epoch 59/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9770
# Epoch 59: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0707 - accuracy: 0.9771 - val_loss: 0.1361 - val_accuracy: 0.9731
# Epoch 60/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9785
# Epoch 60: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 13ms/step - loss: 0.0626 - accuracy: 0.9785 - val_loss: 0.1211 - val_accuracy: 0.9727
# Epoch 61/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9792
# Epoch 61: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0687 - accuracy: 0.9792 - val_loss: 0.1337 - val_accuracy: 0.9665
# Epoch 62/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9760
# Epoch 62: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 15ms/step - loss: 0.0745 - accuracy: 0.9760 - val_loss: 0.1390 - val_accuracy: 0.9683
# Epoch 63/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9784
# Epoch 63: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0690 - accuracy: 0.9783 - val_loss: 0.1442 - val_accuracy: 0.9716
# Epoch 64/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0743 - accuracy: 0.9762
# Epoch 64: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0745 - accuracy: 0.9761 - val_loss: 0.1337 - val_accuracy: 0.9705
# Epoch 65/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9789
# Epoch 65: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0669 - accuracy: 0.9788 - val_loss: 0.1200 - val_accuracy: 0.9731
# Epoch 66/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0612 - accuracy: 0.9798Restoring model weights from the end of the best epoch: 56.
#
# Epoch 66: val_accuracy did not improve from 0.97597
# 344/344 [==============================] - 5s 14ms/step - loss: 0.0615 - accuracy: 0.9798 - val_loss: 0.1255 - val_accuracy: 0.9709
# Epoch 66: early stopping
# 108/108 [==============================] - 1s 3ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             2048      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             2048      ['input_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              163968    ['dropout[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               41024     ['dropout_1[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               10272     ['dropout_2[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  conv1d_5 (Conv1D)           (None, 8, 16)                2576      ['layer_normalization[1][0]']
#
#  attention (Attention)       (None, 16)                   24        ['conv1d_5[1][0]']
#
#  dropout_4 (Dropout)         (None, 16)                   0         ['attention[1][0]']
#
#  dense (Dense)               (None, 6)                    102       ['dropout_4[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 224046 (875.18 KB)
# Trainable params: 223086 (871.43 KB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9694
# Average Accuracy: 0.9420971996856459
# Best Accuracy: 0.979781448841095
# Last Epoch Accuracy: 0.979781448841095
# Micro Accuracy: 0.9694
# Macro Accuracy: 0.9580
# Weighted Accuracy: 0.9694
# Precision (Macro): 0.9520037957930579
# Precision (Weighted): 0.9702252930139058
# Precision (Micro): 0.9694055944055944
# Recall (Macro): 0.9580222263103021
# Recall (Weighted): 0.9694055944055944
# Recall (Micro): 0.9694055944055944
# F1 Score (Macro): 0.9547465794591304
# F1 Score (Weighted): 0.9696682337447398
# F1 Score (Micro): 0.9694055944055944
# Population Std Dev - True Labels: 1.9351159283819863
# Population Std Dev - Predicted Labels: 1.9452671630211866
# Sample Std Dev - True Labels: 1.9353979124896226
# Sample Std Dev - Predicted Labels: 1.9455506263615652
# _______________________________________________________________
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 284
#   True Negatives (TN): 3079
#   False Positives (FP): 47
#   False Negatives (FN): 22
#
# Metrics for JOGGING:
#   True Positives (TP): 1082
#   True Negatives (TN): 2330
#   False Positives (FP): 5
#   False Negatives (FN): 15
#
# Metrics for SITTING:
#   True Positives (TP): 181
#   True Negatives (TN): 3242
#   False Positives (FP): 3
#   False Negatives (FN): 6
#
# Metrics for STANDING:
#   True Positives (TP): 142
#   True Negatives (TN): 3282
#   False Positives (FP): 5
#   False Negatives (FN): 3
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 371
#   True Negatives (TN): 2987
#   False Positives (FP): 33
#   False Negatives (FN): 41
#
# Metrics for WALKING:
#   True Positives (TP): 1267
#   True Negatives (TN): 2135
#   False Positives (FP): 12
#   False Negatives (FN): 18
#
# Timer stopped at 2024-06-03 19:56:06
# Elapsed time: 413.9484632015228 seconds
