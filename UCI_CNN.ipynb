# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 19:25:00

# %% [markdown]
# # **Load the UCI-HAR Dataset**

# %%
root_train = '/content/drive/MyDrive/UCIHARDataset/train/train_Inertial_Signals'
root_test = '/content/drive/MyDrive/UCIHARDataset/test/test_Inertial_Signals'
model_save_path = '/content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5'

def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
        return files

file_x_train =  ['body_acc_x_train.txt', 'body_acc_y_train.txt', 'body_acc_z_train.txt',
                'body_gyro_x_train.txt', 'body_gyro_y_train.txt', 'body_gyro_z_train.txt',
                'total_acc_x_train.txt', 'total_acc_y_train.txt', 'total_acc_z_train.txt']
file_x_test = ['body_acc_x_test.txt', 'body_acc_y_test.txt', 'body_acc_z_test.txt',
               'body_gyro_x_test.txt', 'body_gyro_y_test.txt', 'body_gyro_z_test.txt',
               'total_acc_x_test.txt', 'total_acc_y_test.txt', 'total_acc_z_test.txt']

file_y_train = '/content/drive/MyDrive/UCIHARDataset/train/y_train.txt'
file_y_test = '/content/drive/MyDrive/UCIHARDataset/test/y_test.txt'

def load_x(data, root):
    x_body_acc = []
    for file in data[0:3]:
        x_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_body_acc.append(x_acc_input)
    x_body_acc = np.transpose(np.array(x_body_acc), (1, 2, 0))

    x_gro = []
    for file in data[3:6]:
        x_gro_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_gro.append(x_gro_input)
    x_gro = np.transpose(np.array(x_gro), (1, 2, 0))

    x_total_acc = []
    for file in data[6:9]:
        x_total_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_total_acc.append(x_total_acc_input)
    x_total_acc = np.transpose(np.array(x_total_acc), (1, 2, 0))
    return x_body_acc, x_gro, x_total_acc

def load_y(data):
    file = open(data, 'r')
    y_input = np.array([elem for elem in [row.strip().split(' ') for row in file]], dtype=np.int32)
    file.close()
    return to_categorical(y_input - 1.0)

x_body_acc_train, x_gro_train, x_total_acc_train = load_x(file_x_train, root_train)
x_body_acc_test, x_gro_test, x_total_acc_test = load_x(file_x_test, root_test)
y_train = load_y(file_y_train)
y_test = load_y(file_y_test)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class CNNAttentionModel:

    def __init__(self, kernel_size, learning_rate, batch_size):
        self.model = None
        self.kernel_size = kernel_size
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def Res_CNN_Attention(self, input_forward, input_backward, kernel_size):
        # 1D-CNN layers with different kernels
        conv1_forward = Conv1D(128, kernel_size, activation='relu', padding='same')(input_forward)
        conv1_backward = Conv1D(128, kernel_size, activation='relu', padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

        # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

        # Dropout
        model = Dropout(0.2)(model)

        # Additional Conv1D layers
        model = Conv1D(128, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//2, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//4, kernel_size, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # Layer Normalization
        model = LayerNormalization()(model)

        # Extra CNN layer for demonstration
        model = Conv1D(128//8, kernel_size, activation='relu', padding='same')(model)

        # Attention layer
        output = Attention(8)(model)

        return output

    def create_model(self, kernel_size, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))
        input_2_forward = Input(shape=(128, 3))
        input_2_backward = Input(shape=(128, 3))
        input_3_forward = Input(shape=(128, 3))
        input_3_backward = Input(shape=(128, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)
        input_2_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_2_backward)
        input_3_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_3_backward)

        model1 = self.Res_CNN_Attention(input_1_forward, input_1_backward_flipped, kernel_size)
        model2 = self.Res_CNN_Attention(input_2_forward, input_2_backward_flipped, kernel_size)
        model3 = self.Res_CNN_Attention(input_3_forward, input_3_backward_flipped, kernel_size)


        concatenated_models = Concatenate()([model1, model2, model3])

        output = Dropout(0.2)(concatenated_models)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped, input_2_forward, input_2_backward_flipped, input_3_forward, input_3_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)


        return history

    def fit2(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data):
        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history




    def score(self, X, y):
        loss, accuracy = self.model.evaluate(X, y, verbose=0)
        return accuracy


    def get_params(self, deep=True):
        return {
            'kernel_size': self.kernel_size,
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Now we train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.0001,
    'kernel_size': 5,
    'batch_size': 32
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_body_acc_train, x_gro_train, x_total_acc_train], axis=-1),
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = CNNAttentionModel(kernel_size=best_params['kernel_size'],
                               learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
    X=[
        x_train_final[:, :, :3],
        np.flip(x_train_final[:, :, :3], axis=1),
        x_train_final[:, :, 3:6],
        np.flip(x_train_final[:, :, 3:6], axis=1),
        x_train_final[:, :, 6:],
        np.flip(x_train_final[:, :, 6:], axis=1)
    ],
    y=y_train_final,
    kernel_size=best_params['kernel_size'],
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],
            np.flip(x_val_final[:, :, :3], axis=1),
            x_val_final[:, :, 3:6],
            np.flip(x_val_final[:, :, 3:6], axis=1),
            x_val_final[:, :, 6:],
            np.flip(x_val_final[:, :, 6:], axis=1)
        ],
        y_val_final
    )
)


# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                                      x_gro_test, np.flip(x_gro_test, axis=1),
                                                      x_total_acc_test, np.flip(x_total_acc_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                   x_gro_test, np.flip(x_gro_test, axis=1),
                                   x_total_acc_test, np.flip(x_total_acc_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics

# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'],
                  index=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 184/184 [==============================] - ETA: 0s - loss: 0.8570 - accuracy: 0.7247
# Epoch 1: val_accuracy improved from -inf to 0.18763, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 40s 56ms/step - loss: 0.8570 - accuracy: 0.7247 - val_loss: 1.9081 - val_accuracy: 0.1876
# Epoch 2/150
# 184/184 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.9031
# Epoch 2: val_accuracy improved from 0.18763 to 0.48878, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 6s 35ms/step - loss: 0.3665 - accuracy: 0.9031 - val_loss: 1.1698 - val_accuracy: 0.4888
# Epoch 3/150
# 184/184 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9298
# Epoch 3: val_accuracy improved from 0.48878 to 0.92658, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.2434 - accuracy: 0.9298 - val_loss: 0.2428 - val_accuracy: 0.9266
# Epoch 4/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.9430
# Epoch 4: val_accuracy improved from 0.92658 to 0.95037, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1896 - accuracy: 0.9429 - val_loss: 0.1283 - val_accuracy: 0.9504
# Epoch 5/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9437
# Epoch 5: val_accuracy improved from 0.95037 to 0.95173, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1731 - accuracy: 0.9437 - val_loss: 0.1121 - val_accuracy: 0.9517
# Epoch 6/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9477
# Epoch 6: val_accuracy improved from 0.95173 to 0.96465, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1534 - accuracy: 0.9480 - val_loss: 0.1021 - val_accuracy: 0.9646
# Epoch 7/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1382 - accuracy: 0.9527
# Epoch 7: val_accuracy improved from 0.96465 to 0.97213, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1387 - accuracy: 0.9526 - val_loss: 0.0799 - val_accuracy: 0.9721
# Epoch 8/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1243 - accuracy: 0.9532
# Epoch 8: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 6s 32ms/step - loss: 0.1243 - accuracy: 0.9534 - val_loss: 0.0829 - val_accuracy: 0.9680
# Epoch 9/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1175 - accuracy: 0.9582
# Epoch 9: val_accuracy improved from 0.97213 to 0.97553, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.1175 - accuracy: 0.9582 - val_loss: 0.0691 - val_accuracy: 0.9755
# Epoch 10/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9612
# Epoch 10: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1049 - accuracy: 0.9612 - val_loss: 0.0761 - val_accuracy: 0.9721
# Epoch 11/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9623
# Epoch 11: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1059 - accuracy: 0.9623 - val_loss: 0.1332 - val_accuracy: 0.9307
# Epoch 12/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0975 - accuracy: 0.9650
# Epoch 12: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0975 - accuracy: 0.9650 - val_loss: 0.0606 - val_accuracy: 0.9701
# Epoch 13/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9619
# Epoch 13: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0983 - accuracy: 0.9619 - val_loss: 0.0693 - val_accuracy: 0.9701
# Epoch 14/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9658
# Epoch 14: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0873 - accuracy: 0.9657 - val_loss: 0.0623 - val_accuracy: 0.9742
# Epoch 15/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9677
# Epoch 15: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0849 - accuracy: 0.9677 - val_loss: 0.0624 - val_accuracy: 0.9714
# Epoch 16/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0872 - accuracy: 0.9676
# Epoch 16: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0874 - accuracy: 0.9675 - val_loss: 0.1457 - val_accuracy: 0.9286
# Epoch 17/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9689
# Epoch 17: val_accuracy did not improve from 0.97553
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0821 - accuracy: 0.9689 - val_loss: 0.0866 - val_accuracy: 0.9572
# Epoch 18/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9689
# Epoch 18: val_accuracy improved from 0.97553 to 0.97621, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 8s 44ms/step - loss: 0.0753 - accuracy: 0.9689 - val_loss: 0.0638 - val_accuracy: 0.9762
# Epoch 19/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9693
# Epoch 19: val_accuracy did not improve from 0.97621
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0730 - accuracy: 0.9692 - val_loss: 0.1069 - val_accuracy: 0.9585
# Epoch 20/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9668
# Epoch 20: val_accuracy did not improve from 0.97621
# 184/184 [==============================] - 7s 40ms/step - loss: 0.0780 - accuracy: 0.9668 - val_loss: 0.2091 - val_accuracy: 0.9123
# Epoch 21/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9715
# Epoch 21: val_accuracy did not improve from 0.97621
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0726 - accuracy: 0.9716 - val_loss: 0.0646 - val_accuracy: 0.9728
# Epoch 22/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9713
# Epoch 22: val_accuracy did not improve from 0.97621
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0759 - accuracy: 0.9713 - val_loss: 0.0997 - val_accuracy: 0.9477
# Epoch 23/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0679 - accuracy: 0.9720
# Epoch 23: val_accuracy did not improve from 0.97621
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0680 - accuracy: 0.9719 - val_loss: 0.0580 - val_accuracy: 0.9762
# Epoch 24/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9751
# Epoch 24: val_accuracy improved from 0.97621 to 0.98232, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 8s 46ms/step - loss: 0.0646 - accuracy: 0.9752 - val_loss: 0.0471 - val_accuracy: 0.9823
# Epoch 25/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9740
# Epoch 25: val_accuracy did not improve from 0.98232
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0662 - accuracy: 0.9742 - val_loss: 0.0762 - val_accuracy: 0.9646
# Epoch 26/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9730
# Epoch 26: val_accuracy did not improve from 0.98232
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0651 - accuracy: 0.9730 - val_loss: 0.1511 - val_accuracy: 0.9259
# Epoch 27/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9751
# Epoch 27: val_accuracy did not improve from 0.98232
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0608 - accuracy: 0.9750 - val_loss: 0.0452 - val_accuracy: 0.9782
# Epoch 28/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9767
# Epoch 28: val_accuracy did not improve from 0.98232
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0573 - accuracy: 0.9767 - val_loss: 0.1302 - val_accuracy: 0.9490
# Epoch 29/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9758
# Epoch 29: val_accuracy improved from 0.98232 to 0.98572, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/CNN-R-22/UCI-CNN-R-22.hdf5
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0595 - accuracy: 0.9759 - val_loss: 0.0446 - val_accuracy: 0.9857
# Epoch 30/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9759
# Epoch 30: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0601 - accuracy: 0.9760 - val_loss: 0.0617 - val_accuracy: 0.9708
# Epoch 31/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0543 - accuracy: 0.9795
# Epoch 31: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 6s 32ms/step - loss: 0.0545 - accuracy: 0.9794 - val_loss: 0.0530 - val_accuracy: 0.9748
# Epoch 32/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9770
# Epoch 32: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 7s 38ms/step - loss: 0.0631 - accuracy: 0.9770 - val_loss: 0.0463 - val_accuracy: 0.9789
# Epoch 33/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0560 - accuracy: 0.9771
# Epoch 33: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 6s 31ms/step - loss: 0.0559 - accuracy: 0.9770 - val_loss: 0.1172 - val_accuracy: 0.9470
# Epoch 34/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9769
# Epoch 34: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 7s 37ms/step - loss: 0.0564 - accuracy: 0.9769 - val_loss: 0.0539 - val_accuracy: 0.9776
# Epoch 35/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0514 - accuracy: 0.9783
# Epoch 35: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0516 - accuracy: 0.9782 - val_loss: 0.0432 - val_accuracy: 0.9803
# Epoch 36/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9783
# Epoch 36: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0549 - accuracy: 0.9782 - val_loss: 0.1450 - val_accuracy: 0.9470
# Epoch 37/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9774
# Epoch 37: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0621 - accuracy: 0.9774 - val_loss: 0.0621 - val_accuracy: 0.9735
# Epoch 38/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9781
# Epoch 38: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0566 - accuracy: 0.9782 - val_loss: 0.0481 - val_accuracy: 0.9810
# Epoch 39/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9760Restoring model weights from the end of the best epoch: 29.
#
# Epoch 39: val_accuracy did not improve from 0.98572
# 184/184 [==============================] - 7s 40ms/step - loss: 0.0562 - accuracy: 0.9760 - val_loss: 0.0504 - val_accuracy: 0.9803
# Epoch 39: early stopping
# 93/93 [==============================] - 1s 7ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_7 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_8 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_5 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_9 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             2048      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             2048      ['input_7[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 128, 128)             2048      ['input_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 128, 128)             2048      ['input_8[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 128, 128)             2048      ['input_5[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 128, 128)             2048      ['input_9[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 256)             0         ['conv1d_6[1][0]',
#  )                                                                   'conv1d_7[1][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 256)             0         ['conv1d_12[1][0]',
#  )                                                                   'conv1d_13[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 128, 256)             1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 128, 256)             1024      ['concatenate_2[1][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_4[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_8 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_8[1][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  dropout_4 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_4[1][0]']
#
#  dropout_8 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_8[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              163968    ['dropout[1][0]']
#
#  conv1d_8 (Conv1D)           (None, 64, 128)              163968    ['dropout_4[1][0]']
#
#  conv1d_14 (Conv1D)          (None, 64, 128)              163968    ['dropout_8[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 64, 128)              512       ['conv1d_8[1][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 128)              512       ['conv1d_14[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_5[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_9 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_9[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  dropout_5 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_5[1][0]']
#
#  dropout_9 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_9[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               41024     ['dropout_1[1][0]']
#
#  conv1d_9 (Conv1D)           (None, 32, 64)               41024     ['dropout_5[1][0]']
#
#  conv1d_15 (Conv1D)          (None, 32, 64)               41024     ['dropout_9[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 32, 64)               256       ['conv1d_9[1][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 32, 64)               256       ['conv1d_15[1][0]']
#  tchNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_6[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_10 (MaxPooli  (None, 16, 64)               0         ['batch_normalization_10[1][0]
#  ng1D)                                                              ']
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  dropout_6 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_6[1][0]']
#
#  dropout_10 (Dropout)        (None, 16, 64)               0         ['max_pooling1d_10[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               10272     ['dropout_2[1][0]']
#
#  conv1d_10 (Conv1D)          (None, 16, 32)               10272     ['dropout_6[1][0]']
#
#  conv1d_16 (Conv1D)          (None, 16, 32)               10272     ['dropout_10[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 32)               128       ['conv1d_10[1][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 16, 32)               128       ['conv1d_16[1][0]']
#  tchNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_7[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_11 (MaxPooli  (None, 8, 32)                0         ['batch_normalization_11[1][0]
#  ng1D)                                                              ']
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  dropout_7 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_7[1][0]']
#
#  dropout_11 (Dropout)        (None, 8, 32)                0         ['max_pooling1d_11[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  layer_normalization_1 (Lay  (None, 8, 32)                64        ['dropout_7[1][0]']
#  erNormalization)
#
#  layer_normalization_2 (Lay  (None, 8, 32)                64        ['dropout_11[1][0]']
#  erNormalization)
#
#  conv1d_5 (Conv1D)           (None, 8, 16)                2576      ['layer_normalization[1][0]']
#
#  conv1d_11 (Conv1D)          (None, 8, 16)                2576      ['layer_normalization_1[1][0]'
#                                                                     ]
#
#  conv1d_17 (Conv1D)          (None, 8, 16)                2576      ['layer_normalization_2[1][0]'
#                                                                     ]
#
#  attention (Attention)       (None, 16)                   24        ['conv1d_5[1][0]']
#
#  attention_1 (Attention)     (None, 16)                   24        ['conv1d_11[1][0]']
#
#  attention_2 (Attention)     (None, 16)                   24        ['conv1d_17[1][0]']
#
#  concatenate_3 (Concatenate  (None, 48)                   0         ['attention[1][0]',
#  )                                                                   'attention_1[1][0]',
#                                                                      'attention_2[1][0]']
#
#  dropout_12 (Dropout)        (None, 48)                   0         ['concatenate_3[1][0]']
#
#  dense (Dense)               (None, 6)                    294       ['dropout_12[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 672126 (2.56 MB)
# Trainable params: 669246 (2.55 MB)
# Non-trainable params: 2880 (11.25 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9359
# Average Accuracy: 0.9595001767843198
# Best Accuracy: 0.9794252514839172
# Last Epoch Accuracy: 0.9760245084762573
# Micro Accuracy: 0.9359
# Macro Accuracy: 0.9354
# Weighted Accuracy: 0.9359
# Precision (Macro): 0.9389097200751365
# Precision (Weighted): 0.9374538012783531
# Precision (Micro): 0.9358669833729216
# Recall (Macro): 0.9353942416004727
# Recall (Weighted): 0.9358669833729216
# Recall (Micro): 0.9358669833729216
# F1 Score (Macro): 0.9355338043764405
# F1 Score (Weighted): 0.9350476547684871
# F1 Score (Micro): 0.9358669833729216
# Population Std Dev - True Labels: 1.7400526830680672
# Population Std Dev - Predicted Labels: 1.7762429093590582
# Sample Std Dev - True Labels: 1.7403479826345662
# Sample Std Dev - Predicted Labels: 1.7765443506695626
# _______________________________________________________________
# Metrics for WALKING:
#   True Positives (TP): 496
#   True Negatives (TN): 2402
#   False Positives (FP): 49
#   False Negatives (FN): 0
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 416
#   True Negatives (TN): 2475
#   False Positives (FP): 1
#   False Negatives (FN): 55
#
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 410
#   True Negatives (TN): 2511
#   False Positives (FP): 16
#   False Negatives (FN): 10
#
# Metrics for SITTING:
#   True Positives (TP): 402
#   True Negatives (TN): 2421
#   False Positives (FP): 35
#   False Negatives (FN): 89
#
# Metrics for STANDING:
#   True Positives (TP): 497
#   True Negatives (TN): 2349
#   False Positives (FP): 66
#   False Negatives (FN): 35
#
# Metrics for LAYING:
#   True Positives (TP): 537
#   True Negatives (TN): 2388
#   False Positives (FP): 22
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 19:31:45
# Elapsed time: 405.75342059135437 seconds
