# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()
# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')

from keras.layers import LeakyReLU
# Out:
# Timer started at 2024-06-03 21:01:17

# %% [markdown]
# # **Load the WISDOM Dataset**

# %%
file_path ='/content/drive/MyDrive/WithCV/WISDM_Dataset/WISDM_ar_v1.1_cleaned.txt'
model_load_path = '/content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5'

colnames = ['users', 'activity', 'timestamp', 'x-axis', 'y-axis', 'z-axis']
dataset = pd.read_csv(file_path, names=colnames)
dataset = dataset.dropna()

# Further data cleaning of the database: convert the 'x-axis', 'y-axis', 'z-axis' to numeric values by removing and ; or ,
for axis in ['x-axis', 'y-axis', 'z-axis']:
    dataset[axis] = dataset[axis].astype(str).str.replace(';', '').astype(np.float32)

n_time_step = 128
step = 64
n_feature = 3
segments = []
labels = []

for i in range(0, len(dataset) - n_time_step, step):
    x = dataset['x-axis'].values[i: i + n_time_step]
    y = dataset['y-axis'].values[i: i + n_time_step]
    z = dataset['z-axis'].values[i: i + n_time_step]
    segment_labels = dataset['activity'][i: i + n_time_step]
    # Use pandas to find the most frequent label
    label = segment_labels.value_counts().idxmax()
    segments.append([x, y, z])
    labels.append(label)

reshaped_segments = np.asarray(segments, dtype=np.float32).reshape(-1, n_time_step, n_feature)
labels = np.asarray(pd.get_dummies(labels), dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(reshaped_segments, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class BLSTMAttentionModel:
    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def CNN_BLSTM_Attention(self, input):
        model = Conv1D(256, 3, input_shape=(128, 3), activation=LeakyReLU(alpha=0.3), padding='same')(input)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(64, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(32, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = LayerNormalization()(model)
        x = Bidirectional(LSTM(64, return_sequences=True))(model)

        model = LayerNormalization()(x)
        y = Bidirectional(LSTM(64, return_sequences=True))(model)
        model = Add()([x, y])

        output = Attention(8)(model)
        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))

        # Now, we pass both forward and backward inputs to the ResBLSTMAttentionModel method
        model1 = self.CNN_BLSTM_Attention(input_1_forward)
        output = Dropout(0.3)(model1)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward], outputs=output)
        self.model.compile(
            loss='categorical_crossentropy',
            optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
            metrics=['accuracy']
        )

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_load_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history

    def score(self, X, y):
        loss, accuracy = self.model.evaluate(X, y, verbose=0)
        return accuracy

    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }

    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.0001,
    'batch_size': 32
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = BLSTMAttentionModel(learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


history = best_model.fit(
    X=[
        x_train_final,  # Original body acceleration data for the final model
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final,  # Original validation body acceleration data
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate(X_test,
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict(X_test)

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)



# Print model summary
best_model.model.summary()
total_params = best_model.model.count_params()
print("Total parameters:", total_params)

# Print evaluation metrics
# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'],
                  index=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

# Assuming 'conf_matrix' is your confusion matrix from your model's predictions
TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 344/344 [==============================] - ETA: 0s - loss: 0.8626 - accuracy: 0.6964
# Epoch 1: val_accuracy improved from -inf to 0.84086, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 20s 24ms/step - loss: 0.8626 - accuracy: 0.6964 - val_loss: 0.4740 - val_accuracy: 0.8409
# Epoch 2/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.5056 - accuracy: 0.8163
# Epoch 2: val_accuracy improved from 0.84086 to 0.87509, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.5055 - accuracy: 0.8163 - val_loss: 0.3407 - val_accuracy: 0.8751
# Epoch 3/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.4028 - accuracy: 0.8511
# Epoch 3: val_accuracy improved from 0.87509 to 0.89075, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.4020 - accuracy: 0.8511 - val_loss: 0.2926 - val_accuracy: 0.8908
# Epoch 4/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.3476 - accuracy: 0.8718
# Epoch 4: val_accuracy improved from 0.89075 to 0.92753, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.3473 - accuracy: 0.8717 - val_loss: 0.2269 - val_accuracy: 0.9275
# Epoch 5/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.3140 - accuracy: 0.8857
# Epoch 5: val_accuracy did not improve from 0.92753
# 344/344 [==============================] - 6s 17ms/step - loss: 0.3141 - accuracy: 0.8857 - val_loss: 0.2254 - val_accuracy: 0.9264
# Epoch 6/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.8958
# Epoch 6: val_accuracy improved from 0.92753 to 0.93263, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2887 - accuracy: 0.8954 - val_loss: 0.2025 - val_accuracy: 0.9326
# Epoch 7/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2601 - accuracy: 0.9086
# Epoch 7: val_accuracy improved from 0.93263 to 0.93664, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.2609 - accuracy: 0.9084 - val_loss: 0.1911 - val_accuracy: 0.9366
# Epoch 8/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2398 - accuracy: 0.9156
# Epoch 8: val_accuracy improved from 0.93664 to 0.94392, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2398 - accuracy: 0.9156 - val_loss: 0.1790 - val_accuracy: 0.9439
# Epoch 9/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2290 - accuracy: 0.9213
# Epoch 9: val_accuracy improved from 0.94392 to 0.95266, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2289 - accuracy: 0.9213 - val_loss: 0.1620 - val_accuracy: 0.9527
# Epoch 10/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.9233
# Epoch 10: val_accuracy did not improve from 0.95266
# 344/344 [==============================] - 6s 16ms/step - loss: 0.2196 - accuracy: 0.9232 - val_loss: 0.1602 - val_accuracy: 0.9479
# Epoch 11/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2136 - accuracy: 0.9267
# Epoch 11: val_accuracy improved from 0.95266 to 0.95375, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.2137 - accuracy: 0.9267 - val_loss: 0.1528 - val_accuracy: 0.9538
# Epoch 12/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9342
# Epoch 12: val_accuracy did not improve from 0.95375
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1907 - accuracy: 0.9341 - val_loss: 0.1497 - val_accuracy: 0.9490
# Epoch 13/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1888 - accuracy: 0.9348
# Epoch 13: val_accuracy improved from 0.95375 to 0.95412, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1885 - accuracy: 0.9351 - val_loss: 0.1462 - val_accuracy: 0.9541
# Epoch 14/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9384
# Epoch 14: val_accuracy did not improve from 0.95412
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1756 - accuracy: 0.9384 - val_loss: 0.1433 - val_accuracy: 0.9541
# Epoch 15/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1725 - accuracy: 0.9399
# Epoch 15: val_accuracy did not improve from 0.95412
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1725 - accuracy: 0.9399 - val_loss: 0.1478 - val_accuracy: 0.9483
# Epoch 16/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9446
# Epoch 16: val_accuracy improved from 0.95412 to 0.95849, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1662 - accuracy: 0.9446 - val_loss: 0.1248 - val_accuracy: 0.9585
# Epoch 17/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1564 - accuracy: 0.9459
# Epoch 17: val_accuracy did not improve from 0.95849
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1566 - accuracy: 0.9458 - val_loss: 0.1407 - val_accuracy: 0.9516
# Epoch 18/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1538 - accuracy: 0.9466
# Epoch 18: val_accuracy improved from 0.95849 to 0.96286, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1541 - accuracy: 0.9466 - val_loss: 0.1126 - val_accuracy: 0.9629
# Epoch 19/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1499 - accuracy: 0.9474
# Epoch 19: val_accuracy did not improve from 0.96286
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1500 - accuracy: 0.9474 - val_loss: 0.1269 - val_accuracy: 0.9559
# Epoch 20/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9526
# Epoch 20: val_accuracy improved from 0.96286 to 0.96322, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1422 - accuracy: 0.9526 - val_loss: 0.1074 - val_accuracy: 0.9632
# Epoch 21/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9529
# Epoch 21: val_accuracy did not improve from 0.96322
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1425 - accuracy: 0.9529 - val_loss: 0.1199 - val_accuracy: 0.9592
# Epoch 22/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.9554
# Epoch 22: val_accuracy improved from 0.96322 to 0.96468, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1315 - accuracy: 0.9556 - val_loss: 0.1051 - val_accuracy: 0.9647
# Epoch 23/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9550
# Epoch 23: val_accuracy did not improve from 0.96468
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1303 - accuracy: 0.9549 - val_loss: 0.1038 - val_accuracy: 0.9643
# Epoch 24/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9556
# Epoch 24: val_accuracy did not improve from 0.96468
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1273 - accuracy: 0.9556 - val_loss: 0.1069 - val_accuracy: 0.9599
# Epoch 25/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1264 - accuracy: 0.9552
# Epoch 25: val_accuracy did not improve from 0.96468
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1263 - accuracy: 0.9552 - val_loss: 0.0974 - val_accuracy: 0.9647
# Epoch 26/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1147 - accuracy: 0.9617
# Epoch 26: val_accuracy improved from 0.96468 to 0.96759, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1145 - accuracy: 0.9618 - val_loss: 0.0949 - val_accuracy: 0.9676
# Epoch 27/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1137 - accuracy: 0.9619
# Epoch 27: val_accuracy did not improve from 0.96759
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1136 - accuracy: 0.9619 - val_loss: 0.0949 - val_accuracy: 0.9629
# Epoch 28/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1112 - accuracy: 0.9628
# Epoch 28: val_accuracy did not improve from 0.96759
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1111 - accuracy: 0.9629 - val_loss: 0.0984 - val_accuracy: 0.9625
# Epoch 29/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1020 - accuracy: 0.9636
# Epoch 29: val_accuracy improved from 0.96759 to 0.96832, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1020 - accuracy: 0.9637 - val_loss: 0.0837 - val_accuracy: 0.9683
# Epoch 30/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1027 - accuracy: 0.9648
# Epoch 30: val_accuracy improved from 0.96832 to 0.97123, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1022 - accuracy: 0.9650 - val_loss: 0.0807 - val_accuracy: 0.9712
# Epoch 31/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9657
# Epoch 31: val_accuracy did not improve from 0.97123
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1019 - accuracy: 0.9658 - val_loss: 0.0929 - val_accuracy: 0.9647
# Epoch 32/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9647
# Epoch 32: val_accuracy improved from 0.97123 to 0.97160, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1015 - accuracy: 0.9648 - val_loss: 0.0789 - val_accuracy: 0.9716
# Epoch 33/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9645
# Epoch 33: val_accuracy did not improve from 0.97160
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0977 - accuracy: 0.9645 - val_loss: 0.0804 - val_accuracy: 0.9705
# Epoch 34/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9704
# Epoch 34: val_accuracy did not improve from 0.97160
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0907 - accuracy: 0.9703 - val_loss: 0.0857 - val_accuracy: 0.9690
# Epoch 35/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0944 - accuracy: 0.9663
# Epoch 35: val_accuracy did not improve from 0.97160
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0953 - accuracy: 0.9658 - val_loss: 0.0835 - val_accuracy: 0.9698
# Epoch 36/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9678
# Epoch 36: val_accuracy improved from 0.97160 to 0.97633, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0881 - accuracy: 0.9679 - val_loss: 0.0697 - val_accuracy: 0.9763
# Epoch 37/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9702
# Epoch 37: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0839 - accuracy: 0.9702 - val_loss: 0.0695 - val_accuracy: 0.9741
# Epoch 38/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9721
# Epoch 38: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0824 - accuracy: 0.9721 - val_loss: 0.0713 - val_accuracy: 0.9752
# Epoch 39/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9739
# Epoch 39: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0800 - accuracy: 0.9738 - val_loss: 0.0734 - val_accuracy: 0.9738
# Epoch 40/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0803 - accuracy: 0.9716
# Epoch 40: val_accuracy improved from 0.97633 to 0.97706, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0800 - accuracy: 0.9717 - val_loss: 0.0652 - val_accuracy: 0.9771
# Epoch 41/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9731
# Epoch 41: val_accuracy did not improve from 0.97706
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0782 - accuracy: 0.9731 - val_loss: 0.0784 - val_accuracy: 0.9720
# Epoch 42/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9758
# Epoch 42: val_accuracy improved from 0.97706 to 0.97851, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/ResBiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0735 - accuracy: 0.9759 - val_loss: 0.0649 - val_accuracy: 0.9785
# Epoch 43/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9767
# Epoch 43: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0723 - accuracy: 0.9768 - val_loss: 0.0633 - val_accuracy: 0.9785
# Epoch 44/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0744 - accuracy: 0.9725
# Epoch 44: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0743 - accuracy: 0.9725 - val_loss: 0.0746 - val_accuracy: 0.9734
# Epoch 45/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9743
# Epoch 45: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0739 - accuracy: 0.9744 - val_loss: 0.0656 - val_accuracy: 0.9774
# Epoch 46/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0692 - accuracy: 0.9762
# Epoch 46: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0697 - accuracy: 0.9760 - val_loss: 0.0661 - val_accuracy: 0.9741
# Epoch 47/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0725 - accuracy: 0.9740
# Epoch 47: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0725 - accuracy: 0.9740 - val_loss: 0.0778 - val_accuracy: 0.9698
# Epoch 48/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9758
# Epoch 48: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0679 - accuracy: 0.9758 - val_loss: 0.0652 - val_accuracy: 0.9767
# Epoch 49/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9770
# Epoch 49: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0661 - accuracy: 0.9770 - val_loss: 0.0663 - val_accuracy: 0.9731
# Epoch 50/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0657 - accuracy: 0.9778
# Epoch 50: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 16ms/step - loss: 0.0657 - accuracy: 0.9778 - val_loss: 0.0661 - val_accuracy: 0.9771
# Epoch 51/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9778
# Epoch 51: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0629 - accuracy: 0.9778 - val_loss: 0.0858 - val_accuracy: 0.9687
# Epoch 52/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9770Restoring model weights from the end of the best epoch: 42.
#
# Epoch 52: val_accuracy did not improve from 0.97851
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0661 - accuracy: 0.9770 - val_loss: 0.0642 - val_accuracy: 0.9785
# Epoch 52: early stopping
# 108/108 [==============================] - 2s 5ms/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d_8 (Conv1D)           (None, 128, 256)             2560      ['input_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 128, 256)             1024      ['conv1d_8[0][0]']
#  chNormalization)
#
#  max_pooling1d_8 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_8[0][0]'
#  g1D)                                                               ]
#
#  dropout_10 (Dropout)        (None, 64, 256)              0         ['max_pooling1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 64, 128)              98432     ['dropout_10[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 128)              512       ['conv1d_9[0][0]']
#  chNormalization)
#
#  max_pooling1d_9 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_9[0][0]'
#  g1D)                                                               ]
#
#  dropout_11 (Dropout)        (None, 32, 128)              0         ['max_pooling1d_9[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 32, 64)               24640     ['dropout_11[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 64)               256       ['conv1d_10[0][0]']
#  tchNormalization)
#
#  max_pooling1d_10 (MaxPooli  (None, 16, 64)               0         ['batch_normalization_10[0][0]
#  ng1D)                                                              ']
#
#  dropout_12 (Dropout)        (None, 16, 64)               0         ['max_pooling1d_10[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 16, 32)               6176      ['dropout_12[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 32)               128       ['conv1d_11[0][0]']
#  tchNormalization)
#
#  max_pooling1d_11 (MaxPooli  (None, 8, 32)                0         ['batch_normalization_11[0][0]
#  ng1D)                                                              ']
#
#  dropout_13 (Dropout)        (None, 8, 32)                0         ['max_pooling1d_11[0][0]']
#
#  layer_normalization_4 (Lay  (None, 8, 32)                64        ['dropout_13[0][0]']
#  erNormalization)
#
#  bidirectional_4 (Bidirecti  (None, 8, 128)               49664     ['layer_normalization_4[0][0]'
#  onal)                                                              ]
#
#  layer_normalization_5 (Lay  (None, 8, 128)               256       ['bidirectional_4[0][0]']
#  erNormalization)
#
#  bidirectional_5 (Bidirecti  (None, 8, 128)               98816     ['layer_normalization_5[0][0]'
#  onal)                                                              ]
#
#  add_2 (Add)                 (None, 8, 128)               0         ['bidirectional_4[0][0]',
#                                                                      'bidirectional_5[0][0]']
#
#  attention_2 (Attention)     (None, 128)                  136       ['add_2[0][0]']
#
#  dropout_14 (Dropout)        (None, 128)                  0         ['attention_2[0][0]']
#
#  dense_2 (Dense)             (None, 6)                    774       ['dropout_14[0][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 283438 (1.08 MB)
# Trainable params: 282478 (1.08 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# Total parameters: 283438
# Test Accuracy: 0.9714
# Average Accuracy: 0.9438594659933677
# Best Accuracy: 0.9777777791023254
# Last Epoch Accuracy: 0.9769580960273743
# Micro Accuracy: 0.9714
# Macro Accuracy: 0.9621
# Weighted Accuracy: 0.9714
# Precision (Macro): 0.9554450899356358
# Precision (Weighted): 0.9722504757268315
# Precision (Micro): 0.9714452214452215
# Recall (Macro): 0.9620933893185483
# Recall (Weighted): 0.9714452214452215
# Recall (Micro): 0.9714452214452215
# F1 Score (Macro): 0.9585716500487109
# F1 Score (Weighted): 0.971739948006108
# F1 Score (Micro): 0.9714452214452215
# Population Std Dev - True Labels: 1.9351159283819863
# Population Std Dev - Predicted Labels: 1.940842570188138
# Sample Std Dev - True Labels: 1.9353979124896226
# Sample Std Dev - Predicted Labels: 1.941125388779102
# _______________________________________________________________
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 285
#   True Negatives (TN): 3086
#   False Positives (FP): 40
#   False Negatives (FN): 21
#
# Metrics for JOGGING:
#   True Positives (TP): 1082
#   True Negatives (TN): 2334
#   False Positives (FP): 1
#   False Negatives (FN): 15
#
# Metrics for SITTING:
#   True Positives (TP): 181
#   True Negatives (TN): 3244
#   False Positives (FP): 1
#   False Negatives (FN): 6
#
# Metrics for STANDING:
#   True Positives (TP): 142
#   True Negatives (TN): 3281
#   False Positives (FP): 6
#   False Negatives (FN): 3
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 381
#   True Negatives (TN): 2984
#   False Positives (FP): 36
#   False Negatives (FN): 31
#
# Metrics for WALKING:
#   True Positives (TP): 1263
#   True Negatives (TN): 2133
#   False Positives (FP): 14
#   False Negatives (FN): 22
#
# Timer stopped at 2024-06-03 21:10:06
# Elapsed time: 529.3769061565399 seconds
