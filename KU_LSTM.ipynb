# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %%
start_timer()

# Standard library imports
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import json
import random
import warnings
import itertools

# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 18:47:00

# %%
# Data Augmentation Code

def show_signals(data):
    Accelerometer_X_axis_data = data[:, 0]
    Accelerometer_Y_axis_data = data[:, 1]
    Accelerometer_Z_axis_data = data[:, 2]
    Gyroscope_X_axis_data = data[:, 3]
    Gyroscope_Y_axis_data = data[:, 4]
    Gyroscope_Z_axis_data = data[:, 5]
    time = np.linspace(0.01, data.shape[0] / 100, data.shape[0])

    plt.figure(figsize=(20, 10), dpi=80)

    ax1 = plt.subplot(231)
    ax1.plot(time, Accelerometer_X_axis_data, "b")
    ax1.title.set_text(f"Accelerometer X axis")
    ax1.set_xlabel("time (s) ->")
    ax1.set_ylabel("Acceleration (m/s^2)")
    ax1.grid(True)

    ax2 = plt.subplot(232)
    ax2.plot(time, Accelerometer_Y_axis_data, "g")
    ax2.title.set_text(f"Accelerometer Y axis")
    ax2.set_xlabel("time (s) ->")
    ax2.set_ylabel("Acceleration (m/s^2)")
    ax2.grid(True)

    ax3 = plt.subplot(233)
    ax3.plot(time, Accelerometer_Z_axis_data, "r")
    ax3.title.set_text(f"Accelerometer Z axis")
    ax3.set_xlabel("time (s) ->")
    ax3.set_ylabel("Acceleration (m/s^2)")
    ax3.grid(True)

    ax4 = plt.subplot(234)
    ax4.plot(time, Gyroscope_X_axis_data, "b")
    ax4.title.set_text(f"Gyroscope X axis")
    ax4.set_xlabel("time (s) ->")
    ax4.set_ylabel("Angular rotation (rad/s)")
    ax4.grid(True)

    ax5 = plt.subplot(235)
    ax5.plot(time, Gyroscope_Y_axis_data, "g")
    ax5.title.set_text(f"Gyroscope Y axis")
    ax5.set_xlabel("time (s) ->")
    ax5.set_ylabel("Angular rotation (rad/s)")
    ax5.grid(True)

    ax6 = plt.subplot(236)
    ax6.plot(time, Gyroscope_Z_axis_data, "r")
    ax6.title.set_text(f"Gyroscope Z axis")
    ax6.set_xlabel("time (s) ->")
    ax6.set_ylabel("Angular rotation (rad/s)")
    ax6.grid(True)

    plt.show()

f = open("/content/drive/MyDrive/KU HAR/data_augmentation_KU-HAR.txt", "r")
all_lines = f.readlines()

pairs = []

for line in all_lines:
    line = line.rstrip().split(" ")

    # store pairs
    pairs.append([line[0], line[-1]])

print(pairs, "\n")
print("Num. of samples: ", len(pairs))

CLASS_LABELS = np.array([
    "Stand", "Sit", "Talk-sit", "Talk-stand", "Stand-sit", "Lay", "Lay-stand", "Pick", "Jump", "Push-up",
    "Sit-up", "Walk", "Walk-backward", "Walk-circle", "Run", "Stair-up", "Stair-down", "Table-tennis"
])

df = pd.read_csv("/content/drive/MyDrive/KU HAR/KU-HAR_time_domain_subsamples_20750x300.csv", header=None)

signals = df.values[:, 0:1800]
signals = np.array(signals, dtype=np.float32)
labels = df.values[:, 1800]
labels = np.array(labels, dtype=np.int64)

print(signals.shape, labels.shape, "\n")

# Remove broken samples in original dataset
indexes = [6587, 6588, 6589, 6590, 6591, 6592, 6593, 6594, 6595, 6596, 6597, 6598, 6599, 6600, 6601, 6602, 6603, 6604,
           6605, 6606, 6607, 6660, 6661, 6662, 6663, 6664, 6665, 6666, 6667, 6668, 6669, 6670, 6671, 6672, 6673, 6674,
           6675, 6676, 6677, 6678, 6679, 6680, 6681, 6682, 6683, 6684, 6685, 6686, 6687, 6716, 6717, 6718, 6719, 6720,
           6721, 6722, 6723, 6724, 6725, 6726, 6727, 6728, 6729, 6730, 6731, 6732, 6733, 6734, 6735, 6736, 6737, 6738,
           6739, 6740, 6741, 6742, 6743, 6750, 6751, 6752, 6753, 6754, 6755, 6756, 6757, 6758, 6759, 6760, 6761, 6762,
           6763, 6764, 6765, 6766, 6767]

# delete the broken samples
signals = np.delete(signals, indexes, 0)
labels = np.delete(labels, indexes, 0)

signals = np.stack([
    signals[:, 0:300],    # ACC X
    signals[:, 300:600],  # ACC Y
    signals[:, 600:900],  # ACC Z
    signals[:, 900:1200],  # GYRO X
    signals[:, 1200:1500],  # GYRO Y
    signals[:, 1500:1800],  # GYRO Z
], axis=-1)

labels = np.repeat(labels.reshape(labels.shape[0], 1), signals.shape[1], axis=1)

print("Mean:", np.mean(signals, axis=(0, 1)))
print("Std:", np.std(signals, axis=(0, 1)))
print("Max:", np.max(signals, axis=(0, 1)))
print("Min:", np.min(signals, axis=(0, 1)), "\n")

print(signals.shape, labels.shape, "\n")

new_signals = []
new_labels = []

for i in range(len(pairs)):
    print("Working on ", i, "sample")

    first = np.where(CLASS_LABELS == pairs[i][0])[0]
    second = np.where(CLASS_LABELS == pairs[i][1])[0]

    first_indexes = np.unique(np.where(labels == first)[0])
    second_indexes = np.unique(np.where(labels == second)[0])

    # Minimum for creating absolutely non-duplicate examples - prevention of overfit
    count = min(first_indexes.shape[0], second_indexes.shape[0])

    merged_signals = np.concatenate(
        (signals[first_indexes[:count]], signals[second_indexes[:count]]), axis=1
    )

    merged_labels = np.concatenate(
        (labels[first_indexes[:count]], labels[second_indexes[:count]]), axis=1
    )

    downsample_signals = merged_signals[:, ::2, :]
    new_signals.append(downsample_signals)

    downsample_labels = merged_labels[:, ::2]
    new_labels.append(downsample_labels)

# Merge all pairs into batch axis
new_signals = np.concatenate(new_signals, axis=0)
new_labels = np.concatenate(new_labels, axis=0)

# Merge all pairs into batch axis
final_signals = np.concatenate([signals, new_signals], axis=0)
final_labels = np.concatenate([labels, new_labels], axis=0)


print("Mean:", np.mean(final_signals, axis=(0, 1)))
print("Std:", np.std(final_signals, axis=(0, 1)))
print("Max:", np.max(final_signals, axis=(0, 1)))
print("Min:", np.min(final_signals, axis=(0, 1)), "\n")

print(final_signals.shape, final_labels.shape)

# Visualize labels distribution
plt.figure(figsize=(10, 10), dpi=80)

total_counts = final_labels.shape[0] * final_labels.shape[1]
unique, final_counts = np.unique(final_labels, return_counts=True)
chart = plt.bar(CLASS_LABELS[unique], final_counts)
plt.xticks(rotation=70)

unique, counts = np.unique(new_labels, return_counts=True)
plt.bar(CLASS_LABELS[unique], counts)
plt.xticks(rotation=70)

unique, counts = np.unique(labels, return_counts=True)
plt.bar(CLASS_LABELS[unique], counts)
plt.xticks(rotation=70)

for i, p in enumerate(chart):
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x + width / 2,
             y + height * 1.01,
             str(round((final_counts[i] * 100) / total_counts, 1)) + '%',
             ha='center',
             weight='bold')

plt.legend(["Final", "New", "Original"])
plt.show()

np.savez_compressed("new_dataset", signals=final_signals, labels=final_labels)
# Out:
# [['Stand', 'Talk-stand'], ['Stand', 'Pick'], ['Stand', 'Jump'], ['Stand', 'Walk'], ['Stand', 'Walk-backward'], ['Stand', 'Walk-circle'], ['Stand', 'Run'], ['Stand', 'Stair-up'], ['Stand', 'Stair-down'], ['Stand', 'Table-tennis'], ['Sit', 'Talk-sit'], ['Talk-sit', 'Sit'], ['Talk-stand', 'Stand'], ['Talk-stand', 'Pick'], ['Talk-stand', 'Jump'], ['Talk-stand', 'Walk'], ['Talk-stand', 'Walk-backward'], ['Talk-stand', 'Walk-circle'], ['Talk-stand', 'Run'], ['Talk-stand', 'Stair-up'], ['Talk-stand', 'Stair-down'], ['Talk-stand', 'Table-tennis'], ['Lay', 'Sit-up'], ['Pick', 'Stand'], ['Pick', 'Talk-stand'], ['Pick', 'Jump'], ['Pick', 'Walk'], ['Pick', 'Walk-backward'], ['Pick', 'Walk-circle'], ['Pick', 'Run'], ['Pick', 'Stair-up'], ['Pick', 'Stair-down'], ['Pick', 'Table-tennis'], ['Jump', 'Stand'], ['Jump', 'Talk-stand'], ['Jump', 'Pick'], ['Jump', 'Walk'], ['Jump', 'Walk-backward'], ['Jump', 'Walk-circle'], ['Jump', 'Run'], ['Jump', 'Stair-up'], ['Jump', 'Stair-down'], ['Jump', 'Table-tennis'], ['Sit-up', 'Lay'], ['Walk', 'Stand'], ['Walk', 'Talk-stand'], ['Walk', 'Pick'], ['Walk', 'Jump'], ['Walk', 'Walk-circle'], ['Walk', 'Run'], ['Walk', 'Stair-up'], ['Walk', 'Stair-down'], ['Walk', 'Table-tennis'], ['Walk-backward', 'Stand'], ['Walk-backward', 'Talk-stand'], ['Walk-backward', 'Pick'], ['Walk-backward', 'Jump'], ['Walk-backward', 'Table-tennis'], ['Walk-circle', 'Stand'], ['Walk-circle', 'Talk-stand'], ['Walk-circle', 'Pick'], ['Walk-circle', 'Jump'], ['Walk-circle', 'Walk'], ['Walk-circle', 'Run'], ['Walk-circle', 'Stair-up'], ['Walk-circle', 'Stair-down'], ['Walk-circle', 'Table-tennis'], ['Run', 'Stand'], ['Run', 'Talk-stand'], ['Run', 'Pick'], ['Run', 'Jump'], ['Run', 'Walk'], ['Run', 'Walk-circle'], ['Run', 'Stair-up'], ['Run', 'Stair-down'], ['Run', 'Table-tennis'], ['Stair-up', 'Stand'], ['Stair-up', 'Talk-stand'], ['Stair-up', 'Pick'], ['Stair-up', 'Jump'], ['Stair-up', 'Walk'], ['Stair-up', 'Walk-circle'], ['Stair-up', 'Run'], ['Stair-up', 'Stair-down'], ['Stair-down', 'Stand'], ['Stair-down', 'Talk-stand'], ['Stair-down', 'Pick'], ['Stair-down', 'Jump'], ['Stair-down', 'Walk'], ['Stair-down', 'Walk-circle'], ['Stair-down', 'Run'], ['Stair-down', 'Stair-up'], ['Table-tennis', 'Stand'], ['Table-tennis', 'Talk-stand'], ['Table-tennis', 'Pick'], ['Table-tennis', 'Jump'], ['Table-tennis', 'Walk'], ['Table-tennis', 'Walk-backward'], ['Table-tennis', 'Walk-circle'], ['Table-tennis', 'Run']]
#
# Num. of samples:  100
# (20750, 1800) (20750,)
#
# Mean: [ 0.04835381 -0.04000019 -0.06103219  0.01185658  0.00415822  0.00092788]
# Std: [3.6388602 2.1443195 2.8478932 1.309968  1.0470778 1.0666409]
# Max: [194.52   91.779 340.59   97.376  79.272  78.783]
# Min: [-172.74  -143.17  -315.89  -113.8    -85.757  -78.866]
#
# (20655, 300, 6) (20655, 300)
#
# Working on  0 sample
# Working on  1 sample
# Working on  2 sample
# Working on  3 sample
# Working on  4 sample
# Working on  5 sample
# Working on  6 sample
# Working on  7 sample
# Working on  8 sample
# Working on  9 sample
# Working on  10 sample
# Working on  11 sample
# Working on  12 sample
# Working on  13 sample
# Working on  14 sample
# Working on  15 sample
# Working on  16 sample
# Working on  17 sample
# Working on  18 sample
# Working on  19 sample
# Working on  20 sample
# Working on  21 sample
# Working on  22 sample
# Working on  23 sample
# Working on  24 sample
# Working on  25 sample
# Working on  26 sample
# Working on  27 sample
# Working on  28 sample
# Working on  29 sample
# Working on  30 sample
# Working on  31 sample
# Working on  32 sample
# Working on  33 sample
# Working on  34 sample
# Working on  35 sample
# Working on  36 sample
# Working on  37 sample
# Working on  38 sample
# Working on  39 sample
# Working on  40 sample
# Working on  41 sample
# Working on  42 sample
# Working on  43 sample
# Working on  44 sample
# Working on  45 sample
# Working on  46 sample
# Working on  47 sample
# Working on  48 sample
# Working on  49 sample
# Working on  50 sample
# Working on  51 sample
# Working on  52 sample
# Working on  53 sample
# Working on  54 sample
# Working on  55 sample
# Working on  56 sample
# Working on  57 sample
# Working on  58 sample
# Working on  59 sample
# Working on  60 sample
# Working on  61 sample
# Working on  62 sample
# Working on  63 sample
# Working on  64 sample
# Working on  65 sample
# Working on  66 sample
# Working on  67 sample
# Working on  68 sample
# Working on  69 sample
# Working on  70 sample
# Working on  71 sample
# Working on  72 sample
# Working on  73 sample
# Working on  74 sample
# Working on  75 sample
# Working on  76 sample
# Working on  77 sample
# Working on  78 sample
# Working on  79 sample
# Working on  80 sample
# Working on  81 sample
# Working on  82 sample
# Working on  83 sample
# Working on  84 sample
# Working on  85 sample
# Working on  86 sample
# Working on  87 sample
# Working on  88 sample
# Working on  89 sample
# Working on  90 sample
# Working on  91 sample
# Working on  92 sample
# Working on  93 sample
# Working on  94 sample
# Working on  95 sample
# Working on  96 sample
# Working on  97 sample
# Working on  98 sample
# Working on  99 sample
# Mean: [ 0.10943159 -0.07794212 -0.0883355   0.0306053   0.00974582  0.00629569]
# Std: [5.192652  3.0467124 3.9461544 1.697749  1.36974   1.4093003]
# Max: [194.52   91.779 340.59   97.376  79.272  78.783]
# Min: [-172.74  -143.17  -315.89  -113.8    -85.757  -78.866]
#
# (83129, 300, 6) (83129, 300)

# %%
# Load the dataset
dataset = np.load("new_dataset.npz")

# Separate signals and labels
signals = dataset['signals']
labels = dataset['labels']

# Print the number of columns in the signals array
num_columns = signals.shape[2]
print("Number of columns in the signals array:", num_columns)

# Separate accelerometer and gyroscope data
x_acc = signals[:, :, :3]  # Extract accelerometer data (first three columns)
x_gyro = signals[:, :, 3:]  # Extract gyroscope data (last three columns)

# Split the dataset into train and test sets
x_acc_train, x_acc_test, y_train, y_test = train_test_split(x_acc, labels, test_size=0.2, random_state=42)
x_gyro_train, x_gyro_test, _, _ = train_test_split(x_gyro, labels, test_size=0.2, random_state=42)

# Print shapes to verify
print("x_acc_train shape:", x_acc_train.shape)
print("x_gyro_train shape:", x_gyro_train.shape)
print("x_acc_test shape:", x_acc_test.shape)
print("x_gyro_test shape:", x_gyro_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# One-hot encode the target data
y_train_encoded = to_categorical(y_train, num_classes=18)
y_test_encoded = to_categorical(y_test, num_classes=18)

# Reshape the target data to match the output shape of the model
y_train_reshaped = y_train_encoded[:, 0, :]
y_test_reshaped = y_test_encoded[:, 0, :]

model_save_path = '/content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5'
# Out:
# Number of columns in the signals array: 6
# x_acc_train shape: (66503, 300, 3)
# x_gyro_train shape: (66503, 300, 3)
# x_acc_test shape: (16626, 300, 3)
# x_gyro_test shape: (16626, 300, 3)
# y_train shape: (66503, 300)
# y_test shape: (16626, 300)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# #**Define the Model Structure**

# %%
class LSTMAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def LSTM_Attention(self, input_forward, input_backward):
        conv1_forward = Conv1D(128, 3, activation='relu', padding='same')(input_forward)
        conv1_backward = Conv1D(128, 3, activation='relu', padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

       # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

       # Dropout
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128//2, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128//4, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # Layer Normalization
        model = LayerNormalization()(model)

       # LSTM layers
        x = LSTM(64, return_sequences=True)(model)
        model = LSTM(64, return_sequences=True)(x)

        # Attention layer
        output = Attention(18)(model)

        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(300, 3))
        input_1_backward = Input(shape=(300, 3))
        input_2_forward = Input(shape=(300, 3))
        input_2_backward = Input(shape=(300, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)
        input_2_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_2_backward)


        model1 = self.LSTM_Attention(input_1_forward, input_1_backward_flipped)
        model2 = self.LSTM_Attention(input_2_forward, input_2_backward_flipped)


        concatenated_models = Concatenate()([model1, model2])

        output = Dropout(0.2)(concatenated_models)
        output = Dense(18)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped, input_2_forward, input_2_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)

        return history


    def fit2(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history



    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 32
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_acc_train, x_gyro_train], axis=-1),
    y_train_reshaped,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = LSTMAttentionModel(learning_rate=best_params['learning_rate'], batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
     X=[
        x_train_final[:, :, :3],  # Original body acceleration data for the final model
        np.flip(x_train_final[:, :, :3], axis=1),  # Flipped body acceleration data for the final model
        x_train_final[:, :, 3:],  # Original body gyro data for the final model
        np.flip(x_train_final[:, :, 3:], axis=1)  # Flipped body gyro data for the final model
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],  # Original validation body acceleration data
            np.flip(x_val_final[:, :, :3], axis=1),  # Flipped validation body acceleration data
            x_val_final[:, :, 3:],  # Original validation body gyro data
            np.flip(x_val_final[:, :, 3:], axis=1)  # Flipped validation body gyro data
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_acc_test, np.flip(x_acc_test, axis=1),
                                                      x_gyro_test, np.flip(x_gyro_test, axis=1)],
                                                    y_test_reshaped, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_acc_test, np.flip(x_acc_test, axis=1),
                                   x_gyro_test, np.flip(x_gyro_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax( y_test_reshaped, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics
average_accuracy = np.mean(history.history['accuracy'])
best_accuracy = np.max(history.history['accuracy'])
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

class_labels = ["Stand", "Sit", "Talk-sit", "Talk-stand", "Stand-sit", "Lay", "Lay-stand", "Pick",
                "Jump", "Push-up", "Sit-up", "Walk", "Walk-backward", "Walk-circle", "Run", "Stair-up",
                "Stair-down","Table-tennis"]

conf_matrix = confusion_matrix(y_true_labels, y_pred_labels, labels=range(len(class_labels)))
cm = pd.DataFrame(conf_matrix, columns=class_labels, index=class_labels)

# Plot the confusion matrix heatmap with adjusted annotation size and label size
plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True, annot_kws={"size": 10}, cbar=True)
plt.yticks(rotation=0, fontsize=12, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12, weight='bold')
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

conf_matrix = confusion_matrix(y_true_labels, y_pred_labels, labels=range(len(class_labels)))
TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
for i, class_label in enumerate(class_labels):
    print(f"Metrics for {class_label}:")
    tp = TP[i] if i < len(TP) else 0
    tn = TN[i] if i < len(TN) else 0
    fp = FP[i] if i < len(FP) else 0
    fn = FN[i] if i < len(FN) else 0
    print(f"  True Positives (TP): {tp}")
    print(f"  True Negatives (TN): {tn}")
    print(f"  False Positives (FP): {fp}")
    print(f"  False Negatives (FN): {fn}\n")

stop_timer()
# Out:
# Epoch 1/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.7275 - accuracy: 0.7433
# Epoch 1: val_accuracy improved from -inf to 0.75318, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 103s 44ms/step - loss: 0.7275 - accuracy: 0.7433 - val_loss: 0.9815 - val_accuracy: 0.7532
# Epoch 2/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.3675 - accuracy: 0.8662
# Epoch 2: val_accuracy improved from 0.75318 to 0.76934, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.3675 - accuracy: 0.8662 - val_loss: 0.9921 - val_accuracy: 0.7693
# Epoch 3/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.2866 - accuracy: 0.8953
# Epoch 3: val_accuracy improved from 0.76934 to 0.77468, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.2865 - accuracy: 0.8953 - val_loss: 1.1121 - val_accuracy: 0.7747
# Epoch 4/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.2409 - accuracy: 0.9117
# Epoch 4: val_accuracy improved from 0.77468 to 0.77866, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.2410 - accuracy: 0.9117 - val_loss: 0.9416 - val_accuracy: 0.7787
# Epoch 5/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.2119 - accuracy: 0.9201
# Epoch 5: val_accuracy improved from 0.77866 to 0.79024, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 59s 36ms/step - loss: 0.2119 - accuracy: 0.9201 - val_loss: 0.9933 - val_accuracy: 0.7902
# Epoch 6/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1877 - accuracy: 0.9283
# Epoch 6: val_accuracy did not improve from 0.79024
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.1877 - accuracy: 0.9283 - val_loss: 0.9836 - val_accuracy: 0.7783
# Epoch 7/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9328
# Epoch 7: val_accuracy improved from 0.79024 to 0.80543, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.1723 - accuracy: 0.9328 - val_loss: 0.7844 - val_accuracy: 0.8054
# Epoch 8/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9371
# Epoch 8: val_accuracy did not improve from 0.80543
# 1663/1663 [==============================] - 66s 40ms/step - loss: 0.1611 - accuracy: 0.9371 - val_loss: 0.7109 - val_accuracy: 0.7951
# Epoch 9/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1501 - accuracy: 0.9411
# Epoch 9: val_accuracy did not improve from 0.80543
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.1501 - accuracy: 0.9411 - val_loss: 0.5858 - val_accuracy: 0.8023
# Epoch 10/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1418 - accuracy: 0.9436
# Epoch 10: val_accuracy improved from 0.80543 to 0.88384, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.1417 - accuracy: 0.9436 - val_loss: 0.3267 - val_accuracy: 0.8838
# Epoch 11/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9463
# Epoch 11: val_accuracy did not improve from 0.88384
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.1341 - accuracy: 0.9462 - val_loss: 0.3179 - val_accuracy: 0.8818
# Epoch 12/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9467
# Epoch 12: val_accuracy did not improve from 0.88384
# 1663/1663 [==============================] - 64s 39ms/step - loss: 0.1332 - accuracy: 0.9467 - val_loss: 0.5999 - val_accuracy: 0.8093
# Epoch 13/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9502
# Epoch 13: val_accuracy did not improve from 0.88384
# 1663/1663 [==============================] - 71s 43ms/step - loss: 0.1260 - accuracy: 0.9502 - val_loss: 0.6973 - val_accuracy: 0.8011
# Epoch 14/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9510
# Epoch 14: val_accuracy did not improve from 0.88384
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.1211 - accuracy: 0.9510 - val_loss: 0.3010 - val_accuracy: 0.8796
# Epoch 15/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9537
# Epoch 15: val_accuracy improved from 0.88384 to 0.91023, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 62s 38ms/step - loss: 0.1172 - accuracy: 0.9537 - val_loss: 0.3621 - val_accuracy: 0.9102
# Epoch 16/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.1131 - accuracy: 0.9546
# Epoch 16: val_accuracy did not improve from 0.91023
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.1131 - accuracy: 0.9546 - val_loss: 0.3903 - val_accuracy: 0.8658
# Epoch 17/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9577
# Epoch 17: val_accuracy improved from 0.91023 to 0.94286, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.1073 - accuracy: 0.9577 - val_loss: 0.1647 - val_accuracy: 0.9429
# Epoch 18/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9570
# Epoch 18: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.1081 - accuracy: 0.9570 - val_loss: 0.2033 - val_accuracy: 0.9330
# Epoch 19/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9586
# Epoch 19: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.1049 - accuracy: 0.9586 - val_loss: 0.2567 - val_accuracy: 0.9289
# Epoch 20/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9614
# Epoch 20: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0989 - accuracy: 0.9614 - val_loss: 0.2165 - val_accuracy: 0.9252
# Epoch 21/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9618
# Epoch 21: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0981 - accuracy: 0.9618 - val_loss: 0.1883 - val_accuracy: 0.9220
# Epoch 22/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9628
# Epoch 22: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0950 - accuracy: 0.9628 - val_loss: 0.1900 - val_accuracy: 0.9371
# Epoch 23/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9636
# Epoch 23: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 61s 36ms/step - loss: 0.0938 - accuracy: 0.9636 - val_loss: 0.2242 - val_accuracy: 0.9369
# Epoch 24/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9650
# Epoch 24: val_accuracy did not improve from 0.94286
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0892 - accuracy: 0.9650 - val_loss: 0.1690 - val_accuracy: 0.9414
# Epoch 25/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9647
# Epoch 25: val_accuracy improved from 0.94286 to 0.95933, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0915 - accuracy: 0.9647 - val_loss: 0.1057 - val_accuracy: 0.9593
# Epoch 26/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0870 - accuracy: 0.9670
# Epoch 26: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0870 - accuracy: 0.9670 - val_loss: 0.1281 - val_accuracy: 0.9500
# Epoch 27/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9648
# Epoch 27: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0915 - accuracy: 0.9648 - val_loss: 0.2541 - val_accuracy: 0.9320
# Epoch 28/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9679
# Epoch 28: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0861 - accuracy: 0.9679 - val_loss: 0.2946 - val_accuracy: 0.9339
# Epoch 29/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0832 - accuracy: 0.9696
# Epoch 29: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0831 - accuracy: 0.9696 - val_loss: 0.2543 - val_accuracy: 0.9268
# Epoch 30/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9700
# Epoch 30: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 59s 36ms/step - loss: 0.0788 - accuracy: 0.9700 - val_loss: 0.2003 - val_accuracy: 0.9386
# Epoch 31/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0793 - accuracy: 0.9692
# Epoch 31: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0794 - accuracy: 0.9692 - val_loss: 0.1570 - val_accuracy: 0.9423
# Epoch 32/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9694
# Epoch 32: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 61s 36ms/step - loss: 0.0784 - accuracy: 0.9694 - val_loss: 0.1870 - val_accuracy: 0.9469
# Epoch 33/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9709
# Epoch 33: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0769 - accuracy: 0.9709 - val_loss: 0.1698 - val_accuracy: 0.9474
# Epoch 34/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9715
# Epoch 34: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0757 - accuracy: 0.9715 - val_loss: 0.1227 - val_accuracy: 0.9534
# Epoch 35/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9725
# Epoch 35: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0735 - accuracy: 0.9725 - val_loss: 0.0942 - val_accuracy: 0.9566
# Epoch 36/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9726
# Epoch 36: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0733 - accuracy: 0.9726 - val_loss: 0.1348 - val_accuracy: 0.9533
# Epoch 37/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9724
# Epoch 37: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0735 - accuracy: 0.9724 - val_loss: 0.1268 - val_accuracy: 0.9465
# Epoch 38/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0714 - accuracy: 0.9740
# Epoch 38: val_accuracy did not improve from 0.95933
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0714 - accuracy: 0.9740 - val_loss: 0.2390 - val_accuracy: 0.9361
# Epoch 39/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9732
# Epoch 39: val_accuracy improved from 0.95933 to 0.96805, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 66s 40ms/step - loss: 0.0717 - accuracy: 0.9732 - val_loss: 0.0825 - val_accuracy: 0.9680
# Epoch 40/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9745
# Epoch 40: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 64s 38ms/step - loss: 0.0694 - accuracy: 0.9745 - val_loss: 0.1926 - val_accuracy: 0.9446
# Epoch 41/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9752
# Epoch 41: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0671 - accuracy: 0.9752 - val_loss: 0.1560 - val_accuracy: 0.9526
# Epoch 42/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9747
# Epoch 42: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 64s 39ms/step - loss: 0.0678 - accuracy: 0.9747 - val_loss: 0.0982 - val_accuracy: 0.9588
# Epoch 43/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9756
# Epoch 43: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0651 - accuracy: 0.9756 - val_loss: 0.0848 - val_accuracy: 0.9642
# Epoch 44/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9748
# Epoch 44: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 64s 38ms/step - loss: 0.0659 - accuracy: 0.9748 - val_loss: 0.0960 - val_accuracy: 0.9640
# Epoch 45/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9751
# Epoch 45: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 64s 38ms/step - loss: 0.0644 - accuracy: 0.9751 - val_loss: 0.1361 - val_accuracy: 0.9477
# Epoch 46/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9770
# Epoch 46: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 66s 40ms/step - loss: 0.0618 - accuracy: 0.9770 - val_loss: 0.0867 - val_accuracy: 0.9665
# Epoch 47/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9768
# Epoch 47: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0619 - accuracy: 0.9768 - val_loss: 0.0917 - val_accuracy: 0.9672
# Epoch 48/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0623 - accuracy: 0.9775
# Epoch 48: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 71s 43ms/step - loss: 0.0623 - accuracy: 0.9775 - val_loss: 0.1100 - val_accuracy: 0.9610
# Epoch 49/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0602 - accuracy: 0.9776
# Epoch 49: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0602 - accuracy: 0.9777 - val_loss: 0.1384 - val_accuracy: 0.9429
# Epoch 50/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9774
# Epoch 50: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 64s 38ms/step - loss: 0.0623 - accuracy: 0.9774 - val_loss: 0.1069 - val_accuracy: 0.9544
# Epoch 51/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9778
# Epoch 51: val_accuracy did not improve from 0.96805
# 1663/1663 [==============================] - 65s 39ms/step - loss: 0.0614 - accuracy: 0.9778 - val_loss: 0.0988 - val_accuracy: 0.9556
# Epoch 52/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9786
# Epoch 52: val_accuracy improved from 0.96805 to 0.97985, saving model to /content/drive/MyDrive/KU-HAR/LSTM_SWISH_KUHAR.hdf5
# 1663/1663 [==============================] - 64s 38ms/step - loss: 0.0588 - accuracy: 0.9786 - val_loss: 0.0618 - val_accuracy: 0.9799
# Epoch 53/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0582 - accuracy: 0.9785
# Epoch 53: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0582 - accuracy: 0.9784 - val_loss: 0.1340 - val_accuracy: 0.9510
# Epoch 54/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0586 - accuracy: 0.9786
# Epoch 54: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.0586 - accuracy: 0.9786 - val_loss: 0.0758 - val_accuracy: 0.9742
# Epoch 55/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 0.9787
# Epoch 55: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0588 - accuracy: 0.9787 - val_loss: 0.0871 - val_accuracy: 0.9610
# Epoch 56/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9792
# Epoch 56: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0565 - accuracy: 0.9792 - val_loss: 0.1009 - val_accuracy: 0.9629
# Epoch 57/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9801
# Epoch 57: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 38ms/step - loss: 0.0550 - accuracy: 0.9801 - val_loss: 0.1099 - val_accuracy: 0.9623
# Epoch 58/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0553 - accuracy: 0.9798
# Epoch 58: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0553 - accuracy: 0.9798 - val_loss: 0.1186 - val_accuracy: 0.9539
# Epoch 59/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9800
# Epoch 59: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0548 - accuracy: 0.9800 - val_loss: 0.1088 - val_accuracy: 0.9631
# Epoch 60/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9808
# Epoch 60: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0537 - accuracy: 0.9808 - val_loss: 0.1260 - val_accuracy: 0.9527
# Epoch 61/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9801
# Epoch 61: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.0536 - accuracy: 0.9801 - val_loss: 0.1022 - val_accuracy: 0.9595
# Epoch 62/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9816
# Epoch 62: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0507 - accuracy: 0.9816 - val_loss: 0.1436 - val_accuracy: 0.9529
# Epoch 63/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9808
# Epoch 63: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0533 - accuracy: 0.9808 - val_loss: 0.1438 - val_accuracy: 0.9479
# Epoch 64/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9811
# Epoch 64: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0530 - accuracy: 0.9811 - val_loss: 0.0739 - val_accuracy: 0.9756
# Epoch 65/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9812
# Epoch 65: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0512 - accuracy: 0.9812 - val_loss: 0.0972 - val_accuracy: 0.9581
# Epoch 66/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9813
# Epoch 66: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 60s 36ms/step - loss: 0.0509 - accuracy: 0.9813 - val_loss: 0.0746 - val_accuracy: 0.9738
# Epoch 67/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9811
# Epoch 67: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0515 - accuracy: 0.9811 - val_loss: 0.1159 - val_accuracy: 0.9507
# Epoch 68/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9812
# Epoch 68: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.0509 - accuracy: 0.9812 - val_loss: 0.0936 - val_accuracy: 0.9625
# Epoch 69/150
# 1663/1663 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9832
# Epoch 69: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 61s 37ms/step - loss: 0.0476 - accuracy: 0.9832 - val_loss: 0.0985 - val_accuracy: 0.9611
# Epoch 70/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9826
# Epoch 70: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 63s 38ms/step - loss: 0.0481 - accuracy: 0.9827 - val_loss: 0.1585 - val_accuracy: 0.9565
# Epoch 71/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9831
# Epoch 71: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 65s 39ms/step - loss: 0.0470 - accuracy: 0.9831 - val_loss: 0.0937 - val_accuracy: 0.9605
# Epoch 72/150
# 1662/1663 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9822Restoring model weights from the end of the best epoch: 52.
#
# Epoch 72: val_accuracy did not improve from 0.97985
# 1663/1663 [==============================] - 62s 37ms/step - loss: 0.0497 - accuracy: 0.9822 - val_loss: 0.1156 - val_accuracy: 0.9602
# Epoch 72: early stopping
# 520/520 [==============================] - 7s 9ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 300, 3)]             0         []
#
#  input_5 (InputLayer)        [(None, 300, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 300, 3)]             0         []
#
#  input_6 (InputLayer)        [(None, 300, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 300, 128)             1280      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 300, 128)             1280      ['input_5[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 300, 128)             1280      ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 300, 128)             1280      ['input_6[0][0]']
#
#  concatenate (Concatenate)   (None, 300, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  concatenate_1 (Concatenate  (None, 300, 256)             0         ['conv1d_5[1][0]',
#  )                                                                   'conv1d_6[1][0]']
#
#  batch_normalization (Batch  (None, 300, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 300, 256)             1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 150, 256)             0         ['batch_normalization[1][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 150, 256)             0         ['batch_normalization_4[1][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 150, 256)             0         ['max_pooling1d[1][0]']
#
#  dropout_4 (Dropout)         (None, 150, 256)             0         ['max_pooling1d_4[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 150, 128)             98432     ['dropout[1][0]']
#
#  conv1d_7 (Conv1D)           (None, 150, 128)             98432     ['dropout_4[1][0]']
#
#  batch_normalization_1 (Bat  (None, 150, 128)             512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 150, 128)             512       ['conv1d_7[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 75, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 75, 128)              0         ['batch_normalization_5[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 75, 128)              0         ['max_pooling1d_1[1][0]']
#
#  dropout_5 (Dropout)         (None, 75, 128)              0         ['max_pooling1d_5[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 75, 64)               24640     ['dropout_1[1][0]']
#
#  conv1d_8 (Conv1D)           (None, 75, 64)               24640     ['dropout_5[1][0]']
#
#  batch_normalization_2 (Bat  (None, 75, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 75, 64)               256       ['conv1d_8[1][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 37, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 37, 64)               0         ['batch_normalization_6[1][0]'
#  g1D)                                                               ]
#
#  dropout_2 (Dropout)         (None, 37, 64)               0         ['max_pooling1d_2[1][0]']
#
#  dropout_6 (Dropout)         (None, 37, 64)               0         ['max_pooling1d_6[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 37, 32)               6176      ['dropout_2[1][0]']
#
#  conv1d_9 (Conv1D)           (None, 37, 32)               6176      ['dropout_6[1][0]']
#
#  batch_normalization_3 (Bat  (None, 37, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 37, 32)               128       ['conv1d_9[1][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 18, 32)               0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 18, 32)               0         ['batch_normalization_7[1][0]'
#  g1D)                                                               ]
#
#  dropout_3 (Dropout)         (None, 18, 32)               0         ['max_pooling1d_3[1][0]']
#
#  dropout_7 (Dropout)         (None, 18, 32)               0         ['max_pooling1d_7[1][0]']
#
#  layer_normalization (Layer  (None, 18, 32)               64        ['dropout_3[1][0]']
#  Normalization)
#
#  layer_normalization_1 (Lay  (None, 18, 32)               64        ['dropout_7[1][0]']
#  erNormalization)
#
#  lstm (LSTM)                 (None, 18, 64)               24832     ['layer_normalization[1][0]']
#
#  lstm_2 (LSTM)               (None, 18, 64)               24832     ['layer_normalization_1[1][0]'
#                                                                     ]
#
#  lstm_1 (LSTM)               (None, 18, 64)               33024     ['lstm[1][0]']
#
#  lstm_3 (LSTM)               (None, 18, 64)               33024     ['lstm_2[1][0]']
#
#  attention (Attention)       (None, 64)                   82        ['lstm_1[1][0]']
#
#  attention_1 (Attention)     (None, 64)                   82        ['lstm_3[1][0]']
#
#  concatenate_2 (Concatenate  (None, 128)                  0         ['attention[1][0]',
#  )                                                                   'attention_1[1][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['concatenate_2[1][0]']
#
#  dense (Dense)               (None, 18)                   2322      ['dropout_8[1][0]']
#
#  softmax (Activation)        (None, 18)                   0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 385782 (1.47 MB)
# Trainable params: 383862 (1.46 MB)
# Non-trainable params: 1920 (7.50 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9799
# Average Accuracy: 0.962044820189476
# Best Accuracy: 0.9832336902618408
# Last Epoch Accuracy: 0.9821999073028564
# Micro Accuracy: 0.9799
# Macro Accuracy: 0.9763
# Weighted Accuracy: 0.9799
# Precision (Macro): 0.9787465355750289
# Precision (Weighted): 0.9801079118823552
# Precision (Micro): 0.9799109827980272
# Recall (Macro): 0.9763286068088016
# Recall (Weighted): 0.9799109827980272
# Recall (Micro): 0.9799109827980272
# F1 Score (Macro): 0.9774981953522219
# F1 Score (Weighted): 0.9799820805983738
# F1 Score (Micro): 0.9799109827980272
# Population Std Dev - True Labels: 5.578473957992873
# Population Std Dev - Predicted Labels: 5.587584783406001
# Sample Std Dev - True Labels: 5.578641729122909
# Sample Std Dev - Predicted Labels: 5.587752828541703
# _______________________________________________________________
# Metrics for Stand:
#   True Positives (TP): 1856
#   True Negatives (TN): 14590
#   False Positives (FP): 100
#   False Negatives (FN): 80
#
# Metrics for Sit:
#   True Positives (TP): 672
#   True Negatives (TN): 15745
#   False Positives (FP): 118
#   False Negatives (FN): 91
#
# Metrics for Talk-sit:
#   True Positives (TP): 664
#   True Negatives (TN): 15867
#   False Positives (FP): 41
#   False Negatives (FN): 54
#
# Metrics for Talk-stand:
#   True Positives (TP): 2012
#   True Negatives (TN): 14592
#   False Positives (FP): 8
#   False Negatives (FN): 14
#
# Metrics for Stand-sit:
#   True Positives (TP): 424
#   True Negatives (TN): 16193
#   False Positives (FP): 1
#   False Negatives (FN): 8
#
# Metrics for Lay:
#   True Positives (TP): 510
#   True Negatives (TN): 16027
#   False Positives (FP): 37
#   False Negatives (FN): 52
#
# Metrics for Lay-stand:
#   True Positives (TP): 304
#   True Negatives (TN): 16311
#   False Positives (FP): 6
#   False Negatives (FN): 5
#
# Metrics for Pick:
#   True Positives (TP): 1683
#   True Negatives (TN): 14934
#   False Positives (FP): 5
#   False Negatives (FN): 4
#
# Metrics for Jump:
#   True Positives (TP): 1218
#   True Negatives (TN): 15406
#   False Positives (FP): 0
#   False Negatives (FN): 2
#
# Metrics for Push-up:
#   True Positives (TP): 109
#   True Negatives (TN): 16515
#   False Positives (FP): 0
#   False Negatives (FN): 2
#
# Metrics for Sit-up:
#   True Positives (TP): 400
#   True Negatives (TN): 16218
#   False Positives (FP): 3
#   False Negatives (FN): 5
#
# Metrics for Walk:
#   True Positives (TP): 1409
#   True Negatives (TN): 15211
#   False Positives (FP): 3
#   False Negatives (FN): 3
#
# Metrics for Walk-backward:
#   True Positives (TP): 390
#   True Negatives (TN): 16232
#   False Positives (FP): 1
#   False Negatives (FN): 3
#
# Metrics for Walk-circle:
#   True Positives (TP): 521
#   True Negatives (TN): 16099
#   False Positives (FP): 4
#   False Negatives (FN): 2
#
# Metrics for Run:
#   True Positives (TP): 982
#   True Negatives (TN): 15643
#   False Positives (FP): 0
#   False Negatives (FN): 1
#
# Metrics for Stair-up:
#   True Positives (TP): 1215
#   True Negatives (TN): 15406
#   False Positives (FP): 2
#   False Negatives (FN): 3
#
# Metrics for Stair-down:
#   True Positives (TP): 1188
#   True Negatives (TN): 15433
#   False Positives (FP): 1
#   False Negatives (FN): 4
#
# Metrics for Table-tennis:
#   True Positives (TP): 735
#   True Negatives (TN): 15886
#   False Positives (FP): 4
#   False Negatives (FN): 1
#
# Timer stopped at 2024-06-03 20:05:06
# Elapsed time: 4686.0797436237335 seconds
