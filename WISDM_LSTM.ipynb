# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 19:39:56

# %% [markdown]
# # **Load the WISDM Dataset**

# %%
file_path ='/content/drive/MyDrive/wisdm (1)/WISDM_ar_v1.1_cleaned.txt'
model_save_path = '/content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5'


colnames = ['users', 'activity', 'timestamp', 'x-axis', 'y-axis', 'z-axis']
dataset = pd.read_csv(file_path, names=colnames)
dataset = dataset.dropna()

# Further data cleaning of the database: convert the 'x-axis', 'y-axis', 'z-axis' to numeric values by removing and ; or ,
for axis in ['x-axis', 'y-axis', 'z-axis']:
    dataset[axis] = dataset[axis].astype(str).str.replace(';', '').astype(np.float32)

n_time_step = 128
step = 64
n_feature = 3
segments = []
labels = []

for i in range(0, len(dataset) - n_time_step, step):
    x = dataset['x-axis'].values[i: i + n_time_step]
    y = dataset['y-axis'].values[i: i + n_time_step]
    z = dataset['z-axis'].values[i: i + n_time_step]
    segment_labels = dataset['activity'][i: i + n_time_step]
    label = segment_labels.value_counts().idxmax()
    segments.append([x, y, z])
    labels.append(label)

reshaped_segments = np.asarray(segments, dtype=np.float32).reshape(-1, n_time_step, n_feature)
labels = np.asarray(pd.get_dummies(labels), dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(reshaped_segments, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class CNNAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size



    def CNN_Attention(self, input_forward, input_backward):
      # 1D-CNN layers
      conv1_forward = Conv1D(128, 3, activation="relu", padding='same')(input_forward)
      conv1_backward = Conv1D(128, 3, activation="relu", padding='same')(input_backward)

      # Concatenate CNN outputs
      concatenated = Concatenate()([conv1_forward, conv1_backward])

      # Batch Normalization
      model = BatchNormalization()(concatenated)

      # Max Pooling
      model = MaxPooling1D(pool_size=2)(model)

      # Dropout
      model = Dropout(0.2)(model)

      # Additional Conv1D layers
      model = Conv1D(128, 3, activation="relu", padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      model = Conv1D(128//2, 3, activation="relu", padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      model = Conv1D(128//4, 3, activation="relu", padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      # Layer Normalization
      model = LayerNormalization()(model)

      # 2 LSTM layers
      x = LSTM(64, return_sequences=True)(model)
      model = LSTM(64, return_sequences=True)(x)

      # Attention layer
      output = Attention(8)(model)

      return output


    def create_model(self, learning_rate, batch_size):

        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))


        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)
        model1 = self.CNN_Attention(input_1_forward, input_1_backward_flipped)

        output = Dropout(0.2)(model1)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )


    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history




    def score(self, X, y):
        loss, accuracy = self.model.evaluate(X, y, verbose=0)
        return accuracy


    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Train and Test The Model**

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 32
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = CNNAttentionModel(learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


history = best_model.fit(
    X=[
        x_train_final,
        np.flip(x_train_final, axis=1)
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final,
            np.flip(x_val_final, axis=1)
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([X_test, np.flip(X_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([X_test, np.flip(X_test, axis=1)])


y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics

# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'],
                  index=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 344/344 [==============================] - ETA: 0s - loss: 0.5869 - accuracy: 0.7906
# Epoch 1: val_accuracy improved from -inf to 0.85907, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 28s 28ms/step - loss: 0.5869 - accuracy: 0.7906 - val_loss: 0.4165 - val_accuracy: 0.8591
# Epoch 2/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.3425 - accuracy: 0.8749
# Epoch 2: val_accuracy improved from 0.85907 to 0.89876, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.3424 - accuracy: 0.8750 - val_loss: 0.2840 - val_accuracy: 0.8988
# Epoch 3/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.9134
# Epoch 3: val_accuracy improved from 0.89876 to 0.93336, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.2553 - accuracy: 0.9134 - val_loss: 0.2017 - val_accuracy: 0.9334
# Epoch 4/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2211 - accuracy: 0.9265
# Epoch 4: val_accuracy improved from 0.93336 to 0.94683, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2214 - accuracy: 0.9263 - val_loss: 0.1787 - val_accuracy: 0.9468
# Epoch 5/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9380
# Epoch 5: val_accuracy did not improve from 0.94683
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1856 - accuracy: 0.9380 - val_loss: 0.1680 - val_accuracy: 0.9443
# Epoch 6/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9431
# Epoch 6: val_accuracy did not improve from 0.94683
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1728 - accuracy: 0.9431 - val_loss: 0.1712 - val_accuracy: 0.9428
# Epoch 7/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1480 - accuracy: 0.9528
# Epoch 7: val_accuracy improved from 0.94683 to 0.95339, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1478 - accuracy: 0.9528 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 8/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1472 - accuracy: 0.9539
# Epoch 8: val_accuracy did not improve from 0.95339
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1470 - accuracy: 0.9540 - val_loss: 0.1561 - val_accuracy: 0.9487
# Epoch 9/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9581
# Epoch 9: val_accuracy did not improve from 0.95339
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1320 - accuracy: 0.9581 - val_loss: 0.1402 - val_accuracy: 0.9530
# Epoch 10/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1292 - accuracy: 0.9576
# Epoch 10: val_accuracy improved from 0.95339 to 0.95703, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 8s 22ms/step - loss: 0.1292 - accuracy: 0.9576 - val_loss: 0.1218 - val_accuracy: 0.9570
# Epoch 11/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9619
# Epoch 11: val_accuracy improved from 0.95703 to 0.96577, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1153 - accuracy: 0.9620 - val_loss: 0.1120 - val_accuracy: 0.9658
# Epoch 12/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9618
# Epoch 12: val_accuracy improved from 0.96577 to 0.96686, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1172 - accuracy: 0.9618 - val_loss: 0.1006 - val_accuracy: 0.9669
# Epoch 13/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9668
# Epoch 13: val_accuracy did not improve from 0.96686
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0998 - accuracy: 0.9667 - val_loss: 0.1098 - val_accuracy: 0.9629
# Epoch 14/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1099 - accuracy: 0.9637
# Epoch 14: val_accuracy improved from 0.96686 to 0.96795, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 8s 23ms/step - loss: 0.1098 - accuracy: 0.9638 - val_loss: 0.0943 - val_accuracy: 0.9680
# Epoch 15/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0925 - accuracy: 0.9709
# Epoch 15: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0925 - accuracy: 0.9709 - val_loss: 0.1121 - val_accuracy: 0.9650
# Epoch 16/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9676
# Epoch 16: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 7s 21ms/step - loss: 0.0931 - accuracy: 0.9677 - val_loss: 0.1266 - val_accuracy: 0.9599
# Epoch 17/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9715
# Epoch 17: val_accuracy did not improve from 0.96795
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0838 - accuracy: 0.9715 - val_loss: 0.1088 - val_accuracy: 0.9650
# Epoch 18/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9732
# Epoch 18: val_accuracy improved from 0.96795 to 0.96905, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 21ms/step - loss: 0.0794 - accuracy: 0.9732 - val_loss: 0.0969 - val_accuracy: 0.9690
# Epoch 19/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9750
# Epoch 19: val_accuracy did not improve from 0.96905
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0752 - accuracy: 0.9750 - val_loss: 0.1215 - val_accuracy: 0.9625
# Epoch 20/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9720
# Epoch 20: val_accuracy did not improve from 0.96905
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0825 - accuracy: 0.9719 - val_loss: 0.1032 - val_accuracy: 0.9661
# Epoch 21/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9742
# Epoch 21: val_accuracy improved from 0.96905 to 0.97196, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 9s 25ms/step - loss: 0.0780 - accuracy: 0.9743 - val_loss: 0.0927 - val_accuracy: 0.9720
# Epoch 22/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9781
# Epoch 22: val_accuracy did not improve from 0.97196
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0665 - accuracy: 0.9778 - val_loss: 0.2316 - val_accuracy: 0.9133
# Epoch 23/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9714
# Epoch 23: val_accuracy improved from 0.97196 to 0.97414, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 22ms/step - loss: 0.0824 - accuracy: 0.9714 - val_loss: 0.0791 - val_accuracy: 0.9741
# Epoch 24/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9766
# Epoch 24: val_accuracy did not improve from 0.97414
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0705 - accuracy: 0.9765 - val_loss: 0.1770 - val_accuracy: 0.9348
# Epoch 25/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0672 - accuracy: 0.9769
# Epoch 25: val_accuracy improved from 0.97414 to 0.97524, saving model to /content/drive/MyDrive/wisdm (1)/CNN/WISDM-CNN.hdf5
# 344/344 [==============================] - 7s 22ms/step - loss: 0.0671 - accuracy: 0.9770 - val_loss: 0.0811 - val_accuracy: 0.9752
# Epoch 26/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9815
# Epoch 26: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0515 - accuracy: 0.9816 - val_loss: 0.0969 - val_accuracy: 0.9720
# Epoch 27/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9814
# Epoch 27: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0588 - accuracy: 0.9814 - val_loss: 0.0932 - val_accuracy: 0.9745
# Epoch 28/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9822
# Epoch 28: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0572 - accuracy: 0.9820 - val_loss: 0.1471 - val_accuracy: 0.9574
# Epoch 29/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9794
# Epoch 29: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0651 - accuracy: 0.9794 - val_loss: 0.1164 - val_accuracy: 0.9639
# Epoch 30/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9814
# Epoch 30: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0564 - accuracy: 0.9815 - val_loss: 0.1254 - val_accuracy: 0.9639
# Epoch 31/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9838
# Epoch 31: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0504 - accuracy: 0.9838 - val_loss: 0.1119 - val_accuracy: 0.9669
# Epoch 32/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0526 - accuracy: 0.9819
# Epoch 32: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0525 - accuracy: 0.9819 - val_loss: 0.1221 - val_accuracy: 0.9665
# Epoch 33/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9841
# Epoch 33: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0526 - accuracy: 0.9839 - val_loss: 0.1057 - val_accuracy: 0.9669
# Epoch 34/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9856
# Epoch 34: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0459 - accuracy: 0.9856 - val_loss: 0.1205 - val_accuracy: 0.9698
# Epoch 35/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0475 - accuracy: 0.9834Restoring model weights from the end of the best epoch: 25.
#
# Epoch 35: val_accuracy did not improve from 0.97524
# 344/344 [==============================] - 6s 17ms/step - loss: 0.0473 - accuracy: 0.9835 - val_loss: 0.0835 - val_accuracy: 0.9705
# Epoch 35: early stopping
# 108/108 [==============================] - 2s 7ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             1280      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             1280      ['input_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              98432     ['dropout[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               24640     ['dropout_1[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               6176      ['dropout_2[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  lstm (LSTM)                 (None, 8, 64)                24832     ['layer_normalization[1][0]']
#
#  lstm_1 (LSTM)               (None, 8, 64)                33024     ['lstm[1][0]']
#
#  attention (Attention)       (None, 64)                   72        ['lstm_1[1][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['attention[1][0]']
#
#  dense (Dense)               (None, 6)                    390       ['dropout_4[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 192110 (750.43 KB)
# Trainable params: 191150 (746.68 KB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9712
# Average Accuracy: 0.9598542826516288
# Best Accuracy: 0.9856101870536804
# Last Epoch Accuracy: 0.9835155010223389
# Micro Accuracy: 0.9712
# Macro Accuracy: 0.9613
# Weighted Accuracy: 0.9712
# Precision (Macro): 0.9549643767591952
# Precision (Weighted): 0.9722940823808316
# Precision (Micro): 0.9711538461538461
# Recall (Macro): 0.9612816218124434
# Recall (Weighted): 0.9711538461538461
# Recall (Micro): 0.9711538461538461
# F1 Score (Macro): 0.9577530088002955
# F1 Score (Weighted): 0.9715015678409279
# F1 Score (Micro): 0.9711538461538461
# Population Std Dev - True Labels: 1.9351159283819863
# Population Std Dev - Predicted Labels: 1.9278833768245456
# Sample Std Dev - True Labels: 1.9353979124896226
# Sample Std Dev - Predicted Labels: 1.928164307008452
# _______________________________________________________________
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 278
#   True Negatives (TN): 3099
#   False Positives (FP): 27
#   False Negatives (FN): 28
#
# Metrics for JOGGING:
#   True Positives (TP): 1081
#   True Negatives (TN): 2330
#   False Positives (FP): 5
#   False Negatives (FN): 16
#
# Metrics for SITTING:
#   True Positives (TP): 179
#   True Negatives (TN): 3245
#   False Positives (FP): 0
#   False Negatives (FN): 8
#
# Metrics for STANDING:
#   True Positives (TP): 143
#   True Negatives (TN): 3279
#   False Positives (FP): 8
#   False Negatives (FN): 2
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 391
#   True Negatives (TN): 2967
#   False Positives (FP): 53
#   False Negatives (FN): 21
#
# Metrics for WALKING:
#   True Positives (TP): 1261
#   True Negatives (TN): 2141
#   False Positives (FP): 6
#   False Negatives (FN): 24
#
# Timer stopped at 2024-06-03 19:46:04
# Elapsed time: 368.7809762954712 seconds
