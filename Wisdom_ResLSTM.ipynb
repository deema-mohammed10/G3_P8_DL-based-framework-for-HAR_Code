# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 20:58:34

# %% [markdown]
# # **Load the WISDOM Dataset**

# %%
file_path ='/content/drive/MyDrive/WithCV/WISDM_Dataset/WISDM_ar_v1.1_cleaned.txt'
model_load_path = '/content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5'

colnames = ['users', 'activity', 'timestamp', 'x-axis', 'y-axis', 'z-axis']
dataset = pd.read_csv(file_path, names=colnames)
dataset = dataset.dropna()

# Further data cleaning of the database: convert the 'x-axis', 'y-axis', 'z-axis' to numeric values by removing and ; or ,
for axis in ['x-axis', 'y-axis', 'z-axis']:
    dataset[axis] = dataset[axis].astype(str).str.replace(';', '').astype(np.float32)

n_time_step = 128
step = 64
n_feature = 3
segments = []
labels = []

for i in range(0, len(dataset) - n_time_step, step):
    x = dataset['x-axis'].values[i: i + n_time_step]
    y = dataset['y-axis'].values[i: i + n_time_step]
    z = dataset['z-axis'].values[i: i + n_time_step]
    segment_labels = dataset['activity'][i: i + n_time_step]
    # Use pandas to find the most frequent label
    label = segment_labels.value_counts().idxmax()
    segments.append([x, y, z])
    labels.append(label)

reshaped_segments = np.asarray(segments, dtype=np.float32).reshape(-1, n_time_step, n_feature)
labels = np.asarray(pd.get_dummies(labels), dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(reshaped_segments, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class CNNResLSTMAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def CNN_ResLSTM_Attention(self, input_forward, input_backward):
        # 1D-CNN layers with different kernels
        conv1_forward = Conv1D(128, 3, activation='relu', padding='same')(input_forward)
        conv1_backward = Conv1D(128, 3, activation='relu', padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

        # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

        # Dropout
        model = Dropout(0.2)(model)

        # 1D-CNN layers with different kernels
        model = Conv1D(128, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # 1D-CNN layers with different kernels
        model = Conv1D(64, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # 1D-CNN layers with different kernels
        model = Conv1D(32, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # Layer Normalization
        model = LayerNormalization()(model)

        # LSTM layers
        x = LSTM(64, return_sequences=True)(model)
        model = LayerNormalization()(x)
        y = LSTM(64, return_sequences=True)(model)
        model = Add()([x, y])

        # Attention layer
        output = Attention(8)(model)

        return output

    def create_model(self, learning_rate, batch_size):
         # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)

       # Now, we pass both forward and backward inputs to the CNN_LSTM_Attention method
        model1 = self.CNN_ResLSTM_Attention(input_1_forward, input_1_backward_flipped)

        output = Dropout(0.2)(model1)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_load_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history

    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }

    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.0001,
    'batch_size': 32
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = CNNResLSTMAttentionModel(learning_rate=best_params['learning_rate'],
                                      batch_size=best_params['batch_size'])

history = best_model.fit(
    X=[
        x_train_final,  # Original body acceleration data for the final model
        np.flip(x_train_final, axis=1)  # Flipped body acceleration data for the final model
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final,  # Original validation body acceleration data
            np.flip(x_val_final, axis=1)  # Flipped validation body acceleration data
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([X_test, np.flip(X_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([X_test, np.flip(X_test, axis=1)])
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)

# Print model summary
best_model.model.summary()
total_params = best_model.model.count_params()
print("Total parameters:", total_params)

# Print evaluation metrics
# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'],
                  index=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

# Assuming 'conf_matrix' is your confusion matrix from your model's predictions
TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.9411 - accuracy: 0.6817
# Epoch 1: val_accuracy improved from -inf to 0.82739, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 18s 23ms/step - loss: 0.9395 - accuracy: 0.6822 - val_loss: 0.5061 - val_accuracy: 0.8274
# Epoch 2/150
# 344/344 [==============================] - ETA: 0s - loss: 0.5525 - accuracy: 0.8066
# Epoch 2: val_accuracy improved from 0.82739 to 0.86198, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.5525 - accuracy: 0.8066 - val_loss: 0.3757 - val_accuracy: 0.8620
# Epoch 3/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.4468 - accuracy: 0.8408
# Epoch 3: val_accuracy improved from 0.86198 to 0.88310, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.4464 - accuracy: 0.8411 - val_loss: 0.3223 - val_accuracy: 0.8831
# Epoch 4/150
# 344/344 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8608
# Epoch 4: val_accuracy improved from 0.88310 to 0.90095, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.3852 - accuracy: 0.8608 - val_loss: 0.2815 - val_accuracy: 0.9009
# Epoch 5/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.3500 - accuracy: 0.8705
# Epoch 5: val_accuracy improved from 0.90095 to 0.91661, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.3501 - accuracy: 0.8707 - val_loss: 0.2505 - val_accuracy: 0.9166
# Epoch 6/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.3172 - accuracy: 0.8879
# Epoch 6: val_accuracy improved from 0.91661 to 0.92935, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.3179 - accuracy: 0.8877 - val_loss: 0.2088 - val_accuracy: 0.9294
# Epoch 7/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.8963
# Epoch 7: val_accuracy improved from 0.92935 to 0.93809, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2919 - accuracy: 0.8963 - val_loss: 0.2011 - val_accuracy: 0.9381
# Epoch 8/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2665 - accuracy: 0.9076
# Epoch 8: val_accuracy did not improve from 0.93809
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2671 - accuracy: 0.9074 - val_loss: 0.2113 - val_accuracy: 0.9253
# Epoch 9/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9163
# Epoch 9: val_accuracy improved from 0.93809 to 0.94538, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.2505 - accuracy: 0.9162 - val_loss: 0.1699 - val_accuracy: 0.9454
# Epoch 10/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2371 - accuracy: 0.9207
# Epoch 10: val_accuracy improved from 0.94538 to 0.94865, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 21ms/step - loss: 0.2370 - accuracy: 0.9208 - val_loss: 0.1719 - val_accuracy: 0.9487
# Epoch 11/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9256
# Epoch 11: val_accuracy did not improve from 0.94865
# 344/344 [==============================] - 7s 20ms/step - loss: 0.2229 - accuracy: 0.9255 - val_loss: 0.2000 - val_accuracy: 0.9294
# Epoch 12/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2167 - accuracy: 0.9264
# Epoch 12: val_accuracy did not improve from 0.94865
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2166 - accuracy: 0.9264 - val_loss: 0.1677 - val_accuracy: 0.9417
# Epoch 13/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2103 - accuracy: 0.9298
# Epoch 13: val_accuracy improved from 0.94865 to 0.95047, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.2105 - accuracy: 0.9298 - val_loss: 0.1572 - val_accuracy: 0.9505
# Epoch 14/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.9327
# Epoch 14: val_accuracy improved from 0.95047 to 0.95666, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2061 - accuracy: 0.9328 - val_loss: 0.1446 - val_accuracy: 0.9567
# Epoch 15/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1849 - accuracy: 0.9376
# Epoch 15: val_accuracy did not improve from 0.95666
# 344/344 [==============================] - 6s 19ms/step - loss: 0.1849 - accuracy: 0.9376 - val_loss: 0.1455 - val_accuracy: 0.9505
# Epoch 16/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9419
# Epoch 16: val_accuracy did not improve from 0.95666
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1769 - accuracy: 0.9415 - val_loss: 0.1490 - val_accuracy: 0.9516
# Epoch 17/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9426
# Epoch 17: val_accuracy did not improve from 0.95666
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1776 - accuracy: 0.9426 - val_loss: 0.1413 - val_accuracy: 0.9556
# Epoch 18/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1676 - accuracy: 0.9447
# Epoch 18: val_accuracy improved from 0.95666 to 0.95739, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1679 - accuracy: 0.9446 - val_loss: 0.1265 - val_accuracy: 0.9574
# Epoch 19/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1632 - accuracy: 0.9462
# Epoch 19: val_accuracy improved from 0.95739 to 0.95958, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1634 - accuracy: 0.9461 - val_loss: 0.1259 - val_accuracy: 0.9596
# Epoch 20/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9484
# Epoch 20: val_accuracy did not improve from 0.95958
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1564 - accuracy: 0.9484 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 21/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9486
# Epoch 21: val_accuracy did not improve from 0.95958
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1575 - accuracy: 0.9486 - val_loss: 0.1240 - val_accuracy: 0.9570
# Epoch 22/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1521 - accuracy: 0.9491
# Epoch 22: val_accuracy did not improve from 0.95958
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1521 - accuracy: 0.9491 - val_loss: 0.1191 - val_accuracy: 0.9592
# Epoch 23/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9530
# Epoch 23: val_accuracy improved from 0.95958 to 0.96504, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1358 - accuracy: 0.9532 - val_loss: 0.1106 - val_accuracy: 0.9650
# Epoch 24/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9530
# Epoch 24: val_accuracy did not improve from 0.96504
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1393 - accuracy: 0.9530 - val_loss: 0.1186 - val_accuracy: 0.9567
# Epoch 25/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9553
# Epoch 25: val_accuracy did not improve from 0.96504
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1308 - accuracy: 0.9555 - val_loss: 0.1169 - val_accuracy: 0.9603
# Epoch 26/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9526
# Epoch 26: val_accuracy did not improve from 0.96504
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1371 - accuracy: 0.9526 - val_loss: 0.1240 - val_accuracy: 0.9556
# Epoch 27/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9578
# Epoch 27: val_accuracy did not improve from 0.96504
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1212 - accuracy: 0.9578 - val_loss: 0.1120 - val_accuracy: 0.9596
# Epoch 28/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9583
# Epoch 28: val_accuracy did not improve from 0.96504
# 344/344 [==============================] - 6s 19ms/step - loss: 0.1246 - accuracy: 0.9583 - val_loss: 0.1118 - val_accuracy: 0.9603
# Epoch 29/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9588
# Epoch 29: val_accuracy improved from 0.96504 to 0.96723, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1179 - accuracy: 0.9587 - val_loss: 0.0973 - val_accuracy: 0.9672
# Epoch 30/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1208 - accuracy: 0.9579
# Epoch 30: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1208 - accuracy: 0.9579 - val_loss: 0.1023 - val_accuracy: 0.9625
# Epoch 31/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1121 - accuracy: 0.9626
# Epoch 31: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1120 - accuracy: 0.9627 - val_loss: 0.1009 - val_accuracy: 0.9625
# Epoch 32/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1178 - accuracy: 0.9591
# Epoch 32: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1183 - accuracy: 0.9590 - val_loss: 0.1074 - val_accuracy: 0.9625
# Epoch 33/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9597
# Epoch 33: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 6s 19ms/step - loss: 0.1177 - accuracy: 0.9594 - val_loss: 0.1330 - val_accuracy: 0.9559
# Epoch 34/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9638
# Epoch 34: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1090 - accuracy: 0.9638 - val_loss: 0.1075 - val_accuracy: 0.9650
# Epoch 35/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9619
# Epoch 35: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1083 - accuracy: 0.9619 - val_loss: 0.1044 - val_accuracy: 0.9636
# Epoch 36/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9654
# Epoch 36: val_accuracy did not improve from 0.96723
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0992 - accuracy: 0.9653 - val_loss: 0.1067 - val_accuracy: 0.9665
# Epoch 37/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1013 - accuracy: 0.9653
# Epoch 37: val_accuracy improved from 0.96723 to 0.97050, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.1012 - accuracy: 0.9653 - val_loss: 0.0910 - val_accuracy: 0.9705
# Epoch 38/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9693
# Epoch 38: val_accuracy did not improve from 0.97050
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0928 - accuracy: 0.9693 - val_loss: 0.1138 - val_accuracy: 0.9654
# Epoch 39/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9689
# Epoch 39: val_accuracy did not improve from 0.97050
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0937 - accuracy: 0.9689 - val_loss: 0.0907 - val_accuracy: 0.9701
# Epoch 40/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9675
# Epoch 40: val_accuracy improved from 0.97050 to 0.97305, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0911 - accuracy: 0.9676 - val_loss: 0.0900 - val_accuracy: 0.9731
# Epoch 41/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0881 - accuracy: 0.9699
# Epoch 41: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 20ms/step - loss: 0.0881 - accuracy: 0.9699 - val_loss: 0.1010 - val_accuracy: 0.9669
# Epoch 42/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9691
# Epoch 42: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0901 - accuracy: 0.9691 - val_loss: 0.1020 - val_accuracy: 0.9687
# Epoch 43/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0911 - accuracy: 0.9693
# Epoch 43: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0912 - accuracy: 0.9692 - val_loss: 0.1069 - val_accuracy: 0.9683
# Epoch 44/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9673
# Epoch 44: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0900 - accuracy: 0.9674 - val_loss: 0.1035 - val_accuracy: 0.9683
# Epoch 45/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0867 - accuracy: 0.9704
# Epoch 45: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0868 - accuracy: 0.9703 - val_loss: 0.0894 - val_accuracy: 0.9712
# Epoch 46/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0878 - accuracy: 0.9714
# Epoch 46: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0881 - accuracy: 0.9713 - val_loss: 0.0892 - val_accuracy: 0.9727
# Epoch 47/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9711
# Epoch 47: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0829 - accuracy: 0.9711 - val_loss: 0.0853 - val_accuracy: 0.9712
# Epoch 48/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0799 - accuracy: 0.9739
# Epoch 48: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0799 - accuracy: 0.9739 - val_loss: 0.0940 - val_accuracy: 0.9705
# Epoch 49/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9731
# Epoch 49: val_accuracy did not improve from 0.97305
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0757 - accuracy: 0.9731 - val_loss: 0.0852 - val_accuracy: 0.9727
# Epoch 50/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0721 - accuracy: 0.9757
# Epoch 50: val_accuracy improved from 0.97305 to 0.97633, saving model to /content/drive/MyDrive/WithCV/Models_WISDM/BiLSTM/UCI-CNN-BiLSTM-Attention.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0722 - accuracy: 0.9757 - val_loss: 0.0864 - val_accuracy: 0.9763
# Epoch 51/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9751
# Epoch 51: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0730 - accuracy: 0.9751 - val_loss: 0.0872 - val_accuracy: 0.9727
# Epoch 52/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0708 - accuracy: 0.9758
# Epoch 52: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0708 - accuracy: 0.9758 - val_loss: 0.0887 - val_accuracy: 0.9727
# Epoch 53/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9762
# Epoch 53: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0678 - accuracy: 0.9762 - val_loss: 0.0869 - val_accuracy: 0.9745
# Epoch 54/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9732
# Epoch 54: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 18ms/step - loss: 0.0761 - accuracy: 0.9732 - val_loss: 0.0920 - val_accuracy: 0.9723
# Epoch 55/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.0677 - accuracy: 0.9767
# Epoch 55: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0677 - accuracy: 0.9766 - val_loss: 0.0983 - val_accuracy: 0.9683
# Epoch 56/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9744
# Epoch 56: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0771 - accuracy: 0.9744 - val_loss: 0.0927 - val_accuracy: 0.9720
# Epoch 57/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0724 - accuracy: 0.9752
# Epoch 57: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0725 - accuracy: 0.9752 - val_loss: 0.0847 - val_accuracy: 0.9731
# Epoch 58/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0613 - accuracy: 0.9785
# Epoch 58: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0615 - accuracy: 0.9784 - val_loss: 0.0922 - val_accuracy: 0.9716
# Epoch 59/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9776
# Epoch 59: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 7s 19ms/step - loss: 0.0689 - accuracy: 0.9776 - val_loss: 0.0867 - val_accuracy: 0.9738
# Epoch 60/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9757Restoring model weights from the end of the best epoch: 50.
#
# Epoch 60: val_accuracy did not improve from 0.97633
# 344/344 [==============================] - 6s 19ms/step - loss: 0.0649 - accuracy: 0.9757 - val_loss: 0.0886 - val_accuracy: 0.9727
# Epoch 60: early stopping
# 108/108 [==============================] - 1s 5ms/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_6 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d_5 (Conv1D)           (None, 128, 128)             1280      ['input_4[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 128, 128)             1280      ['input_6[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 256)             0         ['conv1d_5[1][0]',
#  )                                                                   'conv1d_6[1][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 256)             1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  max_pooling1d_4 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_4[1][0]'
#  g1D)                                                               ]
#
#  dropout_5 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_4[1][0]']
#
#  conv1d_7 (Conv1D)           (None, 64, 128)              98432     ['dropout_5[1][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 128)              512       ['conv1d_7[1][0]']
#  chNormalization)
#
#  max_pooling1d_5 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_5[1][0]'
#  g1D)                                                               ]
#
#  dropout_6 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_5[1][0]']
#
#  conv1d_8 (Conv1D)           (None, 32, 64)               24640     ['dropout_6[1][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 64)               256       ['conv1d_8[1][0]']
#  chNormalization)
#
#  max_pooling1d_6 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_6[1][0]'
#  g1D)                                                               ]
#
#  dropout_7 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_6[1][0]']
#
#  conv1d_9 (Conv1D)           (None, 16, 32)               6176      ['dropout_7[1][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 32)               128       ['conv1d_9[1][0]']
#  chNormalization)
#
#  max_pooling1d_7 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_7[1][0]'
#  g1D)                                                               ]
#
#  dropout_8 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_7[1][0]']
#
#  layer_normalization_2 (Lay  (None, 8, 32)                64        ['dropout_8[1][0]']
#  erNormalization)
#
#  lstm_2 (LSTM)               (None, 8, 64)                24832     ['layer_normalization_2[1][0]'
#                                                                     ]
#
#  layer_normalization_3 (Lay  (None, 8, 64)                128       ['lstm_2[1][0]']
#  erNormalization)
#
#  lstm_3 (LSTM)               (None, 8, 64)                33024     ['layer_normalization_3[1][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 8, 64)                0         ['lstm_2[1][0]',
#                                                                      'lstm_3[1][0]']
#
#  attention_1 (Attention)     (None, 64)                   72        ['add_1[1][0]']
#
#  dropout_9 (Dropout)         (None, 64)                   0         ['attention_1[1][0]']
#
#  dense_1 (Dense)             (None, 6)                    390       ['dropout_9[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense_1[1][0]']
#
# ==================================================================================================
# Total params: 192238 (750.93 KB)
# Trainable params: 191278 (747.18 KB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# Total parameters: 192238
# Test Accuracy: 0.9720
# Average Accuracy: 0.9437067379554113
# Best Accuracy: 0.978415310382843
# Last Epoch Accuracy: 0.9756830334663391
# Micro Accuracy: 0.9720
# Macro Accuracy: 0.9582
# Weighted Accuracy: 0.9720
# Precision (Macro): 0.9588786720725292
# Precision (Weighted): 0.9723604240679604
# Precision (Micro): 0.972027972027972
# Recall (Macro): 0.9582221312199408
# Recall (Weighted): 0.972027972027972
# Recall (Micro): 0.972027972027972
# F1 Score (Macro): 0.9581878647254413
# F1 Score (Weighted): 0.9720196843235449
# F1 Score (Micro): 0.972027972027972
# Population Std Dev - True Labels: 1.9351159283819863
# Population Std Dev - Predicted Labels: 1.945745793336313
# Sample Std Dev - True Labels: 1.9353979124896226
# Sample Std Dev - Predicted Labels: 1.946029326422457
# _______________________________________________________________
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 287
#   True Negatives (TN): 3088
#   False Positives (FP): 38
#   False Negatives (FN): 19
#
# Metrics for JOGGING:
#   True Positives (TP): 1090
#   True Negatives (TN): 2324
#   False Positives (FP): 11
#   False Negatives (FN): 7
#
# Metrics for SITTING:
#   True Positives (TP): 186
#   True Negatives (TN): 3238
#   False Positives (FP): 7
#   False Negatives (FN): 1
#
# Metrics for STANDING:
#   True Positives (TP): 137
#   True Negatives (TN): 3286
#   False Positives (FP): 1
#   False Negatives (FN): 8
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 367
#   True Negatives (TN): 2994
#   False Positives (FP): 26
#   False Negatives (FN): 45
#
# Metrics for WALKING:
#   True Positives (TP): 1269
#   True Negatives (TN): 2134
#   False Positives (FP): 13
#   False Negatives (FN): 16
#
# Timer stopped at 2024-06-03 21:06:28
# Elapsed time: 473.8421709537506 seconds
