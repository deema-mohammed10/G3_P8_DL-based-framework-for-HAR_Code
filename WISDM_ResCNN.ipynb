# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer, LeakyReLU)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 19:58:20

# %% [markdown]
# # **Load the WISDM Dataset**

# %%
file_path ='/content/drive/MyDrive/WISDM/WISDM_ar_v1.1_cleaned.txt'
model_save_path = '/content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5'


colnames = ['users', 'activity', 'timestamp', 'x-axis', 'y-axis', 'z-axis']
dataset = pd.read_csv(file_path, names=colnames)
dataset = dataset.dropna()

# Further data cleaning of the database: convert the 'x-axis', 'y-axis', 'z-axis' to numeric values by removing and ; or ,
for axis in ['x-axis', 'y-axis', 'z-axis']:
    dataset[axis] = dataset[axis].astype(str).str.replace(';', '').astype(np.float32)

n_time_step = 128
step = 64
n_feature = 3
segments = []
labels = []

for i in range(0, len(dataset) - n_time_step, step):
    x = dataset['x-axis'].values[i: i + n_time_step]
    y = dataset['y-axis'].values[i: i + n_time_step]
    z = dataset['z-axis'].values[i: i + n_time_step]
    segment_labels = dataset['activity'][i: i + n_time_step]
    # Use pandas to find the most frequent label
    label = segment_labels.value_counts().idxmax()
    segments.append([x, y, z])
    labels.append(label)

reshaped_segments = np.asarray(segments, dtype=np.float32).reshape(-1, n_time_step, n_feature)
labels = np.asarray(pd.get_dummies(labels), dtype=np.float32)

X_train, X_test, y_train, y_test = train_test_split(reshaped_segments, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class CNNAttentionModel:

    def __init__(self, kernel_size, learning_rate, batch_size):
        self.model = None
        self.kernel_size = kernel_size
        self.learning_rate = learning_rate
        self.batch_size = batch_size



    def CNN_Attention(self, input_forward, input_backward, kernel_size):
      # 1D-CNN layers with different kernels
      conv1_forward = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(input_forward)
      conv1_backward = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(input_backward)
      # Concatenate CNN outputs
      concatenated = Concatenate()([conv1_forward, conv1_backward])

      # Batch Normalization
      model = BatchNormalization()(concatenated)

      # Max Pooling
      model = MaxPooling1D(pool_size=2)(model)

      # Dropout
      model = Dropout(0.2)(model)

      # Additional Conv1D layers
      model = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      model = Conv1D(128//2, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      model = Conv1D(128//4, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
      model = BatchNormalization()(model)
      model = MaxPooling1D(pool_size=2)(model)
      model = Dropout(0.2)(model)

      # Layer Normalization
      model = LayerNormalization()(model)

      #ResCNN LAYERS
      x = Conv1D(128//8 , kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
      model = LayerNormalization()(x)
      y = Conv1D(128//8 , kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
      model = Add()([x, y])
      # Attention layer
      output = Attention(8)(model)

      return output


    def create_model(self, kernel_size, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))


        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)

        model1 = self.CNN_Attention(input_1_forward, input_1_backward_flipped, kernel_size)

        output = Dropout(0.3)(model1)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )


    def fit(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data):
        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history




    def score(self, X, y):
        loss, accuracy = self.model.evaluate(X, y, verbose=0)
        return accuracy


    def get_params(self, deep=True):
        return {
            'kernel_size': self.kernel_size,
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Train and Test The Model**

# %%
best_params = {
    'learning_rate': 0.0001,
    'kernel_size': 5,
    'batch_size': 32
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = CNNAttentionModel(kernel_size=best_params['kernel_size'],
                               learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit(
    X=[
        x_train_final,
        np.flip(x_train_final, axis=1)
    ],
    y=y_train_final,
    kernel_size=best_params['kernel_size'],
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final,
            np.flip(x_val_final, axis=1)
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([X_test, np.flip(X_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([X_test, np.flip(X_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics
average_accuracy = np.mean(history.history['accuracy'])
best_accuracy = np.max(history.history['accuracy'])
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'],
                  index=['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['DOWNSTAIRS', 'JOGGING', 'SITTING', 'STANDING', 'UPSTAIRS', 'WALKING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 344/344 [==============================] - ETA: 0s - loss: 1.0888 - accuracy: 0.5947
# Epoch 1: val_accuracy improved from -inf to 0.77640, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 22s 20ms/step - loss: 1.0888 - accuracy: 0.5947 - val_loss: 0.6347 - val_accuracy: 0.7764
# Epoch 2/150
# 344/344 [==============================] - ETA: 0s - loss: 0.7220 - accuracy: 0.7500
# Epoch 2: val_accuracy improved from 0.77640 to 0.80335, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.7220 - accuracy: 0.7500 - val_loss: 0.5199 - val_accuracy: 0.8034
# Epoch 3/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.6036 - accuracy: 0.7981
# Epoch 3: val_accuracy improved from 0.80335 to 0.84450, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 5s 16ms/step - loss: 0.6037 - accuracy: 0.7980 - val_loss: 0.4304 - val_accuracy: 0.8445
# Epoch 4/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.5184 - accuracy: 0.8255
# Epoch 4: val_accuracy improved from 0.84450 to 0.86235, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.5184 - accuracy: 0.8256 - val_loss: 0.3981 - val_accuracy: 0.8623
# Epoch 5/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.4504 - accuracy: 0.8480
# Epoch 5: val_accuracy improved from 0.86235 to 0.90495, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.4504 - accuracy: 0.8481 - val_loss: 0.3138 - val_accuracy: 0.9050
# Epoch 6/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.4097 - accuracy: 0.8618
# Epoch 6: val_accuracy improved from 0.90495 to 0.91952, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.4090 - accuracy: 0.8619 - val_loss: 0.2657 - val_accuracy: 0.9195
# Epoch 7/150
# 344/344 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8817
# Epoch 7: val_accuracy did not improve from 0.91952
# 344/344 [==============================] - 8s 24ms/step - loss: 0.3659 - accuracy: 0.8817 - val_loss: 0.2828 - val_accuracy: 0.9104
# Epoch 8/150
# 340/344 [============================>.] - ETA: 0s - loss: 0.3468 - accuracy: 0.8863
# Epoch 8: val_accuracy did not improve from 0.91952
# 344/344 [==============================] - 5s 15ms/step - loss: 0.3467 - accuracy: 0.8863 - val_loss: 0.3264 - val_accuracy: 0.8944
# Epoch 9/150
# 344/344 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.8966
# Epoch 9: val_accuracy improved from 0.91952 to 0.93336, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.3178 - accuracy: 0.8966 - val_loss: 0.2185 - val_accuracy: 0.9334
# Epoch 10/150
# 344/344 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9031
# Epoch 10: val_accuracy improved from 0.93336 to 0.93773, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.3005 - accuracy: 0.9031 - val_loss: 0.2043 - val_accuracy: 0.9377
# Epoch 11/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2800 - accuracy: 0.9057
# Epoch 11: val_accuracy did not improve from 0.93773
# 344/344 [==============================] - 5s 15ms/step - loss: 0.2811 - accuracy: 0.9054 - val_loss: 0.3300 - val_accuracy: 0.8973
# Epoch 12/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9095
# Epoch 12: val_accuracy did not improve from 0.93773
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2764 - accuracy: 0.9095 - val_loss: 0.2246 - val_accuracy: 0.9308
# Epoch 13/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2592 - accuracy: 0.9180
# Epoch 13: val_accuracy did not improve from 0.93773
# 344/344 [==============================] - 5s 15ms/step - loss: 0.2586 - accuracy: 0.9182 - val_loss: 0.2267 - val_accuracy: 0.9337
# Epoch 14/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.9201
# Epoch 14: val_accuracy did not improve from 0.93773
# 344/344 [==============================] - 5s 16ms/step - loss: 0.2482 - accuracy: 0.9199 - val_loss: 0.2602 - val_accuracy: 0.9181
# Epoch 15/150
# 344/344 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9238
# Epoch 15: val_accuracy improved from 0.93773 to 0.94246, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.2398 - accuracy: 0.9238 - val_loss: 0.1862 - val_accuracy: 0.9425
# Epoch 16/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.2250 - accuracy: 0.9288
# Epoch 16: val_accuracy did not improve from 0.94246
# 344/344 [==============================] - 5s 15ms/step - loss: 0.2250 - accuracy: 0.9287 - val_loss: 0.2258 - val_accuracy: 0.9363
# Epoch 17/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2224 - accuracy: 0.9289
# Epoch 17: val_accuracy did not improve from 0.94246
# 344/344 [==============================] - 6s 17ms/step - loss: 0.2223 - accuracy: 0.9290 - val_loss: 0.1917 - val_accuracy: 0.9410
# Epoch 18/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.2123 - accuracy: 0.9330
# Epoch 18: val_accuracy improved from 0.94246 to 0.94355, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 16ms/step - loss: 0.2124 - accuracy: 0.9330 - val_loss: 0.1871 - val_accuracy: 0.9436
# Epoch 19/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.2046 - accuracy: 0.9355
# Epoch 19: val_accuracy improved from 0.94355 to 0.95047, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 16ms/step - loss: 0.2047 - accuracy: 0.9355 - val_loss: 0.1631 - val_accuracy: 0.9505
# Epoch 20/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9413
# Epoch 20: val_accuracy did not improve from 0.95047
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1857 - accuracy: 0.9411 - val_loss: 0.2232 - val_accuracy: 0.9312
# Epoch 21/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9419
# Epoch 21: val_accuracy did not improve from 0.95047
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1858 - accuracy: 0.9419 - val_loss: 0.1775 - val_accuracy: 0.9490
# Epoch 22/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.9408
# Epoch 22: val_accuracy did not improve from 0.95047
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1826 - accuracy: 0.9407 - val_loss: 0.1569 - val_accuracy: 0.9501
# Epoch 23/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9423
# Epoch 23: val_accuracy improved from 0.95047 to 0.95120, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1854 - accuracy: 0.9420 - val_loss: 0.1557 - val_accuracy: 0.9512
# Epoch 24/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.9468
# Epoch 24: val_accuracy did not improve from 0.95120
# 344/344 [==============================] - 5s 16ms/step - loss: 0.1677 - accuracy: 0.9470 - val_loss: 0.1844 - val_accuracy: 0.9457
# Epoch 25/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9482
# Epoch 25: val_accuracy improved from 0.95120 to 0.95157, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 19ms/step - loss: 0.1633 - accuracy: 0.9482 - val_loss: 0.1582 - val_accuracy: 0.9516
# Epoch 26/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1624 - accuracy: 0.9499
# Epoch 26: val_accuracy improved from 0.95157 to 0.95193, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1624 - accuracy: 0.9499 - val_loss: 0.1586 - val_accuracy: 0.9519
# Epoch 27/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1568 - accuracy: 0.9520
# Epoch 27: val_accuracy did not improve from 0.95193
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1572 - accuracy: 0.9520 - val_loss: 0.1753 - val_accuracy: 0.9450
# Epoch 28/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1463 - accuracy: 0.9537
# Epoch 28: val_accuracy improved from 0.95193 to 0.95557, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1462 - accuracy: 0.9537 - val_loss: 0.1480 - val_accuracy: 0.9556
# Epoch 29/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1500 - accuracy: 0.9511
# Epoch 29: val_accuracy did not improve from 0.95557
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1497 - accuracy: 0.9513 - val_loss: 0.1451 - val_accuracy: 0.9530
# Epoch 30/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9536
# Epoch 30: val_accuracy improved from 0.95557 to 0.95703, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1419 - accuracy: 0.9536 - val_loss: 0.1473 - val_accuracy: 0.9570
# Epoch 31/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9528
# Epoch 31: val_accuracy did not improve from 0.95703
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1484 - accuracy: 0.9526 - val_loss: 0.1431 - val_accuracy: 0.9570
# Epoch 32/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9566
# Epoch 32: val_accuracy improved from 0.95703 to 0.96213, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 7s 19ms/step - loss: 0.1347 - accuracy: 0.9566 - val_loss: 0.1306 - val_accuracy: 0.9621
# Epoch 33/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9591
# Epoch 33: val_accuracy improved from 0.96213 to 0.96540, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1278 - accuracy: 0.9591 - val_loss: 0.1226 - val_accuracy: 0.9654
# Epoch 34/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9606
# Epoch 34: val_accuracy did not improve from 0.96540
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1250 - accuracy: 0.9606 - val_loss: 0.1400 - val_accuracy: 0.9585
# Epoch 35/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9580
# Epoch 35: val_accuracy did not improve from 0.96540
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1260 - accuracy: 0.9582 - val_loss: 0.1410 - val_accuracy: 0.9541
# Epoch 36/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1237 - accuracy: 0.9595
# Epoch 36: val_accuracy did not improve from 0.96540
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1237 - accuracy: 0.9596 - val_loss: 0.1287 - val_accuracy: 0.9625
# Epoch 37/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9608
# Epoch 37: val_accuracy improved from 0.96540 to 0.96650, saving model to /content/drive/MyDrive/content/drive/MyDrive/WISDMWISDM-CNN.hdf5
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1202 - accuracy: 0.9608 - val_loss: 0.1228 - val_accuracy: 0.9665
# Epoch 38/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9633
# Epoch 38: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1157 - accuracy: 0.9631 - val_loss: 0.1284 - val_accuracy: 0.9629
# Epoch 39/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9646
# Epoch 39: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1197 - accuracy: 0.9646 - val_loss: 0.1417 - val_accuracy: 0.9530
# Epoch 40/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9635
# Epoch 40: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1125 - accuracy: 0.9635 - val_loss: 0.1294 - val_accuracy: 0.9629
# Epoch 41/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9671
# Epoch 41: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 6s 16ms/step - loss: 0.1044 - accuracy: 0.9672 - val_loss: 0.1473 - val_accuracy: 0.9545
# Epoch 42/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1115 - accuracy: 0.9667
# Epoch 42: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1114 - accuracy: 0.9668 - val_loss: 0.1205 - val_accuracy: 0.9647
# Epoch 43/150
# 342/344 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9691
# Epoch 43: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 5s 15ms/step - loss: 0.0990 - accuracy: 0.9688 - val_loss: 0.1407 - val_accuracy: 0.9614
# Epoch 44/150
# 343/344 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9651
# Epoch 44: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 6s 18ms/step - loss: 0.1098 - accuracy: 0.9650 - val_loss: 0.1230 - val_accuracy: 0.9643
# Epoch 45/150
# 341/344 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9635
# Epoch 45: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 5s 15ms/step - loss: 0.1150 - accuracy: 0.9635 - val_loss: 0.1554 - val_accuracy: 0.9581
# Epoch 46/150
# 344/344 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9666
# Epoch 46: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 5s 16ms/step - loss: 0.0987 - accuracy: 0.9666 - val_loss: 0.1601 - val_accuracy: 0.9556
# Epoch 47/150
# 344/344 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9655Restoring model weights from the end of the best epoch: 37.
#
# Epoch 47: val_accuracy did not improve from 0.96650
# 344/344 [==============================] - 6s 17ms/step - loss: 0.1033 - accuracy: 0.9655 - val_loss: 0.1560 - val_accuracy: 0.9552
# Epoch 47: early stopping
# 108/108 [==============================] - 1s 3ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             2048      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             2048      ['input_3[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              163968    ['dropout[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               41024     ['dropout_1[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               10272     ['dropout_2[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  conv1d_5 (Conv1D)           (None, 8, 16)                2576      ['layer_normalization[1][0]']
#
#  layer_normalization_1 (Lay  (None, 8, 16)                32        ['conv1d_5[1][0]']
#  erNormalization)
#
#  conv1d_6 (Conv1D)           (None, 8, 16)                1296      ['layer_normalization_1[1][0]'
#                                                                     ]
#
#  add (Add)                   (None, 8, 16)                0         ['conv1d_5[1][0]',
#                                                                      'conv1d_6[1][0]']
#
#  attention (Attention)       (None, 16)                   24        ['add[1][0]']
#
#  dropout_4 (Dropout)         (None, 16)                   0         ['attention[1][0]']
#
#  dense (Dense)               (None, 6)                    102       ['dropout_4[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 225374 (880.37 KB)
# Trainable params: 224414 (876.62 KB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9612
# Average Accuracy: 0.921962559223175
# Best Accuracy: 0.9687613844871521
# Last Epoch Accuracy: 0.9654827117919922
# Micro Accuracy: 0.9612
# Macro Accuracy: 0.9527
# Weighted Accuracy: 0.9612
# Precision (Macro): 0.940597419097626
# Precision (Weighted): 0.963498918744088
# Precision (Micro): 0.9612470862470862
# Recall (Macro): 0.9527145629903119
# Recall (Weighted): 0.9612470862470862
# Recall (Micro): 0.9612470862470862
# F1 Score (Macro): 0.9458856011420943
# F1 Score (Weighted): 0.9619424215162335
# F1 Score (Micro): 0.9612470862470862
# Population Std Dev - True Labels: 1.9351159283819863
# Population Std Dev - Predicted Labels: 1.9511377192796366
# Sample Std Dev - True Labels: 1.9353979124896226
# Sample Std Dev - Predicted Labels: 1.9514220380744836
# _______________________________________________________________
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 284
#   True Negatives (TN): 3059
#   False Positives (FP): 67
#   False Negatives (FN): 22
#
# Metrics for JOGGING:
#   True Positives (TP): 1072
#   True Negatives (TN): 2328
#   False Positives (FP): 7
#   False Negatives (FN): 25
#
# Metrics for SITTING:
#   True Positives (TP): 181
#   True Negatives (TN): 3244
#   False Positives (FP): 1
#   False Negatives (FN): 6
#
# Metrics for STANDING:
#   True Positives (TP): 143
#   True Negatives (TN): 3281
#   False Positives (FP): 6
#   False Negatives (FN): 2
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 362
#   True Negatives (TN): 2977
#   False Positives (FP): 43
#   False Negatives (FN): 50
#
# Metrics for WALKING:
#   True Positives (TP): 1257
#   True Negatives (TN): 2138
#   False Positives (FP): 9
#   False Negatives (FN): 28
#
# Timer stopped at 2024-06-03 20:03:28
# Elapsed time: 308.12180519104004 seconds
