# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 20:55:02

# %% [markdown]
# # **Load the UCI-HAR Dataset**

# %%
root_train = '/content/drive/MyDrive/WithCV/UCI_HAR_Dataset/Train/train_Inertial_Signals'
root_test = '/content/drive/MyDrive/WithCV/UCI_HAR_Dataset/Testing/test_Inertial_Signals'
model_save_path = '/content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5'

def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
        return files

file_x_train =  ['body_acc_x_train.txt', 'body_acc_y_train.txt', 'body_acc_z_train.txt',
                'body_gyro_x_train.txt', 'body_gyro_y_train.txt', 'body_gyro_z_train.txt',
                'total_acc_x_train.txt', 'total_acc_y_train.txt', 'total_acc_z_train.txt']
file_x_test = ['body_acc_x_test.txt', 'body_acc_y_test.txt', 'body_acc_z_test.txt',
               'body_gyro_x_test.txt', 'body_gyro_y_test.txt', 'body_gyro_z_test.txt',
               'total_acc_x_test.txt', 'total_acc_y_test.txt', 'total_acc_z_test.txt']

file_y_train = '/content/drive/MyDrive/WithCV/UCI_HAR_Dataset/Train/y_train.txt'
file_y_test = '/content/drive/MyDrive/WithCV/UCI_HAR_Dataset/Testing/y_test.txt'

def load_x(data, root):
    x_body_acc = []
    for file in data[0:3]:
        x_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_body_acc.append(x_acc_input)
    x_body_acc = np.transpose(np.array(x_body_acc), (1, 2, 0))

    x_gro = []
    for file in data[3:6]:
        x_gro_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_gro.append(x_gro_input)
    x_gro = np.transpose(np.array(x_gro), (1, 2, 0))

    x_total_acc = []
    for file in data[6:9]:
        x_total_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_total_acc.append(x_total_acc_input)
    x_total_acc = np.transpose(np.array(x_total_acc), (1, 2, 0))
    return x_body_acc, x_gro, x_total_acc

def load_y(data):
    file = open(data, 'r')
    y_input = np.array([elem for elem in [row.strip().split(' ') for row in file]], dtype=np.int32)
    file.close()
    return to_categorical(y_input - 1.0)

x_body_acc_train, x_gro_train, x_total_acc_train = load_x(file_x_train, root_train)
x_body_acc_test, x_gro_test, x_total_acc_test = load_x(file_x_test, root_test)
y_train = load_y(file_y_train)
y_test = load_y(file_y_test)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class ResBLSTMAttentionModel:
    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def CNN_ResBLSTM_Attention(self, input):
        model = Conv1D(256, 3, input_shape=(128, 3), activation='swish', padding='same')(input)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128, 3, activation='swish', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(64, 3, activation='swish', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(32, 3, activation='swish', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = LayerNormalization()(model)
        x = Bidirectional(LSTM(64, return_sequences=True))(model)

        model = LayerNormalization()(x)
        y = Bidirectional(LSTM(64, return_sequences=True))(model)
        model = Add()([x, y])

        output = Attention(8)(model)
        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1 = Input(shape=(128, 3))
        input_2 = Input(shape=(128, 3))
        input_3 = Input(shape=(128, 3))

        # Now, we pass both forward and backward inputs to the CNN_LSTM_Attention method
        model1 = self.CNN_ResBLSTM_Attention(input_1)
        model2 = self.CNN_ResBLSTM_Attention(input_2)
        model3 = self.CNN_ResBLSTM_Attention(input_3)

        concatenated_models = Concatenate()([model1, model2, model3])

        output = Dropout(0.3)(concatenated_models)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)

        self.model = Model(inputs=[input_1, input_2, input_3], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate), metrics=['accuracy'])

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data, early_stopping):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
            X, y,
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            validation_data=validation_data,
            callbacks=callbacks
        )

        return history

    def fit2(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history

    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }

    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Use 5-Fold GridSearchCV to test different combinations of the parameters**

# %%
param_grid = {
    'learning_rate': [ 0.01 , 0.001, 0.0001],
    'batch_size': [32 , 64]
}
param_combinations = [(lr, bs) for lr in param_grid['learning_rate'] for bs in param_grid['batch_size']]

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

best_loss = float('inf')
best_params_list = []

# Initialize the best accuracy variable and list for storing the best parameters
best_accuracy = 0

for lr, bs in param_combinations:
    print(f"_________________________________________________________________________\nTesting Parameters: Learning Rate: {lr}, Batch Size: {bs}")

    fold_losses = []

    # Perform cross-validation
    for split, (train_index, val_index) in enumerate(kf.split(x_body_acc_train), 1):
        print(f"____________________________________________________\nSplit {split}\n____________________________________________________")

        # Create an instance of ResBLSTMAttentionModel with the specified hyperparameters
        model = ResBLSTMAttentionModel(learning_rate=lr, batch_size=bs)

        # Split data into training and validation sets for each sensor type
        x_body_acc_train_fold = x_body_acc_train[train_index]
        x_body_acc_val_fold = x_body_acc_train[val_index]

        x_gro_train_fold = x_gro_train[train_index]
        x_gro_val_fold = x_gro_train[val_index]

        x_total_acc_train_fold = x_total_acc_train[train_index]
        x_total_acc_val_fold = x_total_acc_train[val_index]

        y_train_fold = y_train[train_index]
        y_val_fold = y_train[val_index]

        validation_data = (
        [x_body_acc_val_fold,
         x_gro_val_fold,
         x_total_acc_val_fold],
         y_val_fold)


        # Fit the model to the training data for this fold with validation data
        history = model.fit(
         [x_body_acc_train_fold,
         x_gro_train_fold,
         x_total_acc_train_fold],
         y_train_fold,learning_rate=lr, batch_size=bs, epochs=75, validation_data=validation_data, early_stopping=True)

        # Evaluate the model on the validation data directly
        val_loss, val_accuracy = model.model.evaluate(
            [x_body_acc_val_fold,
             x_gro_val_fold,
             x_total_acc_val_fold],
            y_val_fold, verbose=0
        )

        fold_losses.append(val_loss)


        print(f"\n\nValidation Loss for Split {split}: {val_loss:.4f}")

    mean_loss = np.mean(fold_losses)
    print(f"Mean Loss for Parameters: {lr}, {bs} is {mean_loss:.4f}")

    if mean_loss < best_loss:
        best_loss = mean_loss
        best_params_list = [(lr, bs)]
        print(f"New best parameters found: {lr}, {bs}")

print(f"\nBest Overall Parameters: {best_params_list}, with a loss of {best_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 16: val_loss improved from 0.09592 to 0.07566, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0931 - accuracy: 0.9624 - val_loss: 0.0757 - val_accuracy: 0.9660
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9684
# Epoch 17: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0837 - accuracy: 0.9684 - val_loss: 0.2423 - val_accuracy: 0.8905
# Epoch 18/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9648
# Epoch 18: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0898 - accuracy: 0.9648 - val_loss: 0.0943 - val_accuracy: 0.9612
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9587
# Epoch 19: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 62ms/step - loss: 0.1086 - accuracy: 0.9587 - val_loss: 0.8054 - val_accuracy: 0.8340
# Epoch 20/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9634
# Epoch 20: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0953 - accuracy: 0.9634 - val_loss: 0.5087 - val_accuracy: 0.8299
# Epoch 21/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9663
# Epoch 21: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0825 - accuracy: 0.9663 - val_loss: 0.1074 - val_accuracy: 0.9558
# Epoch 22/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9672
# Epoch 22: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0800 - accuracy: 0.9672 - val_loss: 0.0917 - val_accuracy: 0.9605
# Epoch 23/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9713
# Epoch 23: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0785 - accuracy: 0.9713 - val_loss: 0.1634 - val_accuracy: 0.9401
# Epoch 24/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9697
# Epoch 24: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0814 - accuracy: 0.9697 - val_loss: 0.1573 - val_accuracy: 0.9259
# Epoch 25/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9689
# Epoch 25: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0804 - accuracy: 0.9689 - val_loss: 0.1496 - val_accuracy: 0.9524
# Epoch 26/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9674Restoring model weights from the end of the best epoch: 16.
#
# Epoch 26: val_loss did not improve from 0.07566
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0816 - accuracy: 0.9674 - val_loss: 0.4229 - val_accuracy: 0.8687
# Epoch 26: early stopping
#
#
# Validation Loss for Split 4: 0.0757
# ____________________________________________________
# Split 5
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8876
# Epoch 1: val_loss improved from inf to 3.05204, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 50s 123ms/step - loss: 0.3117 - accuracy: 0.8876 - val_loss: 3.0520 - val_accuracy: 0.3197
# Epoch 2/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9274
# Epoch 2: val_loss improved from 3.05204 to 1.30140, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.1952 - accuracy: 0.9274 - val_loss: 1.3014 - val_accuracy: 0.6279
# Epoch 3/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9436
# Epoch 3: val_loss did not improve from 1.30140
# 92/92 [==============================] - 6s 60ms/step - loss: 0.1503 - accuracy: 0.9436 - val_loss: 1.8259 - val_accuracy: 0.4891
# Epoch 4/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9398
# Epoch 4: val_loss improved from 1.30140 to 0.37144, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 68ms/step - loss: 0.1533 - accuracy: 0.9398 - val_loss: 0.3714 - val_accuracy: 0.8871
# Epoch 5/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 0.9475
# Epoch 5: val_loss improved from 0.37144 to 0.27521, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.1348 - accuracy: 0.9475 - val_loss: 0.2752 - val_accuracy: 0.8912
# Epoch 6/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9464
# Epoch 6: val_loss did not improve from 0.27521
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1445 - accuracy: 0.9464 - val_loss: 0.3085 - val_accuracy: 0.9190
# Epoch 7/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9407
# Epoch 7: val_loss improved from 0.27521 to 0.19339, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 68ms/step - loss: 0.1513 - accuracy: 0.9407 - val_loss: 0.1934 - val_accuracy: 0.9354
# Epoch 8/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9497
# Epoch 8: val_loss improved from 0.19339 to 0.14705, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 66ms/step - loss: 0.1385 - accuracy: 0.9497 - val_loss: 0.1471 - val_accuracy: 0.9388
# Epoch 9/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9531
# Epoch 9: val_loss did not improve from 0.14705
# 92/92 [==============================] - 6s 60ms/step - loss: 0.1169 - accuracy: 0.9531 - val_loss: 0.1619 - val_accuracy: 0.9306
# Epoch 10/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9599
# Epoch 10: val_loss did not improve from 0.14705
# 92/92 [==============================] - 6s 62ms/step - loss: 0.1092 - accuracy: 0.9599 - val_loss: 0.1488 - val_accuracy: 0.9422
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9584
# Epoch 11: val_loss did not improve from 0.14705
# 92/92 [==============================] - 6s 60ms/step - loss: 0.1076 - accuracy: 0.9580 - val_loss: 0.2688 - val_accuracy: 0.9170
# Epoch 12/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9544
# Epoch 12: val_loss did not improve from 0.14705
# 92/92 [==============================] - 6s 60ms/step - loss: 0.1208 - accuracy: 0.9544 - val_loss: 0.3197 - val_accuracy: 0.8932
# Epoch 13/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9577
# Epoch 13: val_loss improved from 0.14705 to 0.10820, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 69ms/step - loss: 0.1035 - accuracy: 0.9577 - val_loss: 0.1082 - val_accuracy: 0.9503
# Epoch 14/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9597
# Epoch 14: val_loss did not improve from 0.10820
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1000 - accuracy: 0.9597 - val_loss: 0.2032 - val_accuracy: 0.8993
# Epoch 15/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9490
# Epoch 15: val_loss did not improve from 0.10820
# 92/92 [==============================] - 5s 60ms/step - loss: 0.1311 - accuracy: 0.9490 - val_loss: 0.2552 - val_accuracy: 0.8864
# Epoch 16/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9614
# Epoch 16: val_loss did not improve from 0.10820
# 92/92 [==============================] - 5s 60ms/step - loss: 0.0953 - accuracy: 0.9614 - val_loss: 0.1166 - val_accuracy: 0.9510
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9650
# Epoch 17: val_loss did not improve from 0.10820
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0901 - accuracy: 0.9650 - val_loss: 0.1460 - val_accuracy: 0.9429
# Epoch 18/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9650
# Epoch 18: val_loss did not improve from 0.10820
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0847 - accuracy: 0.9650 - val_loss: 0.1087 - val_accuracy: 0.9612
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9663
# Epoch 19: val_loss did not improve from 0.10820
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0858 - accuracy: 0.9663 - val_loss: 0.1289 - val_accuracy: 0.9442
# Epoch 20/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9665
# Epoch 20: val_loss did not improve from 0.10820
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0838 - accuracy: 0.9665 - val_loss: 0.1368 - val_accuracy: 0.9463
# Epoch 21/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9704
# Epoch 21: val_loss did not improve from 0.10820
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0807 - accuracy: 0.9704 - val_loss: 0.1369 - val_accuracy: 0.9483
# Epoch 22/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9694
# Epoch 22: val_loss did not improve from 0.10820
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0742 - accuracy: 0.9694 - val_loss: 0.1829 - val_accuracy: 0.9252
# Epoch 23/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9716
# Epoch 23: val_loss improved from 0.10820 to 0.10567, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 68ms/step - loss: 0.0682 - accuracy: 0.9716 - val_loss: 0.1057 - val_accuracy: 0.9510
# Epoch 24/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9694
# Epoch 24: val_loss did not improve from 0.10567
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0737 - accuracy: 0.9694 - val_loss: 0.2122 - val_accuracy: 0.9238
# Epoch 25/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9723
# Epoch 25: val_loss improved from 0.10567 to 0.09518, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 71ms/step - loss: 0.0740 - accuracy: 0.9723 - val_loss: 0.0952 - val_accuracy: 0.9605
# Epoch 26/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9743
# Epoch 26: val_loss improved from 0.09518 to 0.09462, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0678 - accuracy: 0.9743 - val_loss: 0.0946 - val_accuracy: 0.9578
# Epoch 27/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9738
# Epoch 27: val_loss did not improve from 0.09462
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0671 - accuracy: 0.9738 - val_loss: 0.1133 - val_accuracy: 0.9571
# Epoch 28/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9723
# Epoch 28: val_loss did not improve from 0.09462
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0739 - accuracy: 0.9723 - val_loss: 0.1178 - val_accuracy: 0.9585
# Epoch 29/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9726
# Epoch 29: val_loss did not improve from 0.09462
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0749 - accuracy: 0.9726 - val_loss: 0.1045 - val_accuracy: 0.9646
# Epoch 30/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9735
# Epoch 30: val_loss improved from 0.09462 to 0.07937, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0682 - accuracy: 0.9735 - val_loss: 0.0794 - val_accuracy: 0.9714
# Epoch 31/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9716
# Epoch 31: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0772 - accuracy: 0.9716 - val_loss: 0.0860 - val_accuracy: 0.9653
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9719
# Epoch 32: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0806 - accuracy: 0.9719 - val_loss: 0.1772 - val_accuracy: 0.9218
# Epoch 33/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9711
# Epoch 33: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0808 - accuracy: 0.9711 - val_loss: 0.2537 - val_accuracy: 0.9150
# Epoch 34/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9691
# Epoch 34: val_loss did not improve from 0.07937
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0779 - accuracy: 0.9691 - val_loss: 0.0948 - val_accuracy: 0.9633
# Epoch 35/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9747
# Epoch 35: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0695 - accuracy: 0.9747 - val_loss: 0.1057 - val_accuracy: 0.9571
# Epoch 36/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9730
# Epoch 36: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0630 - accuracy: 0.9730 - val_loss: 0.0980 - val_accuracy: 0.9585
# Epoch 37/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9747
# Epoch 37: val_loss did not improve from 0.07937
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0630 - accuracy: 0.9747 - val_loss: 1.3849 - val_accuracy: 0.7068
# Epoch 38/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9794
# Epoch 38: val_loss improved from 0.07937 to 0.07881, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0534 - accuracy: 0.9794 - val_loss: 0.0788 - val_accuracy: 0.9707
# Epoch 39/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9787
# Epoch 39: val_loss improved from 0.07881 to 0.07086, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0541 - accuracy: 0.9787 - val_loss: 0.0709 - val_accuracy: 0.9667
# Epoch 40/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9782
# Epoch 40: val_loss did not improve from 0.07086
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0543 - accuracy: 0.9782 - val_loss: 0.1417 - val_accuracy: 0.9476
# Epoch 41/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9769
# Epoch 41: val_loss did not improve from 0.07086
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0627 - accuracy: 0.9769 - val_loss: 0.1278 - val_accuracy: 0.9510
# Epoch 42/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9733
# Epoch 42: val_loss did not improve from 0.07086
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0699 - accuracy: 0.9733 - val_loss: 0.0965 - val_accuracy: 0.9612
# Epoch 43/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9748
# Epoch 43: val_loss did not improve from 0.07086
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0623 - accuracy: 0.9748 - val_loss: 0.1081 - val_accuracy: 0.9435
# Epoch 44/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9752
# Epoch 44: val_loss did not improve from 0.07086
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0618 - accuracy: 0.9752 - val_loss: 0.0713 - val_accuracy: 0.9741
# Epoch 45/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9808
# Epoch 45: val_loss improved from 0.07086 to 0.06346, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 67ms/step - loss: 0.0563 - accuracy: 0.9808 - val_loss: 0.0635 - val_accuracy: 0.9755
# Epoch 46/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9731
# Epoch 46: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0821 - accuracy: 0.9731 - val_loss: 0.1102 - val_accuracy: 0.9605
# Epoch 47/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9757
# Epoch 47: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0681 - accuracy: 0.9757 - val_loss: 0.1112 - val_accuracy: 0.9544
# Epoch 48/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9776
# Epoch 48: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0593 - accuracy: 0.9776 - val_loss: 0.1322 - val_accuracy: 0.9490
# Epoch 49/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9760
# Epoch 49: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0564 - accuracy: 0.9760 - val_loss: 0.0779 - val_accuracy: 0.9735
# Epoch 50/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9791
# Epoch 50: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0529 - accuracy: 0.9791 - val_loss: 0.0701 - val_accuracy: 0.9769
# Epoch 51/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9808
# Epoch 51: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0517 - accuracy: 0.9808 - val_loss: 0.0841 - val_accuracy: 0.9707
# Epoch 52/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9796
# Epoch 52: val_loss did not improve from 0.06346
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0511 - accuracy: 0.9796 - val_loss: 0.1125 - val_accuracy: 0.9558
# Epoch 53/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9808
# Epoch 53: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0581 - accuracy: 0.9808 - val_loss: 0.0750 - val_accuracy: 0.9721
# Epoch 54/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9786
# Epoch 54: val_loss did not improve from 0.06346
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0599 - accuracy: 0.9786 - val_loss: 0.1257 - val_accuracy: 0.9558
# Epoch 55/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9813Restoring model weights from the end of the best epoch: 45.
#
# Epoch 55: val_loss did not improve from 0.06346
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0551 - accuracy: 0.9813 - val_loss: 0.0740 - val_accuracy: 0.9673
# Epoch 55: early stopping
#
#
# Validation Loss for Split 5: 0.0635
# Mean Loss for Parameters: 0.01, 64 is 0.0739
# New best parameters found: 0.01, 64
# _________________________________________________________________________
# Testing Parameters: Learning Rate: 0.001, Batch Size: 32
# ____________________________________________________
# Split 1
# ____________________________________________________
# Epoch 1/75
# 184/184 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8990
# Epoch 1: val_loss improved from inf to 4.23599, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 57s 88ms/step - loss: 0.2630 - accuracy: 0.8990 - val_loss: 4.2360 - val_accuracy: 0.4133
# Epoch 2/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9374
# Epoch 2: val_loss improved from 4.23599 to 1.75400, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.1586 - accuracy: 0.9374 - val_loss: 1.7540 - val_accuracy: 0.6050
# Epoch 3/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9437
# Epoch 3: val_loss improved from 1.75400 to 0.17692, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.1284 - accuracy: 0.9437 - val_loss: 0.1769 - val_accuracy: 0.9361
# Epoch 4/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9400
# Epoch 4: val_loss improved from 0.17692 to 0.10525, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.1452 - accuracy: 0.9400 - val_loss: 0.1052 - val_accuracy: 0.9511
# Epoch 5/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9447
# Epoch 5: val_loss did not improve from 0.10525
# 184/184 [==============================] - 10s 56ms/step - loss: 0.1332 - accuracy: 0.9447 - val_loss: 0.2753 - val_accuracy: 0.8640
# Epoch 6/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9476
# Epoch 6: val_loss improved from 0.10525 to 0.08732, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 60ms/step - loss: 0.1180 - accuracy: 0.9476 - val_loss: 0.0873 - val_accuracy: 0.9660
# Epoch 7/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9500
# Epoch 7: val_loss improved from 0.08732 to 0.08287, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.1146 - accuracy: 0.9500 - val_loss: 0.0829 - val_accuracy: 0.9680
# Epoch 8/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9559
# Epoch 8: val_loss improved from 0.08287 to 0.08174, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 58ms/step - loss: 0.1133 - accuracy: 0.9560 - val_loss: 0.0817 - val_accuracy: 0.9646
# Epoch 9/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9544
# Epoch 9: val_loss did not improve from 0.08174
# 184/184 [==============================] - 10s 56ms/step - loss: 0.1120 - accuracy: 0.9544 - val_loss: 0.1222 - val_accuracy: 0.9490
# Epoch 10/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9590
# Epoch 10: val_loss improved from 0.08174 to 0.06728, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0991 - accuracy: 0.9587 - val_loss: 0.0673 - val_accuracy: 0.9755
# Epoch 11/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9541
# Epoch 11: val_loss did not improve from 0.06728
# 184/184 [==============================] - 10s 55ms/step - loss: 0.1135 - accuracy: 0.9541 - val_loss: 0.0808 - val_accuracy: 0.9680
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9587
# Epoch 12: val_loss did not improve from 0.06728
# 184/184 [==============================] - 10s 54ms/step - loss: 0.1008 - accuracy: 0.9583 - val_loss: 0.0893 - val_accuracy: 0.9694
# Epoch 13/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9643
# Epoch 13: val_loss did not improve from 0.06728
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0847 - accuracy: 0.9643 - val_loss: 0.0728 - val_accuracy: 0.9748
# Epoch 14/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9668
# Epoch 14: val_loss improved from 0.06728 to 0.05963, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0825 - accuracy: 0.9668 - val_loss: 0.0596 - val_accuracy: 0.9782
# Epoch 15/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9640
# Epoch 15: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0879 - accuracy: 0.9640 - val_loss: 0.0812 - val_accuracy: 0.9674
# Epoch 16/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9595
# Epoch 16: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0965 - accuracy: 0.9594 - val_loss: 0.1011 - val_accuracy: 0.9619
# Epoch 17/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9701
# Epoch 17: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0719 - accuracy: 0.9701 - val_loss: 0.0665 - val_accuracy: 0.9735
# Epoch 18/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9675
# Epoch 18: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0763 - accuracy: 0.9675 - val_loss: 0.0889 - val_accuracy: 0.9613
# Epoch 19/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9701
# Epoch 19: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0743 - accuracy: 0.9702 - val_loss: 0.0924 - val_accuracy: 0.9599
# Epoch 20/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9689
# Epoch 20: val_loss did not improve from 0.05963
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0776 - accuracy: 0.9689 - val_loss: 0.0660 - val_accuracy: 0.9728
# Epoch 21/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9738
# Epoch 21: val_loss improved from 0.05963 to 0.03897, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 61ms/step - loss: 0.0648 - accuracy: 0.9738 - val_loss: 0.0390 - val_accuracy: 0.9857
# Epoch 22/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9781
# Epoch 22: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0587 - accuracy: 0.9781 - val_loss: 0.1106 - val_accuracy: 0.9565
# Epoch 23/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9740
# Epoch 23: val_loss did not improve from 0.03897
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0691 - accuracy: 0.9740 - val_loss: 0.0707 - val_accuracy: 0.9640
# Epoch 24/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9733
# Epoch 24: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0678 - accuracy: 0.9733 - val_loss: 0.0590 - val_accuracy: 0.9803
# Epoch 25/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9736
# Epoch 25: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0627 - accuracy: 0.9736 - val_loss: 0.1764 - val_accuracy: 0.9300
# Epoch 26/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9770
# Epoch 26: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0568 - accuracy: 0.9770 - val_loss: 0.0614 - val_accuracy: 0.9762
# Epoch 27/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9801
# Epoch 27: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0497 - accuracy: 0.9801 - val_loss: 0.1655 - val_accuracy: 0.9266
# Epoch 28/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9781
# Epoch 28: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0503 - accuracy: 0.9781 - val_loss: 0.0775 - val_accuracy: 0.9653
# Epoch 29/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9786
# Epoch 29: val_loss did not improve from 0.03897
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0550 - accuracy: 0.9786 - val_loss: 0.0673 - val_accuracy: 0.9714
# Epoch 30/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9781
# Epoch 30: val_loss improved from 0.03897 to 0.03805, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 62ms/step - loss: 0.0517 - accuracy: 0.9781 - val_loss: 0.0381 - val_accuracy: 0.9864
# Epoch 31/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9798
# Epoch 31: val_loss did not improve from 0.03805
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0484 - accuracy: 0.9798 - val_loss: 0.0454 - val_accuracy: 0.9816
# Epoch 32/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9803
# Epoch 32: val_loss did not improve from 0.03805
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0544 - accuracy: 0.9803 - val_loss: 0.0410 - val_accuracy: 0.9864
# Epoch 33/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9789
# Epoch 33: val_loss did not improve from 0.03805
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0570 - accuracy: 0.9789 - val_loss: 0.3611 - val_accuracy: 0.8702
# Epoch 34/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0556 - accuracy: 0.9788
# Epoch 34: val_loss did not improve from 0.03805
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0556 - accuracy: 0.9789 - val_loss: 0.0806 - val_accuracy: 0.9674
# Epoch 35/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9831
# Epoch 35: val_loss did not improve from 0.03805
# 184/184 [==============================] - 10s 54ms/step - loss: 0.0480 - accuracy: 0.9830 - val_loss: 0.2051 - val_accuracy: 0.9069
# Epoch 36/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9792
# Epoch 36: val_loss did not improve from 0.03805
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0504 - accuracy: 0.9791 - val_loss: 0.0786 - val_accuracy: 0.9646
# Epoch 37/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9838
# Epoch 37: val_loss improved from 0.03805 to 0.02750, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0418 - accuracy: 0.9838 - val_loss: 0.0275 - val_accuracy: 0.9884
# Epoch 38/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9844
# Epoch 38: val_loss did not improve from 0.02750
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0407 - accuracy: 0.9844 - val_loss: 0.1282 - val_accuracy: 0.9477
# Epoch 39/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9845
# Epoch 39: val_loss did not improve from 0.02750
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0402 - accuracy: 0.9845 - val_loss: 0.0415 - val_accuracy: 0.9837
# Epoch 40/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9840
# Epoch 40: val_loss did not improve from 0.02750
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0417 - accuracy: 0.9840 - val_loss: 0.0327 - val_accuracy: 0.9898
# Epoch 41/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9876
# Epoch 41: val_loss improved from 0.02750 to 0.02525, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 62ms/step - loss: 0.0360 - accuracy: 0.9876 - val_loss: 0.0252 - val_accuracy: 0.9884
# Epoch 42/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9861
# Epoch 42: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0406 - accuracy: 0.9861 - val_loss: 0.1381 - val_accuracy: 0.9531
# Epoch 43/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9845
# Epoch 43: val_loss did not improve from 0.02525
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0428 - accuracy: 0.9845 - val_loss: 0.2135 - val_accuracy: 0.9347
# Epoch 44/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9833
# Epoch 44: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0462 - accuracy: 0.9833 - val_loss: 0.0337 - val_accuracy: 0.9871
# Epoch 45/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9827
# Epoch 45: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0429 - accuracy: 0.9827 - val_loss: 0.1909 - val_accuracy: 0.9368
# Epoch 46/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9867
# Epoch 46: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0342 - accuracy: 0.9867 - val_loss: 0.3473 - val_accuracy: 0.9150
# Epoch 47/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9879
# Epoch 47: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0326 - accuracy: 0.9879 - val_loss: 0.0262 - val_accuracy: 0.9891
# Epoch 48/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9869
# Epoch 48: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0371 - accuracy: 0.9869 - val_loss: 0.1059 - val_accuracy: 0.9613
# Epoch 49/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9845
# Epoch 49: val_loss did not improve from 0.02525
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0355 - accuracy: 0.9845 - val_loss: 0.0587 - val_accuracy: 0.9762
# Epoch 50/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9847
# Epoch 50: val_loss did not improve from 0.02525
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0394 - accuracy: 0.9847 - val_loss: 0.0487 - val_accuracy: 0.9796
# Epoch 51/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9837
# Epoch 51: val_loss improved from 0.02525 to 0.02235, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 62ms/step - loss: 0.0443 - accuracy: 0.9837 - val_loss: 0.0224 - val_accuracy: 0.9905
# Epoch 52/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9845
# Epoch 52: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0373 - accuracy: 0.9845 - val_loss: 0.0555 - val_accuracy: 0.9803
# Epoch 53/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9854
# Epoch 53: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0361 - accuracy: 0.9854 - val_loss: 0.0872 - val_accuracy: 0.9646
# Epoch 54/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9874
# Epoch 54: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0363 - accuracy: 0.9874 - val_loss: 0.1801 - val_accuracy: 0.9388
# Epoch 55/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9889
# Epoch 55: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0291 - accuracy: 0.9889 - val_loss: 0.1927 - val_accuracy: 0.9402
# Epoch 56/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9901
# Epoch 56: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 57ms/step - loss: 0.0275 - accuracy: 0.9901 - val_loss: 0.0240 - val_accuracy: 0.9912
# Epoch 57/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9881
# Epoch 57: val_loss did not improve from 0.02235
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0321 - accuracy: 0.9881 - val_loss: 0.2549 - val_accuracy: 0.9368
# Epoch 58/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9872
# Epoch 58: val_loss did not improve from 0.02235
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0296 - accuracy: 0.9872 - val_loss: 0.0403 - val_accuracy: 0.9857
# Epoch 59/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9888
# Epoch 59: val_loss did not improve from 0.02235
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0362 - accuracy: 0.9888 - val_loss: 0.2131 - val_accuracy: 0.9395
# Epoch 60/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9876
# Epoch 60: val_loss did not improve from 0.02235
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0312 - accuracy: 0.9876 - val_loss: 0.1628 - val_accuracy: 0.9517
# Epoch 61/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9861Restoring model weights from the end of the best epoch: 51.
#
# Epoch 61: val_loss did not improve from 0.02235
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0352 - accuracy: 0.9861 - val_loss: 0.1438 - val_accuracy: 0.9497
# Epoch 61: early stopping
#
#
# Validation Loss for Split 1: 0.0224
# ____________________________________________________
# Split 2
# ____________________________________________________
# Epoch 1/75
# 184/184 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9097
# Epoch 1: val_loss improved from inf to 3.63515, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 54s 84ms/step - loss: 0.2558 - accuracy: 0.9097 - val_loss: 3.6352 - val_accuracy: 0.4562
# Epoch 2/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9394
# Epoch 2: val_loss improved from 3.63515 to 2.04005, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.1461 - accuracy: 0.9395 - val_loss: 2.0400 - val_accuracy: 0.5391
# Epoch 3/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9437
# Epoch 3: val_loss improved from 2.04005 to 0.17429, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.1305 - accuracy: 0.9437 - val_loss: 0.1743 - val_accuracy: 0.9463
# Epoch 4/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1322 - accuracy: 0.9442
# Epoch 4: val_loss improved from 0.17429 to 0.13629, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.1319 - accuracy: 0.9442 - val_loss: 0.1363 - val_accuracy: 0.9463
# Epoch 5/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9456
# Epoch 5: val_loss improved from 0.13629 to 0.12694, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 58ms/step - loss: 0.1335 - accuracy: 0.9456 - val_loss: 0.1269 - val_accuracy: 0.9436
# Epoch 6/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9510
# Epoch 6: val_loss improved from 0.12694 to 0.10455, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 57ms/step - loss: 0.1208 - accuracy: 0.9510 - val_loss: 0.1045 - val_accuracy: 0.9558
# Epoch 7/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9469
# Epoch 7: val_loss did not improve from 0.10455
# 184/184 [==============================] - 10s 55ms/step - loss: 0.1300 - accuracy: 0.9469 - val_loss: 0.1080 - val_accuracy: 0.9517
# Epoch 8/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9611
# Epoch 8: val_loss improved from 0.10455 to 0.09657, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0987 - accuracy: 0.9611 - val_loss: 0.0966 - val_accuracy: 0.9619
# Epoch 9/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9594
# Epoch 9: val_loss did not improve from 0.09657
# 184/184 [==============================] - 10s 54ms/step - loss: 0.0979 - accuracy: 0.9595 - val_loss: 0.1264 - val_accuracy: 0.9456
# Epoch 10/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9599
# Epoch 10: val_loss improved from 0.09657 to 0.09561, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 60ms/step - loss: 0.0975 - accuracy: 0.9599 - val_loss: 0.0956 - val_accuracy: 0.9640
# Epoch 11/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9623
# Epoch 11: val_loss did not improve from 0.09561
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0912 - accuracy: 0.9623 - val_loss: 0.1509 - val_accuracy: 0.9395
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9580
# Epoch 12: val_loss did not improve from 0.09561
# 184/184 [==============================] - 10s 54ms/step - loss: 0.1083 - accuracy: 0.9582 - val_loss: 0.1133 - val_accuracy: 0.9565
# Epoch 13/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9655
# Epoch 13: val_loss improved from 0.09561 to 0.07831, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0895 - accuracy: 0.9655 - val_loss: 0.0783 - val_accuracy: 0.9613
# Epoch 14/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0916 - accuracy: 0.9648
# Epoch 14: val_loss did not improve from 0.07831
# 184/184 [==============================] - 10s 54ms/step - loss: 0.0917 - accuracy: 0.9646 - val_loss: 0.2151 - val_accuracy: 0.9239
# Epoch 15/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9684
# Epoch 15: val_loss improved from 0.07831 to 0.07815, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0838 - accuracy: 0.9684 - val_loss: 0.0781 - val_accuracy: 0.9701
# Epoch 16/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0842 - accuracy: 0.9645
# Epoch 16: val_loss did not improve from 0.07815
# 184/184 [==============================] - 10s 54ms/step - loss: 0.0851 - accuracy: 0.9643 - val_loss: 0.0811 - val_accuracy: 0.9633
# Epoch 17/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9669
# Epoch 17: val_loss improved from 0.07815 to 0.06368, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0768 - accuracy: 0.9670 - val_loss: 0.0637 - val_accuracy: 0.9755
# Epoch 18/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9718
# Epoch 18: val_loss improved from 0.06368 to 0.05925, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0712 - accuracy: 0.9718 - val_loss: 0.0592 - val_accuracy: 0.9796
# Epoch 19/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9750
# Epoch 19: val_loss did not improve from 0.05925
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0651 - accuracy: 0.9750 - val_loss: 0.0628 - val_accuracy: 0.9776
# Epoch 20/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0649 - accuracy: 0.9727
# Epoch 20: val_loss did not improve from 0.05925
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0647 - accuracy: 0.9728 - val_loss: 0.1223 - val_accuracy: 0.9538
# Epoch 21/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9732
# Epoch 21: val_loss improved from 0.05925 to 0.05908, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 61ms/step - loss: 0.0651 - accuracy: 0.9733 - val_loss: 0.0591 - val_accuracy: 0.9782
# Epoch 22/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9716
# Epoch 22: val_loss did not improve from 0.05908
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0744 - accuracy: 0.9716 - val_loss: 0.0669 - val_accuracy: 0.9694
# Epoch 23/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9772
# Epoch 23: val_loss did not improve from 0.05908
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0603 - accuracy: 0.9772 - val_loss: 0.0942 - val_accuracy: 0.9701
# Epoch 24/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9764
# Epoch 24: val_loss did not improve from 0.05908
# 184/184 [==============================] - 10s 54ms/step - loss: 0.0633 - accuracy: 0.9764 - val_loss: 0.0718 - val_accuracy: 0.9728
# Epoch 25/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9794
# Epoch 25: val_loss improved from 0.05908 to 0.05293, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0501 - accuracy: 0.9794 - val_loss: 0.0529 - val_accuracy: 0.9837
# Epoch 26/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0542 - accuracy: 0.9790
# Epoch 26: val_loss did not improve from 0.05293
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0545 - accuracy: 0.9789 - val_loss: 0.0957 - val_accuracy: 0.9619
# Epoch 27/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0482 - accuracy: 0.9800
# Epoch 27: val_loss improved from 0.05293 to 0.05193, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 11s 60ms/step - loss: 0.0481 - accuracy: 0.9801 - val_loss: 0.0519 - val_accuracy: 0.9769
# Epoch 28/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9782
# ...
# 92/92 [==============================] - 6s 67ms/step - loss: 0.0987 - accuracy: 0.9561 - val_loss: 0.0790 - val_accuracy: 0.9619
# Epoch 25/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9602
# Epoch 25: val_loss improved from 0.07896 to 0.07822, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 69ms/step - loss: 0.0932 - accuracy: 0.9602 - val_loss: 0.0782 - val_accuracy: 0.9646
# Epoch 26/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9633
# Epoch 26: val_loss improved from 0.07822 to 0.07275, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 68ms/step - loss: 0.0883 - accuracy: 0.9633 - val_loss: 0.0727 - val_accuracy: 0.9680
# Epoch 27/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9638
# Epoch 27: val_loss did not improve from 0.07275
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0906 - accuracy: 0.9638 - val_loss: 0.0780 - val_accuracy: 0.9660
# Epoch 28/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9629
# Epoch 28: val_loss did not improve from 0.07275
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0895 - accuracy: 0.9629 - val_loss: 0.0767 - val_accuracy: 0.9680
# Epoch 29/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9619
# Epoch 29: val_loss did not improve from 0.07275
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0878 - accuracy: 0.9619 - val_loss: 0.0785 - val_accuracy: 0.9667
# Epoch 30/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9646
# Epoch 30: val_loss improved from 0.07275 to 0.06794, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 69ms/step - loss: 0.0829 - accuracy: 0.9646 - val_loss: 0.0679 - val_accuracy: 0.9707
# Epoch 31/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9629
# Epoch 31: val_loss did not improve from 0.06794
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0851 - accuracy: 0.9629 - val_loss: 0.0689 - val_accuracy: 0.9755
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9650
# Epoch 32: val_loss did not improve from 0.06794
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0801 - accuracy: 0.9650 - val_loss: 0.0730 - val_accuracy: 0.9701
# Epoch 33/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9658
# Epoch 33: val_loss did not improve from 0.06794
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0782 - accuracy: 0.9658 - val_loss: 0.0722 - val_accuracy: 0.9687
# Epoch 34/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9640
# Epoch 34: val_loss improved from 0.06794 to 0.06547, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 7s 72ms/step - loss: 0.0842 - accuracy: 0.9640 - val_loss: 0.0655 - val_accuracy: 0.9701
# Epoch 35/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9653
# Epoch 35: val_loss did not improve from 0.06547
# 92/92 [==============================] - 6s 64ms/step - loss: 0.0812 - accuracy: 0.9653 - val_loss: 0.0670 - val_accuracy: 0.9687
# Epoch 36/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9657
# Epoch 36: val_loss did not improve from 0.06547
# 92/92 [==============================] - 6s 64ms/step - loss: 0.0785 - accuracy: 0.9657 - val_loss: 0.0733 - val_accuracy: 0.9653
# Epoch 37/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9668
# Epoch 37: val_loss did not improve from 0.06547
# 92/92 [==============================] - 6s 64ms/step - loss: 0.0784 - accuracy: 0.9668 - val_loss: 0.0670 - val_accuracy: 0.9714
# Epoch 38/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9682
# Epoch 38: val_loss improved from 0.06547 to 0.06177, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0725 - accuracy: 0.9682 - val_loss: 0.0618 - val_accuracy: 0.9687
# Epoch 39/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9685
# Epoch 39: val_loss did not improve from 0.06177
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0714 - accuracy: 0.9685 - val_loss: 0.0630 - val_accuracy: 0.9707
# Epoch 40/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9702
# Epoch 40: val_loss did not improve from 0.06177
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0723 - accuracy: 0.9702 - val_loss: 0.0624 - val_accuracy: 0.9728
# Epoch 41/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9668
# Epoch 41: val_loss improved from 0.06177 to 0.05990, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0766 - accuracy: 0.9668 - val_loss: 0.0599 - val_accuracy: 0.9707
# Epoch 42/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9687
# Epoch 42: val_loss improved from 0.05990 to 0.05778, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 64ms/step - loss: 0.0711 - accuracy: 0.9687 - val_loss: 0.0578 - val_accuracy: 0.9741
# Epoch 43/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9685
# Epoch 43: val_loss improved from 0.05778 to 0.05569, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0701 - accuracy: 0.9685 - val_loss: 0.0557 - val_accuracy: 0.9735
# Epoch 44/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9697
# Epoch 44: val_loss did not improve from 0.05569
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0704 - accuracy: 0.9697 - val_loss: 0.0583 - val_accuracy: 0.9748
# Epoch 45/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9730
# Epoch 45: val_loss did not improve from 0.05569
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0648 - accuracy: 0.9730 - val_loss: 0.0674 - val_accuracy: 0.9721
# Epoch 46/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9719
# Epoch 46: val_loss did not improve from 0.05569
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0709 - accuracy: 0.9719 - val_loss: 0.0639 - val_accuracy: 0.9735
# Epoch 47/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9684
# Epoch 47: val_loss did not improve from 0.05569
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0709 - accuracy: 0.9684 - val_loss: 0.0561 - val_accuracy: 0.9741
# Epoch 48/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9736
# Epoch 48: val_loss improved from 0.05569 to 0.05468, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 7s 73ms/step - loss: 0.0682 - accuracy: 0.9736 - val_loss: 0.0547 - val_accuracy: 0.9728
# Epoch 49/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9704
# Epoch 49: val_loss improved from 0.05468 to 0.05447, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 67ms/step - loss: 0.0660 - accuracy: 0.9704 - val_loss: 0.0545 - val_accuracy: 0.9762
# Epoch 50/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9735
# Epoch 50: val_loss did not improve from 0.05447
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0670 - accuracy: 0.9735 - val_loss: 0.0566 - val_accuracy: 0.9721
# Epoch 51/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9733
# Epoch 51: val_loss did not improve from 0.05447
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0637 - accuracy: 0.9733 - val_loss: 0.0553 - val_accuracy: 0.9762
# Epoch 52/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9725
# Epoch 52: val_loss did not improve from 0.05447
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0652 - accuracy: 0.9725 - val_loss: 0.0592 - val_accuracy: 0.9728
# Epoch 53/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9735
# Epoch 53: val_loss improved from 0.05447 to 0.05340, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 70ms/step - loss: 0.0631 - accuracy: 0.9735 - val_loss: 0.0534 - val_accuracy: 0.9755
# Epoch 54/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9716
# Epoch 54: val_loss did not improve from 0.05340
# 92/92 [==============================] - 5s 60ms/step - loss: 0.0696 - accuracy: 0.9716 - val_loss: 0.0553 - val_accuracy: 0.9748
# Epoch 55/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9721
# Epoch 55: val_loss did not improve from 0.05340
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0674 - accuracy: 0.9721 - val_loss: 0.0536 - val_accuracy: 0.9789
# Epoch 56/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0609 - accuracy: 0.9754
# Epoch 56: val_loss did not improve from 0.05340
# 92/92 [==============================] - 5s 55ms/step - loss: 0.0614 - accuracy: 0.9752 - val_loss: 0.0554 - val_accuracy: 0.9776
# Epoch 57/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9747
# Epoch 57: val_loss improved from 0.05340 to 0.05226, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0580 - accuracy: 0.9747 - val_loss: 0.0523 - val_accuracy: 0.9789
# Epoch 58/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9733
# Epoch 58: val_loss did not improve from 0.05226
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0594 - accuracy: 0.9733 - val_loss: 0.0597 - val_accuracy: 0.9714
# Epoch 59/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9772
# Epoch 59: val_loss did not improve from 0.05226
# 92/92 [==============================] - 5s 60ms/step - loss: 0.0529 - accuracy: 0.9772 - val_loss: 0.0670 - val_accuracy: 0.9694
# Epoch 60/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9774
# Epoch 60: val_loss improved from 0.05226 to 0.04620, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0564 - accuracy: 0.9774 - val_loss: 0.0462 - val_accuracy: 0.9789
# Epoch 61/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9760
# Epoch 61: val_loss improved from 0.04620 to 0.04394, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0568 - accuracy: 0.9760 - val_loss: 0.0439 - val_accuracy: 0.9803
# Epoch 62/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9762
# Epoch 62: val_loss did not improve from 0.04394
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0582 - accuracy: 0.9762 - val_loss: 0.0449 - val_accuracy: 0.9803
# Epoch 63/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9721
# Epoch 63: val_loss did not improve from 0.04394
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0602 - accuracy: 0.9721 - val_loss: 0.0484 - val_accuracy: 0.9789
# Epoch 64/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9730
# Epoch 64: val_loss did not improve from 0.04394
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0589 - accuracy: 0.9730 - val_loss: 0.0476 - val_accuracy: 0.9803
# Epoch 65/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9753
# Epoch 65: val_loss did not improve from 0.04394
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0573 - accuracy: 0.9753 - val_loss: 0.0533 - val_accuracy: 0.9789
# Epoch 66/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0556 - accuracy: 0.9758
# Epoch 66: val_loss did not improve from 0.04394
# 92/92 [==============================] - 5s 56ms/step - loss: 0.0554 - accuracy: 0.9760 - val_loss: 0.0522 - val_accuracy: 0.9762
# Epoch 67/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9735
# Epoch 67: val_loss improved from 0.04394 to 0.04319, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 66ms/step - loss: 0.0613 - accuracy: 0.9735 - val_loss: 0.0432 - val_accuracy: 0.9803
# Epoch 68/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9759
# Epoch 68: val_loss did not improve from 0.04319
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0565 - accuracy: 0.9759 - val_loss: 0.0471 - val_accuracy: 0.9796
# Epoch 69/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9760
# Epoch 69: val_loss did not improve from 0.04319
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0551 - accuracy: 0.9760 - val_loss: 0.0446 - val_accuracy: 0.9796
# Epoch 70/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0547 - accuracy: 0.9763
# Epoch 70: val_loss did not improve from 0.04319
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0548 - accuracy: 0.9764 - val_loss: 0.0503 - val_accuracy: 0.9769
# Epoch 71/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9755
# Epoch 71: val_loss did not improve from 0.04319
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0542 - accuracy: 0.9755 - val_loss: 0.0435 - val_accuracy: 0.9850
# Epoch 72/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0529 - accuracy: 0.9770
# Epoch 72: val_loss improved from 0.04319 to 0.04308, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 92/92 [==============================] - 6s 63ms/step - loss: 0.0525 - accuracy: 0.9772 - val_loss: 0.0431 - val_accuracy: 0.9796
# Epoch 73/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9803
# Epoch 73: val_loss did not improve from 0.04308
# 92/92 [==============================] - 5s 53ms/step - loss: 0.0514 - accuracy: 0.9799 - val_loss: 0.0579 - val_accuracy: 0.9735
# Epoch 74/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9787
# Epoch 74: val_loss did not improve from 0.04308
# 92/92 [==============================] - 5s 53ms/step - loss: 0.0532 - accuracy: 0.9787 - val_loss: 0.0562 - val_accuracy: 0.9735
# Epoch 75/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9787
# Epoch 75: val_loss did not improve from 0.04308
# 92/92 [==============================] - 5s 55ms/step - loss: 0.0494 - accuracy: 0.9787 - val_loss: 0.0442 - val_accuracy: 0.9810
#
#
# Validation Loss for Split 5: 0.0442
# Mean Loss for Parameters: 0.0001, 64 is 0.0486
#
# Best Overall Parameters: [(0.001, 32)], with a loss of 0.0342

# %% [markdown]
# # **Now we train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 32
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_body_acc_train, x_gro_train, x_total_acc_train], axis=-1),
    y_train,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = ResBLSTMAttentionModel(learning_rate=best_params['learning_rate'],
                               batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
    X=[
        x_train_final[:, :, :3],  # Original body acceleration data for the final model
        x_train_final[:, :, 3:6],  # Original body gyro data for the final model
        x_train_final[:, :, 6:],  # Original total acceleration data for the final model
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],  # Original validation body acceleration data
            x_val_final[:, :, 3:6],  # Original validation body gyro data
            x_val_final[:, :, 6:],  # Original validation total acceleration data
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_body_acc_test,
                                                      x_gro_test,
                                                      x_total_acc_test],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_body_acc_test,
                                   x_gro_test,
                                   x_total_acc_test])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)


# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)

# Print model summary
best_model.model.summary()
total_params = best_model.model.count_params()
print("Total parameters:", total_params)

# Print evaluation metrics
average_accuracy = np.mean(history.history['accuracy'])
best_accuracy = np.max(history.history['accuracy'])
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'],
                  index=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

# Assuming 'conf_matrix' is your confusion matrix from your model's predictions
TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 184/184 [==============================] - ETA: 0s - loss: 0.2531 - accuracy: 0.9068
# Epoch 1: val_accuracy improved from -inf to 0.25357, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 53s 80ms/step - loss: 0.2531 - accuracy: 0.9068 - val_loss: 4.3534 - val_accuracy: 0.2536
# Epoch 2/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9379
# Epoch 2: val_accuracy improved from 0.25357 to 0.69545, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 57ms/step - loss: 0.1632 - accuracy: 0.9379 - val_loss: 1.4045 - val_accuracy: 0.6954
# Epoch 3/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1392 - accuracy: 0.9416
# Epoch 3: val_accuracy improved from 0.69545 to 0.91978, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 55ms/step - loss: 0.1403 - accuracy: 0.9413 - val_loss: 0.2059 - val_accuracy: 0.9198
# Epoch 4/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9449
# Epoch 4: val_accuracy did not improve from 0.91978
# 184/184 [==============================] - 10s 52ms/step - loss: 0.1294 - accuracy: 0.9449 - val_loss: 0.2383 - val_accuracy: 0.8899
# Epoch 5/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9468
# Epoch 5: val_accuracy improved from 0.91978 to 0.95853, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 56ms/step - loss: 0.1332 - accuracy: 0.9468 - val_loss: 0.1042 - val_accuracy: 0.9585
# Epoch 6/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9408
# Epoch 6: val_accuracy improved from 0.95853 to 0.96057, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 53ms/step - loss: 0.1401 - accuracy: 0.9408 - val_loss: 0.0938 - val_accuracy: 0.9606
# Epoch 7/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1094 - accuracy: 0.9539
# Epoch 7: val_accuracy did not improve from 0.96057
# 184/184 [==============================] - 10s 52ms/step - loss: 0.1092 - accuracy: 0.9541 - val_loss: 0.0867 - val_accuracy: 0.9545
# Epoch 8/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9536
# Epoch 8: val_accuracy did not improve from 0.96057
# 184/184 [==============================] - 9s 51ms/step - loss: 0.1115 - accuracy: 0.9534 - val_loss: 0.1052 - val_accuracy: 0.9538
# Epoch 9/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9546
# Epoch 9: val_accuracy did not improve from 0.96057
# 184/184 [==============================] - 10s 53ms/step - loss: 0.1166 - accuracy: 0.9543 - val_loss: 0.1030 - val_accuracy: 0.9456
# Epoch 10/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9561
# Epoch 10: val_accuracy did not improve from 0.96057
# 184/184 [==============================] - 10s 55ms/step - loss: 0.1044 - accuracy: 0.9560 - val_loss: 0.1076 - val_accuracy: 0.9538
# Epoch 11/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9612
# Epoch 11: val_accuracy improved from 0.96057 to 0.97961, saving model to /content/drive/MyDrive/WithCV/Hyperparameter-Tuning/UCI-CNN-ResLSTM-Attention.hdf5
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0931 - accuracy: 0.9612 - val_loss: 0.0585 - val_accuracy: 0.9796
# Epoch 12/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9634
# Epoch 12: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 53ms/step - loss: 0.0855 - accuracy: 0.9634 - val_loss: 0.0736 - val_accuracy: 0.9742
# Epoch 13/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0968 - accuracy: 0.9612
# Epoch 13: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 11s 58ms/step - loss: 0.0972 - accuracy: 0.9611 - val_loss: 0.0668 - val_accuracy: 0.9728
# Epoch 14/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9609
# Epoch 14: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0898 - accuracy: 0.9609 - val_loss: 0.1169 - val_accuracy: 0.9592
# Epoch 15/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9681
# Epoch 15: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0761 - accuracy: 0.9682 - val_loss: 0.0619 - val_accuracy: 0.9789
# Epoch 16/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9674
# Epoch 16: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0770 - accuracy: 0.9675 - val_loss: 0.0889 - val_accuracy: 0.9667
# Epoch 17/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9655
# Epoch 17: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0862 - accuracy: 0.9655 - val_loss: 0.0567 - val_accuracy: 0.9748
# Epoch 18/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9714
# Epoch 18: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 55ms/step - loss: 0.0715 - accuracy: 0.9714 - val_loss: 0.0590 - val_accuracy: 0.9782
# Epoch 19/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9702
# Epoch 19: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 57ms/step - loss: 0.0688 - accuracy: 0.9702 - val_loss: 0.0564 - val_accuracy: 0.9748
# Epoch 20/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0632 - accuracy: 0.9735
# Epoch 20: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 11s 59ms/step - loss: 0.0635 - accuracy: 0.9733 - val_loss: 0.0598 - val_accuracy: 0.9755
# Epoch 21/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9728Restoring model weights from the end of the best epoch: 11.
#
# Epoch 21: val_accuracy did not improve from 0.97961
# 184/184 [==============================] - 10s 56ms/step - loss: 0.0672 - accuracy: 0.9728 - val_loss: 0.0651 - val_accuracy: 0.9789
# Epoch 21: early stopping
# 93/93 [==============================] - 6s 14ms/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 128, 3)]     0           []
#
#  input_8 (InputLayer)           [(None, 128, 3)]     0           []
#
#  input_9 (InputLayer)           [(None, 128, 3)]     0           []
#
#  conv1d_24 (Conv1D)             (None, 128, 256)     2560        ['input_7[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 128, 256)     2560        ['input_8[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 128, 256)     2560        ['input_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 128, 256)    1024        ['conv1d_24[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 128, 256)    1024        ['conv1d_28[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 128, 256)    1024        ['conv1d_32[0][0]']
#  ormalization)
#
#  max_pooling1d_24 (MaxPooling1D  (None, 64, 256)     0           ['batch_normalization_24[0][0]']
#  )
#
#  max_pooling1d_28 (MaxPooling1D  (None, 64, 256)     0           ['batch_normalization_28[0][0]']
#  )
#
#  max_pooling1d_32 (MaxPooling1D  (None, 64, 256)     0           ['batch_normalization_32[0][0]']
#  )
#
#  dropout_26 (Dropout)           (None, 64, 256)      0           ['max_pooling1d_24[0][0]']
#
#  dropout_30 (Dropout)           (None, 64, 256)      0           ['max_pooling1d_28[0][0]']
#
#  dropout_34 (Dropout)           (None, 64, 256)      0           ['max_pooling1d_32[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 64, 128)      98432       ['dropout_26[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 64, 128)      98432       ['dropout_30[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 64, 128)      98432       ['dropout_34[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 128)     512         ['conv1d_25[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 64, 128)     512         ['conv1d_29[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 64, 128)     512         ['conv1d_33[0][0]']
#  ormalization)
#
#  max_pooling1d_25 (MaxPooling1D  (None, 32, 128)     0           ['batch_normalization_25[0][0]']
#  )
#
#  max_pooling1d_29 (MaxPooling1D  (None, 32, 128)     0           ['batch_normalization_29[0][0]']
#  )
#
#  max_pooling1d_33 (MaxPooling1D  (None, 32, 128)     0           ['batch_normalization_33[0][0]']
#  )
#
#  dropout_27 (Dropout)           (None, 32, 128)      0           ['max_pooling1d_25[0][0]']
#
#  dropout_31 (Dropout)           (None, 32, 128)      0           ['max_pooling1d_29[0][0]']
#
#  dropout_35 (Dropout)           (None, 32, 128)      0           ['max_pooling1d_33[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 32, 64)       24640       ['dropout_27[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 32, 64)       24640       ['dropout_31[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 32, 64)       24640       ['dropout_35[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 64)      256         ['conv1d_26[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 32, 64)      256         ['conv1d_30[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 32, 64)      256         ['conv1d_34[0][0]']
#  ormalization)
#
#  max_pooling1d_26 (MaxPooling1D  (None, 16, 64)      0           ['batch_normalization_26[0][0]']
#  )
#
#  max_pooling1d_30 (MaxPooling1D  (None, 16, 64)      0           ['batch_normalization_30[0][0]']
#  )
#
#  max_pooling1d_34 (MaxPooling1D  (None, 16, 64)      0           ['batch_normalization_34[0][0]']
#  )
#
#  dropout_28 (Dropout)           (None, 16, 64)       0           ['max_pooling1d_26[0][0]']
#
#  dropout_32 (Dropout)           (None, 16, 64)       0           ['max_pooling1d_30[0][0]']
#
#  dropout_36 (Dropout)           (None, 16, 64)       0           ['max_pooling1d_34[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 16, 32)       6176        ['dropout_28[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 16, 32)       6176        ['dropout_32[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 16, 32)       6176        ['dropout_36[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 32)      128         ['conv1d_27[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 16, 32)      128         ['conv1d_31[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 16, 32)      128         ['conv1d_35[0][0]']
#  ormalization)
#
#  max_pooling1d_27 (MaxPooling1D  (None, 8, 32)       0           ['batch_normalization_27[0][0]']
#  )
#
#  max_pooling1d_31 (MaxPooling1D  (None, 8, 32)       0           ['batch_normalization_31[0][0]']
#  )
#
#  max_pooling1d_35 (MaxPooling1D  (None, 8, 32)       0           ['batch_normalization_35[0][0]']
#  )
#
#  dropout_29 (Dropout)           (None, 8, 32)        0           ['max_pooling1d_27[0][0]']
#
#  dropout_33 (Dropout)           (None, 8, 32)        0           ['max_pooling1d_31[0][0]']
#
#  dropout_37 (Dropout)           (None, 8, 32)        0           ['max_pooling1d_35[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 8, 32)       64          ['dropout_29[0][0]']
#  ormalization)
#
#  layer_normalization_14 (LayerN  (None, 8, 32)       64          ['dropout_33[0][0]']
#  ormalization)
#
#  layer_normalization_16 (LayerN  (None, 8, 32)       64          ['dropout_37[0][0]']
#  ormalization)
#
#  bidirectional_12 (Bidirectiona  (None, 8, 128)      49664       ['layer_normalization_12[0][0]']
#  l)
#
#  bidirectional_14 (Bidirectiona  (None, 8, 128)      49664       ['layer_normalization_14[0][0]']
#  l)
#
#  bidirectional_16 (Bidirectiona  (None, 8, 128)      49664       ['layer_normalization_16[0][0]']
#  l)
#
#  layer_normalization_13 (LayerN  (None, 8, 128)      256         ['bidirectional_12[0][0]']
#  ormalization)
#
#  layer_normalization_15 (LayerN  (None, 8, 128)      256         ['bidirectional_14[0][0]']
#  ormalization)
#
#  layer_normalization_17 (LayerN  (None, 8, 128)      256         ['bidirectional_16[0][0]']
#  ormalization)
#
#  bidirectional_13 (Bidirectiona  (None, 8, 128)      98816       ['layer_normalization_13[0][0]']
#  l)
#
#  bidirectional_15 (Bidirectiona  (None, 8, 128)      98816       ['layer_normalization_15[0][0]']
#  l)
#
#  bidirectional_17 (Bidirectiona  (None, 8, 128)      98816       ['layer_normalization_17[0][0]']
#  l)
#
#  add_6 (Add)                    (None, 8, 128)       0           ['bidirectional_12[0][0]',
#                                                                   'bidirectional_13[0][0]']
#
#  add_7 (Add)                    (None, 8, 128)       0           ['bidirectional_14[0][0]',
#                                                                   'bidirectional_15[0][0]']
#
#  add_8 (Add)                    (None, 8, 128)       0           ['bidirectional_16[0][0]',
#                                                                   'bidirectional_17[0][0]']
#
#  attention_6 (Attention)        (None, 128)          136         ['add_6[0][0]']
#
#  attention_7 (Attention)        (None, 128)          136         ['add_7[0][0]']
#
#  attention_8 (Attention)        (None, 128)          136         ['add_8[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 384)          0           ['attention_6[0][0]',
#                                                                   'attention_7[0][0]',
#                                                                   'attention_8[0][0]']
#
#  dropout_38 (Dropout)           (None, 384)          0           ['concatenate_2[0][0]']
#
#  dense_2 (Dense)                (None, 6)            2310        ['dropout_38[0][0]']
#
#  softmax (Activation)           (None, 6)            0           ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 850,302
# Trainable params: 847,422
# Non-trainable params: 2,880
# __________________________________________________________________________________________________
# Total parameters: 850302
# Test Accuracy: 0.9532
# Average Accuracy: 0.9558060254369464
# Best Accuracy: 0.9733038544654846
# Last Epoch Accuracy: 0.9727937579154968
# Micro Accuracy: 0.9532
# Macro Accuracy: 0.9529
# Weighted Accuracy: 0.9532
# Precision (Macro): 0.9570310000828561
# Precision (Weighted): 0.9552258434216693
# Precision (Micro): 0.9531727180183237
# Recall (Macro): 0.9528907556726774
# Recall (Weighted): 0.9531727180183237
# Recall (Micro): 0.9531727180183237
# F1 Score (Macro): 0.9537472332038283
# F1 Score (Weighted): 0.9529660772402072
# F1 Score (Micro): 0.9531727180183237
# Population Std Dev - True Labels: 1.7400526830680672
# Population Std Dev - Predicted Labels: 1.7608423629236514
# Sample Std Dev - True Labels: 1.7403479826345662
# Sample Std Dev - Predicted Labels: 1.7611411906496761
# _______________________________________________________________
# Metrics for WALKING:
#   True Positives (TP): 496
#   True Negatives (TN): 2419
#   False Positives (FP): 32
#   False Negatives (FN): 0
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 430
#   True Negatives (TN): 2476
#   False Positives (FP): 0
#   False Negatives (FN): 41
#
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 417
#   True Negatives (TN): 2526
#   False Positives (FP): 1
#   False Negatives (FN): 3
#
# Metrics for SITTING:
#   True Positives (TP): 416
#   True Negatives (TN): 2426
#   False Positives (FP): 30
#   False Negatives (FN): 75
#
# Metrics for STANDING:
#   True Positives (TP): 513
#   True Negatives (TN): 2340
#   False Positives (FP): 75
#   False Negatives (FN): 19
#
# Metrics for LAYING:
#   True Positives (TP): 537
#   True Negatives (TN): 2410
#   False Positives (FP): 0
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 21:01:56
# Elapsed time: 414.35157108306885 seconds
