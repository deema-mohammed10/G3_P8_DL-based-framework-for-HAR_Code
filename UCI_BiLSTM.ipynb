# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import The Needed Library**

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')

from keras.layers import LeakyReLU
# Out:
# Timer started at 2024-06-03 16:09:04

# %% [markdown]
# # **Load the UCI-HAR Dataset**

# %%
root_train = '/content/drive/MyDrive/UCIHARDataset/train/train_Inertial_Signals'
root_test = '/content/drive/MyDrive/UCIHARDataset/test/test_Inertial_Signals'
model_save_path = '/content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5'

def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
        return files

file_x_train =  ['body_acc_x_train.txt', 'body_acc_y_train.txt', 'body_acc_z_train.txt',
                'body_gyro_x_train.txt', 'body_gyro_y_train.txt', 'body_gyro_z_train.txt',
                'total_acc_x_train.txt', 'total_acc_y_train.txt', 'total_acc_z_train.txt']
file_x_test = ['body_acc_x_test.txt', 'body_acc_y_test.txt', 'body_acc_z_test.txt',
               'body_gyro_x_test.txt', 'body_gyro_y_test.txt', 'body_gyro_z_test.txt',
               'total_acc_x_test.txt', 'total_acc_y_test.txt', 'total_acc_z_test.txt']

file_y_train = '/content/drive/MyDrive/UCIHARDataset/train/y_train.txt'
file_y_test = '/content/drive/MyDrive/UCIHARDataset/test/y_test.txt'

def load_x(data, root):
    x_body_acc = []
    for file in data[0:3]:
        x_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_body_acc.append(x_acc_input)
    x_body_acc = np.transpose(np.array(x_body_acc), (1, 2, 0))

    x_gro = []
    for file in data[3:6]:
        x_gro_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_gro.append(x_gro_input)
    x_gro = np.transpose(np.array(x_gro), (1, 2, 0))

    x_total_acc = []
    for file in data[6:9]:
        x_total_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_total_acc.append(x_total_acc_input)
    x_total_acc = np.transpose(np.array(x_total_acc), (1, 2, 0))
    return x_body_acc, x_gro, x_total_acc

def load_y(data):
    file = open(data, 'r')
    y_input = np.array([elem for elem in [row.strip().split(' ') for row in file]], dtype=np.int32)
    file.close()
    return to_categorical(y_input - 1.0)

x_body_acc_train, x_gro_train, x_total_acc_train = load_x(file_x_train, root_train)
x_body_acc_test, x_gro_test, x_total_acc_test = load_x(file_x_test, root_test)
y_train = load_y(file_y_train)
y_test = load_y(file_y_test)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class BLSTMAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def BLSTM_Attention(self, input):
        model = Conv1D(256, 3, input_shape=(128, 3), activation=LeakyReLU(alpha=0.3), padding='same')(input)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//2, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//4, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//8, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)


        model = LayerNormalization()(model)

        x = Bidirectional(LSTM(64, return_sequences=True))(model)
        model = Bidirectional(LSTM(64, return_sequences=True))(x)

        output = Attention(8)(model)
        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1 = Input(shape=(128, 3))
        input_2 = Input(shape=(128, 3))
        input_3 = Input(shape=(128, 3))

        model1 = self.BLSTM_Attention(input_1)
        model2 = self.BLSTM_Attention(input_2)
        model3 = self.BLSTM_Attention(input_3)


        concatenated_models = Concatenate()([model1, model2, model3])

        output = Dropout(0.2)(concatenated_models)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)

        self.model = Model(inputs=[input_1, input_2, input_3], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )


    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
          callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)


        return history

    def fit2(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history

    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Use 5-Fold GridSearchCV to test different combinations of the parameters**

# %%
param_grid = {
   'learning_rate': [ 0.01, 0.001, 0.0001],
    'batch_size': [32, 64]
}
param_combinations = [(lr, bs) for lr in param_grid['learning_rate'] for bs in param_grid['batch_size']]

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

best_loss = float('inf')
best_params_list = []


for lr, bs in param_combinations:
    print(f"_________________________________________________________________________\nTesting Parameters: Learning Rate: {lr}, Batch Size: {bs}")

    fold_losses = []

    # Perform cross-validation
    for split, (train_index, val_index) in enumerate(kf.split(x_body_acc_train), 1):
        print(f"____________________________________________________\nSplit {split}\n____________________________________________________")

        # Create an instance of BLSTMAttentionModel with the specified hyperparameters
        model = BLSTMAttentionModel(learning_rate=lr, batch_size=bs)

        # Split data into training and validation sets for each sensor type
        x_body_acc_train_fold = x_body_acc_train[train_index]
        x_body_acc_val_fold = x_body_acc_train[val_index]

        x_gro_train_fold = x_gro_train[train_index]
        x_gro_val_fold = x_gro_train[val_index]

        x_total_acc_train_fold = x_total_acc_train[train_index]
        x_total_acc_val_fold = x_total_acc_train[val_index]

        y_train_fold = y_train[train_index]
        y_val_fold = y_train[val_index]

        validation_data = (
        [x_body_acc_val_fold,
         x_gro_val_fold,
         x_total_acc_val_fold],
         y_val_fold)


        # Fit the model to the training data for this fold with validation data
        history = model.fit(
         [x_body_acc_train_fold,
         x_gro_train_fold,
         x_total_acc_train_fold],
         y_train_fold,learning_rate=lr, batch_size=bs, epochs=75, validation_data=validation_data, early_stopping=True)

        # Evaluate the model on the validation data directly
        val_loss, val_accuracy = model.model.evaluate(
            [x_body_acc_val_fold,
             x_gro_val_fold,
             x_total_acc_val_fold],
            y_val_fold, verbose=0
        )

        fold_losses.append(val_loss)


        print(f"\n\nValidation Loss for Split {split}: {val_loss:.4f}")

    mean_loss = np.mean(fold_losses)
    print(f"Mean Loss for Parameters: {lr}, {bs} is {mean_loss:.4f}")

    if mean_loss < best_loss:
        best_loss = mean_loss
        best_params_list = [(lr, bs)]
        print(f"New best parameters found: {lr}, {bs}")

print(f"\nBest Overall Parameters: {best_params_list}, with a loss of {best_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 183/184 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9484
# Epoch 19: val_loss did not improve from 0.07926
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1321 - accuracy: 0.9483 - val_loss: 0.1146 - val_accuracy: 0.9626
# Epoch 20/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9544
# Epoch 20: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1198 - accuracy: 0.9546 - val_loss: 0.1247 - val_accuracy: 0.9544
# Epoch 21/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9568
# Epoch 21: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1085 - accuracy: 0.9570 - val_loss: 0.0847 - val_accuracy: 0.9701
# Epoch 22/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9609
# Epoch 22: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1004 - accuracy: 0.9609 - val_loss: 0.0936 - val_accuracy: 0.9592
# Epoch 23/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9506
# Epoch 23: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1295 - accuracy: 0.9502 - val_loss: 0.1003 - val_accuracy: 0.9592
# Epoch 24/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9524
# Epoch 24: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1262 - accuracy: 0.9522 - val_loss: 0.1706 - val_accuracy: 0.9497
# Epoch 25/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9559Restoring model weights from the end of the best epoch: 15.
#
# Epoch 25: val_loss did not improve from 0.07926
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1180 - accuracy: 0.9558 - val_loss: 0.0936 - val_accuracy: 0.9639
# Epoch 25: early stopping
#
#
# Validation Loss for Split 5: 0.0793
# Mean Loss for Parameters: 0.01, 32 is 0.0914
# New best parameters found: 0.01, 32
# _________________________________________________________________________
# Testing Parameters: Learning Rate: 0.01, Batch Size: 64
# ____________________________________________________
# Split 1
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8614
# Epoch 1: val_loss improved from inf to 1.51406, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 45s 120ms/step - loss: 0.3711 - accuracy: 0.8614 - val_loss: 1.5141 - val_accuracy: 0.6866
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1560 - accuracy: 0.9404
# Epoch 2: val_loss improved from 1.51406 to 0.76686, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1561 - accuracy: 0.9403 - val_loss: 0.7669 - val_accuracy: 0.7961
# Epoch 3/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9404
# Epoch 3: val_loss improved from 0.76686 to 0.34339, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1432 - accuracy: 0.9396 - val_loss: 0.3434 - val_accuracy: 0.8627
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1459 - accuracy: 0.9408
# Epoch 4: val_loss did not improve from 0.34339
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1455 - accuracy: 0.9408 - val_loss: 0.5991 - val_accuracy: 0.8158
# Epoch 5/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9454
# Epoch 5: val_loss improved from 0.34339 to 0.20442, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 68ms/step - loss: 0.1335 - accuracy: 0.9454 - val_loss: 0.2044 - val_accuracy: 0.8865
# Epoch 6/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9435
# Epoch 6: val_loss improved from 0.20442 to 0.12750, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1438 - accuracy: 0.9435 - val_loss: 0.1275 - val_accuracy: 0.9409
# Epoch 7/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1430 - accuracy: 0.9456
# Epoch 7: val_loss did not improve from 0.12750
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1429 - accuracy: 0.9458 - val_loss: 0.1678 - val_accuracy: 0.9273
# Epoch 8/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9447
# Epoch 8: val_loss improved from 0.12750 to 0.10879, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 62ms/step - loss: 0.1437 - accuracy: 0.9449 - val_loss: 0.1088 - val_accuracy: 0.9524
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9530
# Epoch 9: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1208 - accuracy: 0.9529 - val_loss: 0.1489 - val_accuracy: 0.9483
# Epoch 10/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9532
# Epoch 10: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1172 - accuracy: 0.9532 - val_loss: 0.1259 - val_accuracy: 0.9463
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1200 - accuracy: 0.9523
# Epoch 11: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1201 - accuracy: 0.9520 - val_loss: 0.1917 - val_accuracy: 0.9273
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9488
# Epoch 12: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1224 - accuracy: 0.9488 - val_loss: 0.1137 - val_accuracy: 0.9449
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9552
# Epoch 13: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1157 - accuracy: 0.9551 - val_loss: 0.1458 - val_accuracy: 0.9402
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9521
# Epoch 14: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1210 - accuracy: 0.9517 - val_loss: 0.1294 - val_accuracy: 0.9402
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9530
# Epoch 15: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1183 - accuracy: 0.9529 - val_loss: 0.1200 - val_accuracy: 0.9524
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9499
# Epoch 16: val_loss did not improve from 0.10879
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1269 - accuracy: 0.9493 - val_loss: 0.1395 - val_accuracy: 0.9524
# Epoch 17/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1174 - accuracy: 0.9542
# Epoch 17: val_loss improved from 0.10879 to 0.10185, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 56ms/step - loss: 0.1176 - accuracy: 0.9539 - val_loss: 0.1019 - val_accuracy: 0.9579
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1138 - accuracy: 0.9555
# Epoch 18: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1142 - accuracy: 0.9554 - val_loss: 0.2331 - val_accuracy: 0.8851
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9590
# Epoch 19: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1016 - accuracy: 0.9590 - val_loss: 0.1412 - val_accuracy: 0.9470
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1143 - accuracy: 0.9593
# Epoch 20: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1160 - accuracy: 0.9589 - val_loss: 0.3246 - val_accuracy: 0.9225
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9574
# Epoch 21: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1029 - accuracy: 0.9578 - val_loss: 0.1314 - val_accuracy: 0.9497
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9538
# Epoch 22: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1177 - accuracy: 0.9541 - val_loss: 0.1100 - val_accuracy: 0.9511
# Epoch 23/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9556
# Epoch 23: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1149 - accuracy: 0.9556 - val_loss: 0.1663 - val_accuracy: 0.9293
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9614
# Epoch 24: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1045 - accuracy: 0.9616 - val_loss: 0.1307 - val_accuracy: 0.9429
# Epoch 25/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9570
# Epoch 25: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1079 - accuracy: 0.9570 - val_loss: 0.2432 - val_accuracy: 0.8824
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9586
# Epoch 26: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0999 - accuracy: 0.9587 - val_loss: 0.1406 - val_accuracy: 0.9388
# Epoch 27/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9612Restoring model weights from the end of the best epoch: 17.
#
# Epoch 27: val_loss did not improve from 0.10185
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0969 - accuracy: 0.9612 - val_loss: 0.1087 - val_accuracy: 0.9565
# Epoch 27: early stopping
#
#
# Validation Loss for Split 1: 0.1019
# ____________________________________________________
# Split 2
# ____________________________________________________
# Epoch 1/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8714
# Epoch 1: val_loss improved from inf to 1.93330, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 43s 103ms/step - loss: 0.3498 - accuracy: 0.8711 - val_loss: 1.9333 - val_accuracy: 0.5996
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1744 - accuracy: 0.9272
# Epoch 2: val_loss improved from 1.93330 to 1.39119, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1757 - accuracy: 0.9264 - val_loss: 1.3912 - val_accuracy: 0.6717
# Epoch 3/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9350
# Epoch 3: val_loss improved from 1.39119 to 0.17473, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1608 - accuracy: 0.9350 - val_loss: 0.1747 - val_accuracy: 0.9320
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1523 - accuracy: 0.9353
# Epoch 4: val_loss did not improve from 0.17473
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1516 - accuracy: 0.9354 - val_loss: 0.1914 - val_accuracy: 0.9354
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1359 - accuracy: 0.9451
# Epoch 5: val_loss did not improve from 0.17473
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1353 - accuracy: 0.9454 - val_loss: 0.3531 - val_accuracy: 0.8600
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1575 - accuracy: 0.9394
# Epoch 6: val_loss did not improve from 0.17473
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1565 - accuracy: 0.9396 - val_loss: 0.2471 - val_accuracy: 0.9184
# Epoch 7/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9480
# Epoch 7: val_loss improved from 0.17473 to 0.16863, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 60ms/step - loss: 0.1300 - accuracy: 0.9480 - val_loss: 0.1686 - val_accuracy: 0.9211
# Epoch 8/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9461
# Epoch 8: val_loss improved from 0.16863 to 0.13447, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 53ms/step - loss: 0.1376 - accuracy: 0.9461 - val_loss: 0.1345 - val_accuracy: 0.9443
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9488
# Epoch 9: val_loss improved from 0.13447 to 0.11700, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1292 - accuracy: 0.9490 - val_loss: 0.1170 - val_accuracy: 0.9497
# Epoch 10/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1254 - accuracy: 0.9500
# Epoch 10: val_loss did not improve from 0.11700
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1254 - accuracy: 0.9500 - val_loss: 0.1240 - val_accuracy: 0.9415
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9533
# Epoch 11: val_loss did not improve from 0.11700
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1149 - accuracy: 0.9532 - val_loss: 0.1234 - val_accuracy: 0.9490
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9562
# Epoch 12: val_loss did not improve from 0.11700
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1135 - accuracy: 0.9563 - val_loss: 0.2122 - val_accuracy: 0.9307
# Epoch 13/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9577
# Epoch 13: val_loss improved from 0.11700 to 0.11562, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1083 - accuracy: 0.9577 - val_loss: 0.1156 - val_accuracy: 0.9531
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9562
# Epoch 14: val_loss did not improve from 0.11562
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1072 - accuracy: 0.9556 - val_loss: 0.1261 - val_accuracy: 0.9422
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9547
# Epoch 15: val_loss improved from 0.11562 to 0.11339, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.1170 - accuracy: 0.9544 - val_loss: 0.1134 - val_accuracy: 0.9517
# Epoch 16/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9585
# Epoch 16: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 49ms/step - loss: 0.1049 - accuracy: 0.9585 - val_loss: 0.1241 - val_accuracy: 0.9504
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9478
# Epoch 17: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1314 - accuracy: 0.9478 - val_loss: 0.5473 - val_accuracy: 0.8538
# Epoch 18/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9469
# Epoch 18: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1434 - accuracy: 0.9469 - val_loss: 0.1722 - val_accuracy: 0.9436
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9556
# Epoch 19: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1163 - accuracy: 0.9556 - val_loss: 0.1479 - val_accuracy: 0.9463
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1189 - accuracy: 0.9554
# Epoch 20: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1191 - accuracy: 0.9554 - val_loss: 0.1521 - val_accuracy: 0.9409
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9526
# Epoch 21: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1161 - accuracy: 0.9526 - val_loss: 0.1156 - val_accuracy: 0.9504
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9615
# Epoch 22: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1045 - accuracy: 0.9614 - val_loss: 0.1667 - val_accuracy: 0.9388
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.9560
# Epoch 23: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1138 - accuracy: 0.9560 - val_loss: 0.1275 - val_accuracy: 0.9524
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1113 - accuracy: 0.9559
# Epoch 24: val_loss did not improve from 0.11339
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1116 - accuracy: 0.9558 - val_loss: 0.1248 - val_accuracy: 0.9449
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1078 - accuracy: 0.9572
# Epoch 25: val_loss improved from 0.11339 to 0.10653, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1077 - accuracy: 0.9572 - val_loss: 0.1065 - val_accuracy: 0.9545
# Epoch 26/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9554
# Epoch 26: val_loss did not improve from 0.10653
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1062 - accuracy: 0.9554 - val_loss: 0.1609 - val_accuracy: 0.9402
# Epoch 27/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9600
# Epoch 27: val_loss did not improve from 0.10653
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1023 - accuracy: 0.9600 - val_loss: 0.1171 - val_accuracy: 0.9524
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9581
# Epoch 28: val_loss improved from 0.10653 to 0.10269, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 58ms/step - loss: 0.1028 - accuracy: 0.9583 - val_loss: 0.1027 - val_accuracy: 0.9558
# Epoch 29/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9554
# Epoch 29: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1119 - accuracy: 0.9554 - val_loss: 0.1476 - val_accuracy: 0.9415
# Epoch 30/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9578
# Epoch 30: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0994 - accuracy: 0.9580 - val_loss: 0.1271 - val_accuracy: 0.9443
# Epoch 31/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1117 - accuracy: 0.9566
# Epoch 31: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1114 - accuracy: 0.9568 - val_loss: 0.1311 - val_accuracy: 0.9456
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9592
# Epoch 32: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0962 - accuracy: 0.9592 - val_loss: 0.1339 - val_accuracy: 0.9422
# Epoch 33/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9600
# Epoch 33: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1013 - accuracy: 0.9600 - val_loss: 0.2306 - val_accuracy: 0.9279
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9581
# Epoch 34: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1078 - accuracy: 0.9578 - val_loss: 0.1090 - val_accuracy: 0.9517
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0879 - accuracy: 0.9657
# Epoch 35: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0876 - accuracy: 0.9657 - val_loss: 0.1526 - val_accuracy: 0.9531
# Epoch 36/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9616
# Epoch 36: val_loss did not improve from 0.10269
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1082 - accuracy: 0.9616 - val_loss: 0.1045 - val_accuracy: 0.9585
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9646
# Epoch 37: val_loss improved from 0.10269 to 0.10127, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0909 - accuracy: 0.9650 - val_loss: 0.1013 - val_accuracy: 0.9538
# Epoch 38/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9579
# Epoch 38: val_loss did not improve from 0.10127
# 92/92 [==============================] - 4s 49ms/step - loss: 0.1045 - accuracy: 0.9577 - val_loss: 0.1469 - val_accuracy: 0.9422
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1121 - accuracy: 0.9567
# Epoch 39: val_loss did not improve from 0.10127
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1116 - accuracy: 0.9570 - val_loss: 0.2505 - val_accuracy: 0.8926
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9518
# Epoch 40: val_loss improved from 0.10127 to 0.09845, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1227 - accuracy: 0.9519 - val_loss: 0.0984 - val_accuracy: 0.9626
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1014 - accuracy: 0.9626
# Epoch 41: val_loss improved from 0.09845 to 0.08839, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1010 - accuracy: 0.9626 - val_loss: 0.0884 - val_accuracy: 0.9640
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9626
# Epoch 42: val_loss did not improve from 0.08839
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1036 - accuracy: 0.9623 - val_loss: 0.1002 - val_accuracy: 0.9592
# Epoch 43/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9648
# Epoch 43: val_loss did not improve from 0.08839
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0942 - accuracy: 0.9648 - val_loss: 0.1285 - val_accuracy: 0.9579
# Epoch 44/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0844 - accuracy: 0.9674
# Epoch 44: val_loss improved from 0.08839 to 0.08476, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0854 - accuracy: 0.9670 - val_loss: 0.0848 - val_accuracy: 0.9633
# Epoch 45/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9660
# Epoch 45: val_loss did not improve from 0.08476
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0877 - accuracy: 0.9658 - val_loss: 0.1069 - val_accuracy: 0.9511
# Epoch 46/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9663
# Epoch 46: val_loss did not improve from 0.08476
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0857 - accuracy: 0.9665 - val_loss: 0.0877 - val_accuracy: 0.9585
# Epoch 47/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0842 - accuracy: 0.9663
# Epoch 47: val_loss did not improve from 0.08476
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0837 - accuracy: 0.9665 - val_loss: 0.1169 - val_accuracy: 0.9572
# Epoch 48/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9694
# Epoch 48: val_loss did not improve from 0.08476
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0785 - accuracy: 0.9694 - val_loss: 0.0941 - val_accuracy: 0.9599
# Epoch 49/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9672
# Epoch 49: val_loss did not improve from 0.08476
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0838 - accuracy: 0.9672 - val_loss: 0.1319 - val_accuracy: 0.9436
# Epoch 50/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0803 - accuracy: 0.9691
# Epoch 50: val_loss improved from 0.08476 to 0.08329, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0802 - accuracy: 0.9692 - val_loss: 0.0833 - val_accuracy: 0.9667
# Epoch 51/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9675
# Epoch 51: val_loss did not improve from 0.08329
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0815 - accuracy: 0.9674 - val_loss: 0.1225 - val_accuracy: 0.9606
# Epoch 52/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9710
# Epoch 52: val_loss improved from 0.08329 to 0.07329, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0732 - accuracy: 0.9711 - val_loss: 0.0733 - val_accuracy: 0.9742
# Epoch 53/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0780 - accuracy: 0.9706
# Epoch 53: val_loss did not improve from 0.07329
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0777 - accuracy: 0.9706 - val_loss: 0.0867 - val_accuracy: 0.9667
# Epoch 54/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9706
# Epoch 54: val_loss improved from 0.07329 to 0.07036, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0730 - accuracy: 0.9709 - val_loss: 0.0704 - val_accuracy: 0.9755
# Epoch 55/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9723
# Epoch 55: val_loss did not improve from 0.07036
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0726 - accuracy: 0.9723 - val_loss: 0.0752 - val_accuracy: 0.9680
# Epoch 56/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9684
# Epoch 56: val_loss did not improve from 0.07036
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0740 - accuracy: 0.9684 - val_loss: 0.0722 - val_accuracy: 0.9701
# Epoch 57/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9675
# Epoch 57: val_loss improved from 0.07036 to 0.06419, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0785 - accuracy: 0.9675 - val_loss: 0.0642 - val_accuracy: 0.9748
# Epoch 58/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9693
# Epoch 58: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0771 - accuracy: 0.9692 - val_loss: 0.0786 - val_accuracy: 0.9633
# Epoch 59/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9722
# Epoch 59: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0654 - accuracy: 0.9725 - val_loss: 0.0866 - val_accuracy: 0.9667
# Epoch 60/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9708
# Epoch 60: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0728 - accuracy: 0.9708 - val_loss: 0.0734 - val_accuracy: 0.9667
# Epoch 61/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0723 - accuracy: 0.9712
# Epoch 61: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0724 - accuracy: 0.9711 - val_loss: 0.0772 - val_accuracy: 0.9701
# Epoch 62/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9694
# Epoch 62: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0790 - accuracy: 0.9694 - val_loss: 0.1104 - val_accuracy: 0.9626
# Epoch 63/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9718
# Epoch 63: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0756 - accuracy: 0.9719 - val_loss: 0.1716 - val_accuracy: 0.9572
# Epoch 64/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9720
# Epoch 64: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0737 - accuracy: 0.9719 - val_loss: 0.0794 - val_accuracy: 0.9680
# Epoch 65/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0761 - accuracy: 0.9732
# Epoch 65: val_loss improved from 0.06419 to 0.06366, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0762 - accuracy: 0.9733 - val_loss: 0.0637 - val_accuracy: 0.9769
# Epoch 66/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0752 - accuracy: 0.9708
# Epoch 66: val_loss did not improve from 0.06366
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0760 - accuracy: 0.9706 - val_loss: 0.0802 - val_accuracy: 0.9667
# Epoch 67/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9725
# Epoch 67: val_loss did not improve from 0.06366
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0697 - accuracy: 0.9725 - val_loss: 0.0649 - val_accuracy: 0.9776
# Epoch 68/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0646 - accuracy: 0.9736
# Epoch 68: val_loss did not improve from 0.06366
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0646 - accuracy: 0.9736 - val_loss: 0.0756 - val_accuracy: 0.9653
# Epoch 69/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9733
# Epoch 69: val_loss did not improve from 0.06366
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0716 - accuracy: 0.9733 - val_loss: 0.0671 - val_accuracy: 0.9721
# Epoch 70/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9741
# Epoch 70: val_loss did not improve from 0.06366
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0596 - accuracy: 0.9743 - val_loss: 0.0751 - val_accuracy: 0.9694
# Epoch 71/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9745
# Epoch 71: val_loss did not improve from 0.06366
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0651 - accuracy: 0.9745 - val_loss: 0.0766 - val_accuracy: 0.9660
# Epoch 72/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0641 - accuracy: 0.9753
# Epoch 72: val_loss improved from 0.06366 to 0.05937, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0638 - accuracy: 0.9755 - val_loss: 0.0594 - val_accuracy: 0.9782
# Epoch 73/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0706 - accuracy: 0.9725
# Epoch 73: val_loss improved from 0.05937 to 0.05699, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0703 - accuracy: 0.9728 - val_loss: 0.0570 - val_accuracy: 0.9755
# Epoch 74/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9733
# Epoch 74: val_loss did not improve from 0.05699
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0687 - accuracy: 0.9733 - val_loss: 0.0623 - val_accuracy: 0.9789
# Epoch 75/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9735
# Epoch 75: val_loss did not improve from 0.05699
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0644 - accuracy: 0.9735 - val_loss: 0.0664 - val_accuracy: 0.9721
#
#
# Validation Loss for Split 2: 0.0664
# ____________________________________________________
# Split 3
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.8745
# Epoch 1: val_loss improved from inf to 0.45001, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 43s 120ms/step - loss: 0.3335 - accuracy: 0.8745 - val_loss: 0.4500 - val_accuracy: 0.8320
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9320
# Epoch 2: val_loss did not improve from 0.45001
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1794 - accuracy: 0.9320 - val_loss: 0.9886 - val_accuracy: 0.7238
# Epoch 3/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9294
# Epoch 3: val_loss did not improve from 0.45001
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1854 - accuracy: 0.9294 - val_loss: 0.4594 - val_accuracy: 0.8388
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1503 - accuracy: 0.9416
# Epoch 4: val_loss did not improve from 0.45001
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1505 - accuracy: 0.9412 - val_loss: 0.4694 - val_accuracy: 0.8707
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1502 - accuracy: 0.9387
# Epoch 5: val_loss improved from 0.45001 to 0.21346, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.1497 - accuracy: 0.9391 - val_loss: 0.2135 - val_accuracy: 0.9163
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9473
# Epoch 6: val_loss improved from 0.21346 to 0.14591, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1384 - accuracy: 0.9471 - val_loss: 0.1459 - val_accuracy: 0.9381
# Epoch 7/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1458 - accuracy: 0.9468
# Epoch 7: val_loss did not improve from 0.14591
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1460 - accuracy: 0.9466 - val_loss: 0.1709 - val_accuracy: 0.9381
# Epoch 8/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1327 - accuracy: 0.9457
# Epoch 8: val_loss did not improve from 0.14591
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1339 - accuracy: 0.9459 - val_loss: 0.9194 - val_accuracy: 0.8116
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9435
# Epoch 9: val_loss improved from 0.14591 to 0.12568, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1372 - accuracy: 0.9437 - val_loss: 0.1257 - val_accuracy: 0.9422
# Epoch 10/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9475
# Epoch 10: val_loss did not improve from 0.12568
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1324 - accuracy: 0.9475 - val_loss: 0.1294 - val_accuracy: 0.9476
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9457
# Epoch 11: val_loss improved from 0.12568 to 0.11716, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1270 - accuracy: 0.9454 - val_loss: 0.1172 - val_accuracy: 0.9463
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9487
# Epoch 12: val_loss improved from 0.11716 to 0.10581, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1181 - accuracy: 0.9483 - val_loss: 0.1058 - val_accuracy: 0.9565
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9502
# Epoch 13: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1136 - accuracy: 0.9502 - val_loss: 0.1144 - val_accuracy: 0.9503
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9535
# Epoch 14: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1130 - accuracy: 0.9532 - val_loss: 0.1459 - val_accuracy: 0.9299
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1076 - accuracy: 0.9543
# Epoch 15: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1073 - accuracy: 0.9544 - val_loss: 0.1518 - val_accuracy: 0.9299
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9499
# Epoch 16: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1192 - accuracy: 0.9498 - val_loss: 0.1140 - val_accuracy: 0.9558
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9498
# Epoch 17: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1224 - accuracy: 0.9498 - val_loss: 0.1078 - val_accuracy: 0.9565
# Epoch 18/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9522
# Epoch 18: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1167 - accuracy: 0.9522 - val_loss: 0.1108 - val_accuracy: 0.9551
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1104 - accuracy: 0.9547
# Epoch 19: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1102 - accuracy: 0.9546 - val_loss: 0.1291 - val_accuracy: 0.9374
# Epoch 20/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9560
# Epoch 20: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1100 - accuracy: 0.9560 - val_loss: 0.1351 - val_accuracy: 0.9456
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9516
# Epoch 21: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1162 - accuracy: 0.9519 - val_loss: 0.1165 - val_accuracy: 0.9551
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1260 - accuracy: 0.9524Restoring model weights from the end of the best epoch: 12.
#
# Epoch 22: val_loss did not improve from 0.10581
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1260 - accuracy: 0.9524 - val_loss: 0.2819 - val_accuracy: 0.8871
# Epoch 22: early stopping
#
#
# Validation Loss for Split 3: 0.1058
# ____________________________________________________
# Split 4
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8705
# Epoch 1: val_loss improved from inf to 1.41796, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 43s 104ms/step - loss: 0.3307 - accuracy: 0.8705 - val_loss: 1.4180 - val_accuracy: 0.6075
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1768 - accuracy: 0.9287
# Epoch 2: val_loss did not improve from 1.41796
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1755 - accuracy: 0.9294 - val_loss: 1.6728 - val_accuracy: 0.5272
# Epoch 3/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9402
# Epoch 3: val_loss improved from 1.41796 to 0.38987, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1577 - accuracy: 0.9402 - val_loss: 0.3899 - val_accuracy: 0.8782
# Epoch 4/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9427
# Epoch 4: val_loss did not improve from 0.38987
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1334 - accuracy: 0.9427 - val_loss: 0.8125 - val_accuracy: 0.7395
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1538 - accuracy: 0.9370
# Epoch 5: val_loss improved from 0.38987 to 0.11262, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1535 - accuracy: 0.9371 - val_loss: 0.1126 - val_accuracy: 0.9605
# Epoch 6/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9320
# Epoch 6: val_loss did not improve from 0.11262
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1626 - accuracy: 0.9320 - val_loss: 0.1305 - val_accuracy: 0.9395
# Epoch 7/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1582 - accuracy: 0.9372
# Epoch 7: val_loss did not improve from 0.11262
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1577 - accuracy: 0.9371 - val_loss: 0.1481 - val_accuracy: 0.9531
# Epoch 8/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9419
# Epoch 8: val_loss did not improve from 0.11262
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1328 - accuracy: 0.9419 - val_loss: 0.1185 - val_accuracy: 0.9585
# Epoch 9/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9439
# Epoch 9: val_loss did not improve from 0.11262
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1316 - accuracy: 0.9439 - val_loss: 0.1358 - val_accuracy: 0.9429
# Epoch 10/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9459
# Epoch 10: val_loss improved from 0.11262 to 0.09164, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1237 - accuracy: 0.9459 - val_loss: 0.0916 - val_accuracy: 0.9653
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1155 - accuracy: 0.9531
# Epoch 11: val_loss did not improve from 0.09164
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1155 - accuracy: 0.9531 - val_loss: 0.1037 - val_accuracy: 0.9605
# Epoch 12/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9549
# Epoch 12: val_loss improved from 0.09164 to 0.08049, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1130 - accuracy: 0.9549 - val_loss: 0.0805 - val_accuracy: 0.9707
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1032 - accuracy: 0.9609
# Epoch 13: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1050 - accuracy: 0.9604 - val_loss: 0.1551 - val_accuracy: 0.9388
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9554
# Epoch 14: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1066 - accuracy: 0.9558 - val_loss: 0.0806 - val_accuracy: 0.9762
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9560
# Epoch 15: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1021 - accuracy: 0.9561 - val_loss: 0.1219 - val_accuracy: 0.9422
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9564
# Epoch 16: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1072 - accuracy: 0.9563 - val_loss: 0.1414 - val_accuracy: 0.9286
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9565
# Epoch 17: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1102 - accuracy: 0.9565 - val_loss: 0.0937 - val_accuracy: 0.9633
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1227 - accuracy: 0.9542
# Epoch 18: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1224 - accuracy: 0.9541 - val_loss: 0.1657 - val_accuracy: 0.9184
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9633
# Epoch 19: val_loss did not improve from 0.08049
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0993 - accuracy: 0.9633 - val_loss: 0.1516 - val_accuracy: 0.9497
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.9590
# Epoch 20: val_loss improved from 0.08049 to 0.07466, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.1002 - accuracy: 0.9589 - val_loss: 0.0747 - val_accuracy: 0.9680
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0896 - accuracy: 0.9621
# Epoch 21: val_loss did not improve from 0.07466
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0894 - accuracy: 0.9621 - val_loss: 0.1161 - val_accuracy: 0.9544
# Epoch 22/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9677
# Epoch 22: val_loss improved from 0.07466 to 0.05923, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0862 - accuracy: 0.9677 - val_loss: 0.0592 - val_accuracy: 0.9776
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0957 - accuracy: 0.9624
# Epoch 23: val_loss did not improve from 0.05923
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0954 - accuracy: 0.9623 - val_loss: 0.1258 - val_accuracy: 0.9381
# Epoch 24/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9643
# Epoch 24: val_loss did not improve from 0.05923
# 92/92 [==============================] - 4s 49ms/step - loss: 0.0915 - accuracy: 0.9643 - val_loss: 0.1137 - val_accuracy: 0.9483
# Epoch 25/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9655
# Epoch 25: val_loss did not improve from 0.05923
# ...
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9775
# Epoch 36: val_loss did not improve from 0.03739
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0562 - accuracy: 0.9772 - val_loss: 0.0379 - val_accuracy: 0.9878
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9768
# Epoch 37: val_loss improved from 0.03739 to 0.03557, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0545 - accuracy: 0.9770 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 38/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9739
# Epoch 38: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0573 - accuracy: 0.9742 - val_loss: 0.0791 - val_accuracy: 0.9592
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9763
# Epoch 39: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0577 - accuracy: 0.9764 - val_loss: 0.0426 - val_accuracy: 0.9810
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9777
# Epoch 40: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0542 - accuracy: 0.9779 - val_loss: 0.0469 - val_accuracy: 0.9837
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9797
# Epoch 41: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0494 - accuracy: 0.9799 - val_loss: 0.0916 - val_accuracy: 0.9551
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0550 - accuracy: 0.9787
# Epoch 42: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0546 - accuracy: 0.9787 - val_loss: 0.0882 - val_accuracy: 0.9571
# Epoch 43/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9784
# Epoch 43: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0560 - accuracy: 0.9779 - val_loss: 0.0684 - val_accuracy: 0.9646
# Epoch 44/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9779
# Epoch 44: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0537 - accuracy: 0.9779 - val_loss: 0.0457 - val_accuracy: 0.9816
# Epoch 45/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9809
# Epoch 45: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0492 - accuracy: 0.9811 - val_loss: 0.0414 - val_accuracy: 0.9830
# Epoch 46/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0469 - accuracy: 0.9811
# Epoch 46: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0467 - accuracy: 0.9813 - val_loss: 0.0382 - val_accuracy: 0.9844
# Epoch 47/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0529 - accuracy: 0.9753Restoring model weights from the end of the best epoch: 37.
#
# Epoch 47: val_loss did not improve from 0.03557
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0526 - accuracy: 0.9755 - val_loss: 0.0451 - val_accuracy: 0.9816
# Epoch 47: early stopping
#
#
# Validation Loss for Split 4: 0.0356
# ____________________________________________________
# Split 5
# ____________________________________________________
# Epoch 1/75
# 91/92 [============================>.] - ETA: 0s - loss: 1.1192 - accuracy: 0.7388
# Epoch 1: val_loss improved from inf to 2.12207, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 47s 102ms/step - loss: 1.1144 - accuracy: 0.7406 - val_loss: 2.1221 - val_accuracy: 0.4163
# Epoch 2/75
# 92/92 [==============================] - ETA: 0s - loss: 0.4072 - accuracy: 0.9199
# Epoch 2: val_loss did not improve from 2.12207
# 92/92 [==============================] - 4s 48ms/step - loss: 0.4072 - accuracy: 0.9199 - val_loss: 2.4210 - val_accuracy: 0.2741
# Epoch 3/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9425
# Epoch 3: val_loss improved from 2.12207 to 2.05405, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1985 - accuracy: 0.9425 - val_loss: 2.0540 - val_accuracy: 0.3435
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1475 - accuracy: 0.9490
# Epoch 4: val_loss improved from 2.05405 to 1.03125, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1467 - accuracy: 0.9493 - val_loss: 1.0313 - val_accuracy: 0.6061
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1346 - accuracy: 0.9509
# Epoch 5: val_loss improved from 1.03125 to 0.33105, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1346 - accuracy: 0.9510 - val_loss: 0.3310 - val_accuracy: 0.8673
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1284 - accuracy: 0.9485
# Epoch 6: val_loss improved from 0.33105 to 0.13645, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1288 - accuracy: 0.9481 - val_loss: 0.1364 - val_accuracy: 0.9361
# Epoch 7/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9509
# Epoch 7: val_loss improved from 0.13645 to 0.12556, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.1236 - accuracy: 0.9509 - val_loss: 0.1256 - val_accuracy: 0.9395
# Epoch 8/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1164 - accuracy: 0.9505
# Epoch 8: val_loss did not improve from 0.12556
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1163 - accuracy: 0.9509 - val_loss: 0.1278 - val_accuracy: 0.9395
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9519
# Epoch 9: val_loss improved from 0.12556 to 0.11412, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1169 - accuracy: 0.9521 - val_loss: 0.1141 - val_accuracy: 0.9449
# Epoch 10/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.9531
# Epoch 10: val_loss improved from 0.11412 to 0.09387, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.1142 - accuracy: 0.9529 - val_loss: 0.0939 - val_accuracy: 0.9605
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1111 - accuracy: 0.9543
# Epoch 11: val_loss did not improve from 0.09387
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1110 - accuracy: 0.9541 - val_loss: 0.1058 - val_accuracy: 0.9537
# Epoch 12/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9561
# Epoch 12: val_loss improved from 0.09387 to 0.09121, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.1047 - accuracy: 0.9561 - val_loss: 0.0912 - val_accuracy: 0.9619
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1085 - accuracy: 0.9540
# Epoch 13: val_loss did not improve from 0.09121
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1084 - accuracy: 0.9541 - val_loss: 0.0922 - val_accuracy: 0.9599
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1017 - accuracy: 0.9559
# Epoch 14: val_loss did not improve from 0.09121
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1019 - accuracy: 0.9556 - val_loss: 0.0963 - val_accuracy: 0.9565
# Epoch 15/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9565
# Epoch 15: val_loss did not improve from 0.09121
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1023 - accuracy: 0.9565 - val_loss: 0.0926 - val_accuracy: 0.9605
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1031 - accuracy: 0.9559
# Epoch 16: val_loss did not improve from 0.09121
# 92/92 [==============================] - 4s 47ms/step - loss: 0.1029 - accuracy: 0.9561 - val_loss: 0.1088 - val_accuracy: 0.9476
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9594
# Epoch 17: val_loss improved from 0.09121 to 0.08355, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0906 - accuracy: 0.9594 - val_loss: 0.0836 - val_accuracy: 0.9646
# Epoch 18/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9619
# Epoch 18: val_loss improved from 0.08355 to 0.08295, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0919 - accuracy: 0.9619 - val_loss: 0.0830 - val_accuracy: 0.9667
# Epoch 19/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9616
# Epoch 19: val_loss did not improve from 0.08295
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0934 - accuracy: 0.9616 - val_loss: 0.0869 - val_accuracy: 0.9680
# Epoch 20/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9668
# Epoch 20: val_loss improved from 0.08295 to 0.07044, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0786 - accuracy: 0.9668 - val_loss: 0.0704 - val_accuracy: 0.9707
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0806 - accuracy: 0.9638
# Epoch 21: val_loss did not improve from 0.07044
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0799 - accuracy: 0.9641 - val_loss: 0.0715 - val_accuracy: 0.9673
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9667
# Epoch 22: val_loss did not improve from 0.07044
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0783 - accuracy: 0.9668 - val_loss: 0.0820 - val_accuracy: 0.9687
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9670
# Epoch 23: val_loss improved from 0.07044 to 0.06663, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 60ms/step - loss: 0.0758 - accuracy: 0.9670 - val_loss: 0.0666 - val_accuracy: 0.9735
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9674
# Epoch 24: val_loss did not improve from 0.06663
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0763 - accuracy: 0.9674 - val_loss: 0.0719 - val_accuracy: 0.9680
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9722
# Epoch 25: val_loss improved from 0.06663 to 0.06566, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0684 - accuracy: 0.9721 - val_loss: 0.0657 - val_accuracy: 0.9776
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9742
# Epoch 26: val_loss did not improve from 0.06566
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0670 - accuracy: 0.9740 - val_loss: 0.0738 - val_accuracy: 0.9701
# Epoch 27/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0648 - accuracy: 0.9703
# Epoch 27: val_loss improved from 0.06566 to 0.05099, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0655 - accuracy: 0.9699 - val_loss: 0.0510 - val_accuracy: 0.9789
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0672 - accuracy: 0.9725
# Epoch 28: val_loss improved from 0.05099 to 0.04788, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0676 - accuracy: 0.9725 - val_loss: 0.0479 - val_accuracy: 0.9810
# Epoch 29/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9728
# Epoch 29: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0622 - accuracy: 0.9728 - val_loss: 0.0900 - val_accuracy: 0.9619
# Epoch 30/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9740
# Epoch 30: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0627 - accuracy: 0.9740 - val_loss: 0.0555 - val_accuracy: 0.9769
# Epoch 31/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0673 - accuracy: 0.9727
# Epoch 31: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0669 - accuracy: 0.9730 - val_loss: 0.0548 - val_accuracy: 0.9789
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9730
# Epoch 32: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0625 - accuracy: 0.9730 - val_loss: 0.0697 - val_accuracy: 0.9721
# Epoch 33/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9749
# Epoch 33: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0625 - accuracy: 0.9752 - val_loss: 0.0718 - val_accuracy: 0.9667
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0587 - accuracy: 0.9739
# Epoch 34: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0588 - accuracy: 0.9738 - val_loss: 0.0598 - val_accuracy: 0.9728
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9773
# Epoch 35: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0581 - accuracy: 0.9767 - val_loss: 0.0730 - val_accuracy: 0.9673
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9724
# Epoch 36: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0660 - accuracy: 0.9723 - val_loss: 0.0858 - val_accuracy: 0.9599
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9761
# Epoch 37: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0570 - accuracy: 0.9764 - val_loss: 0.0738 - val_accuracy: 0.9646
# Epoch 38/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9762Restoring model weights from the end of the best epoch: 28.
#
# Epoch 38: val_loss did not improve from 0.04788
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0558 - accuracy: 0.9762 - val_loss: 0.0620 - val_accuracy: 0.9728
# Epoch 38: early stopping
#
#
# Validation Loss for Split 5: 0.0479
# Mean Loss for Parameters: 0.0001, 64 is 0.0462
#
# Best Overall Parameters: [(0.001, 64)], with a loss of 0.0285

# %% [markdown]
# # **Now we train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 64
}


# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_body_acc_train, x_gro_train, x_total_acc_train], axis=-1),
    y_train,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = BLSTMAttentionModel(learning_rate=best_params['learning_rate'], batch_size=best_params['batch_size'])

# Fit the model to the training data with validation data
history = best_model.fit2(X=[x_train_final[:, :, :3],
       x_train_final[:, :, 3:6],
       x_train_final[:, :, 6:]],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=([x_val_final[:, :, :3], x_val_final[:, :, 3:6], x_val_final[:, :, 6:]], y_val_final)
)


# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_body_acc_test,
                                                      x_gro_test,
                                                      x_total_acc_test],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_body_acc_test,
                                   x_gro_test,
                                   x_total_acc_test])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics

# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'],
                  index=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 92/92 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.8902
# Epoch 1: val_accuracy improved from -inf to 0.25969, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 72s 156ms/step - loss: 0.3591 - accuracy: 0.8902 - val_loss: 4.3905 - val_accuracy: 0.2597
# Epoch 2/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9466
# Epoch 2: val_accuracy improved from 0.25969 to 0.28960, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 67ms/step - loss: 0.1321 - accuracy: 0.9468 - val_loss: 4.1901 - val_accuracy: 0.2896
# Epoch 3/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9473
# Epoch 3: val_accuracy improved from 0.28960 to 0.35690, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 56ms/step - loss: 0.1302 - accuracy: 0.9473 - val_loss: 3.6160 - val_accuracy: 0.3569
# Epoch 4/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9497
# Epoch 4: val_accuracy improved from 0.35690 to 0.55337, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 64ms/step - loss: 0.1163 - accuracy: 0.9497 - val_loss: 1.6297 - val_accuracy: 0.5534
# Epoch 5/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9556
# Epoch 5: val_accuracy improved from 0.55337 to 0.88511, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 64ms/step - loss: 0.1050 - accuracy: 0.9556 - val_loss: 0.3020 - val_accuracy: 0.8851
# Epoch 6/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.1183 - accuracy: 0.9483
# Epoch 6: val_accuracy improved from 0.88511 to 0.95173, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1181 - accuracy: 0.9485 - val_loss: 0.1207 - val_accuracy: 0.9517
# Epoch 7/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9514
# Epoch 7: val_accuracy did not improve from 0.95173
# 92/92 [==============================] - 6s 61ms/step - loss: 0.1178 - accuracy: 0.9514 - val_loss: 0.1128 - val_accuracy: 0.9483
# Epoch 8/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.1098 - accuracy: 0.9540
# Epoch 8: val_accuracy improved from 0.95173 to 0.95513, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 63ms/step - loss: 0.1108 - accuracy: 0.9536 - val_loss: 0.1014 - val_accuracy: 0.9551
# Epoch 9/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9561
# Epoch 9: val_accuracy did not improve from 0.95513
# 92/92 [==============================] - 5s 59ms/step - loss: 0.1045 - accuracy: 0.9561 - val_loss: 0.1187 - val_accuracy: 0.9449
# Epoch 10/150
# 92/92 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9560
# Epoch 10: val_accuracy improved from 0.95513 to 0.95785, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.1005 - accuracy: 0.9560 - val_loss: 0.0931 - val_accuracy: 0.9579
# Epoch 11/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.1100 - accuracy: 0.9497
# Epoch 11: val_accuracy improved from 0.95785 to 0.95921, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 55ms/step - loss: 0.1097 - accuracy: 0.9497 - val_loss: 0.0918 - val_accuracy: 0.9592
# Epoch 12/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9585
# Epoch 12: val_accuracy did not improve from 0.95921
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0937 - accuracy: 0.9585 - val_loss: 0.0948 - val_accuracy: 0.9545
# Epoch 13/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9581
# Epoch 13: val_accuracy improved from 0.95921 to 0.96737, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 55ms/step - loss: 0.0945 - accuracy: 0.9582 - val_loss: 0.0817 - val_accuracy: 0.9674
# Epoch 14/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9582
# Epoch 14: val_accuracy improved from 0.96737 to 0.97281, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0941 - accuracy: 0.9582 - val_loss: 0.0783 - val_accuracy: 0.9728
# Epoch 15/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9645
# Epoch 15: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 5s 58ms/step - loss: 0.0852 - accuracy: 0.9648 - val_loss: 0.0751 - val_accuracy: 0.9728
# Epoch 16/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9640
# Epoch 16: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0860 - accuracy: 0.9640 - val_loss: 0.0719 - val_accuracy: 0.9646
# Epoch 17/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9638
# Epoch 17: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0853 - accuracy: 0.9638 - val_loss: 0.1121 - val_accuracy: 0.9477
# Epoch 18/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0778 - accuracy: 0.9657
# Epoch 18: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0781 - accuracy: 0.9657 - val_loss: 0.0881 - val_accuracy: 0.9680
# Epoch 19/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9692
# Epoch 19: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0775 - accuracy: 0.9692 - val_loss: 0.0817 - val_accuracy: 0.9619
# Epoch 20/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9691
# Epoch 20: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0779 - accuracy: 0.9691 - val_loss: 0.0654 - val_accuracy: 0.9721
# Epoch 21/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9731
# Epoch 21: val_accuracy did not improve from 0.97281
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0669 - accuracy: 0.9731 - val_loss: 0.1303 - val_accuracy: 0.9572
# Epoch 22/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0680 - accuracy: 0.9718
# Epoch 22: val_accuracy improved from 0.97281 to 0.97757, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0676 - accuracy: 0.9721 - val_loss: 0.0592 - val_accuracy: 0.9776
# Epoch 23/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9743
# Epoch 23: val_accuracy improved from 0.97757 to 0.97825, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 61ms/step - loss: 0.0604 - accuracy: 0.9743 - val_loss: 0.0548 - val_accuracy: 0.9782
# Epoch 24/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9777
# Epoch 24: val_accuracy improved from 0.97825 to 0.98232, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 55ms/step - loss: 0.0579 - accuracy: 0.9777 - val_loss: 0.0357 - val_accuracy: 0.9823
# Epoch 25/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0520 - accuracy: 0.9792
# Epoch 25: val_accuracy improved from 0.98232 to 0.98436, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 65ms/step - loss: 0.0523 - accuracy: 0.9793 - val_loss: 0.0437 - val_accuracy: 0.9844
# Epoch 26/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9744
# Epoch 26: val_accuracy did not improve from 0.98436
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0637 - accuracy: 0.9747 - val_loss: 0.0513 - val_accuracy: 0.9782
# Epoch 27/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9767
# Epoch 27: val_accuracy did not improve from 0.98436
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0571 - accuracy: 0.9767 - val_loss: 0.0461 - val_accuracy: 0.9796
# Epoch 28/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9785
# Epoch 28: val_accuracy did not improve from 0.98436
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0535 - accuracy: 0.9784 - val_loss: 0.0547 - val_accuracy: 0.9789
# Epoch 29/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9803
# Epoch 29: val_accuracy did not improve from 0.98436
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0477 - accuracy: 0.9804 - val_loss: 0.0640 - val_accuracy: 0.9789
# Epoch 30/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9791
# Epoch 30: val_accuracy improved from 0.98436 to 0.98572, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 7s 71ms/step - loss: 0.0501 - accuracy: 0.9791 - val_loss: 0.0296 - val_accuracy: 0.9857
# Epoch 31/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9825
# Epoch 31: val_accuracy did not improve from 0.98572
# 92/92 [==============================] - 5s 53ms/step - loss: 0.0461 - accuracy: 0.9825 - val_loss: 0.0347 - val_accuracy: 0.9837
# Epoch 32/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9845
# Epoch 32: val_accuracy did not improve from 0.98572
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0442 - accuracy: 0.9845 - val_loss: 0.0432 - val_accuracy: 0.9796
# Epoch 33/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0492 - accuracy: 0.9810
# Epoch 33: val_accuracy improved from 0.98572 to 0.98708, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 7s 72ms/step - loss: 0.0492 - accuracy: 0.9810 - val_loss: 0.0299 - val_accuracy: 0.9871
# Epoch 34/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9810
# Epoch 34: val_accuracy did not improve from 0.98708
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0484 - accuracy: 0.9810 - val_loss: 0.0704 - val_accuracy: 0.9714
# Epoch 35/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9842
# Epoch 35: val_accuracy improved from 0.98708 to 0.98776, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 64ms/step - loss: 0.0404 - accuracy: 0.9842 - val_loss: 0.0329 - val_accuracy: 0.9878
# Epoch 36/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9869
# Epoch 36: val_accuracy did not improve from 0.98776
# 92/92 [==============================] - 5s 56ms/step - loss: 0.0329 - accuracy: 0.9869 - val_loss: 0.0312 - val_accuracy: 0.9850
# Epoch 37/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9821
# Epoch 37: val_accuracy improved from 0.98776 to 0.98844, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 56ms/step - loss: 0.0393 - accuracy: 0.9821 - val_loss: 0.0290 - val_accuracy: 0.9884
# Epoch 38/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0384 - accuracy: 0.9857
# Epoch 38: val_accuracy did not improve from 0.98844
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0382 - accuracy: 0.9859 - val_loss: 0.0332 - val_accuracy: 0.9857
# Epoch 39/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9871
# Epoch 39: val_accuracy did not improve from 0.98844
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0339 - accuracy: 0.9871 - val_loss: 0.0599 - val_accuracy: 0.9782
# Epoch 40/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9854
# Epoch 40: val_accuracy improved from 0.98844 to 0.98912, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 6s 60ms/step - loss: 0.0373 - accuracy: 0.9855 - val_loss: 0.0236 - val_accuracy: 0.9891
# Epoch 41/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9874
# Epoch 41: val_accuracy did not improve from 0.98912
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0320 - accuracy: 0.9874 - val_loss: 0.0384 - val_accuracy: 0.9878
# Epoch 42/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9857
# Epoch 42: val_accuracy improved from 0.98912 to 0.99252, saving model to /content/drive/MyDrive/ColabNotebooks/tuning/GridSearchCV-Tuning-0202-Leakyrelu-BILSTM.hdf5
# 92/92 [==============================] - 5s 56ms/step - loss: 0.0419 - accuracy: 0.9857 - val_loss: 0.0247 - val_accuracy: 0.9925
# Epoch 43/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9857
# Epoch 43: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0355 - accuracy: 0.9857 - val_loss: 0.0554 - val_accuracy: 0.9762
# Epoch 44/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9872
# Epoch 44: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0326 - accuracy: 0.9872 - val_loss: 0.0327 - val_accuracy: 0.9878
# Epoch 45/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9875
# Epoch 45: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0326 - accuracy: 0.9874 - val_loss: 0.0310 - val_accuracy: 0.9878
# Epoch 46/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9889
# Epoch 46: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 6s 62ms/step - loss: 0.0298 - accuracy: 0.9889 - val_loss: 0.0284 - val_accuracy: 0.9878
# Epoch 47/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9849
# Epoch 47: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 53ms/step - loss: 0.0361 - accuracy: 0.9849 - val_loss: 0.0408 - val_accuracy: 0.9830
# Epoch 48/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9862
# Epoch 48: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0355 - accuracy: 0.9862 - val_loss: 0.0395 - val_accuracy: 0.9857
# Epoch 49/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9889
# Epoch 49: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0331 - val_accuracy: 0.9857
# Epoch 50/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0298 - accuracy: 0.9880
# Epoch 50: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 53ms/step - loss: 0.0296 - accuracy: 0.9881 - val_loss: 0.0464 - val_accuracy: 0.9830
# Epoch 51/150
# 92/92 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9888
# Epoch 51: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 59ms/step - loss: 0.0299 - accuracy: 0.9888 - val_loss: 0.0288 - val_accuracy: 0.9891
# Epoch 52/150
# 91/92 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9871Restoring model weights from the end of the best epoch: 42.
#
# Epoch 52: val_accuracy did not improve from 0.99252
# 92/92 [==============================] - 5s 57ms/step - loss: 0.0309 - accuracy: 0.9872 - val_loss: 0.0516 - val_accuracy: 0.9789
# Epoch 52: early stopping
# 93/93 [==============================] - 6s 16ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_2 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 256)             2560      ['input_1[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 128, 256)             2560      ['input_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 128, 256)             2560      ['input_3[0][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['conv1d[0][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 128, 256)             1024      ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 128, 256)             1024      ['conv1d_8[0][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[0][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_4[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_8 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_8[0][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_4[0][0]']
#
#  dropout_8 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_8[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 64, 128)              98432     ['dropout[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 64, 128)              98432     ['dropout_4[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 64, 128)              98432     ['dropout_8[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 64, 128)              512       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 128)              512       ['conv1d_9[0][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_5[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_9 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_9[0][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[0][0]']
#
#  dropout_5 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_5[0][0]']
#
#  dropout_9 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_9[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 32, 64)               24640     ['dropout_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 32, 64)               24640     ['dropout_5[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 32, 64)               24640     ['dropout_9[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 32, 64)               256       ['conv1d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 32, 64)               256       ['conv1d_10[0][0]']
#  tchNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_6[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_10 (MaxPooli  (None, 16, 64)               0         ['batch_normalization_10[0][0]
#  ng1D)                                                              ']
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[0][0]']
#
#  dropout_6 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_6[0][0]']
#
#  dropout_10 (Dropout)        (None, 16, 64)               0         ['max_pooling1d_10[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 16, 32)               6176      ['dropout_2[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 16, 32)               6176      ['dropout_6[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 16, 32)               6176      ['dropout_10[0][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 32)               128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 16, 32)               128       ['conv1d_11[0][0]']
#  tchNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_7[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_11 (MaxPooli  (None, 8, 32)                0         ['batch_normalization_11[0][0]
#  ng1D)                                                              ']
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_7[0][0]']
#
#  dropout_11 (Dropout)        (None, 8, 32)                0         ['max_pooling1d_11[0][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[0][0]']
#  Normalization)
#
#  layer_normalization_1 (Lay  (None, 8, 32)                64        ['dropout_7[0][0]']
#  erNormalization)
#
#  layer_normalization_2 (Lay  (None, 8, 32)                64        ['dropout_11[0][0]']
#  erNormalization)
#
#  bidirectional (Bidirection  (None, 8, 128)               49664     ['layer_normalization[0][0]']
#  al)
#
#  bidirectional_2 (Bidirecti  (None, 8, 128)               49664     ['layer_normalization_1[0][0]'
#  onal)                                                              ]
#
#  bidirectional_4 (Bidirecti  (None, 8, 128)               49664     ['layer_normalization_2[0][0]'
#  onal)                                                              ]
#
#  bidirectional_1 (Bidirecti  (None, 8, 128)               98816     ['bidirectional[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 8, 128)               98816     ['bidirectional_2[0][0]']
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 8, 128)               98816     ['bidirectional_4[0][0]']
#  onal)
#
#  attention (Attention)       (None, 128)                  136       ['bidirectional_1[0][0]']
#
#  attention_1 (Attention)     (None, 128)                  136       ['bidirectional_3[0][0]']
#
#  attention_2 (Attention)     (None, 128)                  136       ['bidirectional_5[0][0]']
#
#  concatenate (Concatenate)   (None, 384)                  0         ['attention[0][0]',
#                                                                      'attention_1[0][0]',
#                                                                      'attention_2[0][0]']
#
#  dropout_12 (Dropout)        (None, 384)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 6)                    2310      ['dropout_12[0][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 849534 (3.24 MB)
# Trainable params: 846654 (3.23 MB)
# Non-trainable params: 2880 (11.25 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9559
# Average Accuracy: 0.9717146433316745
# Best Accuracy: 0.9889474511146545
# Last Epoch Accuracy: 0.9872470498085022
# Micro Accuracy: 0.9559
# Macro Accuracy: 0.9562
# Weighted Accuracy: 0.9559
# Precision (Macro): 0.9560839187729835
# Precision (Weighted): 0.9567116916683166
# Precision (Micro): 0.9558873430607397
# Recall (Macro): 0.9562259811885339
# Recall (Weighted): 0.9558873430607397
# Recall (Micro): 0.9558873430607397
# F1 Score (Macro): 0.9556562919969073
# F1 Score (Weighted): 0.955826485802426
# F1 Score (Micro): 0.9558873430607397
# Population Std Dev - True Labels: 1.7400526830680672
# Population Std Dev - Predicted Labels: 1.7316114308074289
# Sample Std Dev - True Labels: 1.7403479826345662
# Sample Std Dev - Predicted Labels: 1.7319052978321678
# _______________________________________________________________
# Metrics for WALKING:
#   True Positives (TP): 477
#   True Negatives (TN): 2448
#   False Positives (FP): 3
#   False Negatives (FN): 19
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 446
#   True Negatives (TN): 2465
#   False Positives (FP): 11
#   False Negatives (FN): 25
#
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 419
#   True Negatives (TN): 2494
#   False Positives (FP): 33
#   False Negatives (FN): 1
#
# Metrics for SITTING:
#   True Positives (TP): 433
#   True Negatives (TN): 2425
#   False Positives (FP): 31
#   False Negatives (FN): 58
#
# Metrics for STANDING:
#   True Positives (TP): 505
#   True Negatives (TN): 2363
#   False Positives (FP): 52
#   False Negatives (FN): 27
#
# Metrics for LAYING:
#   True Positives (TP): 537
#   True Negatives (TN): 2410
#   False Positives (FP): 0
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 16:16:20
# Elapsed time: 435.8341567516327 seconds
