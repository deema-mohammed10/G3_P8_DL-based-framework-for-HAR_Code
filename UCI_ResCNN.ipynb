# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')

from keras.layers import LeakyReLU
# Out:
# Timer started at 2024-06-03 17:42:22

# %% [markdown]
# # **Load the UCI-HAR Dataset**

# %%
root_train = '/content/drive/MyDrive/UCIHARDataset/train/train_Inertial_Signals'
root_test = '/content/drive/MyDrive/UCIHARDataset/test/test_Inertial_Signals'
model_save_path = '/content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5'

def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
        return files

file_x_train =  ['body_acc_x_train.txt', 'body_acc_y_train.txt', 'body_acc_z_train.txt',
                'body_gyro_x_train.txt', 'body_gyro_y_train.txt', 'body_gyro_z_train.txt',
                'total_acc_x_train.txt', 'total_acc_y_train.txt', 'total_acc_z_train.txt']
file_x_test = ['body_acc_x_test.txt', 'body_acc_y_test.txt', 'body_acc_z_test.txt',
               'body_gyro_x_test.txt', 'body_gyro_y_test.txt', 'body_gyro_z_test.txt',
               'total_acc_x_test.txt', 'total_acc_y_test.txt', 'total_acc_z_test.txt']

file_y_train = '/content/drive/MyDrive/UCIHARDataset/train/y_train.txt'
file_y_test = '/content/drive/MyDrive/UCIHARDataset/test/y_test.txt'

def load_x(data, root):
    x_body_acc = []
    for file in data[0:3]:
        x_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_body_acc.append(x_acc_input)
    x_body_acc = np.transpose(np.array(x_body_acc), (1, 2, 0))

    x_gro = []
    for file in data[3:6]:
        x_gro_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_gro.append(x_gro_input)
    x_gro = np.transpose(np.array(x_gro), (1, 2, 0))

    x_total_acc = []
    for file in data[6:9]:
        x_total_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_total_acc.append(x_total_acc_input)
    x_total_acc = np.transpose(np.array(x_total_acc), (1, 2, 0))
    return x_body_acc, x_gro, x_total_acc

def load_y(data):
    file = open(data, 'r')
    y_input = np.array([elem for elem in [row.strip().split(' ') for row in file]], dtype=np.int32)
    file.close()
    return to_categorical(y_input - 1.0)

x_body_acc_train, x_gro_train, x_total_acc_train = load_x(file_x_train, root_train)
x_body_acc_test, x_gro_test, x_total_acc_test = load_x(file_x_test, root_test)
y_train = load_y(file_y_train)
y_test = load_y(file_y_test)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class ResCNNAttentionModel:

    def __init__(self, kernel_size, learning_rate, batch_size):
        self.model = None
        self.kernel_size = kernel_size
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def Res_CNN_Attention(self, input_forward, input_backward, kernel_size):
        # 1D-CNN layers with different kernels
        conv1_forward = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(input_forward)
        conv1_backward = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

        # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

        # Dropout
        model = Dropout(0.2)(model)

        # Additional Conv1D layers
        model = Conv1D(128, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//2, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(128//4, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        # Layer Normalization
        model = LayerNormalization()(model)

        #ResCNN LAYERS
        x = Conv1D(128//8, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = LayerNormalization()(x)
        y = Conv1D(128//8, kernel_size, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = Add()([x, y])

        # Attention layer
        output = Attention(8)(model)

        return output

    def create_model(self, kernel_size, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))
        input_2_forward = Input(shape=(128, 3))
        input_2_backward = Input(shape=(128, 3))
        input_3_forward = Input(shape=(128, 3))
        input_3_backward = Input(shape=(128, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)
        input_2_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_2_backward)
        input_3_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_3_backward)

        model1 = self.Res_CNN_Attention(input_1_forward, input_1_backward_flipped, kernel_size)
        model2 = self.Res_CNN_Attention(input_2_forward, input_2_backward_flipped, kernel_size)
        model3 = self.Res_CNN_Attention(input_3_forward, input_3_backward_flipped, kernel_size)


        concatenated_models = Concatenate()([model1, model2, model3])

        output = Dropout(0.3)(concatenated_models)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped, input_2_forward, input_2_backward_flipped, input_3_forward, input_3_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)


        return history

    def fit2(self, X, y, kernel_size, learning_rate, batch_size, epochs, validation_data):
        self.create_model(kernel_size, learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history


    def get_params(self, deep=True):
        return {
            'kernel_size': self.kernel_size,
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Use 5-Fold GridSearchCV to test different combinations of the parameters**

# %%
param_grid = {
   'learning_rate': [0.01, 0.001, 0.0001],
  'kernel_size': [3, 5, 7],
   'batch_size': [32, 64]
 }
param_combinations = [(lr, ks, bs) for lr in param_grid['learning_rate'] for ks in param_grid['kernel_size'] for bs in param_grid['batch_size']]

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

best_loss = float('inf')
best_params_list = []

# Initialize the best accuracy variable and list for storing the best parameters
best_accuracy = 0

for lr, ks, bs in param_combinations:
    print(f"_________________________________________________________________________\nTesting Parameters: Learning Rate: {lr}, Kernel Size: {ks}, Batch Size: {bs}")

    fold_losses = []


    # Perform cross-validation
    for split, (train_index, val_index) in enumerate(kf.split(x_body_acc_train), 1):
        print(f"____________________________________________________\nSplit {split}\n____________________________________________________")

        # Create an instance of ResCNNAttentionModel with the specified hyperparameters
        model = ResCNNAttentionModel(kernel_size=ks, learning_rate=lr, batch_size=bs)

                # Split data into training and validation sets for each sensor type
        x_body_acc_train_fold = x_body_acc_train[train_index]
        x_body_acc_val_fold = x_body_acc_train[val_index]

        x_gro_train_fold = x_gro_train[train_index]
        x_gro_val_fold = x_gro_train[val_index]

        x_total_acc_train_fold = x_total_acc_train[train_index]
        x_total_acc_val_fold = x_total_acc_train[val_index]

        y_train_fold = y_train[train_index]
        y_val_fold = y_train[val_index]

        validation_data = (
        [x_body_acc_val_fold, np.flip(x_body_acc_val_fold, axis=1),
         x_gro_val_fold, np.flip(x_gro_val_fold, axis=1),
         x_total_acc_val_fold, np.flip(x_total_acc_val_fold, axis=1)],
         y_val_fold)


        # Fit the model to the training data for this fold with validation data
        history = model.fit(
         [x_body_acc_train_fold, np.flip(x_body_acc_train_fold, axis=1),
         x_gro_train_fold, np.flip(x_gro_train_fold, axis=1),
         x_total_acc_train_fold, np.flip(x_total_acc_train_fold, axis=1)],
         y_train_fold, kernel_size=ks, learning_rate=lr, batch_size=bs, epochs=75, validation_data=validation_data, early_stopping=True)

        # Evaluate the model on the validation data directly
        val_loss, val_accuracy = model.model.evaluate(
            [x_body_acc_val_fold, np.flip(x_body_acc_val_fold, axis=1),
             x_gro_val_fold, np.flip(x_gro_val_fold, axis=1),
             x_total_acc_val_fold, np.flip(x_total_acc_val_fold, axis=1)],
            y_val_fold, verbose=0
        )

        fold_losses.append(val_loss)

        print(f"Validation Loss for Split {split}: {val_loss:.4f}")

    mean_loss = np.mean(fold_losses)

    print(f"Mean Loss for Parameters: {lr}, {ks}, {bs} is {mean_loss:.4f}")

    if mean_loss < best_loss:
        best_loss = mean_loss
        best_params_list = [(lr, ks, bs)]
        print(f"New best parameters found: {lr}, {ks}, {bs}")

print(f"\nBest Overall Parameters: {best_params_list}, with a loss of {best_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 59: val_loss did not improve from 0.06473
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0581 - accuracy: 0.9772 - val_loss: 0.0811 - val_accuracy: 0.9701
# Epoch 60/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9733
# Epoch 60: val_loss did not improve from 0.06473
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0624 - accuracy: 0.9733 - val_loss: 0.0684 - val_accuracy: 0.9762
# Epoch 61/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9791
# Epoch 61: val_loss did not improve from 0.06473
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0589 - accuracy: 0.9793 - val_loss: 0.0658 - val_accuracy: 0.9762
# Epoch 62/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9748Restoring model weights from the end of the best epoch: 52.
#
# Epoch 62: val_loss did not improve from 0.06473
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0614 - accuracy: 0.9747 - val_loss: 0.0721 - val_accuracy: 0.9728
# Epoch 62: early stopping
# Validation Loss for Split 3: 0.0647
# ____________________________________________________
# Split 4
# ____________________________________________________
# Epoch 1/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.9940 - accuracy: 0.6178
# Epoch 1: val_loss improved from inf to 2.68457, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 26s 58ms/step - loss: 0.9916 - accuracy: 0.6185 - val_loss: 2.6846 - val_accuracy: 0.2027
# Epoch 2/75
# 92/92 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.8295
# Epoch 2: val_loss did not improve from 2.68457
# 92/92 [==============================] - 4s 40ms/step - loss: 0.5086 - accuracy: 0.8295 - val_loss: 2.7511 - val_accuracy: 0.1932
# Epoch 3/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.3841 - accuracy: 0.8678
# Epoch 3: val_loss improved from 2.68457 to 2.24300, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.3830 - accuracy: 0.8681 - val_loss: 2.2430 - val_accuracy: 0.2905
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2989 - accuracy: 0.9056
# Epoch 4: val_loss improved from 2.24300 to 1.15442, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.2979 - accuracy: 0.9058 - val_loss: 1.1544 - val_accuracy: 0.5415
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2539 - accuracy: 0.9172
# Epoch 5: val_loss improved from 1.15442 to 0.42613, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.2535 - accuracy: 0.9175 - val_loss: 0.4261 - val_accuracy: 0.8211
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2262 - accuracy: 0.9224
# Epoch 6: val_loss improved from 0.42613 to 0.21378, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.2254 - accuracy: 0.9230 - val_loss: 0.2138 - val_accuracy: 0.9122
# Epoch 7/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1966 - accuracy: 0.9318
# Epoch 7: val_loss improved from 0.21378 to 0.14000, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1967 - accuracy: 0.9318 - val_loss: 0.1400 - val_accuracy: 0.9408
# Epoch 8/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1942 - accuracy: 0.9336
# Epoch 8: val_loss improved from 0.14000 to 0.12627, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1942 - accuracy: 0.9335 - val_loss: 0.1263 - val_accuracy: 0.9361
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1768 - accuracy: 0.9360
# Epoch 9: val_loss improved from 0.12627 to 0.11178, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1759 - accuracy: 0.9364 - val_loss: 0.1118 - val_accuracy: 0.9565
# Epoch 10/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9439
# Epoch 10: val_loss did not improve from 0.11178
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1670 - accuracy: 0.9439 - val_loss: 0.1227 - val_accuracy: 0.9510
# Epoch 11/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9437
# Epoch 11: val_loss improved from 0.11178 to 0.10829, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1529 - accuracy: 0.9437 - val_loss: 0.1083 - val_accuracy: 0.9558
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1432 - accuracy: 0.9469
# Epoch 12: val_loss did not improve from 0.10829
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1432 - accuracy: 0.9470 - val_loss: 0.1085 - val_accuracy: 0.9599
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1465 - accuracy: 0.9454
# Epoch 13: val_loss did not improve from 0.10829
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1462 - accuracy: 0.9456 - val_loss: 0.1101 - val_accuracy: 0.9592
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1391 - accuracy: 0.9497
# Epoch 14: val_loss improved from 0.10829 to 0.10579, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1391 - accuracy: 0.9495 - val_loss: 0.1058 - val_accuracy: 0.9619
# Epoch 15/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9512
# Epoch 15: val_loss improved from 0.10579 to 0.10359, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1322 - accuracy: 0.9512 - val_loss: 0.1036 - val_accuracy: 0.9585
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1309 - accuracy: 0.9492
# Epoch 16: val_loss did not improve from 0.10359
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1308 - accuracy: 0.9492 - val_loss: 0.1060 - val_accuracy: 0.9551
# Epoch 17/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1257 - accuracy: 0.9557
# Epoch 17: val_loss did not improve from 0.10359
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1256 - accuracy: 0.9558 - val_loss: 0.1162 - val_accuracy: 0.9524
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9552
# Epoch 18: val_loss improved from 0.10359 to 0.09134, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1214 - accuracy: 0.9549 - val_loss: 0.0913 - val_accuracy: 0.9605
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9530
# Epoch 19: val_loss improved from 0.09134 to 0.09059, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1204 - accuracy: 0.9532 - val_loss: 0.0906 - val_accuracy: 0.9626
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9581
# Epoch 20: val_loss did not improve from 0.09059
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1141 - accuracy: 0.9578 - val_loss: 0.1227 - val_accuracy: 0.9524
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9605
# Epoch 21: val_loss did not improve from 0.09059
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1047 - accuracy: 0.9604 - val_loss: 0.0953 - val_accuracy: 0.9578
# Epoch 22/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9582
# Epoch 22: val_loss improved from 0.09059 to 0.08182, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1085 - accuracy: 0.9582 - val_loss: 0.0818 - val_accuracy: 0.9639
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1108 - accuracy: 0.9572
# Epoch 23: val_loss did not improve from 0.08182
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1104 - accuracy: 0.9575 - val_loss: 0.1110 - val_accuracy: 0.9551
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9596
# Epoch 24: val_loss improved from 0.08182 to 0.08058, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1094 - accuracy: 0.9599 - val_loss: 0.0806 - val_accuracy: 0.9707
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0997 - accuracy: 0.9610
# Epoch 25: val_loss improved from 0.08058 to 0.07743, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1009 - accuracy: 0.9604 - val_loss: 0.0774 - val_accuracy: 0.9612
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9621
# Epoch 26: val_loss improved from 0.07743 to 0.07429, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1015 - accuracy: 0.9616 - val_loss: 0.0743 - val_accuracy: 0.9707
# Epoch 27/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9634
# Epoch 27: val_loss improved from 0.07429 to 0.07368, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0908 - accuracy: 0.9634 - val_loss: 0.0737 - val_accuracy: 0.9639
# Epoch 28/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9636
# Epoch 28: val_loss did not improve from 0.07368
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0913 - accuracy: 0.9636 - val_loss: 0.1084 - val_accuracy: 0.9565
# Epoch 29/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0903 - accuracy: 0.9648
# Epoch 29: val_loss did not improve from 0.07368
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0896 - accuracy: 0.9651 - val_loss: 0.0740 - val_accuracy: 0.9639
# Epoch 30/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0894 - accuracy: 0.9658
# Epoch 30: val_loss improved from 0.07368 to 0.07317, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0889 - accuracy: 0.9660 - val_loss: 0.0732 - val_accuracy: 0.9762
# Epoch 31/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0857 - accuracy: 0.9675
# Epoch 31: val_loss improved from 0.07317 to 0.06942, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0856 - accuracy: 0.9674 - val_loss: 0.0694 - val_accuracy: 0.9762
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9640
# Epoch 32: val_loss improved from 0.06942 to 0.05793, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0881 - accuracy: 0.9640 - val_loss: 0.0579 - val_accuracy: 0.9782
# Epoch 33/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9679
# Epoch 33: val_loss did not improve from 0.05793
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0850 - accuracy: 0.9679 - val_loss: 0.1004 - val_accuracy: 0.9531
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9682
# Epoch 34: val_loss did not improve from 0.05793
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0859 - accuracy: 0.9685 - val_loss: 0.0602 - val_accuracy: 0.9721
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9670
# Epoch 35: val_loss did not improve from 0.05793
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0802 - accuracy: 0.9672 - val_loss: 0.1164 - val_accuracy: 0.9531
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9658
# Epoch 36: val_loss did not improve from 0.05793
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0811 - accuracy: 0.9657 - val_loss: 0.0744 - val_accuracy: 0.9639
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9650
# Epoch 37: val_loss improved from 0.05793 to 0.05417, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0792 - accuracy: 0.9651 - val_loss: 0.0542 - val_accuracy: 0.9789
# Epoch 38/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9704
# Epoch 38: val_loss did not improve from 0.05417
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0711 - accuracy: 0.9704 - val_loss: 0.0612 - val_accuracy: 0.9769
# Epoch 39/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9667
# Epoch 39: val_loss did not improve from 0.05417
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0797 - accuracy: 0.9667 - val_loss: 0.0587 - val_accuracy: 0.9755
# Epoch 40/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9687
# Epoch 40: val_loss improved from 0.05417 to 0.04806, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0766 - accuracy: 0.9687 - val_loss: 0.0481 - val_accuracy: 0.9816
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0751 - accuracy: 0.9684
# Epoch 41: val_loss did not improve from 0.04806
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0749 - accuracy: 0.9685 - val_loss: 0.0571 - val_accuracy: 0.9782
# Epoch 42/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9718
# Epoch 42: val_loss did not improve from 0.04806
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0730 - accuracy: 0.9718 - val_loss: 0.0792 - val_accuracy: 0.9728
# Epoch 43/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9703
# Epoch 43: val_loss did not improve from 0.04806
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0742 - accuracy: 0.9706 - val_loss: 0.0550 - val_accuracy: 0.9776
# Epoch 44/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9718
# Epoch 44: val_loss did not improve from 0.04806
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0704 - accuracy: 0.9718 - val_loss: 0.0917 - val_accuracy: 0.9551
# Epoch 45/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9709
# Epoch 45: val_loss improved from 0.04806 to 0.04617, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 47ms/step - loss: 0.0664 - accuracy: 0.9709 - val_loss: 0.0462 - val_accuracy: 0.9816
# Epoch 46/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0700 - accuracy: 0.9729
# Epoch 46: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0700 - accuracy: 0.9726 - val_loss: 0.0513 - val_accuracy: 0.9803
# Epoch 47/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0665 - accuracy: 0.9725
# Epoch 47: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0675 - accuracy: 0.9721 - val_loss: 0.0529 - val_accuracy: 0.9769
# Epoch 48/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9697
# Epoch 48: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0714 - accuracy: 0.9697 - val_loss: 0.0694 - val_accuracy: 0.9680
# Epoch 49/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9738
# Epoch 49: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0653 - accuracy: 0.9738 - val_loss: 0.0494 - val_accuracy: 0.9776
# Epoch 50/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0627 - accuracy: 0.9729
# Epoch 50: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0622 - accuracy: 0.9731 - val_loss: 0.0533 - val_accuracy: 0.9721
# Epoch 51/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0706 - accuracy: 0.9710
# Epoch 51: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0704 - accuracy: 0.9711 - val_loss: 0.0933 - val_accuracy: 0.9490
# Epoch 52/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9725
# Epoch 52: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0656 - accuracy: 0.9725 - val_loss: 0.0511 - val_accuracy: 0.9782
# Epoch 53/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9730
# Epoch 53: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0629 - accuracy: 0.9728 - val_loss: 0.0719 - val_accuracy: 0.9714
# Epoch 54/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9759
# Epoch 54: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0564 - accuracy: 0.9759 - val_loss: 0.0793 - val_accuracy: 0.9707
# Epoch 55/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9736Restoring model weights from the end of the best epoch: 45.
#
# Epoch 55: val_loss did not improve from 0.04617
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0656 - accuracy: 0.9736 - val_loss: 0.0892 - val_accuracy: 0.9639
# Epoch 55: early stopping
# Validation Loss for Split 4: 0.0462
# ____________________________________________________
# Split 5
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 1.1080 - accuracy: 0.5622
# Epoch 1: val_loss improved from inf to 2.20527, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 25s 58ms/step - loss: 1.1080 - accuracy: 0.5622 - val_loss: 2.2053 - val_accuracy: 0.3973
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.5962 - accuracy: 0.7960
# Epoch 2: val_loss did not improve from 2.20527
# 92/92 [==============================] - 4s 39ms/step - loss: 0.5972 - accuracy: 0.7955 - val_loss: 2.2087 - val_accuracy: 0.4143
# Epoch 3/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.4270 - accuracy: 0.8686
# Epoch 3: val_loss improved from 2.20527 to 1.92297, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.4262 - accuracy: 0.8688 - val_loss: 1.9230 - val_accuracy: 0.4469
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.3441 - accuracy: 0.8939
# Epoch 4: val_loss improved from 1.92297 to 1.11831, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.3438 - accuracy: 0.8943 - val_loss: 1.1183 - val_accuracy: 0.5959
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2872 - accuracy: 0.9116
# Epoch 5: val_loss improved from 1.11831 to 0.42869, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.2867 - accuracy: 0.9118 - val_loss: 0.4287 - val_accuracy: 0.8381
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9231
# Epoch 6: val_loss improved from 0.42869 to 0.21227, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.2504 - accuracy: 0.9232 - val_loss: 0.2123 - val_accuracy: 0.9286
# Epoch 7/75
# 92/92 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9323
# Epoch 7: val_loss improved from 0.21227 to 0.13894, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.2280 - accuracy: 0.9323 - val_loss: 0.1389 - val_accuracy: 0.9510
# Epoch 8/75
# 92/92 [==============================] - ETA: 0s - loss: 0.2091 - accuracy: 0.9315
# Epoch 8: val_loss improved from 0.13894 to 0.13754, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.2091 - accuracy: 0.9315 - val_loss: 0.1375 - val_accuracy: 0.9517
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.2005 - accuracy: 0.9330
# Epoch 9: val_loss improved from 0.13754 to 0.13207, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.2008 - accuracy: 0.9328 - val_loss: 0.1321 - val_accuracy: 0.9503
# Epoch 10/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9403
# Epoch 10: val_loss improved from 0.13207 to 0.12015, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1822 - accuracy: 0.9403 - val_loss: 0.1201 - val_accuracy: 0.9483
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9372
# Epoch 11: val_loss improved from 0.12015 to 0.10784, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1758 - accuracy: 0.9374 - val_loss: 0.1078 - val_accuracy: 0.9599
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9456
# Epoch 12: val_loss did not improve from 0.10784
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1599 - accuracy: 0.9458 - val_loss: 0.1097 - val_accuracy: 0.9578
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1635 - accuracy: 0.9402
# Epoch 13: val_loss improved from 0.10784 to 0.09446, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.1630 - accuracy: 0.9405 - val_loss: 0.0945 - val_accuracy: 0.9639
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9500
# Epoch 14: val_loss did not improve from 0.09446
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1450 - accuracy: 0.9502 - val_loss: 0.1059 - val_accuracy: 0.9558
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9476
# Epoch 15: val_loss improved from 0.09446 to 0.08977, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1441 - accuracy: 0.9475 - val_loss: 0.0898 - val_accuracy: 0.9653
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1495 - accuracy: 0.9459
# Epoch 16: val_loss did not improve from 0.08977
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1495 - accuracy: 0.9461 - val_loss: 0.0901 - val_accuracy: 0.9626
# Epoch 17/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1353 - accuracy: 0.9514
# Epoch 17: val_loss improved from 0.08977 to 0.08389, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1355 - accuracy: 0.9517 - val_loss: 0.0839 - val_accuracy: 0.9660
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1332 - accuracy: 0.9518
# Epoch 18: val_loss did not improve from 0.08389
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1332 - accuracy: 0.9517 - val_loss: 0.0917 - val_accuracy: 0.9585
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1320 - accuracy: 0.9505
# Epoch 19: val_loss improved from 0.08389 to 0.08102, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1323 - accuracy: 0.9505 - val_loss: 0.0810 - val_accuracy: 0.9694
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1239 - accuracy: 0.9519
# Epoch 20: val_loss did not improve from 0.08102
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1249 - accuracy: 0.9515 - val_loss: 0.0818 - val_accuracy: 0.9660
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9548
# Epoch 21: val_loss did not improve from 0.08102
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1203 - accuracy: 0.9549 - val_loss: 0.0817 - val_accuracy: 0.9639
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1221 - accuracy: 0.9560
# Epoch 22: val_loss did not improve from 0.08102
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1219 - accuracy: 0.9561 - val_loss: 0.0993 - val_accuracy: 0.9592
# Epoch 23/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.9560
# Epoch 23: val_loss improved from 0.08102 to 0.07940, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.1164 - accuracy: 0.9560 - val_loss: 0.0794 - val_accuracy: 0.9667
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9584
# Epoch 24: val_loss improved from 0.07940 to 0.06664, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1132 - accuracy: 0.9585 - val_loss: 0.0666 - val_accuracy: 0.9707
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1110 - accuracy: 0.9584
# Epoch 25: val_loss did not improve from 0.06664
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1110 - accuracy: 0.9587 - val_loss: 0.0780 - val_accuracy: 0.9694
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9569
# Epoch 26: val_loss did not improve from 0.06664
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1134 - accuracy: 0.9568 - val_loss: 0.0776 - val_accuracy: 0.9687
# Epoch 27/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9592
# Epoch 27: val_loss did not improve from 0.06664
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1064 - accuracy: 0.9592 - val_loss: 0.0670 - val_accuracy: 0.9714
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1122 - accuracy: 0.9569
# Epoch 28: val_loss improved from 0.06664 to 0.05861, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1119 - accuracy: 0.9572 - val_loss: 0.0586 - val_accuracy: 0.9748
# Epoch 29/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0990 - accuracy: 0.9607
# Epoch 29: val_loss did not improve from 0.05861
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0989 - accuracy: 0.9606 - val_loss: 0.0728 - val_accuracy: 0.9660
# Epoch 30/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9590
# Epoch 30: val_loss did not improve from 0.05861
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1029 - accuracy: 0.9590 - val_loss: 0.0665 - val_accuracy: 0.9667
# Epoch 31/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9623
# Epoch 31: val_loss did not improve from 0.05861
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0980 - accuracy: 0.9623 - val_loss: 0.0658 - val_accuracy: 0.9687
# Epoch 32/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9609
# Epoch 32: val_loss did not improve from 0.05861
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0940 - accuracy: 0.9607 - val_loss: 0.0646 - val_accuracy: 0.9714
# Epoch 33/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9629
# Epoch 33: val_loss improved from 0.05861 to 0.05637, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0981 - accuracy: 0.9626 - val_loss: 0.0564 - val_accuracy: 0.9748
# Epoch 34/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9628
# Epoch 34: val_loss improved from 0.05637 to 0.05313, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0911 - accuracy: 0.9628 - val_loss: 0.0531 - val_accuracy: 0.9769
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9634
# Epoch 35: val_loss did not improve from 0.05313
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0909 - accuracy: 0.9636 - val_loss: 0.0728 - val_accuracy: 0.9687
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9663
# Epoch 36: val_loss improved from 0.05313 to 0.05241, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0871 - accuracy: 0.9665 - val_loss: 0.0524 - val_accuracy: 0.9735
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0856 - accuracy: 0.9667
# Epoch 37: val_loss did not improve from 0.05241
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0863 - accuracy: 0.9663 - val_loss: 0.0648 - val_accuracy: 0.9728
# Epoch 38/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9657
# Epoch 38: val_loss did not improve from 0.05241
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0883 - accuracy: 0.9657 - val_loss: 0.0764 - val_accuracy: 0.9653
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0815 - accuracy: 0.9665
# Epoch 39: val_loss did not improve from 0.05241
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0815 - accuracy: 0.9665 - val_loss: 0.0735 - val_accuracy: 0.9680
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0784 - accuracy: 0.9679
# Epoch 40: val_loss improved from 0.05241 to 0.04539, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0795 - accuracy: 0.9672 - val_loss: 0.0454 - val_accuracy: 0.9782
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0839 - accuracy: 0.9648
# Epoch 41: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0838 - accuracy: 0.9650 - val_loss: 0.0604 - val_accuracy: 0.9701
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0781 - accuracy: 0.9698
# Epoch 42: val_loss did not improve from 0.04539
# 92/92 [==============================] - 3s 38ms/step - loss: 0.0780 - accuracy: 0.9696 - val_loss: 0.0600 - val_accuracy: 0.9721
# Epoch 43/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9675
# Epoch 43: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0779 - accuracy: 0.9675 - val_loss: 0.0578 - val_accuracy: 0.9803
# Epoch 44/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9697
# Epoch 44: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0758 - accuracy: 0.9697 - val_loss: 0.0588 - val_accuracy: 0.9762
# Epoch 45/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9693
# Epoch 45: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0783 - accuracy: 0.9685 - val_loss: 0.0999 - val_accuracy: 0.9469
# Epoch 46/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9680
# Epoch 46: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0748 - accuracy: 0.9680 - val_loss: 0.0510 - val_accuracy: 0.9803
# Epoch 47/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9698
# Epoch 47: val_loss did not improve from 0.04539
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0789 - accuracy: 0.9694 - val_loss: 0.0545 - val_accuracy: 0.9735
# Epoch 48/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9710
# Epoch 48: val_loss improved from 0.04539 to 0.04374, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 46ms/step - loss: 0.0745 - accuracy: 0.9711 - val_loss: 0.0437 - val_accuracy: 0.9810
# Epoch 49/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0722 - accuracy: 0.9703
# Epoch 49: val_loss did not improve from 0.04374
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0723 - accuracy: 0.9702 - val_loss: 0.0463 - val_accuracy: 0.9803
# Epoch 50/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0738 - accuracy: 0.9694
# Epoch 50: val_loss improved from 0.04374 to 0.04044, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0744 - accuracy: 0.9689 - val_loss: 0.0404 - val_accuracy: 0.9796
# Epoch 51/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9713
# Epoch 51: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0687 - accuracy: 0.9716 - val_loss: 0.0521 - val_accuracy: 0.9762
# Epoch 52/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9686
# Epoch 52: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0813 - accuracy: 0.9684 - val_loss: 0.0514 - val_accuracy: 0.9748
# Epoch 53/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0721 - accuracy: 0.9727
# Epoch 53: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0716 - accuracy: 0.9730 - val_loss: 0.0423 - val_accuracy: 0.9803
# Epoch 54/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9741
# Epoch 54: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0698 - accuracy: 0.9743 - val_loss: 0.0676 - val_accuracy: 0.9680
# Epoch 55/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9720
# Epoch 55: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0699 - accuracy: 0.9716 - val_loss: 0.0510 - val_accuracy: 0.9816
# Epoch 56/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0685 - accuracy: 0.9708
# Epoch 56: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0681 - accuracy: 0.9711 - val_loss: 0.0674 - val_accuracy: 0.9707
# Epoch 57/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9697
# Epoch 57: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0726 - accuracy: 0.9697 - val_loss: 0.0427 - val_accuracy: 0.9810
# Epoch 58/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0690 - accuracy: 0.9720
# Epoch 58: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0686 - accuracy: 0.9723 - val_loss: 0.0497 - val_accuracy: 0.9789
# Epoch 59/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9715
# Epoch 59: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0674 - accuracy: 0.9716 - val_loss: 0.0424 - val_accuracy: 0.9803
# Epoch 60/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0654 - accuracy: 0.9736Restoring model weights from the end of the best epoch: 50.
#
# Epoch 60: val_loss did not improve from 0.04044
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0650 - accuracy: 0.9738 - val_loss: 0.0417 - val_accuracy: 0.9844
# Epoch 60: early stopping
# Validation Loss for Split 5: 0.0404
# Mean Loss for Parameters: 0.0001, 3, 64 is 0.0469
# _________________________________________________________________________
# Testing Parameters: Learning Rate: 0.0001, Kernel Size: 5, Batch Size: 32
# ____________________________________________________
# Split 1
# ____________________________________________________
# Epoch 1/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.8133 - accuracy: 0.6988
# Epoch 1: val_loss improved from inf to 1.79941, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 28s 45ms/step - loss: 0.8117 - accuracy: 0.6994 - val_loss: 1.7994 - val_accuracy: 0.2060
# Epoch 2/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.8842
# Epoch 2: val_loss improved from 1.79941 to 0.74591, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.3588 - accuracy: 0.8842 - val_loss: 0.7459 - val_accuracy: 0.6676
# Epoch 3/75
# 184/184 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.9170
# Epoch 3: val_loss improved from 0.74591 to 0.21097, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.2523 - accuracy: 0.9170 - val_loss: 0.2110 - val_accuracy: 0.9096
# Epoch 4/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.2126 - accuracy: 0.9266
# Epoch 4: val_loss improved from 0.21097 to 0.12282, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.2123 - accuracy: 0.9269 - val_loss: 0.1228 - val_accuracy: 0.9436
# Epoch 5/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9356
# Epoch 5: val_loss improved from 0.12282 to 0.11175, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1829 - accuracy: 0.9356 - val_loss: 0.1117 - val_accuracy: 0.9504
# Epoch 6/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1678 - accuracy: 0.9421
# Epoch 6: val_loss improved from 0.11175 to 0.09592, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1676 - accuracy: 0.9422 - val_loss: 0.0959 - val_accuracy: 0.9592
# Epoch 7/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1645 - accuracy: 0.9407
# Epoch 7: val_loss did not improve from 0.09592
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1643 - accuracy: 0.9408 - val_loss: 0.0969 - val_accuracy: 0.9579
# Epoch 8/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9476
# Epoch 8: val_loss improved from 0.09592 to 0.09077, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1453 - accuracy: 0.9476 - val_loss: 0.0908 - val_accuracy: 0.9599
# Epoch 9/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9469
# Epoch 9: val_loss improved from 0.09077 to 0.08933, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1434 - accuracy: 0.9469 - val_loss: 0.0893 - val_accuracy: 0.9626
# Epoch 10/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9514
# Epoch 10: val_loss did not improve from 0.08933
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1388 - accuracy: 0.9514 - val_loss: 0.0904 - val_accuracy: 0.9592
# Epoch 11/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9507
# Epoch 11: val_loss improved from 0.08933 to 0.08201, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1281 - accuracy: 0.9507 - val_loss: 0.0820 - val_accuracy: 0.9640
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9496
# Epoch 12: val_loss did not improve from 0.08201
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1282 - accuracy: 0.9498 - val_loss: 0.0996 - val_accuracy: 0.9599
# Epoch 13/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9561
# Epoch 13: val_loss did not improve from 0.08201
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1227 - accuracy: 0.9561 - val_loss: 0.0968 - val_accuracy: 0.9633
# Epoch 14/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1277 - accuracy: 0.9493
# Epoch 14: val_loss did not improve from 0.08201
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1275 - accuracy: 0.9493 - val_loss: 0.0914 - val_accuracy: 0.9592
# Epoch 15/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1139 - accuracy: 0.9565
# Epoch 15: val_loss did not improve from 0.08201
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1135 - accuracy: 0.9566 - val_loss: 0.1057 - val_accuracy: 0.9619
# Epoch 16/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9534
# Epoch 16: val_loss did not improve from 0.08201
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1136 - accuracy: 0.9534 - val_loss: 0.0855 - val_accuracy: 0.9633
# Epoch 17/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9592
# Epoch 17: val_loss did not improve from 0.08201
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1010 - accuracy: 0.9592 - val_loss: 0.0992 - val_accuracy: 0.9633
# Epoch 18/75
# 184/184 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9590
# Epoch 18: val_loss improved from 0.08201 to 0.07569, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1078 - accuracy: 0.9590 - val_loss: 0.0757 - val_accuracy: 0.9694
# Epoch 19/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9611
# Epoch 19: val_loss did not improve from 0.07569
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0975 - accuracy: 0.9612 - val_loss: 0.0800 - val_accuracy: 0.9674
# Epoch 20/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9635
# Epoch 20: val_loss did not improve from 0.07569
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0989 - accuracy: 0.9634 - val_loss: 0.0785 - val_accuracy: 0.9660
# Epoch 21/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9614
# Epoch 21: val_loss did not improve from 0.07569
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1000 - accuracy: 0.9612 - val_loss: 0.0892 - val_accuracy: 0.9674
# Epoch 22/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9607
# Epoch 22: val_loss did not improve from 0.07569
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0955 - accuracy: 0.9607 - val_loss: 0.0858 - val_accuracy: 0.9667
# Epoch 23/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9626
# Epoch 23: val_loss did not improve from 0.07569
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0989 - accuracy: 0.9624 - val_loss: 0.0864 - val_accuracy: 0.9653
# Epoch 24/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9653
# Epoch 24: val_loss improved from 0.07569 to 0.06512, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.0875 - accuracy: 0.9653 - val_loss: 0.0651 - val_accuracy: 0.9735
# Epoch 25/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9667
# Epoch 25: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0825 - accuracy: 0.9667 - val_loss: 0.0787 - val_accuracy: 0.9660
# Epoch 26/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9684
# Epoch 26: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0809 - accuracy: 0.9684 - val_loss: 0.0893 - val_accuracy: 0.9572
# Epoch 27/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0847 - accuracy: 0.9676
# Epoch 27: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0845 - accuracy: 0.9677 - val_loss: 0.0770 - val_accuracy: 0.9701
# Epoch 28/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9662
# Epoch 28: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0818 - accuracy: 0.9660 - val_loss: 0.0890 - val_accuracy: 0.9674
# Epoch 29/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9682
# Epoch 29: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0788 - accuracy: 0.9682 - val_loss: 0.0689 - val_accuracy: 0.9708
# Epoch 30/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9650
# Epoch 30: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0836 - accuracy: 0.9651 - val_loss: 0.0988 - val_accuracy: 0.9606
# Epoch 31/75
# 184/184 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9672
# Epoch 31: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0795 - accuracy: 0.9672 - val_loss: 0.0858 - val_accuracy: 0.9640
# Epoch 32/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0776 - accuracy: 0.9684
# Epoch 32: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0774 - accuracy: 0.9685 - val_loss: 0.1097 - val_accuracy: 0.9531
# Epoch 33/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9710
# Epoch 33: val_loss did not improve from 0.06512
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0739 - accuracy: 0.9711 - val_loss: 0.1060 - val_accuracy: 0.9436
# Epoch 34/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0764 - accuracy: 0.9672Restoring model weights from the end of the best epoch: 24.
#
# Epoch 34: val_loss did not improve from 0.06512
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0771 - accuracy: 0.9672 - val_loss: 0.0830 - val_accuracy: 0.9640
# Epoch 34: early stopping
# Validation Loss for Split 1: 0.0651
# ____________________________________________________
# Split 2
# ____________________________________________________
# Epoch 1/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.7645 - accuracy: 0.7123
# ...
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1130 - accuracy: 0.9543
# Epoch 16: val_loss did not improve from 0.07788
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1126 - accuracy: 0.9546 - val_loss: 0.0963 - val_accuracy: 0.9544
# Epoch 17/75
# 92/92 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9575
# Epoch 17: val_loss improved from 0.07788 to 0.07359, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 48ms/step - loss: 0.1090 - accuracy: 0.9575 - val_loss: 0.0736 - val_accuracy: 0.9646
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9596
# Epoch 18: val_loss did not improve from 0.07359
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1040 - accuracy: 0.9599 - val_loss: 0.1267 - val_accuracy: 0.9531
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9591
# Epoch 19: val_loss did not improve from 0.07359
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1022 - accuracy: 0.9592 - val_loss: 0.0925 - val_accuracy: 0.9619
# Epoch 20/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9585
# Epoch 20: val_loss did not improve from 0.07359
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0989 - accuracy: 0.9585 - val_loss: 0.0748 - val_accuracy: 0.9687
# Epoch 21/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9609
# Epoch 21: val_loss improved from 0.07359 to 0.06378, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 49ms/step - loss: 0.0953 - accuracy: 0.9609 - val_loss: 0.0638 - val_accuracy: 0.9735
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9614
# Epoch 22: val_loss did not improve from 0.06378
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0951 - accuracy: 0.9612 - val_loss: 0.1266 - val_accuracy: 0.9422
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0893 - accuracy: 0.9629
# Epoch 23: val_loss did not improve from 0.06378
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0891 - accuracy: 0.9631 - val_loss: 0.0703 - val_accuracy: 0.9687
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0906 - accuracy: 0.9648
# Epoch 24: val_loss did not improve from 0.06378
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0904 - accuracy: 0.9650 - val_loss: 0.1754 - val_accuracy: 0.9347
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9679
# Epoch 25: val_loss did not improve from 0.06378
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0807 - accuracy: 0.9680 - val_loss: 0.1067 - val_accuracy: 0.9476
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9672
# Epoch 26: val_loss did not improve from 0.06378
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0820 - accuracy: 0.9674 - val_loss: 0.0845 - val_accuracy: 0.9633
# Epoch 27/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9697
# Epoch 27: val_loss improved from 0.06378 to 0.05207, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.0799 - accuracy: 0.9697 - val_loss: 0.0521 - val_accuracy: 0.9762
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9653
# Epoch 28: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0821 - accuracy: 0.9653 - val_loss: 0.0720 - val_accuracy: 0.9701
# Epoch 29/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0765 - accuracy: 0.9691
# Epoch 29: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0764 - accuracy: 0.9692 - val_loss: 0.0656 - val_accuracy: 0.9714
# Epoch 30/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9712
# Epoch 30: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0789 - accuracy: 0.9709 - val_loss: 0.1680 - val_accuracy: 0.9224
# Epoch 31/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9716
# Epoch 31: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0731 - accuracy: 0.9716 - val_loss: 0.0575 - val_accuracy: 0.9769
# Epoch 32/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9684
# Epoch 32: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0748 - accuracy: 0.9684 - val_loss: 0.1993 - val_accuracy: 0.9340
# Epoch 33/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9720
# Epoch 33: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0708 - accuracy: 0.9721 - val_loss: 0.1331 - val_accuracy: 0.9435
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0734 - accuracy: 0.9691
# Epoch 34: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0745 - accuracy: 0.9685 - val_loss: 0.0615 - val_accuracy: 0.9741
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0700 - accuracy: 0.9706
# Epoch 35: val_loss did not improve from 0.05207
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0697 - accuracy: 0.9708 - val_loss: 0.0560 - val_accuracy: 0.9796
# Epoch 36/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9706
# Epoch 36: val_loss improved from 0.05207 to 0.05103, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0695 - accuracy: 0.9706 - val_loss: 0.0510 - val_accuracy: 0.9735
# Epoch 37/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9716
# Epoch 37: val_loss did not improve from 0.05103
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0673 - accuracy: 0.9716 - val_loss: 0.1275 - val_accuracy: 0.9476
# Epoch 38/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0674 - accuracy: 0.9717
# Epoch 38: val_loss did not improve from 0.05103
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0672 - accuracy: 0.9718 - val_loss: 0.0921 - val_accuracy: 0.9517
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0695 - accuracy: 0.9710
# Epoch 39: val_loss did not improve from 0.05103
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0695 - accuracy: 0.9711 - val_loss: 0.1428 - val_accuracy: 0.9367
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9708
# Epoch 40: val_loss improved from 0.05103 to 0.04930, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 49ms/step - loss: 0.0735 - accuracy: 0.9711 - val_loss: 0.0493 - val_accuracy: 0.9769
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9700
# Epoch 41: val_loss improved from 0.04930 to 0.04840, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0698 - accuracy: 0.9699 - val_loss: 0.0484 - val_accuracy: 0.9810
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0695 - accuracy: 0.9713
# Epoch 42: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0693 - accuracy: 0.9713 - val_loss: 0.0755 - val_accuracy: 0.9660
# Epoch 43/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0606 - accuracy: 0.9768
# Epoch 43: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0610 - accuracy: 0.9765 - val_loss: 0.0589 - val_accuracy: 0.9694
# Epoch 44/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9717
# Epoch 44: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0674 - accuracy: 0.9718 - val_loss: 0.0654 - val_accuracy: 0.9673
# Epoch 45/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9730
# Epoch 45: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0664 - accuracy: 0.9733 - val_loss: 0.0820 - val_accuracy: 0.9646
# Epoch 46/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0604 - accuracy: 0.9766
# Epoch 46: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0604 - accuracy: 0.9765 - val_loss: 0.0991 - val_accuracy: 0.9503
# Epoch 47/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9774
# Epoch 47: val_loss did not improve from 0.04840
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0575 - accuracy: 0.9774 - val_loss: 0.0728 - val_accuracy: 0.9694
# Epoch 48/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9775
# Epoch 48: val_loss improved from 0.04840 to 0.04511, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.0545 - accuracy: 0.9777 - val_loss: 0.0451 - val_accuracy: 0.9810
# Epoch 49/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9739
# Epoch 49: val_loss did not improve from 0.04511
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0655 - accuracy: 0.9742 - val_loss: 0.0652 - val_accuracy: 0.9755
# Epoch 50/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9772
# Epoch 50: val_loss did not improve from 0.04511
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0592 - accuracy: 0.9774 - val_loss: 0.0794 - val_accuracy: 0.9660
# Epoch 51/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0571 - accuracy: 0.9748
# Epoch 51: val_loss did not improve from 0.04511
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0572 - accuracy: 0.9748 - val_loss: 0.0585 - val_accuracy: 0.9776
# Epoch 52/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9791
# Epoch 52: val_loss did not improve from 0.04511
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0523 - accuracy: 0.9791 - val_loss: 0.0458 - val_accuracy: 0.9803
# Epoch 53/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9772
# Epoch 53: val_loss improved from 0.04511 to 0.04420, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 49ms/step - loss: 0.0562 - accuracy: 0.9772 - val_loss: 0.0442 - val_accuracy: 0.9796
# Epoch 54/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9801
# Epoch 54: val_loss improved from 0.04420 to 0.04170, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0511 - accuracy: 0.9801 - val_loss: 0.0417 - val_accuracy: 0.9830
# Epoch 55/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9770
# Epoch 55: val_loss improved from 0.04170 to 0.03786, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0562 - accuracy: 0.9772 - val_loss: 0.0379 - val_accuracy: 0.9850
# Epoch 56/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9748
# Epoch 56: val_loss did not improve from 0.03786
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0606 - accuracy: 0.9748 - val_loss: 0.0641 - val_accuracy: 0.9714
# Epoch 57/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9770
# Epoch 57: val_loss did not improve from 0.03786
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0545 - accuracy: 0.9764 - val_loss: 0.0422 - val_accuracy: 0.9810
# Epoch 58/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9768
# Epoch 58: val_loss did not improve from 0.03786
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0540 - accuracy: 0.9769 - val_loss: 0.0404 - val_accuracy: 0.9837
# Epoch 59/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9821
# Epoch 59: val_loss improved from 0.03786 to 0.03634, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0472 - accuracy: 0.9820 - val_loss: 0.0363 - val_accuracy: 0.9837
# Epoch 60/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0565 - accuracy: 0.9787
# Epoch 60: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0572 - accuracy: 0.9784 - val_loss: 0.0401 - val_accuracy: 0.9823
# Epoch 61/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9801
# Epoch 61: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0516 - accuracy: 0.9803 - val_loss: 0.0524 - val_accuracy: 0.9782
# Epoch 62/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9782
# Epoch 62: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0561 - accuracy: 0.9782 - val_loss: 0.0421 - val_accuracy: 0.9837
# Epoch 63/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9796
# Epoch 63: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0540 - accuracy: 0.9791 - val_loss: 0.0637 - val_accuracy: 0.9714
# Epoch 64/75
# 92/92 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9782
# Epoch 64: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0521 - accuracy: 0.9782 - val_loss: 0.0467 - val_accuracy: 0.9803
# Epoch 65/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0501 - accuracy: 0.9804
# Epoch 65: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0503 - accuracy: 0.9803 - val_loss: 0.0667 - val_accuracy: 0.9680
# Epoch 66/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9775
# Epoch 66: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0535 - accuracy: 0.9777 - val_loss: 0.0423 - val_accuracy: 0.9830
# Epoch 67/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0566 - accuracy: 0.9773
# Epoch 67: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0565 - accuracy: 0.9772 - val_loss: 0.0457 - val_accuracy: 0.9844
# Epoch 68/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9804
# Epoch 68: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0500 - accuracy: 0.9801 - val_loss: 0.0372 - val_accuracy: 0.9878
# Epoch 69/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9780Restoring model weights from the end of the best epoch: 59.
#
# Epoch 69: val_loss did not improve from 0.03634
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0524 - accuracy: 0.9781 - val_loss: 0.0523 - val_accuracy: 0.9769
# Epoch 69: early stopping
# Validation Loss for Split 5: 0.0363
# Mean Loss for Parameters: 0.0001, 7, 64 is 0.0443
#
# Best Overall Parameters: [(0.001, 3, 32)], with a loss of 0.0382

# %% [markdown]
# # **Now we train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.001,
    'kernel_size': 3,
    'batch_size': 32
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_body_acc_train, x_gro_train, x_total_acc_train], axis=-1),
    y_train,
    test_size=0.2,
    random_state=42
)


# Train the final model using the best hyperparameters
best_model = ResCNNAttentionModel(kernel_size=best_params['kernel_size'], learning_rate=best_params['learning_rate'], batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
    X=[
        x_train_final[:, :, :3],
        np.flip(x_train_final[:, :, :3], axis=1),
        x_train_final[:, :, 3:6],
        np.flip(x_train_final[:, :, 3:6], axis=1),
        x_train_final[:, :, 6:],
        np.flip(x_train_final[:, :, 6:], axis=1)
    ],
    y=y_train_final,
    kernel_size=best_params['kernel_size'],
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],
            np.flip(x_val_final[:, :, :3], axis=1),
            x_val_final[:, :, 3:6],
            np.flip(x_val_final[:, :, 3:6], axis=1),
            x_val_final[:, :, 6:],
            np.flip(x_val_final[:, :, 6:], axis=1)
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                                      x_gro_test, np.flip(x_gro_test, axis=1),
                                                      x_total_acc_test, np.flip(x_total_acc_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                   x_gro_test, np.flip(x_gro_test, axis=1),
                                   x_total_acc_test, np.flip(x_total_acc_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics

# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'],
                  index=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 184/184 [==============================] - ETA: 0s - loss: 0.4302 - accuracy: 0.8442
# Epoch 1: val_accuracy improved from -inf to 0.24949, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 43s 53ms/step - loss: 0.4302 - accuracy: 0.8442 - val_loss: 3.9035 - val_accuracy: 0.2495
# Epoch 2/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1953 - accuracy: 0.9247
# Epoch 2: val_accuracy improved from 0.24949 to 0.62882, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1955 - accuracy: 0.9247 - val_loss: 1.2463 - val_accuracy: 0.6288
# Epoch 3/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9345
# Epoch 3: val_accuracy improved from 0.62882 to 0.89463, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 8s 45ms/step - loss: 0.1632 - accuracy: 0.9345 - val_loss: 0.2351 - val_accuracy: 0.8946
# Epoch 4/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9439
# Epoch 4: val_accuracy improved from 0.89463 to 0.95717, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1503 - accuracy: 0.9439 - val_loss: 0.1044 - val_accuracy: 0.9572
# Epoch 5/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9393
# Epoch 5: val_accuracy improved from 0.95717 to 0.95921, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1529 - accuracy: 0.9393 - val_loss: 0.1022 - val_accuracy: 0.9592
# Epoch 6/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1397 - accuracy: 0.9433
# Epoch 6: val_accuracy did not improve from 0.95921
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1395 - accuracy: 0.9434 - val_loss: 0.1256 - val_accuracy: 0.9585
# Epoch 7/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9469
# Epoch 7: val_accuracy did not improve from 0.95921
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1243 - accuracy: 0.9469 - val_loss: 0.1176 - val_accuracy: 0.9477
# Epoch 8/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1176 - accuracy: 0.9512
# Epoch 8: val_accuracy improved from 0.95921 to 0.96329, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 8s 45ms/step - loss: 0.1175 - accuracy: 0.9512 - val_loss: 0.0869 - val_accuracy: 0.9633
# Epoch 9/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9497
# Epoch 9: val_accuracy improved from 0.96329 to 0.96601, saving model to /content/drive/MyDrive/UCI-HAR/GridSearchCV-Tuning-ResCNN3.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1302 - accuracy: 0.9497 - val_loss: 0.0863 - val_accuracy: 0.9660
# Epoch 10/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.9510
# Epoch 10: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1247 - accuracy: 0.9507 - val_loss: 0.1603 - val_accuracy: 0.9307
# Epoch 11/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9527
# Epoch 11: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1220 - accuracy: 0.9527 - val_loss: 0.0917 - val_accuracy: 0.9619
# Epoch 12/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9529
# Epoch 12: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1149 - accuracy: 0.9531 - val_loss: 0.0803 - val_accuracy: 0.9653
# Epoch 13/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1131 - accuracy: 0.9568
# Epoch 13: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1131 - accuracy: 0.9568 - val_loss: 0.0903 - val_accuracy: 0.9599
# Epoch 14/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1106 - accuracy: 0.9532
# Epoch 14: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1108 - accuracy: 0.9531 - val_loss: 0.0768 - val_accuracy: 0.9660
# Epoch 15/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0982 - accuracy: 0.9612
# Epoch 15: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0997 - accuracy: 0.9606 - val_loss: 0.0793 - val_accuracy: 0.9646
# Epoch 16/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9577
# Epoch 16: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1011 - accuracy: 0.9575 - val_loss: 0.0865 - val_accuracy: 0.9606
# Epoch 17/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9589
# Epoch 17: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1041 - accuracy: 0.9589 - val_loss: 0.2122 - val_accuracy: 0.9130
# Epoch 18/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9558
# Epoch 18: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1058 - accuracy: 0.9556 - val_loss: 0.0784 - val_accuracy: 0.9613
# Epoch 19/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9563Restoring model weights from the end of the best epoch: 9.
#
# Epoch 19: val_accuracy did not improve from 0.96601
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1088 - accuracy: 0.9563 - val_loss: 0.1672 - val_accuracy: 0.9218
# Epoch 19: early stopping
# 93/93 [==============================] - 1s 7ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_7 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_8 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_5 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_9 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             1280      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             1280      ['input_7[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 128, 128)             1280      ['input_3[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 128, 128)             1280      ['input_8[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 128, 128)             1280      ['input_5[0][0]']
#
#  conv1d_15 (Conv1D)          (None, 128, 128)             1280      ['input_9[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 256)             0         ['conv1d_7[1][0]',
#  )                                                                   'conv1d_8[1][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 256)             0         ['conv1d_14[1][0]',
#  )                                                                   'conv1d_15[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 128, 256)             1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 128, 256)             1024      ['concatenate_2[1][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_4[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_8 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_8[1][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  dropout_4 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_4[1][0]']
#
#  dropout_8 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_8[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              98432     ['dropout[1][0]']
#
#  conv1d_9 (Conv1D)           (None, 64, 128)              98432     ['dropout_4[1][0]']
#
#  conv1d_16 (Conv1D)          (None, 64, 128)              98432     ['dropout_8[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 64, 128)              512       ['conv1d_9[1][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 128)              512       ['conv1d_16[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_5[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_9 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_9[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  dropout_5 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_5[1][0]']
#
#  dropout_9 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_9[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               24640     ['dropout_1[1][0]']
#
#  conv1d_10 (Conv1D)          (None, 32, 64)               24640     ['dropout_5[1][0]']
#
#  conv1d_17 (Conv1D)          (None, 32, 64)               24640     ['dropout_9[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 32, 64)               256       ['conv1d_10[1][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 32, 64)               256       ['conv1d_17[1][0]']
#  tchNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_6[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_10 (MaxPooli  (None, 16, 64)               0         ['batch_normalization_10[1][0]
#  ng1D)                                                              ']
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  dropout_6 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_6[1][0]']
#
#  dropout_10 (Dropout)        (None, 16, 64)               0         ['max_pooling1d_10[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               6176      ['dropout_2[1][0]']
#
#  conv1d_11 (Conv1D)          (None, 16, 32)               6176      ['dropout_6[1][0]']
#
#  conv1d_18 (Conv1D)          (None, 16, 32)               6176      ['dropout_10[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 32)               128       ['conv1d_11[1][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 16, 32)               128       ['conv1d_18[1][0]']
#  tchNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_7[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_11 (MaxPooli  (None, 8, 32)                0         ['batch_normalization_11[1][0]
#  ng1D)                                                              ']
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  dropout_7 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_7[1][0]']
#
#  dropout_11 (Dropout)        (None, 8, 32)                0         ['max_pooling1d_11[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  layer_normalization_2 (Lay  (None, 8, 32)                64        ['dropout_7[1][0]']
#  erNormalization)
#
#  layer_normalization_4 (Lay  (None, 8, 32)                64        ['dropout_11[1][0]']
#  erNormalization)
#
#  conv1d_5 (Conv1D)           (None, 8, 16)                1552      ['layer_normalization[1][0]']
#
#  conv1d_12 (Conv1D)          (None, 8, 16)                1552      ['layer_normalization_2[1][0]'
#                                                                     ]
#
#  conv1d_19 (Conv1D)          (None, 8, 16)                1552      ['layer_normalization_4[1][0]'
#                                                                     ]
#
#  layer_normalization_1 (Lay  (None, 8, 16)                32        ['conv1d_5[1][0]']
#  erNormalization)
#
#  layer_normalization_3 (Lay  (None, 8, 16)                32        ['conv1d_12[1][0]']
#  erNormalization)
#
#  layer_normalization_5 (Lay  (None, 8, 16)                32        ['conv1d_19[1][0]']
#  erNormalization)
#
#  conv1d_6 (Conv1D)           (None, 8, 16)                784       ['layer_normalization_1[1][0]'
#                                                                     ]
#
#  conv1d_13 (Conv1D)          (None, 8, 16)                784       ['layer_normalization_3[1][0]'
#                                                                     ]
#
#  conv1d_20 (Conv1D)          (None, 8, 16)                784       ['layer_normalization_5[1][0]'
#                                                                     ]
#
#  add (Add)                   (None, 8, 16)                0         ['conv1d_5[1][0]',
#                                                                      'conv1d_6[1][0]']
#
#  add_1 (Add)                 (None, 8, 16)                0         ['conv1d_12[1][0]',
#                                                                      'conv1d_13[1][0]']
#
#  add_2 (Add)                 (None, 8, 16)                0         ['conv1d_19[1][0]',
#                                                                      'conv1d_20[1][0]']
#
#  attention (Attention)       (None, 16)                   24        ['add[1][0]']
#
#  attention_1 (Attention)     (None, 16)                   24        ['add_1[1][0]']
#
#  attention_2 (Attention)     (None, 16)                   24        ['add_2[1][0]']
#
#  concatenate_3 (Concatenate  (None, 48)                   0         ['attention[1][0]',
#  )                                                                   'attention_1[1][0]',
#                                                                      'attention_2[1][0]']
#
#  dropout_12 (Dropout)        (None, 48)                   0         ['concatenate_3[1][0]']
#
#  dense (Dense)               (None, 6)                    294       ['dropout_12[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 408846 (1.56 MB)
# Trainable params: 405966 (1.55 MB)
# Non-trainable params: 2880 (11.25 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9410
# Average Accuracy: 0.9438423482995284
# Best Accuracy: 0.9605509042739868
# Last Epoch Accuracy: 0.9562999606132507
# Micro Accuracy: 0.9410
# Macro Accuracy: 0.9413
# Weighted Accuracy: 0.9410
# Precision (Macro): 0.9420309336608069
# Precision (Weighted): 0.9410340264912729
# Precision (Micro): 0.9409569053274517
# Recall (Macro): 0.9412688370152248
# Recall (Weighted): 0.9409569053274517
# Recall (Micro): 0.9409569053274517
# F1 Score (Macro): 0.9412987593681478
# F1 Score (Weighted): 0.9406375695315536
# F1 Score (Micro): 0.9409569053274517
# Population Std Dev - True Labels: 1.7400526830680672
# Population Std Dev - Predicted Labels: 1.751072231911334
# Sample Std Dev - True Labels: 1.7403479826345662
# Sample Std Dev - Predicted Labels: 1.751369401575232
# _______________________________________________________________
# Metrics for WALKING:
#   True Positives (TP): 486
#   True Negatives (TN): 2432
#   False Positives (FP): 19
#   False Negatives (FN): 10
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 444
#   True Negatives (TN): 2460
#   False Positives (FP): 16
#   False Negatives (FN): 27
#
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 411
#   True Negatives (TN): 2513
#   False Positives (FP): 14
#   False Negatives (FN): 9
#
# Metrics for SITTING:
#   True Positives (TP): 409
#   True Negatives (TN): 2410
#   False Positives (FP): 46
#   False Negatives (FN): 82
#
# Metrics for STANDING:
#   True Positives (TP): 486
#   True Negatives (TN): 2341
#   False Positives (FP): 74
#   False Negatives (FN): 46
#
# Metrics for LAYING:
#   True Positives (TP): 537
#   True Negatives (TN): 2405
#   False Positives (FP): 5
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 17:47:07
# Elapsed time: 284.9531614780426 seconds
