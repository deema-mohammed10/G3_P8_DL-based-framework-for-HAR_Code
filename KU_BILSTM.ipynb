# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %%
start_timer()

# Standard library imports
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import json
import random
import warnings
import itertools

# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')

from keras.layers import LeakyReLU
# Out:
# Timer started at 2024-06-03 16:56:41

# %%
# Data Augmentation Code

def show_signals(data):
    Accelerometer_X_axis_data = data[:, 0]
    Accelerometer_Y_axis_data = data[:, 1]
    Accelerometer_Z_axis_data = data[:, 2]
    Gyroscope_X_axis_data = data[:, 3]
    Gyroscope_Y_axis_data = data[:, 4]
    Gyroscope_Z_axis_data = data[:, 5]
    time = np.linspace(0.01, data.shape[0] / 100, data.shape[0])

    plt.figure(figsize=(20, 10), dpi=80)

    ax1 = plt.subplot(231)
    ax1.plot(time, Accelerometer_X_axis_data, "b")
    ax1.title.set_text(f"Accelerometer X axis")
    ax1.set_xlabel("time (s) ->")
    ax1.set_ylabel("Acceleration (m/s^2)")
    ax1.grid(True)

    ax2 = plt.subplot(232)
    ax2.plot(time, Accelerometer_Y_axis_data, "g")
    ax2.title.set_text(f"Accelerometer Y axis")
    ax2.set_xlabel("time (s) ->")
    ax2.set_ylabel("Acceleration (m/s^2)")
    ax2.grid(True)

    ax3 = plt.subplot(233)
    ax3.plot(time, Accelerometer_Z_axis_data, "r")
    ax3.title.set_text(f"Accelerometer Z axis")
    ax3.set_xlabel("time (s) ->")
    ax3.set_ylabel("Acceleration (m/s^2)")
    ax3.grid(True)

    ax4 = plt.subplot(234)
    ax4.plot(time, Gyroscope_X_axis_data, "b")
    ax4.title.set_text(f"Gyroscope X axis")
    ax4.set_xlabel("time (s) ->")
    ax4.set_ylabel("Angular rotation (rad/s)")
    ax4.grid(True)

    ax5 = plt.subplot(235)
    ax5.plot(time, Gyroscope_Y_axis_data, "g")
    ax5.title.set_text(f"Gyroscope Y axis")
    ax5.set_xlabel("time (s) ->")
    ax5.set_ylabel("Angular rotation (rad/s)")
    ax5.grid(True)

    ax6 = plt.subplot(236)
    ax6.plot(time, Gyroscope_Z_axis_data, "r")
    ax6.title.set_text(f"Gyroscope Z axis")
    ax6.set_xlabel("time (s) ->")
    ax6.set_ylabel("Angular rotation (rad/s)")
    ax6.grid(True)

    plt.show()

f = open("/content/drive/MyDrive/KU-HAR/data_augmentation_KU-HAR.txt", "r")
all_lines = f.readlines()

pairs = []

for line in all_lines:
    line = line.rstrip().split(" ")

    # store pairs
    pairs.append([line[0], line[-1]])

print(pairs, "\n")
print("Num. of samples: ", len(pairs))

CLASS_LABELS = np.array([
    "Stand", "Sit", "Talk-sit", "Talk-stand", "Stand-sit", "Lay", "Lay-stand", "Pick", "Jump", "Push-up",
    "Sit-up", "Walk", "Walk-backward", "Walk-circle", "Run", "Stair-up", "Stair-down", "Table-tennis"
])

df = pd.read_csv("/content/drive/MyDrive/KU-HAR/KU-HAR_time_domain_subsamples_20750x300.csv", header=None)

signals = df.values[:, 0:1800]
signals = np.array(signals, dtype=np.float32)
labels = df.values[:, 1800]
labels = np.array(labels, dtype=np.int64)

print(signals.shape, labels.shape, "\n")

# Remove broken samples in original dataset
indexes = [6587, 6588, 6589, 6590, 6591, 6592, 6593, 6594, 6595, 6596, 6597, 6598, 6599, 6600, 6601, 6602, 6603, 6604,
           6605, 6606, 6607, 6660, 6661, 6662, 6663, 6664, 6665, 6666, 6667, 6668, 6669, 6670, 6671, 6672, 6673, 6674,
           6675, 6676, 6677, 6678, 6679, 6680, 6681, 6682, 6683, 6684, 6685, 6686, 6687, 6716, 6717, 6718, 6719, 6720,
           6721, 6722, 6723, 6724, 6725, 6726, 6727, 6728, 6729, 6730, 6731, 6732, 6733, 6734, 6735, 6736, 6737, 6738,
           6739, 6740, 6741, 6742, 6743, 6750, 6751, 6752, 6753, 6754, 6755, 6756, 6757, 6758, 6759, 6760, 6761, 6762,
           6763, 6764, 6765, 6766, 6767]

# delete the broken samples
signals = np.delete(signals, indexes, 0)
labels = np.delete(labels, indexes, 0)

signals = np.stack([
    signals[:, 0:300],    # ACC X
    signals[:, 300:600],  # ACC Y
    signals[:, 600:900],  # ACC Z
    signals[:, 900:1200],  # GYRO X
    signals[:, 1200:1500],  # GYRO Y
    signals[:, 1500:1800],  # GYRO Z
], axis=-1)

labels = np.repeat(labels.reshape(labels.shape[0], 1), signals.shape[1], axis=1)

print("Mean:", np.mean(signals, axis=(0, 1)))
print("Std:", np.std(signals, axis=(0, 1)))
print("Max:", np.max(signals, axis=(0, 1)))
print("Min:", np.min(signals, axis=(0, 1)), "\n")

print(signals.shape, labels.shape, "\n")

new_signals = []
new_labels = []

for i in range(len(pairs)):
    print("Working on ", i, "sample")

    first = np.where(CLASS_LABELS == pairs[i][0])[0]
    second = np.where(CLASS_LABELS == pairs[i][1])[0]

    first_indexes = np.unique(np.where(labels == first)[0])
    second_indexes = np.unique(np.where(labels == second)[0])

    # Minimum for creating absolutely non-duplicate examples - prevention of overfit
    count = min(first_indexes.shape[0], second_indexes.shape[0])

    merged_signals = np.concatenate(
        (signals[first_indexes[:count]], signals[second_indexes[:count]]), axis=1
    )

    merged_labels = np.concatenate(
        (labels[first_indexes[:count]], labels[second_indexes[:count]]), axis=1
    )

    downsample_signals = merged_signals[:, ::2, :]
    new_signals.append(downsample_signals)

    downsample_labels = merged_labels[:, ::2]
    new_labels.append(downsample_labels)

# Merge all pairs into batch axis
new_signals = np.concatenate(new_signals, axis=0)
new_labels = np.concatenate(new_labels, axis=0)

# Merge all pairs into batch axis
final_signals = np.concatenate([signals, new_signals], axis=0)
final_labels = np.concatenate([labels, new_labels], axis=0)


print("Mean:", np.mean(final_signals, axis=(0, 1)))
print("Std:", np.std(final_signals, axis=(0, 1)))
print("Max:", np.max(final_signals, axis=(0, 1)))
print("Min:", np.min(final_signals, axis=(0, 1)), "\n")

print(final_signals.shape, final_labels.shape)

# Visualize labels distribution
plt.figure(figsize=(10, 10), dpi=80)

total_counts = final_labels.shape[0] * final_labels.shape[1]
unique, final_counts = np.unique(final_labels, return_counts=True)
chart = plt.bar(CLASS_LABELS[unique], final_counts)
plt.xticks(rotation=70)

unique, counts = np.unique(new_labels, return_counts=True)
plt.bar(CLASS_LABELS[unique], counts)
plt.xticks(rotation=70)

unique, counts = np.unique(labels, return_counts=True)
plt.bar(CLASS_LABELS[unique], counts)
plt.xticks(rotation=70)

for i, p in enumerate(chart):
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x + width / 2,
             y + height * 1.01,
             str(round((final_counts[i] * 100) / total_counts, 1)) + '%',
             ha='center',
             weight='bold')

plt.legend(["Final", "New", "Original"])
plt.show()

np.savez_compressed("new_dataset", signals=final_signals, labels=final_labels)
# Out:
# [['Stand', 'Talk-stand'], ['Stand', 'Pick'], ['Stand', 'Jump'], ['Stand', 'Walk'], ['Stand', 'Walk-backward'], ['Stand', 'Walk-circle'], ['Stand', 'Run'], ['Stand', 'Stair-up'], ['Stand', 'Stair-down'], ['Stand', 'Table-tennis'], ['Sit', 'Talk-sit'], ['Talk-sit', 'Sit'], ['Talk-stand', 'Stand'], ['Talk-stand', 'Pick'], ['Talk-stand', 'Jump'], ['Talk-stand', 'Walk'], ['Talk-stand', 'Walk-backward'], ['Talk-stand', 'Walk-circle'], ['Talk-stand', 'Run'], ['Talk-stand', 'Stair-up'], ['Talk-stand', 'Stair-down'], ['Talk-stand', 'Table-tennis'], ['Lay', 'Sit-up'], ['Pick', 'Stand'], ['Pick', 'Talk-stand'], ['Pick', 'Jump'], ['Pick', 'Walk'], ['Pick', 'Walk-backward'], ['Pick', 'Walk-circle'], ['Pick', 'Run'], ['Pick', 'Stair-up'], ['Pick', 'Stair-down'], ['Pick', 'Table-tennis'], ['Jump', 'Stand'], ['Jump', 'Talk-stand'], ['Jump', 'Pick'], ['Jump', 'Walk'], ['Jump', 'Walk-backward'], ['Jump', 'Walk-circle'], ['Jump', 'Run'], ['Jump', 'Stair-up'], ['Jump', 'Stair-down'], ['Jump', 'Table-tennis'], ['Sit-up', 'Lay'], ['Walk', 'Stand'], ['Walk', 'Talk-stand'], ['Walk', 'Pick'], ['Walk', 'Jump'], ['Walk', 'Walk-circle'], ['Walk', 'Run'], ['Walk', 'Stair-up'], ['Walk', 'Stair-down'], ['Walk', 'Table-tennis'], ['Walk-backward', 'Stand'], ['Walk-backward', 'Talk-stand'], ['Walk-backward', 'Pick'], ['Walk-backward', 'Jump'], ['Walk-backward', 'Table-tennis'], ['Walk-circle', 'Stand'], ['Walk-circle', 'Talk-stand'], ['Walk-circle', 'Pick'], ['Walk-circle', 'Jump'], ['Walk-circle', 'Walk'], ['Walk-circle', 'Run'], ['Walk-circle', 'Stair-up'], ['Walk-circle', 'Stair-down'], ['Walk-circle', 'Table-tennis'], ['Run', 'Stand'], ['Run', 'Talk-stand'], ['Run', 'Pick'], ['Run', 'Jump'], ['Run', 'Walk'], ['Run', 'Walk-circle'], ['Run', 'Stair-up'], ['Run', 'Stair-down'], ['Run', 'Table-tennis'], ['Stair-up', 'Stand'], ['Stair-up', 'Talk-stand'], ['Stair-up', 'Pick'], ['Stair-up', 'Jump'], ['Stair-up', 'Walk'], ['Stair-up', 'Walk-circle'], ['Stair-up', 'Run'], ['Stair-up', 'Stair-down'], ['Stair-down', 'Stand'], ['Stair-down', 'Talk-stand'], ['Stair-down', 'Pick'], ['Stair-down', 'Jump'], ['Stair-down', 'Walk'], ['Stair-down', 'Walk-circle'], ['Stair-down', 'Run'], ['Stair-down', 'Stair-up'], ['Table-tennis', 'Stand'], ['Table-tennis', 'Talk-stand'], ['Table-tennis', 'Pick'], ['Table-tennis', 'Jump'], ['Table-tennis', 'Walk'], ['Table-tennis', 'Walk-backward'], ['Table-tennis', 'Walk-circle'], ['Table-tennis', 'Run']]
#
# Num. of samples:  100
# (20750, 1800) (20750,)
#
# Mean: [ 0.04835381 -0.04000019 -0.06103219  0.01185658  0.00415822  0.00092788]
# Std: [3.6388602 2.1443195 2.8478932 1.309968  1.0470778 1.0666409]
# Max: [194.52   91.779 340.59   97.376  79.272  78.783]
# Min: [-172.74  -143.17  -315.89  -113.8    -85.757  -78.866]
#
# (20655, 300, 6) (20655, 300)
#
# Working on  0 sample
# Working on  1 sample
# Working on  2 sample
# Working on  3 sample
# Working on  4 sample
# Working on  5 sample
# Working on  6 sample
# Working on  7 sample
# Working on  8 sample
# Working on  9 sample
# Working on  10 sample
# Working on  11 sample
# Working on  12 sample
# Working on  13 sample
# Working on  14 sample
# Working on  15 sample
# Working on  16 sample
# Working on  17 sample
# Working on  18 sample
# Working on  19 sample
# Working on  20 sample
# Working on  21 sample
# Working on  22 sample
# Working on  23 sample
# Working on  24 sample
# Working on  25 sample
# Working on  26 sample
# Working on  27 sample
# Working on  28 sample
# Working on  29 sample
# Working on  30 sample
# Working on  31 sample
# Working on  32 sample
# Working on  33 sample
# Working on  34 sample
# Working on  35 sample
# Working on  36 sample
# Working on  37 sample
# Working on  38 sample
# Working on  39 sample
# Working on  40 sample
# Working on  41 sample
# Working on  42 sample
# Working on  43 sample
# Working on  44 sample
# Working on  45 sample
# Working on  46 sample
# Working on  47 sample
# Working on  48 sample
# Working on  49 sample
# Working on  50 sample
# Working on  51 sample
# Working on  52 sample
# Working on  53 sample
# Working on  54 sample
# Working on  55 sample
# Working on  56 sample
# Working on  57 sample
# Working on  58 sample
# Working on  59 sample
# Working on  60 sample
# Working on  61 sample
# Working on  62 sample
# Working on  63 sample
# Working on  64 sample
# Working on  65 sample
# Working on  66 sample
# Working on  67 sample
# Working on  68 sample
# Working on  69 sample
# Working on  70 sample
# Working on  71 sample
# Working on  72 sample
# Working on  73 sample
# Working on  74 sample
# Working on  75 sample
# Working on  76 sample
# Working on  77 sample
# Working on  78 sample
# Working on  79 sample
# Working on  80 sample
# Working on  81 sample
# Working on  82 sample
# Working on  83 sample
# Working on  84 sample
# Working on  85 sample
# Working on  86 sample
# Working on  87 sample
# Working on  88 sample
# Working on  89 sample
# Working on  90 sample
# Working on  91 sample
# Working on  92 sample
# Working on  93 sample
# Working on  94 sample
# Working on  95 sample
# Working on  96 sample
# Working on  97 sample
# Working on  98 sample
# Working on  99 sample
# Mean: [ 0.10943159 -0.07794212 -0.0883355   0.0306053   0.00974582  0.00629569]
# Std: [5.192652  3.0467124 3.9461544 1.697749  1.36974   1.4093003]
# Max: [194.52   91.779 340.59   97.376  79.272  78.783]
# Min: [-172.74  -143.17  -315.89  -113.8    -85.757  -78.866]
#
# (83129, 300, 6) (83129, 300)

# %%
# Load the dataset
dataset = np.load("new_dataset.npz")

# Separate signals and labels
signals = dataset['signals']
labels = dataset['labels']

# Print the number of columns in the signals array
num_columns = signals.shape[2]
print("Number of columns in the signals array:", num_columns)

# Separate accelerometer and gyroscope data
x_acc = signals[:, :, :3]  # Extract accelerometer data (first three columns)
x_gyro = signals[:, :, 3:]  # Extract gyroscope data (last three columns)

# Split the dataset into train and test sets
x_acc_train, x_acc_test, y_train, y_test = train_test_split(x_acc, labels, test_size=0.2, random_state=42)
x_gyro_train, x_gyro_test, _, _ = train_test_split(x_gyro, labels, test_size=0.2, random_state=42)

# Print shapes to verify
print("x_acc_train shape:", x_acc_train.shape)
print("x_gyro_train shape:", x_gyro_train.shape)
print("x_acc_test shape:", x_acc_test.shape)
print("x_gyro_test shape:", x_gyro_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# One-hot encode the target data
y_train_encoded = to_categorical(y_train, num_classes=18)
y_test_encoded = to_categorical(y_test, num_classes=18)

# Reshape the target data to match the output shape of the model
y_train_reshaped = y_train_encoded[:, 0, :]
y_test_reshaped = y_test_encoded[:, 0, :]

model_save_path = '/content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5'
# Out:
# Number of columns in the signals array: 6
# x_acc_train shape: (66503, 300, 3)
# x_gyro_train shape: (66503, 300, 3)
# x_acc_test shape: (16626, 300, 3)
# x_gyro_test shape: (16626, 300, 3)
# y_train shape: (66503, 300)
# y_test shape: (16626, 300)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# #**Define the Model Structure**

# %%
class BLSTMAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def BLSTM_Attention(self, input):
        model = Conv1D(256, 3, input_shape=(128, 3), activation=LeakyReLU(alpha=0.3), padding='same')(input)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//2, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//4, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

        model = Conv1D(256//8, 3, activation=LeakyReLU(alpha=0.3), padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)


        model = LayerNormalization()(model)

        x = Bidirectional(LSTM(64, return_sequences=True))(model)
        model = Bidirectional(LSTM(64, return_sequences=True))(x)

        output = Attention(18)(model)
        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1= Input(shape=(300, 3))
        input_2= Input(shape=(300, 3))


        model1 = self.BLSTM_Attention(input_1)
        model2 = self.BLSTM_Attention(input_2)


        concatenated_models = Concatenate()([model1, model2])

        output = Dropout(0.2)(concatenated_models)
        output = Dense(18)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1, input_2], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)

        return history


    def fit2(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history



    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 64
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_acc_train, x_gyro_train], axis=-1),
    y_train_reshaped,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = BLSTMAttentionModel(learning_rate=best_params['learning_rate'], batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
     X=[
        x_train_final[:, :, :3],  # Original body acceleration data for the final model
        x_train_final[:, :, 3:],  # Original body gyro data for the final model
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],  # Original validation body acceleration data
            x_val_final[:, :, 3:],  # Original validation body gyro data
        ],
        y_val_final
    )
)

# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_acc_test,
                                                      x_gyro_test],
                                                    y_test_reshaped, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_acc_test,
                                   x_gyro_test])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax( y_test_reshaped, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics
average_accuracy = np.mean(history.history['accuracy'])
best_accuracy = np.max(history.history['accuracy'])
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

class_labels = ["Stand", "Sit", "Talk-sit", "Talk-stand", "Stand-sit", "Lay", "Lay-stand", "Pick",
                "Jump", "Push-up", "Sit-up", "Walk", "Walk-backward", "Walk-circle", "Run", "Stair-up",
                "Stair-down","Table-tennis"]

conf_matrix = confusion_matrix(y_true_labels, y_pred_labels, labels=range(len(class_labels)))
cm = pd.DataFrame(conf_matrix, columns=class_labels, index=class_labels)

# Plot the confusion matrix heatmap with adjusted annotation size and label size
plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True, annot_kws={"size": 10}, cbar=True)
plt.yticks(rotation=0, fontsize=12, weight='bold')
plt.xticks(rotation=45, ha='right', fontsize=12, weight='bold')
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

conf_matrix = confusion_matrix(y_true_labels, y_pred_labels, labels=range(len(class_labels)))
TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
for i, class_label in enumerate(class_labels):
    print(f"Metrics for {class_label}:")
    tp = TP[i] if i < len(TP) else 0
    tn = TN[i] if i < len(TN) else 0
    fp = FP[i] if i < len(FP) else 0
    fn = FN[i] if i < len(FN) else 0
    print(f"  True Positives (TP): {tp}")
    print(f"  True Negatives (TN): {tn}")
    print(f"  False Positives (FP): {fp}")
    print(f"  False Negatives (FN): {fn}\n")

stop_timer()
# Out:
# Epoch 1/150
# 832/832 [==============================] - ETA: 0s - loss: 0.5768 - accuracy: 0.7963
# Epoch 1: val_accuracy improved from -inf to 0.82595, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 90s 62ms/step - loss: 0.5768 - accuracy: 0.7963 - val_loss: 0.4355 - val_accuracy: 0.8260
# Epoch 2/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.2966 - accuracy: 0.8891
# Epoch 2: val_accuracy improved from 0.82595 to 0.88016, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 48s 58ms/step - loss: 0.2967 - accuracy: 0.8891 - val_loss: 0.3894 - val_accuracy: 0.8802
# Epoch 3/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.9099
# Epoch 3: val_accuracy improved from 0.88016 to 0.89347, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 46s 55ms/step - loss: 0.2389 - accuracy: 0.9100 - val_loss: 0.3240 - val_accuracy: 0.8935
# Epoch 4/150
# 832/832 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9207
# Epoch 4: val_accuracy improved from 0.89347 to 0.92053, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 46s 55ms/step - loss: 0.2052 - accuracy: 0.9207 - val_loss: 0.1894 - val_accuracy: 0.9205
# Epoch 5/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9285
# Epoch 5: val_accuracy did not improve from 0.92053
# 832/832 [==============================] - 48s 57ms/step - loss: 0.1837 - accuracy: 0.9285 - val_loss: 0.2578 - val_accuracy: 0.8889
# Epoch 6/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9311
# Epoch 6: val_accuracy did not improve from 0.92053
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1734 - accuracy: 0.9311 - val_loss: 0.4883 - val_accuracy: 0.8823
# Epoch 7/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9354
# Epoch 7: val_accuracy improved from 0.92053 to 0.93933, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 46s 55ms/step - loss: 0.1591 - accuracy: 0.9354 - val_loss: 0.1441 - val_accuracy: 0.9393
# Epoch 8/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1512 - accuracy: 0.9398
# Epoch 8: val_accuracy improved from 0.93933 to 0.95301, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 47s 57ms/step - loss: 0.1512 - accuracy: 0.9398 - val_loss: 0.1344 - val_accuracy: 0.9530
# Epoch 9/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9413
# Epoch 9: val_accuracy did not improve from 0.95301
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1441 - accuracy: 0.9413 - val_loss: 0.1456 - val_accuracy: 0.9382
# Epoch 10/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9434
# Epoch 10: val_accuracy did not improve from 0.95301
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1375 - accuracy: 0.9434 - val_loss: 0.1308 - val_accuracy: 0.9459
# Epoch 11/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9466
# Epoch 11: val_accuracy did not improve from 0.95301
# 832/832 [==============================] - 45s 54ms/step - loss: 0.1311 - accuracy: 0.9466 - val_loss: 0.1864 - val_accuracy: 0.9235
# Epoch 12/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9455
# Epoch 12: val_accuracy did not improve from 0.95301
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1321 - accuracy: 0.9455 - val_loss: 0.1654 - val_accuracy: 0.9266
# Epoch 13/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9483
# Epoch 13: val_accuracy did not improve from 0.95301
# 832/832 [==============================] - 45s 54ms/step - loss: 0.1243 - accuracy: 0.9483 - val_loss: 0.1799 - val_accuracy: 0.9318
# Epoch 14/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9496
# Epoch 14: val_accuracy improved from 0.95301 to 0.95331, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 47s 57ms/step - loss: 0.1192 - accuracy: 0.9496 - val_loss: 0.1107 - val_accuracy: 0.9533
# Epoch 15/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9497
# Epoch 15: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1192 - accuracy: 0.9497 - val_loss: 0.1470 - val_accuracy: 0.9360
# Epoch 16/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9523
# Epoch 16: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1125 - accuracy: 0.9523 - val_loss: 0.1556 - val_accuracy: 0.9456
# Epoch 17/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9521
# Epoch 17: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1147 - accuracy: 0.9521 - val_loss: 0.1300 - val_accuracy: 0.9433
# Epoch 18/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9546
# Epoch 18: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1071 - accuracy: 0.9546 - val_loss: 0.1429 - val_accuracy: 0.9452
# Epoch 19/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1086 - accuracy: 0.9540
# Epoch 19: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 45s 54ms/step - loss: 0.1086 - accuracy: 0.9539 - val_loss: 0.1312 - val_accuracy: 0.9468
# Epoch 20/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9537
# Epoch 20: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1073 - accuracy: 0.9536 - val_loss: 0.1846 - val_accuracy: 0.9335
# Epoch 21/150
# 832/832 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9565
# Epoch 21: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 46s 55ms/step - loss: 0.1032 - accuracy: 0.9565 - val_loss: 0.1291 - val_accuracy: 0.9529
# Epoch 22/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1018 - accuracy: 0.9562
# Epoch 22: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 46s 55ms/step - loss: 0.1018 - accuracy: 0.9562 - val_loss: 0.1026 - val_accuracy: 0.9496
# Epoch 23/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.1003 - accuracy: 0.9569
# Epoch 23: val_accuracy did not improve from 0.95331
# 832/832 [==============================] - 44s 53ms/step - loss: 0.1003 - accuracy: 0.9569 - val_loss: 0.1354 - val_accuracy: 0.9477
# Epoch 24/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9575
# Epoch 24: val_accuracy improved from 0.95331 to 0.95519, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0998 - accuracy: 0.9575 - val_loss: 0.1126 - val_accuracy: 0.9552
# Epoch 25/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0952 - accuracy: 0.9597
# Epoch 25: val_accuracy did not improve from 0.95519
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0953 - accuracy: 0.9597 - val_loss: 0.1476 - val_accuracy: 0.9456
# Epoch 26/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9608
# Epoch 26: val_accuracy did not improve from 0.95519
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0931 - accuracy: 0.9608 - val_loss: 0.1493 - val_accuracy: 0.9422
# Epoch 27/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9619
# Epoch 27: val_accuracy improved from 0.95519 to 0.95669, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0907 - accuracy: 0.9619 - val_loss: 0.1010 - val_accuracy: 0.9567
# Epoch 28/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9640
# Epoch 28: val_accuracy did not improve from 0.95669
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0878 - accuracy: 0.9639 - val_loss: 0.1505 - val_accuracy: 0.9460
# Epoch 29/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9642
# Epoch 29: val_accuracy did not improve from 0.95669
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0862 - accuracy: 0.9642 - val_loss: 0.1471 - val_accuracy: 0.9445
# Epoch 30/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9659
# Epoch 30: val_accuracy did not improve from 0.95669
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0826 - accuracy: 0.9659 - val_loss: 0.1055 - val_accuracy: 0.9545
# Epoch 31/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9663
# Epoch 31: val_accuracy did not improve from 0.95669
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0824 - accuracy: 0.9663 - val_loss: 0.1196 - val_accuracy: 0.9529
# Epoch 32/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0818 - accuracy: 0.9665
# Epoch 32: val_accuracy improved from 0.95669 to 0.97166, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0818 - accuracy: 0.9665 - val_loss: 0.0791 - val_accuracy: 0.9717
# Epoch 33/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9682
# Epoch 33: val_accuracy did not improve from 0.97166
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0781 - accuracy: 0.9682 - val_loss: 0.1477 - val_accuracy: 0.9498
# Epoch 34/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9693
# Epoch 34: val_accuracy improved from 0.97166 to 0.97286, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0770 - accuracy: 0.9693 - val_loss: 0.0771 - val_accuracy: 0.9729
# Epoch 35/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9699
# Epoch 35: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0757 - accuracy: 0.9699 - val_loss: 0.1627 - val_accuracy: 0.9391
# Epoch 36/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0740 - accuracy: 0.9704
# Epoch 36: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0742 - accuracy: 0.9704 - val_loss: 0.0906 - val_accuracy: 0.9627
# Epoch 37/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9712
# Epoch 37: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0721 - accuracy: 0.9712 - val_loss: 0.0859 - val_accuracy: 0.9702
# Epoch 38/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9707
# Epoch 38: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0730 - accuracy: 0.9707 - val_loss: 0.1144 - val_accuracy: 0.9536
# Epoch 39/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0687 - accuracy: 0.9730
# Epoch 39: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0688 - accuracy: 0.9730 - val_loss: 0.0789 - val_accuracy: 0.9651
# Epoch 40/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9738
# Epoch 40: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0670 - accuracy: 0.9738 - val_loss: 0.0889 - val_accuracy: 0.9632
# Epoch 41/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9736
# Epoch 41: val_accuracy did not improve from 0.97286
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0680 - accuracy: 0.9736 - val_loss: 0.0805 - val_accuracy: 0.9675
# Epoch 42/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9737
# Epoch 42: val_accuracy improved from 0.97286 to 0.97527, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0659 - accuracy: 0.9737 - val_loss: 0.0690 - val_accuracy: 0.9753
# Epoch 43/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9757
# Epoch 43: val_accuracy did not improve from 0.97527
# 832/832 [==============================] - 46s 55ms/step - loss: 0.0629 - accuracy: 0.9757 - val_loss: 0.1895 - val_accuracy: 0.9429
# Epoch 44/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0646 - accuracy: 0.9753
# Epoch 44: val_accuracy improved from 0.97527 to 0.97752, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 47s 57ms/step - loss: 0.0646 - accuracy: 0.9753 - val_loss: 0.0651 - val_accuracy: 0.9775
# Epoch 45/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9770
# Epoch 45: val_accuracy did not improve from 0.97752
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0595 - accuracy: 0.9770 - val_loss: 0.0617 - val_accuracy: 0.9772
# Epoch 46/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9771
# Epoch 46: val_accuracy did not improve from 0.97752
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0598 - accuracy: 0.9771 - val_loss: 0.0604 - val_accuracy: 0.9766
# Epoch 47/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9763
# Epoch 47: val_accuracy improved from 0.97752 to 0.98038, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0614 - accuracy: 0.9763 - val_loss: 0.0566 - val_accuracy: 0.9804
# Epoch 48/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9779
# Epoch 48: val_accuracy did not improve from 0.98038
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0570 - accuracy: 0.9779 - val_loss: 0.0988 - val_accuracy: 0.9617
# Epoch 49/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9789
# Epoch 49: val_accuracy did not improve from 0.98038
# 832/832 [==============================] - 48s 58ms/step - loss: 0.0554 - accuracy: 0.9789 - val_loss: 0.0928 - val_accuracy: 0.9616
# Epoch 50/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9778
# Epoch 50: val_accuracy did not improve from 0.98038
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0572 - accuracy: 0.9778 - val_loss: 0.0800 - val_accuracy: 0.9707
# Epoch 51/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9797
# Epoch 51: val_accuracy improved from 0.98038 to 0.98158, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0540 - accuracy: 0.9797 - val_loss: 0.0561 - val_accuracy: 0.9816
# Epoch 52/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0549 - accuracy: 0.9798
# Epoch 52: val_accuracy did not improve from 0.98158
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0549 - accuracy: 0.9798 - val_loss: 0.0608 - val_accuracy: 0.9792
# Epoch 53/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9800
# Epoch 53: val_accuracy did not improve from 0.98158
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0527 - accuracy: 0.9800 - val_loss: 0.0655 - val_accuracy: 0.9781
# Epoch 54/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9799
# Epoch 54: val_accuracy improved from 0.98158 to 0.98196, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 48s 57ms/step - loss: 0.0540 - accuracy: 0.9799 - val_loss: 0.0549 - val_accuracy: 0.9820
# Epoch 55/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0517 - accuracy: 0.9808
# Epoch 55: val_accuracy did not improve from 0.98196
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0517 - accuracy: 0.9808 - val_loss: 0.0582 - val_accuracy: 0.9802
# Epoch 56/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9802
# Epoch 56: val_accuracy did not improve from 0.98196
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0522 - accuracy: 0.9802 - val_loss: 0.0559 - val_accuracy: 0.9809
# Epoch 57/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9816
# Epoch 57: val_accuracy improved from 0.98196 to 0.98241, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0506 - accuracy: 0.9816 - val_loss: 0.0537 - val_accuracy: 0.9824
# Epoch 58/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9827
# Epoch 58: val_accuracy did not improve from 0.98241
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0477 - accuracy: 0.9827 - val_loss: 0.0622 - val_accuracy: 0.9797
# Epoch 59/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9821
# Epoch 59: val_accuracy improved from 0.98241 to 0.98271, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 46s 55ms/step - loss: 0.0491 - accuracy: 0.9821 - val_loss: 0.0501 - val_accuracy: 0.9827
# Epoch 60/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0469 - accuracy: 0.9832
# Epoch 60: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 47s 57ms/step - loss: 0.0468 - accuracy: 0.9832 - val_loss: 0.0715 - val_accuracy: 0.9769
# Epoch 61/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0477 - accuracy: 0.9823
# Epoch 61: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0478 - accuracy: 0.9823 - val_loss: 0.0538 - val_accuracy: 0.9809
# Epoch 62/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9836
# Epoch 62: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0458 - accuracy: 0.9836 - val_loss: 0.0691 - val_accuracy: 0.9738
# Epoch 63/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0444 - accuracy: 0.9834
# Epoch 63: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0444 - accuracy: 0.9834 - val_loss: 0.1031 - val_accuracy: 0.9636
# Epoch 64/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9833
# Epoch 64: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0440 - accuracy: 0.9833 - val_loss: 0.0696 - val_accuracy: 0.9772
# Epoch 65/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9835
# Epoch 65: val_accuracy did not improve from 0.98271
# 832/832 [==============================] - 47s 57ms/step - loss: 0.0445 - accuracy: 0.9835 - val_loss: 0.0685 - val_accuracy: 0.9786
# Epoch 66/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9845
# Epoch 66: val_accuracy improved from 0.98271 to 0.98526, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 47s 57ms/step - loss: 0.0424 - accuracy: 0.9845 - val_loss: 0.0482 - val_accuracy: 0.9853
# Epoch 67/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0431 - accuracy: 0.9847
# Epoch 67: val_accuracy did not improve from 0.98526
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0430 - accuracy: 0.9847 - val_loss: 0.0523 - val_accuracy: 0.9820
# Epoch 68/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9848
# Epoch 68: val_accuracy did not improve from 0.98526
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0422 - accuracy: 0.9848 - val_loss: 0.0728 - val_accuracy: 0.9753
# Epoch 69/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0424 - accuracy: 0.9843
# Epoch 69: val_accuracy did not improve from 0.98526
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0424 - accuracy: 0.9843 - val_loss: 0.0597 - val_accuracy: 0.9817
# Epoch 70/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9853
# Epoch 70: val_accuracy did not improve from 0.98526
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0412 - accuracy: 0.9853 - val_loss: 0.1061 - val_accuracy: 0.9605
# Epoch 71/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9860
# Epoch 71: val_accuracy did not improve from 0.98526
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0394 - accuracy: 0.9860 - val_loss: 0.0513 - val_accuracy: 0.9841
# Epoch 72/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9858
# Epoch 72: val_accuracy improved from 0.98526 to 0.98557, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 46s 56ms/step - loss: 0.0395 - accuracy: 0.9858 - val_loss: 0.0450 - val_accuracy: 0.9856
# Epoch 73/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9864
# Epoch 73: val_accuracy did not improve from 0.98557
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0388 - accuracy: 0.9864 - val_loss: 0.0602 - val_accuracy: 0.9799
# Epoch 74/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9859
# Epoch 74: val_accuracy did not improve from 0.98557
# 832/832 [==============================] - 50s 61ms/step - loss: 0.0387 - accuracy: 0.9859 - val_loss: 0.0455 - val_accuracy: 0.9853
# Epoch 75/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9864
# Epoch 75: val_accuracy did not improve from 0.98557
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0383 - accuracy: 0.9864 - val_loss: 0.0984 - val_accuracy: 0.9684
# Epoch 76/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9853
# Epoch 76: val_accuracy improved from 0.98557 to 0.98744, saving model to /content/drive/MyDrive/KU-HAR/BILSTM_LEAKYRELU_KUHAR.hdf5
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0408 - accuracy: 0.9853 - val_loss: 0.0399 - val_accuracy: 0.9874
# Epoch 77/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0373 - accuracy: 0.9868
# Epoch 77: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.0443 - val_accuracy: 0.9866
# Epoch 78/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9861
# Epoch 78: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0379 - accuracy: 0.9861 - val_loss: 0.0454 - val_accuracy: 0.9839
# Epoch 79/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9865
# Epoch 79: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0365 - accuracy: 0.9865 - val_loss: 0.0648 - val_accuracy: 0.9796
# Epoch 80/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9872
# Epoch 80: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0364 - accuracy: 0.9872 - val_loss: 0.0499 - val_accuracy: 0.9839
# Epoch 81/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9871
# Epoch 81: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.0579 - val_accuracy: 0.9811
# Epoch 82/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0353 - accuracy: 0.9872
# Epoch 82: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0353 - accuracy: 0.9872 - val_loss: 0.0516 - val_accuracy: 0.9841
# Epoch 83/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9870
# Epoch 83: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 46s 55ms/step - loss: 0.0352 - accuracy: 0.9870 - val_loss: 0.0735 - val_accuracy: 0.9756
# Epoch 84/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9870
# Epoch 84: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0348 - accuracy: 0.9870 - val_loss: 0.0520 - val_accuracy: 0.9825
# Epoch 85/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9875
# Epoch 85: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0360 - accuracy: 0.9875 - val_loss: 0.0558 - val_accuracy: 0.9817
# Epoch 86/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0355 - accuracy: 0.9875
# Epoch 86: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0356 - accuracy: 0.9875 - val_loss: 0.0641 - val_accuracy: 0.9766
# Epoch 87/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9871
# Epoch 87: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 45s 53ms/step - loss: 0.0342 - accuracy: 0.9871 - val_loss: 0.0437 - val_accuracy: 0.9868
# Epoch 88/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9875
# Epoch 88: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.0427 - val_accuracy: 0.9858
# Epoch 89/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9882
# Epoch 89: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0328 - accuracy: 0.9882 - val_loss: 0.0403 - val_accuracy: 0.9873
# Epoch 90/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0335 - accuracy: 0.9881
# Epoch 90: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0335 - accuracy: 0.9881 - val_loss: 0.0434 - val_accuracy: 0.9859
# Epoch 91/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9879
# Epoch 91: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0339 - accuracy: 0.9879 - val_loss: 0.0527 - val_accuracy: 0.9845
# Epoch 92/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.9886
# Epoch 92: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0320 - accuracy: 0.9886 - val_loss: 0.0477 - val_accuracy: 0.9858
# Epoch 93/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9883
# Epoch 93: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 47s 56ms/step - loss: 0.0315 - accuracy: 0.9883 - val_loss: 0.0625 - val_accuracy: 0.9829
# Epoch 94/150
# 831/832 [============================>.] - ETA: 0s - loss: 0.0317 - accuracy: 0.9881
# Epoch 94: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 44s 53ms/step - loss: 0.0317 - accuracy: 0.9881 - val_loss: 0.0464 - val_accuracy: 0.9872
# Epoch 95/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9887
# Epoch 95: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 46s 55ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.0720 - val_accuracy: 0.9783
# Epoch 96/150
# 832/832 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9878Restoring model weights from the end of the best epoch: 76.
#
# Epoch 96: val_accuracy did not improve from 0.98744
# 832/832 [==============================] - 45s 54ms/step - loss: 0.0331 - accuracy: 0.9878 - val_loss: 0.0410 - val_accuracy: 0.9867
# Epoch 96: early stopping
# 520/520 [==============================] - 8s 11ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 300, 3)]             0         []
#
#  input_2 (InputLayer)        [(None, 300, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 300, 256)             2560      ['input_1[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 300, 256)             2560      ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 300, 256)             1024      ['conv1d[0][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 300, 256)             1024      ['conv1d_4[0][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 150, 256)             0         ['batch_normalization[0][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 150, 256)             0         ['batch_normalization_4[0][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 150, 256)             0         ['max_pooling1d[0][0]']
#
#  dropout_4 (Dropout)         (None, 150, 256)             0         ['max_pooling1d_4[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 150, 128)             98432     ['dropout[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 150, 128)             98432     ['dropout_4[0][0]']
#
#  batch_normalization_1 (Bat  (None, 150, 128)             512       ['conv1d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 150, 128)             512       ['conv1d_5[0][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 75, 128)              0         ['batch_normalization_1[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 75, 128)              0         ['batch_normalization_5[0][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 75, 128)              0         ['max_pooling1d_1[0][0]']
#
#  dropout_5 (Dropout)         (None, 75, 128)              0         ['max_pooling1d_5[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 75, 64)               24640     ['dropout_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 75, 64)               24640     ['dropout_5[0][0]']
#
#  batch_normalization_2 (Bat  (None, 75, 64)               256       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 75, 64)               256       ['conv1d_6[0][0]']
#  chNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 37, 64)               0         ['batch_normalization_2[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 37, 64)               0         ['batch_normalization_6[0][0]'
#  g1D)                                                               ]
#
#  dropout_2 (Dropout)         (None, 37, 64)               0         ['max_pooling1d_2[0][0]']
#
#  dropout_6 (Dropout)         (None, 37, 64)               0         ['max_pooling1d_6[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 37, 32)               6176      ['dropout_2[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 37, 32)               6176      ['dropout_6[0][0]']
#
#  batch_normalization_3 (Bat  (None, 37, 32)               128       ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 37, 32)               128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 18, 32)               0         ['batch_normalization_3[0][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 18, 32)               0         ['batch_normalization_7[0][0]'
#  g1D)                                                               ]
#
#  dropout_3 (Dropout)         (None, 18, 32)               0         ['max_pooling1d_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 18, 32)               0         ['max_pooling1d_7[0][0]']
#
#  layer_normalization (Layer  (None, 18, 32)               64        ['dropout_3[0][0]']
#  Normalization)
#
#  layer_normalization_1 (Lay  (None, 18, 32)               64        ['dropout_7[0][0]']
#  erNormalization)
#
#  bidirectional (Bidirection  (None, 18, 128)              49664     ['layer_normalization[0][0]']
#  al)
#
#  bidirectional_2 (Bidirecti  (None, 18, 128)              49664     ['layer_normalization_1[0][0]'
#  onal)                                                              ]
#
#  bidirectional_1 (Bidirecti  (None, 18, 128)              98816     ['bidirectional[0][0]']
#  onal)
#
#  bidirectional_3 (Bidirecti  (None, 18, 128)              98816     ['bidirectional_2[0][0]']
#  onal)
#
#  attention (Attention)       (None, 128)                  146       ['bidirectional_1[0][0]']
#
#  attention_1 (Attention)     (None, 128)                  146       ['bidirectional_3[0][0]']
#
#  concatenate (Concatenate)   (None, 256)                  0         ['attention[0][0]',
#                                                                      'attention_1[0][0]']
#
#  dropout_8 (Dropout)         (None, 256)                  0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 18)                   4626      ['dropout_8[0][0]']
#
#  softmax (Activation)        (None, 18)                   0         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 569462 (2.17 MB)
# Trainable params: 567542 (2.17 MB)
# Non-trainable params: 1920 (7.50 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9869
# Average Accuracy: 0.9689959194511175
# Best Accuracy: 0.9886658191680908
# Last Epoch Accuracy: 0.9877824187278748
# Micro Accuracy: 0.9869
# Macro Accuracy: 0.9815
# Weighted Accuracy: 0.9869
# Precision (Macro): 0.9856431943401271
# Precision (Weighted): 0.9872985841411288
# Precision (Micro): 0.986888006736437
# Recall (Macro): 0.9814753888125066
# Recall (Weighted): 0.986888006736437
# Recall (Micro): 0.986888006736437
# F1 Score (Macro): 0.9833087194885931
# F1 Score (Weighted): 0.9869215405467519
# F1 Score (Micro): 0.986888006736437
# Population Std Dev - True Labels: 5.578473957992873
# Population Std Dev - Predicted Labels: 5.593185095710682
# Sample Std Dev - True Labels: 5.578641729122909
# Sample Std Dev - Predicted Labels: 5.593353309274296
# _______________________________________________________________
# Metrics for Stand:
#   True Positives (TP): 1905
#   True Negatives (TN): 14649
#   False Positives (FP): 41
#   False Negatives (FN): 31
#
# Metrics for Sit:
#   True Positives (TP): 736
#   True Negatives (TN): 15762
#   False Positives (FP): 101
#   False Negatives (FN): 27
#
# Metrics for Talk-sit:
#   True Positives (TP): 666
#   True Negatives (TN): 15885
#   False Positives (FP): 23
#   False Negatives (FN): 52
#
# Metrics for Talk-stand:
#   True Positives (TP): 2019
#   True Negatives (TN): 14589
#   False Positives (FP): 11
#   False Negatives (FN): 7
#
# Metrics for Stand-sit:
#   True Positives (TP): 429
#   True Negatives (TN): 16190
#   False Positives (FP): 4
#   False Negatives (FN): 3
#
# Metrics for Lay:
#   True Positives (TP): 500
#   True Negatives (TN): 16049
#   False Positives (FP): 15
#   False Negatives (FN): 62
#
# Metrics for Lay-stand:
#   True Positives (TP): 303
#   True Negatives (TN): 16313
#   False Positives (FP): 4
#   False Negatives (FN): 6
#
# Metrics for Pick:
#   True Positives (TP): 1683
#   True Negatives (TN): 14934
#   False Positives (FP): 5
#   False Negatives (FN): 4
#
# Metrics for Jump:
#   True Positives (TP): 1218
#   True Negatives (TN): 15405
#   False Positives (FP): 1
#   False Negatives (FN): 2
#
# Metrics for Push-up:
#   True Positives (TP): 107
#   True Negatives (TN): 16515
#   False Positives (FP): 0
#   False Negatives (FN): 4
#
# Metrics for Sit-up:
#   True Positives (TP): 401
#   True Negatives (TN): 16216
#   False Positives (FP): 5
#   False Negatives (FN): 4
#
# Metrics for Walk:
#   True Positives (TP): 1407
#   True Negatives (TN): 15214
#   False Positives (FP): 0
#   False Negatives (FN): 5
#
# Metrics for Walk-backward:
#   True Positives (TP): 391
#   True Negatives (TN): 16233
#   False Positives (FP): 0
#   False Negatives (FN): 2
#
# Metrics for Walk-circle:
#   True Positives (TP): 520
#   True Negatives (TN): 16100
#   False Positives (FP): 3
#   False Negatives (FN): 3
#
# Metrics for Run:
#   True Positives (TP): 982
#   True Negatives (TN): 15643
#   False Positives (FP): 0
#   False Negatives (FN): 1
#
# Metrics for Stair-up:
#   True Positives (TP): 1217
#   True Negatives (TN): 15405
#   False Positives (FP): 3
#   False Negatives (FN): 1
#
# Metrics for Stair-down:
#   True Positives (TP): 1188
#   True Negatives (TN): 15433
#   False Positives (FP): 1
#   False Negatives (FN): 4
#
# Metrics for Table-tennis:
#   True Positives (TP): 736
#   True Negatives (TN): 15889
#   False Positives (FP): 1
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 18:11:49
# Elapsed time: 4507.8038239479065 seconds
