# %%
# Mount Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

def start_timer():
    global start_time
    start_time = time.time()
    print(f"Timer started at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(start_time))}")

def stop_timer():
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Timer stopped at {time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(end_time))}")
    print(f"Elapsed time: {elapsed_time} seconds")

# %% [markdown]
# # **Import The Needed Library**

# %%
start_timer()

# Standard library imports
import os
import json
import random
import warnings
import itertools


# Data manipulation and scientific computing
import numpy as np
import pandas as pd
from scipy import stats

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning and neural network libraries
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import Input, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import (BatchNormalization, Bidirectional, Conv1D,
                                     Dense, Dropout, LSTM, MaxPooling1D, Activation,
                                     AveragePooling1D, Concatenate, LayerNormalization,
                                     Add, Lambda, Flatten, Layer)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Model evaluation metrics
from sklearn.metrics import (confusion_matrix, f1_score, recall_score,
                             precision_score, accuracy_score, classification_report)
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV

# Filter out all warnings
warnings.filterwarnings("ignore")

# Disable TensorFlow warnings
tf.get_logger().setLevel('ERROR')
# Out:
# Timer started at 2024-06-03 16:15:47

# %% [markdown]
# # **Load the UCI-HAR Dataset**

# %%
root_train = '/content/drive/MyDrive/UCIHARDataset/train/train_Inertial_Signals'
root_test = '/content/drive/MyDrive/UCIHARDataset/test/test_Inertial_Signals'
model_save_path = '/content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5'

def file_name(file_dir):
    for root, dirs, files in os.walk(file_dir):
        return files

file_x_train =  ['body_acc_x_train.txt', 'body_acc_y_train.txt', 'body_acc_z_train.txt',
                'body_gyro_x_train.txt', 'body_gyro_y_train.txt', 'body_gyro_z_train.txt',
                'total_acc_x_train.txt', 'total_acc_y_train.txt', 'total_acc_z_train.txt']
file_x_test = ['body_acc_x_test.txt', 'body_acc_y_test.txt', 'body_acc_z_test.txt',
               'body_gyro_x_test.txt', 'body_gyro_y_test.txt', 'body_gyro_z_test.txt',
               'total_acc_x_test.txt', 'total_acc_y_test.txt', 'total_acc_z_test.txt']

file_y_train = '/content/drive/MyDrive/UCIHARDataset/train/y_train.txt'
file_y_test = '/content/drive/MyDrive/UCIHARDataset/test/y_test.txt'

def load_x(data, root):
    x_body_acc = []
    for file in data[0:3]:
        x_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_body_acc.append(x_acc_input)
    x_body_acc = np.transpose(np.array(x_body_acc), (1, 2, 0))

    x_gro = []
    for file in data[3:6]:
        x_gro_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_gro.append(x_gro_input)
    x_gro = np.transpose(np.array(x_gro), (1, 2, 0))

    x_total_acc = []
    for file in data[6:9]:
        x_total_acc_input = np.array(pd.DataFrame(pd.read_csv(root + '/' + file, sep='\s+', header=None)))
        x_total_acc.append(x_total_acc_input)
    x_total_acc = np.transpose(np.array(x_total_acc), (1, 2, 0))
    return x_body_acc, x_gro, x_total_acc

def load_y(data):
    file = open(data, 'r')
    y_input = np.array([elem for elem in [row.strip().split(' ') for row in file]], dtype=np.int32)
    file.close()
    return to_categorical(y_input - 1.0)

x_body_acc_train, x_gro_train, x_total_acc_train = load_x(file_x_train, root_train)
x_body_acc_test, x_gro_test, x_total_acc_test = load_x(file_x_test, root_test)
y_train = load_y(file_y_train)
y_test = load_y(file_y_test)

# %% [markdown]
# # **Define the Attention Model**

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = tf.keras.initializers.get('glorot_uniform')
        self.W_regularizer = tf.keras.regularizers.get(W_regularizer)
        self.b_regularizer = tf.keras.regularizers.get(b_regularizer)
        self.W_constraint = tf.keras.constraints.get(W_constraint)
        self.b_constraint = tf.keras.constraints.get(b_constraint)
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'step_dim': self.step_dim,
            'W_regularizer': self.W_regularizer,
            'b_regularizer': self.b_regularizer,
            'W_constraint': self.W_constraint,
            'b_constraint': self.b_constraint,
            'bias': self.bias,
        })
        return config

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                              K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a

        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim

# %% [markdown]
# # **Define the Model Structure**

# %%
class LSTMAttentionModel:

    def __init__(self, learning_rate, batch_size):
        self.model = None
        self.learning_rate = learning_rate
        self.batch_size = batch_size

    def LSTM_Attention(self, input_forward, input_backward):
        conv1_forward = Conv1D(128, 3, activation='relu', padding='same')(input_forward)
        conv1_backward = Conv1D(128, 3, activation='relu', padding='same')(input_backward)

        # Concatenate CNN outputs
        concatenated = Concatenate()([conv1_forward, conv1_backward])

        # Batch Normalization
        model = BatchNormalization()(concatenated)

       # Max Pooling
        model = MaxPooling1D(pool_size=2)(model)

       # Dropout
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128//2, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # 1D-CNN layers with different kernels
        model = Conv1D(128//4, 3, activation='relu', padding='same')(model)
        model = BatchNormalization()(model)
        model = MaxPooling1D(pool_size=2)(model)
        model = Dropout(0.2)(model)

       # Layer Normalization
        model = LayerNormalization()(model)

       # LSTM layers
        x = LSTM(64, return_sequences=True)(model)
        model = LSTM(64, return_sequences=True)(x)

        # Attention layer
        output = Attention(8)(model)

        return output

    def create_model(self, learning_rate, batch_size):
        # Define the input layers
        input_1_forward = Input(shape=(128, 3))
        input_1_backward = Input(shape=(128, 3))
        input_2_forward = Input(shape=(128, 3))
        input_2_backward = Input(shape=(128, 3))
        input_3_forward = Input(shape=(128, 3))
        input_3_backward = Input(shape=(128, 3))

        # Flip the second input data
        input_1_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_1_backward)
        input_2_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_2_backward)
        input_3_backward_flipped = Lambda(lambda x: K.reverse(x, axes=1))(input_3_backward)

        model1 = self.LSTM_Attention(input_1_forward, input_1_backward_flipped)
        model2 = self.LSTM_Attention(input_2_forward, input_2_backward_flipped)
        model3 = self.LSTM_Attention(input_3_forward, input_3_backward_flipped)

        concatenated_models = Concatenate()([model1, model2, model3])

        output = Dropout(0.2)(concatenated_models)
        output = Dense(6)(output)
        output = Activation('softmax', name="softmax")(output)
        self.model = Model(inputs=[input_1_forward, input_1_backward_flipped, input_2_forward, input_2_backward_flipped, input_3_forward, input_3_backward_flipped], outputs=output)
        self.model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),metrics=['accuracy'] )

    def fit(self, X, y, learning_rate, batch_size, epochs, validation_data, early_stopping):

        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []

        if early_stopping:
            callbacks.append(EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True))

        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_loss', save_best_only=True, mode='min', verbose=1))

        # Training the model with validation
        history = self.model.fit(
        X, y,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=validation_data,
        callbacks=callbacks)

        return history


    def fit2(self, X, y, learning_rate, batch_size, epochs, validation_data):
        self.create_model(learning_rate, batch_size)

        # Callbacks
        callbacks = []
        callbacks.append(EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='max', restore_best_weights=True))
        callbacks.append(ModelCheckpoint(model_save_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1))

        # Training the model with validation
        history = self.model.fit(
             X, y,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=validation_data,
             callbacks=callbacks
         )
        return history



    def get_params(self, deep=True):
        return {
            'learning_rate': self.learning_rate,
            'batch_size': self.batch_size
        }


    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# # **Use 5-Fold GridSearchCV to test different combinations of the parameters**

# %%
param_grid = {
   'learning_rate': [0.01, 0.001, 0.0001],
   'batch_size': [32, 64]
 }

param_combinations = [(lr,bs) for lr in param_grid['learning_rate'] for bs in param_grid['batch_size']]

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True)

best_loss = float('inf')
best_params_list = []


for lr, bs in param_combinations:
    print(f"_________________________________________________________________________\nTesting Parameters: Learning Rate: {lr}, Batch Size: {bs}")

    fold_losses = []

    # Perform cross-validation
    for split, (train_index, val_index) in enumerate(kf.split(x_body_acc_train), 1):
        print(f"____________________________________________________\nSplit {split}\n____________________________________________________")

        # Create an instance of LSTMAttentionModel with the specified hyperparameters
        model = LSTMAttentionModel(learning_rate=lr, batch_size=bs)

        # Split data into training and validation sets for each sensor type
        x_body_acc_train_fold = x_body_acc_train[train_index]
        x_body_acc_val_fold = x_body_acc_train[val_index]

        x_gro_train_fold = x_gro_train[train_index]
        x_gro_val_fold = x_gro_train[val_index]

        x_total_acc_train_fold = x_total_acc_train[train_index]
        x_total_acc_val_fold = x_total_acc_train[val_index]

        y_train_fold = y_train[train_index]
        y_val_fold = y_train[val_index]

        validation_data = (
        [x_body_acc_val_fold, np.flip(x_body_acc_val_fold, axis=1),
         x_gro_val_fold, np.flip(x_gro_val_fold, axis=1),
         x_total_acc_val_fold, np.flip(x_total_acc_val_fold, axis=1)],
         y_val_fold)


        # Fit the model to the training data for this fold with validation data
        history = model.fit(
         [x_body_acc_train_fold, np.flip(x_body_acc_train_fold, axis=1),
         x_gro_train_fold, np.flip(x_gro_train_fold, axis=1),
         x_total_acc_train_fold, np.flip(x_total_acc_train_fold, axis=1)],
         y_train_fold, learning_rate=lr, batch_size=bs, epochs=75, validation_data=validation_data, early_stopping=True)

        # Evaluate the model on the validation data directly
        val_loss, val_accuracy = model.model.evaluate(
            [x_body_acc_val_fold, np.flip(x_body_acc_val_fold, axis=1),
             x_gro_val_fold, np.flip(x_gro_val_fold, axis=1),
             x_total_acc_val_fold, np.flip(x_total_acc_val_fold, axis=1)],
            y_val_fold, verbose=0
        )

        fold_losses.append(val_loss)

        print(f"Validation Loss for Split {split}: {val_loss:.4f}")

    mean_loss = np.mean(fold_losses)

    print(f"Mean Loss for Parameters: {lr},{bs} is {mean_loss:.4f}")

    if mean_loss < best_loss:
        best_loss = mean_loss
        best_params_list = [(lr, bs)]
        print(f"New best parameters found: {lr}, {bs}")

print(f"\nBest Overall Parameters: {best_params_list}, with a loss of {best_loss:.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1098 - accuracy: 0.9577 - val_loss: 0.0993 - val_accuracy: 0.9633
# Epoch 26: early stopping
# Validation Loss for Split 2: 0.0898
# ____________________________________________________
# Split 3
# ____________________________________________________
# Epoch 1/75
# 184/184 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8388
# Epoch 1: val_loss improved from inf to 1.28457, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 34s 57ms/step - loss: 0.4238 - accuracy: 0.8388 - val_loss: 1.2846 - val_accuracy: 0.6823
# Epoch 2/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.2376 - accuracy: 0.9150
# Epoch 2: val_loss improved from 1.28457 to 0.45435, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 6s 35ms/step - loss: 0.2375 - accuracy: 0.9152 - val_loss: 0.4543 - val_accuracy: 0.7626
# Epoch 3/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9262
# Epoch 3: val_loss improved from 0.45435 to 0.15984, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1975 - accuracy: 0.9264 - val_loss: 0.1598 - val_accuracy: 0.9333
# Epoch 4/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1926 - accuracy: 0.9279
# Epoch 4: val_loss improved from 0.15984 to 0.12823, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1924 - accuracy: 0.9281 - val_loss: 0.1282 - val_accuracy: 0.9490
# Epoch 5/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1646 - accuracy: 0.9332
# Epoch 5: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1652 - accuracy: 0.9330 - val_loss: 0.2207 - val_accuracy: 0.9054
# Epoch 6/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1749 - accuracy: 0.9346
# Epoch 6: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1749 - accuracy: 0.9347 - val_loss: 0.1773 - val_accuracy: 0.9313
# Epoch 7/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1662 - accuracy: 0.9373
# Epoch 7: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1677 - accuracy: 0.9371 - val_loss: 0.1454 - val_accuracy: 0.9442
# Epoch 8/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9414
# Epoch 8: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1430 - accuracy: 0.9412 - val_loss: 0.2738 - val_accuracy: 0.8177
# Epoch 9/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1510 - accuracy: 0.9423
# Epoch 9: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1524 - accuracy: 0.9419 - val_loss: 0.1772 - val_accuracy: 0.9231
# Epoch 10/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9474
# Epoch 10: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1286 - accuracy: 0.9473 - val_loss: 0.1339 - val_accuracy: 0.9456
# Epoch 11/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9469
# Epoch 11: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1367 - accuracy: 0.9470 - val_loss: 0.1635 - val_accuracy: 0.9374
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9423
# Epoch 12: val_loss did not improve from 0.12823
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1285 - accuracy: 0.9425 - val_loss: 0.1964 - val_accuracy: 0.9143
# Epoch 13/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1379 - accuracy: 0.9466
# Epoch 13: val_loss improved from 0.12823 to 0.11948, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1380 - accuracy: 0.9463 - val_loss: 0.1195 - val_accuracy: 0.9449
# Epoch 14/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9464
# Epoch 14: val_loss did not improve from 0.11948
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1313 - accuracy: 0.9464 - val_loss: 0.1821 - val_accuracy: 0.9327
# Epoch 15/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9440
# Epoch 15: val_loss improved from 0.11948 to 0.11910, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1418 - accuracy: 0.9441 - val_loss: 0.1191 - val_accuracy: 0.9483
# Epoch 16/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9459
# Epoch 16: val_loss did not improve from 0.11910
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1434 - accuracy: 0.9458 - val_loss: 0.1236 - val_accuracy: 0.9340
# Epoch 17/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1284 - accuracy: 0.9489
# Epoch 17: val_loss did not improve from 0.11910
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1280 - accuracy: 0.9492 - val_loss: 0.1385 - val_accuracy: 0.9429
# Epoch 18/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1287 - accuracy: 0.9464
# Epoch 18: val_loss did not improve from 0.11910
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1293 - accuracy: 0.9464 - val_loss: 0.1437 - val_accuracy: 0.9456
# Epoch 19/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9501
# Epoch 19: val_loss improved from 0.11910 to 0.11899, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1232 - accuracy: 0.9502 - val_loss: 0.1190 - val_accuracy: 0.9551
# Epoch 20/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1321 - accuracy: 0.9503
# Epoch 20: val_loss improved from 0.11899 to 0.11296, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1323 - accuracy: 0.9500 - val_loss: 0.1130 - val_accuracy: 0.9524
# Epoch 21/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9513
# Epoch 21: val_loss did not improve from 0.11296
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1156 - accuracy: 0.9514 - val_loss: 0.1240 - val_accuracy: 0.9497
# Epoch 22/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9486
# Epoch 22: val_loss did not improve from 0.11296
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1214 - accuracy: 0.9487 - val_loss: 0.1300 - val_accuracy: 0.9524
# Epoch 23/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1216 - accuracy: 0.9546
# Epoch 23: val_loss improved from 0.11296 to 0.10706, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 38ms/step - loss: 0.1213 - accuracy: 0.9548 - val_loss: 0.1071 - val_accuracy: 0.9585
# Epoch 24/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9493
# Epoch 24: val_loss did not improve from 0.10706
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1234 - accuracy: 0.9495 - val_loss: 0.1109 - val_accuracy: 0.9503
# Epoch 25/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1235 - accuracy: 0.9517
# Epoch 25: val_loss did not improve from 0.10706
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1231 - accuracy: 0.9519 - val_loss: 0.1149 - val_accuracy: 0.9490
# Epoch 26/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1141 - accuracy: 0.9534
# Epoch 26: val_loss improved from 0.10706 to 0.09953, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1141 - accuracy: 0.9532 - val_loss: 0.0995 - val_accuracy: 0.9571
# Epoch 27/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9527
# Epoch 27: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1229 - accuracy: 0.9529 - val_loss: 0.1064 - val_accuracy: 0.9551
# Epoch 28/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9532
# Epoch 28: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1145 - accuracy: 0.9532 - val_loss: 0.1800 - val_accuracy: 0.9102
# Epoch 29/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9585
# Epoch 29: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1058 - accuracy: 0.9585 - val_loss: 0.1263 - val_accuracy: 0.9524
# Epoch 30/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1054 - accuracy: 0.9585
# Epoch 30: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1058 - accuracy: 0.9582 - val_loss: 0.2322 - val_accuracy: 0.9184
# Epoch 31/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1137 - accuracy: 0.9561
# Epoch 31: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1136 - accuracy: 0.9561 - val_loss: 0.1175 - val_accuracy: 0.9551
# Epoch 32/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9558
# Epoch 32: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1175 - accuracy: 0.9560 - val_loss: 0.1093 - val_accuracy: 0.9565
# Epoch 33/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.9554
# Epoch 33: val_loss did not improve from 0.09953
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1131 - accuracy: 0.9556 - val_loss: 0.1092 - val_accuracy: 0.9667
# Epoch 34/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0976 - accuracy: 0.9629
# Epoch 34: val_loss improved from 0.09953 to 0.09923, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0975 - accuracy: 0.9629 - val_loss: 0.0992 - val_accuracy: 0.9605
# Epoch 35/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9633
# Epoch 35: val_loss improved from 0.09923 to 0.08218, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0959 - accuracy: 0.9634 - val_loss: 0.0822 - val_accuracy: 0.9673
# Epoch 36/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9609
# Epoch 36: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1013 - accuracy: 0.9611 - val_loss: 0.1546 - val_accuracy: 0.9429
# Epoch 37/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0951 - accuracy: 0.9636
# Epoch 37: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0949 - accuracy: 0.9638 - val_loss: 0.1480 - val_accuracy: 0.9435
# Epoch 38/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1005 - accuracy: 0.9633
# Epoch 38: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1013 - accuracy: 0.9629 - val_loss: 0.0973 - val_accuracy: 0.9626
# Epoch 39/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1090 - accuracy: 0.9611
# Epoch 39: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1088 - accuracy: 0.9612 - val_loss: 0.1444 - val_accuracy: 0.9531
# Epoch 40/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1012 - accuracy: 0.9624
# Epoch 40: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1010 - accuracy: 0.9626 - val_loss: 0.1153 - val_accuracy: 0.9537
# Epoch 41/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9660
# Epoch 41: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0946 - accuracy: 0.9662 - val_loss: 0.0919 - val_accuracy: 0.9578
# Epoch 42/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0977 - accuracy: 0.9638
# Epoch 42: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0978 - accuracy: 0.9638 - val_loss: 0.0936 - val_accuracy: 0.9619
# Epoch 43/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0928 - accuracy: 0.9662
# Epoch 43: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0928 - accuracy: 0.9662 - val_loss: 0.1103 - val_accuracy: 0.9551
# Epoch 44/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0856 - accuracy: 0.9681
# Epoch 44: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0855 - accuracy: 0.9680 - val_loss: 0.1107 - val_accuracy: 0.9578
# Epoch 45/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 35.
#
# Epoch 45: val_loss did not improve from 0.08218
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0819 - accuracy: 0.9689 - val_loss: 0.0878 - val_accuracy: 0.9653
# Epoch 45: early stopping
# Validation Loss for Split 3: 0.0822
# ____________________________________________________
# Split 4
# ____________________________________________________
# Epoch 1/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.4206 - accuracy: 0.8350
# Epoch 1: val_loss improved from inf to 0.85078, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 33s 52ms/step - loss: 0.4201 - accuracy: 0.8353 - val_loss: 0.8508 - val_accuracy: 0.7912
# Epoch 2/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9247
# Epoch 2: val_loss improved from 0.85078 to 0.37399, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1990 - accuracy: 0.9249 - val_loss: 0.3740 - val_accuracy: 0.8741
# Epoch 3/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9291
# Epoch 3: val_loss improved from 0.37399 to 0.13132, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1838 - accuracy: 0.9289 - val_loss: 0.1313 - val_accuracy: 0.9415
# Epoch 4/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9358
# Epoch 4: val_loss did not improve from 0.13132
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1774 - accuracy: 0.9356 - val_loss: 0.1473 - val_accuracy: 0.9503
# Epoch 5/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1605 - accuracy: 0.9355
# Epoch 5: val_loss did not improve from 0.13132
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1602 - accuracy: 0.9356 - val_loss: 0.1913 - val_accuracy: 0.9374
# Epoch 6/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9373
# Epoch 6: val_loss improved from 0.13132 to 0.09590, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1536 - accuracy: 0.9374 - val_loss: 0.0959 - val_accuracy: 0.9558
# Epoch 7/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1472 - accuracy: 0.9443
# Epoch 7: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1481 - accuracy: 0.9439 - val_loss: 0.1260 - val_accuracy: 0.9558
# Epoch 8/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1354 - accuracy: 0.9425
# Epoch 8: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1352 - accuracy: 0.9425 - val_loss: 0.1032 - val_accuracy: 0.9510
# Epoch 9/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1291 - accuracy: 0.9454
# Epoch 9: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1293 - accuracy: 0.9453 - val_loss: 0.1326 - val_accuracy: 0.9490
# Epoch 10/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1310 - accuracy: 0.9457
# Epoch 10: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1308 - accuracy: 0.9458 - val_loss: 0.1183 - val_accuracy: 0.9456
# Epoch 11/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9426
# Epoch 11: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1303 - accuracy: 0.9427 - val_loss: 0.1715 - val_accuracy: 0.9333
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9438
# Epoch 12: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1274 - accuracy: 0.9441 - val_loss: 0.1025 - val_accuracy: 0.9537
# Epoch 13/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9493
# Epoch 13: val_loss did not improve from 0.09590
# 184/184 [==============================] - 7s 35ms/step - loss: 0.1279 - accuracy: 0.9493 - val_loss: 0.1243 - val_accuracy: 0.9524
# Epoch 14/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9471
# Epoch 14: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1337 - accuracy: 0.9471 - val_loss: 0.1555 - val_accuracy: 0.9449
# Epoch 15/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9450
# Epoch 15: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1293 - accuracy: 0.9453 - val_loss: 0.1125 - val_accuracy: 0.9558
# Epoch 16/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1239 - accuracy: 0.9506Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: val_loss did not improve from 0.09590
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1240 - accuracy: 0.9505 - val_loss: 0.1083 - val_accuracy: 0.9592
# Epoch 16: early stopping
# Validation Loss for Split 4: 0.0959
# ____________________________________________________
# Split 5
# ____________________________________________________
# Epoch 1/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.4539 - accuracy: 0.8180
# Epoch 1: val_loss improved from inf to 0.46021, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 33s 52ms/step - loss: 0.4539 - accuracy: 0.8181 - val_loss: 0.4602 - val_accuracy: 0.7449
# Epoch 2/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9244
# Epoch 2: val_loss improved from 0.46021 to 0.18864, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 37ms/step - loss: 0.2153 - accuracy: 0.9243 - val_loss: 0.1886 - val_accuracy: 0.9320
# Epoch 3/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.9332
# Epoch 3: val_loss improved from 0.18864 to 0.13553, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1661 - accuracy: 0.9332 - val_loss: 0.1355 - val_accuracy: 0.9429
# Epoch 4/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1709 - accuracy: 0.9344
# Epoch 4: val_loss did not improve from 0.13553
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1705 - accuracy: 0.9347 - val_loss: 0.1482 - val_accuracy: 0.9476
# Epoch 5/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1527 - accuracy: 0.9389
# Epoch 5: val_loss improved from 0.13553 to 0.10442, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1530 - accuracy: 0.9388 - val_loss: 0.1044 - val_accuracy: 0.9599
# Epoch 6/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1437 - accuracy: 0.9411
# Epoch 6: val_loss did not improve from 0.10442
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1441 - accuracy: 0.9410 - val_loss: 0.1063 - val_accuracy: 0.9442
# Epoch 7/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.9377
# Epoch 7: val_loss did not improve from 0.10442
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1432 - accuracy: 0.9376 - val_loss: 0.1869 - val_accuracy: 0.9490
# Epoch 8/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1494 - accuracy: 0.9375
# Epoch 8: val_loss improved from 0.10442 to 0.09241, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1491 - accuracy: 0.9376 - val_loss: 0.0924 - val_accuracy: 0.9633
# Epoch 9/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1310 - accuracy: 0.9438
# Epoch 9: val_loss did not improve from 0.09241
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1313 - accuracy: 0.9439 - val_loss: 0.1082 - val_accuracy: 0.9395
# Epoch 10/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1346 - accuracy: 0.9445
# Epoch 10: val_loss did not improve from 0.09241
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1347 - accuracy: 0.9447 - val_loss: 0.1038 - val_accuracy: 0.9605
# Epoch 11/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9395
# Epoch 11: val_loss did not improve from 0.09241
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1346 - accuracy: 0.9396 - val_loss: 0.0967 - val_accuracy: 0.9476
# Epoch 12/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1338 - accuracy: 0.9462
# Epoch 12: val_loss did not improve from 0.09241
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1338 - accuracy: 0.9463 - val_loss: 0.1117 - val_accuracy: 0.9633
# Epoch 13/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1712 - accuracy: 0.9341
# Epoch 13: val_loss improved from 0.09241 to 0.08847, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1705 - accuracy: 0.9344 - val_loss: 0.0885 - val_accuracy: 0.9626
# Epoch 14/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9483
# Epoch 14: val_loss did not improve from 0.08847
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1356 - accuracy: 0.9481 - val_loss: 0.0929 - val_accuracy: 0.9605
# Epoch 15/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9489
# Epoch 15: val_loss did not improve from 0.08847
# 184/184 [==============================] - 7s 35ms/step - loss: 0.1343 - accuracy: 0.9492 - val_loss: 0.1601 - val_accuracy: 0.9259
# Epoch 16/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1265 - accuracy: 0.9524
# Epoch 16: val_loss did not improve from 0.08847
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1261 - accuracy: 0.9524 - val_loss: 0.1349 - val_accuracy: 0.9469
# Epoch 17/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1111 - accuracy: 0.9559
# Epoch 17: val_loss did not improve from 0.08847
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1110 - accuracy: 0.9560 - val_loss: 0.1063 - val_accuracy: 0.9585
# Epoch 18/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1077 - accuracy: 0.9580
# Epoch 18: val_loss improved from 0.08847 to 0.08133, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1074 - accuracy: 0.9582 - val_loss: 0.0813 - val_accuracy: 0.9694
# Epoch 19/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9570
# Epoch 19: val_loss did not improve from 0.08133
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1038 - accuracy: 0.9570 - val_loss: 0.1058 - val_accuracy: 0.9578
# Epoch 20/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1094 - accuracy: 0.9565
# Epoch 20: val_loss did not improve from 0.08133
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1090 - accuracy: 0.9566 - val_loss: 0.1211 - val_accuracy: 0.9469
# Epoch 21/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1144 - accuracy: 0.9544
# Epoch 21: val_loss improved from 0.08133 to 0.07832, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1149 - accuracy: 0.9539 - val_loss: 0.0783 - val_accuracy: 0.9653
# Epoch 22/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9587
# Epoch 22: val_loss did not improve from 0.07832
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1026 - accuracy: 0.9587 - val_loss: 0.2401 - val_accuracy: 0.8619
# Epoch 23/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9529
# Epoch 23: val_loss did not improve from 0.07832
# 184/184 [==============================] - 6s 34ms/step - loss: 0.1179 - accuracy: 0.9529 - val_loss: 0.0821 - val_accuracy: 0.9707
# Epoch 24/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1222 - accuracy: 0.9501
# Epoch 24: val_loss did not improve from 0.07832
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1218 - accuracy: 0.9502 - val_loss: 0.1100 - val_accuracy: 0.9585
# Epoch 25/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1072 - accuracy: 0.9582
# Epoch 25: val_loss did not improve from 0.07832
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1070 - accuracy: 0.9582 - val_loss: 0.0899 - val_accuracy: 0.9619
# Epoch 26/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9587
# Epoch 26: val_loss did not improve from 0.07832
# 184/184 [==============================] - 6s 35ms/step - loss: 0.1056 - accuracy: 0.9589 - val_loss: 0.1235 - val_accuracy: 0.9578
# Epoch 27/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9583
# Epoch 27: val_loss did not improve from 0.07832
# 184/184 [==============================] - 7s 37ms/step - loss: 0.1052 - accuracy: 0.9585 - val_loss: 0.0837 - val_accuracy: 0.9667
# Epoch 28/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0921 - accuracy: 0.9611
# Epoch 28: val_loss did not improve from 0.07832
# 184/184 [==============================] - 7s 35ms/step - loss: 0.0931 - accuracy: 0.9609 - val_loss: 0.1111 - val_accuracy: 0.9565
# Epoch 29/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0957 - accuracy: 0.9624
# Epoch 29: val_loss did not improve from 0.07832
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0958 - accuracy: 0.9624 - val_loss: 0.0872 - val_accuracy: 0.9646
# Epoch 30/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0966 - accuracy: 0.9607
# Epoch 30: val_loss improved from 0.07832 to 0.07185, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 8s 41ms/step - loss: 0.0967 - accuracy: 0.9607 - val_loss: 0.0719 - val_accuracy: 0.9721
# Epoch 31/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9578
# Epoch 31: val_loss did not improve from 0.07185
# 184/184 [==============================] - 7s 36ms/step - loss: 0.1057 - accuracy: 0.9577 - val_loss: 0.1130 - val_accuracy: 0.9381
# Epoch 32/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0876 - accuracy: 0.9640
# Epoch 32: val_loss did not improve from 0.07185
# 184/184 [==============================] - 7s 36ms/step - loss: 0.0874 - accuracy: 0.9641 - val_loss: 0.0981 - val_accuracy: 0.9599
# Epoch 33/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9629
# Epoch 33: val_loss did not improve from 0.07185
# 184/184 [==============================] - 6s 35ms/step - loss: 0.0897 - accuracy: 0.9631 - val_loss: 0.1213 - val_accuracy: 0.9626
# Epoch 34/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9577
# Epoch 34: val_loss improved from 0.07185 to 0.05834, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.0963 - accuracy: 0.9578 - val_loss: 0.0583 - val_accuracy: 0.9748
# Epoch 35/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9626
# Epoch 35: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0918 - accuracy: 0.9628 - val_loss: 0.1602 - val_accuracy: 0.9435
# Epoch 36/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.1088 - accuracy: 0.9590
# Epoch 36: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 33ms/step - loss: 0.1088 - accuracy: 0.9589 - val_loss: 0.1065 - val_accuracy: 0.9531
# Epoch 37/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0911 - accuracy: 0.9641
# Epoch 37: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0908 - accuracy: 0.9643 - val_loss: 0.1867 - val_accuracy: 0.9306
# Epoch 38/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9655
# Epoch 38: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0890 - accuracy: 0.9653 - val_loss: 0.0708 - val_accuracy: 0.9735
# Epoch 39/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0856 - accuracy: 0.9623
# Epoch 39: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0857 - accuracy: 0.9623 - val_loss: 0.0856 - val_accuracy: 0.9680
# Epoch 40/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9677
# Epoch 40: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0789 - accuracy: 0.9677 - val_loss: 0.1792 - val_accuracy: 0.9041
# Epoch 41/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0938 - accuracy: 0.9626
# Epoch 41: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0935 - accuracy: 0.9628 - val_loss: 0.0916 - val_accuracy: 0.9585
# Epoch 42/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9650
# Epoch 42: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 33ms/step - loss: 0.0870 - accuracy: 0.9648 - val_loss: 0.1947 - val_accuracy: 0.8878
# Epoch 43/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9660
# Epoch 43: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0849 - accuracy: 0.9662 - val_loss: 0.0908 - val_accuracy: 0.9599
# Epoch 44/75
# 183/184 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9645Restoring model weights from the end of the best epoch: 34.
#
# Epoch 44: val_loss did not improve from 0.05834
# 184/184 [==============================] - 6s 34ms/step - loss: 0.0909 - accuracy: 0.9646 - val_loss: 0.0704 - val_accuracy: 0.9694
# Epoch 44: early stopping
# Validation Loss for Split 5: 0.0583
# Mean Loss for Parameters: 0.01,32 is 0.0781
# New best parameters found: 0.01, 32
# _________________________________________________________________________
# Testing Parameters: Learning Rate: 0.01, Batch Size: 64
# ____________________________________________________
# Split 1
# ____________________________________________________
# Epoch 1/75
# 92/92 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8473
# Epoch 1: val_loss improved from inf to 6.28328, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 34s 91ms/step - loss: 0.3851 - accuracy: 0.8473 - val_loss: 6.2833 - val_accuracy: 0.2488
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1841 - accuracy: 0.9282
# Epoch 2: val_loss improved from 6.28328 to 0.61801, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1846 - accuracy: 0.9276 - val_loss: 0.6180 - val_accuracy: 0.7811
# Epoch 3/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1518 - accuracy: 0.9387
# Epoch 3: val_loss improved from 0.61801 to 0.20349, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1511 - accuracy: 0.9391 - val_loss: 0.2035 - val_accuracy: 0.9293
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1602 - accuracy: 0.9373
# Epoch 4: val_loss did not improve from 0.20349
# 92/92 [==============================] - 4s 38ms/step - loss: 0.1603 - accuracy: 0.9373 - val_loss: 0.2913 - val_accuracy: 0.8470
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1655 - accuracy: 0.9353
# Epoch 5: val_loss improved from 0.20349 to 0.14367, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 41ms/step - loss: 0.1661 - accuracy: 0.9352 - val_loss: 0.1437 - val_accuracy: 0.9436
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1376 - accuracy: 0.9439
# Epoch 6: val_loss improved from 0.14367 to 0.14123, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1374 - accuracy: 0.9441 - val_loss: 0.1412 - val_accuracy: 0.9504
# Epoch 7/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.9476
# Epoch 7: val_loss improved from 0.14123 to 0.11806, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1253 - accuracy: 0.9473 - val_loss: 0.1181 - val_accuracy: 0.9511
# Epoch 8/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1136 - accuracy: 0.9526
# Epoch 8: val_loss improved from 0.11806 to 0.11317, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1137 - accuracy: 0.9524 - val_loss: 0.1132 - val_accuracy: 0.9619
# Epoch 9/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9473
# Epoch 9: val_loss did not improve from 0.11317
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1198 - accuracy: 0.9469 - val_loss: 0.1478 - val_accuracy: 0.9395
# Epoch 10/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9478
# Epoch 10: val_loss did not improve from 0.11317
# 92/92 [==============================] - 4s 38ms/step - loss: 0.1294 - accuracy: 0.9476 - val_loss: 0.2624 - val_accuracy: 0.9137
# Epoch 11/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9488
# Epoch 11: val_loss did not improve from 0.11317
# 92/92 [==============================] - 4s 38ms/step - loss: 0.1354 - accuracy: 0.9492 - val_loss: 0.2288 - val_accuracy: 0.8702
# Epoch 12/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1161 - accuracy: 0.9542
# Epoch 12: val_loss did not improve from 0.11317
# 92/92 [==============================] - 4s 39ms/step - loss: 0.1158 - accuracy: 0.9544 - val_loss: 0.1344 - val_accuracy: 0.9436
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9475
# Epoch 13: val_loss improved from 0.11317 to 0.11209, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.1300 - accuracy: 0.9475 - val_loss: 0.1121 - val_accuracy: 0.9524
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1116 - accuracy: 0.9526
# Epoch 14: val_loss improved from 0.11209 to 0.10822, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1122 - accuracy: 0.9524 - val_loss: 0.1082 - val_accuracy: 0.9592
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.9528
# Epoch 15: val_loss did not improve from 0.10822
# 92/92 [==============================] - 4s 38ms/step - loss: 0.1144 - accuracy: 0.9527 - val_loss: 0.1193 - val_accuracy: 0.9538
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1080 - accuracy: 0.9566
# Epoch 16: val_loss improved from 0.10822 to 0.08874, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.1082 - accuracy: 0.9565 - val_loss: 0.0887 - val_accuracy: 0.9613
# Epoch 17/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9578
# Epoch 17: val_loss did not improve from 0.08874
# 92/92 [==============================] - 3s 38ms/step - loss: 0.1035 - accuracy: 0.9577 - val_loss: 0.1620 - val_accuracy: 0.9443
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9593
# Epoch 18: val_loss did not improve from 0.08874
# 92/92 [==============================] - 3s 38ms/step - loss: 0.0997 - accuracy: 0.9594 - val_loss: 0.0936 - val_accuracy: 0.9640
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0887 - accuracy: 0.9638
# Epoch 19: val_loss improved from 0.08874 to 0.08862, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0892 - accuracy: 0.9636 - val_loss: 0.0886 - val_accuracy: 0.9646
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9655
# Epoch 20: val_loss did not improve from 0.08862
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0929 - accuracy: 0.9657 - val_loss: 0.1716 - val_accuracy: 0.9273
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1015 - accuracy: 0.9595
# Epoch 21: val_loss did not improve from 0.08862
# 92/92 [==============================] - 3s 38ms/step - loss: 0.1009 - accuracy: 0.9597 - val_loss: 0.1293 - val_accuracy: 0.9497
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9663
# Epoch 22: val_loss did not improve from 0.08862
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0893 - accuracy: 0.9660 - val_loss: 0.1439 - val_accuracy: 0.9449
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0998 - accuracy: 0.9631
# Epoch 23: val_loss did not improve from 0.08862
# 92/92 [==============================] - 4s 38ms/step - loss: 0.1000 - accuracy: 0.9629 - val_loss: 0.0890 - val_accuracy: 0.9613
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9610
# Epoch 24: val_loss improved from 0.08862 to 0.08787, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.0956 - accuracy: 0.9612 - val_loss: 0.0879 - val_accuracy: 0.9606
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9639
# Epoch 25: val_loss did not improve from 0.08787
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0919 - accuracy: 0.9643 - val_loss: 0.1304 - val_accuracy: 0.9504
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9682
# Epoch 26: val_loss did not improve from 0.08787
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0822 - accuracy: 0.9684 - val_loss: 0.0974 - val_accuracy: 0.9653
# Epoch 27/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9684
# Epoch 27: val_loss improved from 0.08787 to 0.07011, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0847 - accuracy: 0.9685 - val_loss: 0.0701 - val_accuracy: 0.9748
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0772 - accuracy: 0.9698
# Epoch 28: val_loss did not improve from 0.07011
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0776 - accuracy: 0.9696 - val_loss: 0.1561 - val_accuracy: 0.9103
# Epoch 29/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9710
# Epoch 29: val_loss did not improve from 0.07011
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0737 - accuracy: 0.9709 - val_loss: 0.0737 - val_accuracy: 0.9667
# Epoch 30/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0767 - accuracy: 0.9688
# Epoch 30: val_loss did not improve from 0.07011
# 92/92 [==============================] - 3s 38ms/step - loss: 0.0765 - accuracy: 0.9689 - val_loss: 0.1523 - val_accuracy: 0.9483
# Epoch 31/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9694
# Epoch 31: val_loss did not improve from 0.07011
# 92/92 [==============================] - 4s 38ms/step - loss: 0.0851 - accuracy: 0.9692 - val_loss: 0.0771 - val_accuracy: 0.9714
# Epoch 32/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9677
# Epoch 32: val_loss improved from 0.07011 to 0.06718, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 48ms/step - loss: 0.0757 - accuracy: 0.9679 - val_loss: 0.0672 - val_accuracy: 0.9789
# Epoch 33/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9677
# Epoch 33: val_loss improved from 0.06718 to 0.05960, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0744 - accuracy: 0.9679 - val_loss: 0.0596 - val_accuracy: 0.9762
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9710
# Epoch 34: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0704 - accuracy: 0.9709 - val_loss: 0.0728 - val_accuracy: 0.9735
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9691
# Epoch 35: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0741 - accuracy: 0.9691 - val_loss: 0.1111 - val_accuracy: 0.9633
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0688 - accuracy: 0.9736
# Epoch 36: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0685 - accuracy: 0.9736 - val_loss: 0.2179 - val_accuracy: 0.9123
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0738 - accuracy: 0.9724
# Epoch 37: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0739 - accuracy: 0.9725 - val_loss: 0.2504 - val_accuracy: 0.9116
# Epoch 38/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0901 - accuracy: 0.9663
# Epoch 38: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0897 - accuracy: 0.9663 - val_loss: 0.0809 - val_accuracy: 0.9687
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9724
# Epoch 39: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0733 - accuracy: 0.9726 - val_loss: 0.0646 - val_accuracy: 0.9776
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0746 - accuracy: 0.9746
# Epoch 40: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0751 - accuracy: 0.9743 - val_loss: 0.0960 - val_accuracy: 0.9606
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0644 - accuracy: 0.9727
# Epoch 41: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0651 - accuracy: 0.9725 - val_loss: 0.1495 - val_accuracy: 0.9375
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9753
# Epoch 42: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0636 - accuracy: 0.9752 - val_loss: 0.0928 - val_accuracy: 0.9599
# Epoch 43/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9787Restoring model weights from the end of the best epoch: 33.
#
# Epoch 43: val_loss did not improve from 0.05960
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0586 - accuracy: 0.9789 - val_loss: 0.0649 - val_accuracy: 0.9714
# Epoch 43: early stopping
# Validation Loss for Split 1: 0.0596
# ____________________________________________________
# Split 2
# ____________________________________________________
# Epoch 1/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.4054 - accuracy: 0.8376
# Epoch 1: val_loss improved from inf to 2.58452, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 40s 187ms/step - loss: 0.4034 - accuracy: 0.8383 - val_loss: 2.5845 - val_accuracy: 0.5303
# Epoch 2/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9325
# Epoch 2: val_loss improved from 2.58452 to 0.94349, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.1788 - accuracy: 0.9323 - val_loss: 0.9435 - val_accuracy: 0.6519
# Epoch 3/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1713 - accuracy: 0.9370
# Epoch 3: val_loss improved from 0.94349 to 0.71095, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1707 - accuracy: 0.9373 - val_loss: 0.7110 - val_accuracy: 0.7940
# Epoch 4/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1380 - accuracy: 0.9452
# Epoch 4: val_loss improved from 0.71095 to 0.13125, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.1378 - accuracy: 0.9454 - val_loss: 0.1313 - val_accuracy: 0.9483
# Epoch 5/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9439
# Epoch 5: val_loss did not improve from 0.13125
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1333 - accuracy: 0.9442 - val_loss: 0.1526 - val_accuracy: 0.9388
# Epoch 6/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9463
# ...
# Epoch 13/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1064 - accuracy: 0.9574
# Epoch 13: val_loss did not improve from 0.10655
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1066 - accuracy: 0.9572 - val_loss: 0.1102 - val_accuracy: 0.9524
# Epoch 14/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9605
# Epoch 14: val_loss did not improve from 0.10655
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1033 - accuracy: 0.9606 - val_loss: 0.1145 - val_accuracy: 0.9469
# Epoch 15/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9607
# Epoch 15: val_loss did not improve from 0.10655
# 92/92 [==============================] - 4s 40ms/step - loss: 0.1017 - accuracy: 0.9611 - val_loss: 0.1362 - val_accuracy: 0.9320
# Epoch 16/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9567
# Epoch 16: val_loss improved from 0.10655 to 0.08696, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 49ms/step - loss: 0.1027 - accuracy: 0.9565 - val_loss: 0.0870 - val_accuracy: 0.9694
# Epoch 17/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0986 - accuracy: 0.9615
# Epoch 17: val_loss did not improve from 0.08696
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0992 - accuracy: 0.9614 - val_loss: 0.0946 - val_accuracy: 0.9667
# Epoch 18/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9634
# Epoch 18: val_loss did not improve from 0.08696
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0923 - accuracy: 0.9633 - val_loss: 0.0925 - val_accuracy: 0.9626
# Epoch 19/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0877 - accuracy: 0.9646
# Epoch 19: val_loss improved from 0.08696 to 0.07922, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0888 - accuracy: 0.9645 - val_loss: 0.0792 - val_accuracy: 0.9721
# Epoch 20/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9648
# Epoch 20: val_loss did not improve from 0.07922
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0880 - accuracy: 0.9650 - val_loss: 0.1299 - val_accuracy: 0.9374
# Epoch 21/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0783 - accuracy: 0.9694
# Epoch 21: val_loss improved from 0.07922 to 0.07325, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0779 - accuracy: 0.9697 - val_loss: 0.0733 - val_accuracy: 0.9714
# Epoch 22/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9694
# Epoch 22: val_loss did not improve from 0.07325
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0760 - accuracy: 0.9694 - val_loss: 0.1315 - val_accuracy: 0.9381
# Epoch 23/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9724
# Epoch 23: val_loss did not improve from 0.07325
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0723 - accuracy: 0.9726 - val_loss: 0.0802 - val_accuracy: 0.9701
# Epoch 24/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9694
# Epoch 24: val_loss did not improve from 0.07325
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0800 - accuracy: 0.9689 - val_loss: 0.0873 - val_accuracy: 0.9633
# Epoch 25/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9736
# Epoch 25: val_loss improved from 0.07325 to 0.06656, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.0701 - accuracy: 0.9738 - val_loss: 0.0666 - val_accuracy: 0.9741
# Epoch 26/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0732 - accuracy: 0.9689
# Epoch 26: val_loss did not improve from 0.06656
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0729 - accuracy: 0.9691 - val_loss: 0.0904 - val_accuracy: 0.9599
# Epoch 27/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9729
# Epoch 27: val_loss improved from 0.06656 to 0.06419, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0667 - accuracy: 0.9731 - val_loss: 0.0642 - val_accuracy: 0.9762
# Epoch 28/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0634 - accuracy: 0.9753
# Epoch 28: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0629 - accuracy: 0.9755 - val_loss: 0.2311 - val_accuracy: 0.8925
# Epoch 29/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0636 - accuracy: 0.9720
# Epoch 29: val_loss did not improve from 0.06419
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0636 - accuracy: 0.9721 - val_loss: 0.2416 - val_accuracy: 0.9204
# Epoch 30/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9749
# Epoch 30: val_loss improved from 0.06419 to 0.06088, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.0612 - accuracy: 0.9752 - val_loss: 0.0609 - val_accuracy: 0.9782
# Epoch 31/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9768
# Epoch 31: val_loss improved from 0.06088 to 0.05133, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0607 - accuracy: 0.9767 - val_loss: 0.0513 - val_accuracy: 0.9837
# Epoch 32/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9746
# Epoch 32: val_loss did not improve from 0.05133
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0640 - accuracy: 0.9743 - val_loss: 0.0838 - val_accuracy: 0.9660
# Epoch 33/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0611 - accuracy: 0.9741
# Epoch 33: val_loss did not improve from 0.05133
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0609 - accuracy: 0.9743 - val_loss: 0.0823 - val_accuracy: 0.9660
# Epoch 34/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0573 - accuracy: 0.9784
# Epoch 34: val_loss did not improve from 0.05133
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0585 - accuracy: 0.9779 - val_loss: 0.0542 - val_accuracy: 0.9803
# Epoch 35/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9742
# Epoch 35: val_loss did not improve from 0.05133
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0603 - accuracy: 0.9740 - val_loss: 0.0636 - val_accuracy: 0.9769
# Epoch 36/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9782
# Epoch 36: val_loss improved from 0.05133 to 0.05086, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 50ms/step - loss: 0.0583 - accuracy: 0.9784 - val_loss: 0.0509 - val_accuracy: 0.9816
# Epoch 37/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9808
# Epoch 37: val_loss did not improve from 0.05086
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0501 - accuracy: 0.9808 - val_loss: 0.0673 - val_accuracy: 0.9721
# Epoch 38/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0526 - accuracy: 0.9780
# Epoch 38: val_loss did not improve from 0.05086
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0522 - accuracy: 0.9782 - val_loss: 0.0527 - val_accuracy: 0.9810
# Epoch 39/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0563 - accuracy: 0.9773
# Epoch 39: val_loss did not improve from 0.05086
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0560 - accuracy: 0.9776 - val_loss: 0.0544 - val_accuracy: 0.9810
# Epoch 40/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0531 - accuracy: 0.9799
# Epoch 40: val_loss did not improve from 0.05086
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0532 - accuracy: 0.9798 - val_loss: 0.1269 - val_accuracy: 0.9456
# Epoch 41/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9748
# Epoch 41: val_loss did not improve from 0.05086
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0596 - accuracy: 0.9747 - val_loss: 0.0539 - val_accuracy: 0.9782
# Epoch 42/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9773
# Epoch 42: val_loss improved from 0.05086 to 0.04703, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.0540 - accuracy: 0.9770 - val_loss: 0.0470 - val_accuracy: 0.9776
# Epoch 43/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9821
# Epoch 43: val_loss improved from 0.04703 to 0.03991, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 45ms/step - loss: 0.0460 - accuracy: 0.9818 - val_loss: 0.0399 - val_accuracy: 0.9884
# Epoch 44/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9796
# Epoch 44: val_loss did not improve from 0.03991
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0500 - accuracy: 0.9798 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 45/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0506 - accuracy: 0.9785
# Epoch 45: val_loss improved from 0.03991 to 0.03936, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 43ms/step - loss: 0.0503 - accuracy: 0.9787 - val_loss: 0.0394 - val_accuracy: 0.9878
# Epoch 46/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9782
# Epoch 46: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0497 - accuracy: 0.9779 - val_loss: 0.0560 - val_accuracy: 0.9782
# Epoch 47/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9797
# Epoch 47: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0503 - accuracy: 0.9796 - val_loss: 0.0590 - val_accuracy: 0.9789
# Epoch 48/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9796
# Epoch 48: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0496 - accuracy: 0.9794 - val_loss: 0.1833 - val_accuracy: 0.9408
# Epoch 49/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9787
# Epoch 49: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0483 - accuracy: 0.9789 - val_loss: 0.0422 - val_accuracy: 0.9857
# Epoch 50/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0461 - accuracy: 0.9813
# Epoch 50: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0460 - accuracy: 0.9813 - val_loss: 0.0663 - val_accuracy: 0.9748
# Epoch 51/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0468 - accuracy: 0.9820
# Epoch 51: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0473 - accuracy: 0.9815 - val_loss: 0.0562 - val_accuracy: 0.9803
# Epoch 52/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0481 - accuracy: 0.9804
# Epoch 52: val_loss did not improve from 0.03936
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0482 - accuracy: 0.9803 - val_loss: 0.1971 - val_accuracy: 0.9381
# Epoch 53/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9811
# Epoch 53: val_loss improved from 0.03936 to 0.03633, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 5s 52ms/step - loss: 0.0477 - accuracy: 0.9808 - val_loss: 0.0363 - val_accuracy: 0.9864
# Epoch 54/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9835
# Epoch 54: val_loss did not improve from 0.03633
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0404 - accuracy: 0.9833 - val_loss: 0.0380 - val_accuracy: 0.9864
# Epoch 55/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9828
# Epoch 55: val_loss improved from 0.03633 to 0.03620, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-Relu-LSTM.hdf5
# 92/92 [==============================] - 4s 44ms/step - loss: 0.0469 - accuracy: 0.9828 - val_loss: 0.0362 - val_accuracy: 0.9884
# Epoch 56/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9811
# Epoch 56: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 42ms/step - loss: 0.0443 - accuracy: 0.9811 - val_loss: 0.0490 - val_accuracy: 0.9857
# Epoch 57/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9835
# Epoch 57: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0410 - accuracy: 0.9835 - val_loss: 0.0691 - val_accuracy: 0.9748
# Epoch 58/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9794
# Epoch 58: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0447 - accuracy: 0.9794 - val_loss: 0.0414 - val_accuracy: 0.9844
# Epoch 59/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0420 - accuracy: 0.9821
# Epoch 59: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0420 - accuracy: 0.9821 - val_loss: 0.0452 - val_accuracy: 0.9796
# Epoch 60/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0398 - accuracy: 0.9818
# Epoch 60: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 39ms/step - loss: 0.0403 - accuracy: 0.9816 - val_loss: 0.0564 - val_accuracy: 0.9769
# Epoch 61/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9815
# Epoch 61: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0430 - accuracy: 0.9811 - val_loss: 0.0481 - val_accuracy: 0.9816
# Epoch 62/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0458 - accuracy: 0.9808
# Epoch 62: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0455 - accuracy: 0.9810 - val_loss: 0.0620 - val_accuracy: 0.9714
# Epoch 63/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0411 - accuracy: 0.9827
# Epoch 63: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0413 - accuracy: 0.9827 - val_loss: 0.0415 - val_accuracy: 0.9844
# Epoch 64/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0429 - accuracy: 0.9840
# Epoch 64: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 40ms/step - loss: 0.0430 - accuracy: 0.9840 - val_loss: 0.0456 - val_accuracy: 0.9816
# Epoch 65/75
# 91/92 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9815Restoring model weights from the end of the best epoch: 55.
#
# Epoch 65: val_loss did not improve from 0.03620
# 92/92 [==============================] - 4s 41ms/step - loss: 0.0422 - accuracy: 0.9816 - val_loss: 0.0660 - val_accuracy: 0.9762
# Epoch 65: early stopping
# Validation Loss for Split 5: 0.0362
# Mean Loss for Parameters: 0.0001,64 is 0.0401
#
# Best Overall Parameters: [(0.001, 32)], with a loss of 0.0389

# %% [markdown]
# # **Now we train and test with the "test" section of the database that we set aside:**

# %%
best_params = {
    'learning_rate': 0.001,
    'batch_size': 32
}

# Reserve a portion of the training data for validation
x_train_final, x_val_final, y_train_final, y_val_final = train_test_split(
    np.concatenate([x_body_acc_train, x_gro_train, x_total_acc_train], axis=-1),
    y_train,
    test_size=0.2,
    random_state=42
)

# Train the final model using the best hyperparameters
best_model = LSTMAttentionModel(learning_rate=best_params['learning_rate'], batch_size=best_params['batch_size'])


# Fit the model to the training data with validation data
history = best_model.fit2(
    X=[
        x_train_final[:, :, :3],
        np.flip(x_train_final[:, :, :3], axis=1),
        x_train_final[:, :, 3:6],
        np.flip(x_train_final[:, :, 3:6], axis=1),
        x_train_final[:, :, 6:],
        np.flip(x_train_final[:, :, 6:], axis=1)
    ],
    y=y_train_final,
    learning_rate=best_params['learning_rate'],
    batch_size=best_params['batch_size'],
    epochs=150,
    validation_data=(
        [
            x_val_final[:, :, :3],
            np.flip(x_val_final[:, :, :3], axis=1),
            x_val_final[:, :, 3:6],
            np.flip(x_val_final[:, :, 3:6], axis=1),
            x_val_final[:, :, 6:],
            np.flip(x_val_final[:, :, 6:], axis=1)
        ],
        y_val_final
    )
)


# Evaluate the model on the test data
test_loss, test_accuracy = best_model.model.evaluate([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                                      x_gro_test, np.flip(x_gro_test, axis=1),
                                                      x_total_acc_test, np.flip(x_total_acc_test, axis=1)],
                                                     y_test, verbose=0)

# Calculate additional evaluation metrics
y_pred = best_model.model.predict([x_body_acc_test, np.flip(x_body_acc_test, axis=1),
                                   x_gro_test, np.flip(x_gro_test, axis=1),
                                   x_total_acc_test, np.flip(x_total_acc_test, axis=1)])

y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Calculate various precision, recall, and F1 scores
precision_macro = precision_score(y_true_labels, y_pred_labels, average='macro')
precision_weighted = precision_score(y_true_labels, y_pred_labels, average='weighted')
precision_micro = precision_score(y_true_labels, y_pred_labels, average='micro')

recall_macro = recall_score(y_true_labels, y_pred_labels, average='macro')
recall_weighted = recall_score(y_true_labels, y_pred_labels, average='weighted')
recall_micro = recall_score(y_true_labels, y_pred_labels, average='micro')

f1_macro = f1_score(y_true_labels, y_pred_labels, average='macro')
f1_weighted = f1_score(y_true_labels, y_pred_labels, average='weighted')
f1_micro = f1_score(y_true_labels, y_pred_labels, average='micro')

accuracy = accuracy_score(y_true_labels, y_pred_labels)

# Calculate per-class accuracy
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
per_class_accuracy = conf_matrix.diagonal() / conf_matrix.sum(axis=1)

# Calculate macro accuracy
macro_accuracy = per_class_accuracy.mean()

# Calculate weighted accuracy
weighted_accuracy = np.average(per_class_accuracy, weights=np.bincount(y_true_labels))

population_std_dev_true = np.std(y_true_labels, ddof=0)
population_std_dev_pred = np.std(y_pred_labels, ddof=0)

sample_std_dev_true = np.std(y_true_labels, ddof=1)
sample_std_dev_pred = np.std(y_pred_labels, ddof=1)


# Print model summary
best_model.model.summary()

# Print evaluation metrics

# Calculate the average accuracy over all epochs
average_accuracy = np.mean(history.history['accuracy'])
# Best accuracy over all epochs
best_accuracy = np.max(history.history['accuracy'])
# Accuracy of the last epoch
last_accuracy = history.history['accuracy'][-1]

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Average Accuracy: {average_accuracy}")
print(f"Best Accuracy: {best_accuracy}")
print(f"Last Epoch Accuracy: {last_accuracy}")

print(f"Micro Accuracy: {accuracy:.4f}")
print(f"Macro Accuracy: {macro_accuracy:.4f}")
print(f"Weighted Accuracy: {weighted_accuracy:.4f}")

print("Precision (Macro):", precision_macro)
print("Precision (Weighted):", precision_weighted)
print("Precision (Micro):", precision_micro)

print("Recall (Macro):", recall_macro)
print("Recall (Weighted):", recall_weighted)
print("Recall (Micro):", recall_micro)

print("F1 Score (Macro):", f1_macro)
print("F1 Score (Weighted):", f1_weighted)
print("F1 Score (Micro):", f1_micro)

print("Population Std Dev - True Labels:", population_std_dev_true)
print("Population Std Dev - Predicted Labels:", population_std_dev_pred)
print("Sample Std Dev - True Labels:", sample_std_dev_true)
print("Sample Std Dev - Predicted Labels:", sample_std_dev_pred)
print("_______________________________________________________________\n")


plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Calculate y_true and y_pred_classes
y_true = np.argmax(y_test, axis=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
cm = pd.DataFrame(conf_matrix, columns=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'],
                  index=['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING'])
sns.heatmap(cm, cmap="YlOrBr", fmt="d", annot=True)
plt.tight_layout()
plt.show()

# Calculate TP, TN, FP, FN for each class
def calculate_confusion_metrics(conf_matrix):
    TP = np.diag(conf_matrix)  # True Positives are on the diagonal
    FP = np.sum(conf_matrix, axis=0) - TP  # False Positives are column sums minus TP
    FN = np.sum(conf_matrix, axis=1) - TP  # False Negatives are row sums minus TP
    TN = conf_matrix.sum() - (FP + FN + TP)  # True Negatives are total sum minus FP, FN, TP

    return TP, TN, FP, FN

TP, TN, FP, FN = calculate_confusion_metrics(conf_matrix)

# Print results for each class
classes = ['WALKING', 'UPSTAIRS', 'DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']
for i, class_label in enumerate(classes):
    print(f"Metrics for {class_label}:")
    print(f"  True Positives (TP): {TP[i]}")
    print(f"  True Negatives (TN): {TN[i]}")
    print(f"  False Positives (FP): {FP[i]}")
    print(f"  False Negatives (FN): {FN[i]}\n")

stop_timer()
# Out:
# Epoch 1/150
# 184/184 [==============================] - ETA: 0s - loss: 0.3926 - accuracy: 0.8716
# Epoch 1: val_accuracy improved from -inf to 0.44663, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 55s 83ms/step - loss: 0.3926 - accuracy: 0.8716 - val_loss: 3.0956 - val_accuracy: 0.4466
# Epoch 2/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.9420
# Epoch 2: val_accuracy improved from 0.44663 to 0.71924, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 51ms/step - loss: 0.1527 - accuracy: 0.9420 - val_loss: 0.8234 - val_accuracy: 0.7192
# Epoch 3/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9396
# Epoch 3: val_accuracy improved from 0.71924 to 0.91230, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 51ms/step - loss: 0.1452 - accuracy: 0.9396 - val_loss: 0.1545 - val_accuracy: 0.9123
# Epoch 4/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1341 - accuracy: 0.9443
# Epoch 4: val_accuracy improved from 0.91230 to 0.94833, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1343 - accuracy: 0.9444 - val_loss: 0.1434 - val_accuracy: 0.9483
# Epoch 5/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1262 - accuracy: 0.9471
# Epoch 5: val_accuracy improved from 0.94833 to 0.95989, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.1258 - accuracy: 0.9473 - val_loss: 0.1071 - val_accuracy: 0.9599
# Epoch 6/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9546
# Epoch 6: val_accuracy improved from 0.95989 to 0.96329, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1103 - accuracy: 0.9546 - val_loss: 0.0911 - val_accuracy: 0.9633
# Epoch 7/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1114 - accuracy: 0.9534
# Epoch 7: val_accuracy did not improve from 0.96329
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1113 - accuracy: 0.9534 - val_loss: 0.0960 - val_accuracy: 0.9606
# Epoch 8/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9526
# Epoch 8: val_accuracy did not improve from 0.96329
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1151 - accuracy: 0.9526 - val_loss: 0.1040 - val_accuracy: 0.9599
# Epoch 9/150
# 184/184 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9561
# Epoch 9: val_accuracy did not improve from 0.96329
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1085 - accuracy: 0.9561 - val_loss: 0.0961 - val_accuracy: 0.9558
# Epoch 10/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.1026 - accuracy: 0.9606
# Epoch 10: val_accuracy improved from 0.96329 to 0.96533, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.1024 - accuracy: 0.9607 - val_loss: 0.0854 - val_accuracy: 0.9653
# Epoch 11/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9600
# Epoch 11: val_accuracy improved from 0.96533 to 0.97213, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0963 - accuracy: 0.9600 - val_loss: 0.0715 - val_accuracy: 0.9721
# Epoch 12/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9633
# Epoch 12: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 8s 43ms/step - loss: 0.0998 - accuracy: 0.9633 - val_loss: 0.0831 - val_accuracy: 0.9667
# Epoch 13/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0841 - accuracy: 0.9652
# Epoch 13: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0840 - accuracy: 0.9653 - val_loss: 0.1312 - val_accuracy: 0.9368
# Epoch 14/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9653
# Epoch 14: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 8s 43ms/step - loss: 0.0875 - accuracy: 0.9653 - val_loss: 0.0682 - val_accuracy: 0.9701
# Epoch 15/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9692
# Epoch 15: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0701 - accuracy: 0.9692 - val_loss: 0.0734 - val_accuracy: 0.9660
# Epoch 16/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9682
# Epoch 16: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 9s 50ms/step - loss: 0.0809 - accuracy: 0.9682 - val_loss: 0.0742 - val_accuracy: 0.9653
# Epoch 17/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9718
# Epoch 17: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 8s 41ms/step - loss: 0.0670 - accuracy: 0.9718 - val_loss: 0.0702 - val_accuracy: 0.9708
# Epoch 18/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0792 - accuracy: 0.9688
# Epoch 18: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 9s 46ms/step - loss: 0.0793 - accuracy: 0.9687 - val_loss: 0.0840 - val_accuracy: 0.9660
# Epoch 19/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9769
# Epoch 19: val_accuracy did not improve from 0.97213
# 184/184 [==============================] - 8s 43ms/step - loss: 0.0627 - accuracy: 0.9769 - val_loss: 0.0823 - val_accuracy: 0.9694
# Epoch 20/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0582 - accuracy: 0.9766
# Epoch 20: val_accuracy improved from 0.97213 to 0.97621, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.0582 - accuracy: 0.9767 - val_loss: 0.0691 - val_accuracy: 0.9762
# Epoch 21/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9772
# Epoch 21: val_accuracy improved from 0.97621 to 0.97893, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.0568 - accuracy: 0.9772 - val_loss: 0.0482 - val_accuracy: 0.9789
# Epoch 22/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9743
# Epoch 22: val_accuracy improved from 0.97893 to 0.97961, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0641 - accuracy: 0.9743 - val_loss: 0.0608 - val_accuracy: 0.9796
# Epoch 23/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9788
# Epoch 23: val_accuracy improved from 0.97961 to 0.98232, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 49ms/step - loss: 0.0516 - accuracy: 0.9789 - val_loss: 0.0439 - val_accuracy: 0.9823
# Epoch 24/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9818
# Epoch 24: val_accuracy did not improve from 0.98232
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0500 - accuracy: 0.9818 - val_loss: 0.1026 - val_accuracy: 0.9551
# Epoch 25/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9796
# Epoch 25: val_accuracy improved from 0.98232 to 0.98436, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0494 - accuracy: 0.9796 - val_loss: 0.0420 - val_accuracy: 0.9844
# Epoch 26/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9816
# Epoch 26: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0477 - accuracy: 0.9816 - val_loss: 0.1291 - val_accuracy: 0.9429
# Epoch 27/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9769
# Epoch 27: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 8s 44ms/step - loss: 0.0619 - accuracy: 0.9769 - val_loss: 0.0598 - val_accuracy: 0.9742
# Epoch 28/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9804
# Epoch 28: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 8s 44ms/step - loss: 0.0470 - accuracy: 0.9804 - val_loss: 0.0585 - val_accuracy: 0.9782
# Epoch 29/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0392 - accuracy: 0.9847
# Epoch 29: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0392 - accuracy: 0.9847 - val_loss: 0.0627 - val_accuracy: 0.9748
# Epoch 30/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9817
# Epoch 30: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0455 - accuracy: 0.9816 - val_loss: 0.0416 - val_accuracy: 0.9844
# Epoch 31/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9811
# Epoch 31: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0426 - accuracy: 0.9811 - val_loss: 0.0672 - val_accuracy: 0.9789
# Epoch 32/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9844
# Epoch 32: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 8s 43ms/step - loss: 0.0365 - accuracy: 0.9844 - val_loss: 0.0809 - val_accuracy: 0.9626
# Epoch 33/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9845
# Epoch 33: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 8s 44ms/step - loss: 0.0405 - accuracy: 0.9845 - val_loss: 0.0403 - val_accuracy: 0.9816
# Epoch 34/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9827
# Epoch 34: val_accuracy did not improve from 0.98436
# 184/184 [==============================] - 9s 46ms/step - loss: 0.0413 - accuracy: 0.9827 - val_loss: 0.2407 - val_accuracy: 0.9334
# Epoch 35/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9847
# Epoch 35: val_accuracy improved from 0.98436 to 0.98980, saving model to /content/drive/MyDrive/UCIHARDataset/GridSearchCV-Tuning-0203-Relu-LSTM.hdf5
# 184/184 [==============================] - 9s 46ms/step - loss: 0.0382 - accuracy: 0.9847 - val_loss: 0.0324 - val_accuracy: 0.9898
# Epoch 36/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9878
# Epoch 36: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0309 - accuracy: 0.9878 - val_loss: 0.0700 - val_accuracy: 0.9714
# Epoch 37/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9833
# Epoch 37: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 47ms/step - loss: 0.0402 - accuracy: 0.9833 - val_loss: 0.0886 - val_accuracy: 0.9660
# Epoch 38/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9850
# Epoch 38: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 8s 45ms/step - loss: 0.0411 - accuracy: 0.9849 - val_loss: 0.1164 - val_accuracy: 0.9572
# Epoch 39/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9871
# Epoch 39: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 46ms/step - loss: 0.0378 - accuracy: 0.9871 - val_loss: 0.0406 - val_accuracy: 0.9816
# Epoch 40/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9844
# Epoch 40: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 8s 42ms/step - loss: 0.0398 - accuracy: 0.9844 - val_loss: 0.0612 - val_accuracy: 0.9789
# Epoch 41/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9862
# Epoch 41: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0350 - accuracy: 0.9862 - val_loss: 0.1016 - val_accuracy: 0.9714
# Epoch 42/150
# 184/184 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9886
# Epoch 42: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 46ms/step - loss: 0.0320 - accuracy: 0.9886 - val_loss: 0.0322 - val_accuracy: 0.9884
# Epoch 43/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9891
# Epoch 43: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 8s 44ms/step - loss: 0.0300 - accuracy: 0.9891 - val_loss: 0.1943 - val_accuracy: 0.9443
# Epoch 44/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9896
# Epoch 44: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 9s 48ms/step - loss: 0.0266 - accuracy: 0.9896 - val_loss: 0.0379 - val_accuracy: 0.9850
# Epoch 45/150
# 183/184 [============================>.] - ETA: 0s - loss: 0.0288 - accuracy: 0.9898Restoring model weights from the end of the best epoch: 35.
#
# Epoch 45: val_accuracy did not improve from 0.98980
# 184/184 [==============================] - 8s 42ms/step - loss: 0.0290 - accuracy: 0.9895 - val_loss: 0.0945 - val_accuracy: 0.9646
# Epoch 45: early stopping
# 93/93 [==============================] - 3s 9ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_7 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_3 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_8 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_5 (InputLayer)        [(None, 128, 3)]             0         []
#
#  input_9 (InputLayer)        [(None, 128, 3)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 128)             1280      ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 128, 128)             1280      ['input_7[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 128, 128)             1280      ['input_3[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 128, 128)             1280      ['input_8[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 128, 128)             1280      ['input_5[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 128, 128)             1280      ['input_9[0][0]']
#
#  concatenate (Concatenate)   (None, 128, 256)             0         ['conv1d[1][0]',
#                                                                      'conv1d_1[1][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 256)             0         ['conv1d_5[1][0]',
#  )                                                                   'conv1d_6[1][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 256)             0         ['conv1d_10[1][0]',
#  )                                                                   'conv1d_11[1][0]']
#
#  batch_normalization (Batch  (None, 128, 256)             1024      ['concatenate[1][0]']
#  Normalization)
#
#  batch_normalization_4 (Bat  (None, 128, 256)             1024      ['concatenate_1[1][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 128, 256)             1024      ['concatenate_2[1][0]']
#  chNormalization)
#
#  max_pooling1d (MaxPooling1  (None, 64, 256)              0         ['batch_normalization[1][0]']
#  D)
#
#  max_pooling1d_4 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_4[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_8 (MaxPoolin  (None, 64, 256)              0         ['batch_normalization_8[1][0]'
#  g1D)                                                               ]
#
#  dropout (Dropout)           (None, 64, 256)              0         ['max_pooling1d[1][0]']
#
#  dropout_4 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_4[1][0]']
#
#  dropout_8 (Dropout)         (None, 64, 256)              0         ['max_pooling1d_8[1][0]']
#
#  conv1d_2 (Conv1D)           (None, 64, 128)              98432     ['dropout[1][0]']
#
#  conv1d_7 (Conv1D)           (None, 64, 128)              98432     ['dropout_4[1][0]']
#
#  conv1d_12 (Conv1D)          (None, 64, 128)              98432     ['dropout_8[1][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 128)              512       ['conv1d_2[1][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 64, 128)              512       ['conv1d_7[1][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 128)              512       ['conv1d_12[1][0]']
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_1[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_5 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_5[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_9 (MaxPoolin  (None, 32, 128)              0         ['batch_normalization_9[1][0]'
#  g1D)                                                               ]
#
#  dropout_1 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_1[1][0]']
#
#  dropout_5 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_5[1][0]']
#
#  dropout_9 (Dropout)         (None, 32, 128)              0         ['max_pooling1d_9[1][0]']
#
#  conv1d_3 (Conv1D)           (None, 32, 64)               24640     ['dropout_1[1][0]']
#
#  conv1d_8 (Conv1D)           (None, 32, 64)               24640     ['dropout_5[1][0]']
#
#  conv1d_13 (Conv1D)          (None, 32, 64)               24640     ['dropout_9[1][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64)               256       ['conv1d_3[1][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 32, 64)               256       ['conv1d_8[1][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 32, 64)               256       ['conv1d_13[1][0]']
#  tchNormalization)
#
#  max_pooling1d_2 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_2[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_6 (MaxPoolin  (None, 16, 64)               0         ['batch_normalization_6[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_10 (MaxPooli  (None, 16, 64)               0         ['batch_normalization_10[1][0]
#  ng1D)                                                              ']
#
#  dropout_2 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_2[1][0]']
#
#  dropout_6 (Dropout)         (None, 16, 64)               0         ['max_pooling1d_6[1][0]']
#
#  dropout_10 (Dropout)        (None, 16, 64)               0         ['max_pooling1d_10[1][0]']
#
#  conv1d_4 (Conv1D)           (None, 16, 32)               6176      ['dropout_2[1][0]']
#
#  conv1d_9 (Conv1D)           (None, 16, 32)               6176      ['dropout_6[1][0]']
#
#  conv1d_14 (Conv1D)          (None, 16, 32)               6176      ['dropout_10[1][0]']
#
#  batch_normalization_3 (Bat  (None, 16, 32)               128       ['conv1d_4[1][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 16, 32)               128       ['conv1d_9[1][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 16, 32)               128       ['conv1d_14[1][0]']
#  tchNormalization)
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_3[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_7 (MaxPoolin  (None, 8, 32)                0         ['batch_normalization_7[1][0]'
#  g1D)                                                               ]
#
#  max_pooling1d_11 (MaxPooli  (None, 8, 32)                0         ['batch_normalization_11[1][0]
#  ng1D)                                                              ']
#
#  dropout_3 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_3[1][0]']
#
#  dropout_7 (Dropout)         (None, 8, 32)                0         ['max_pooling1d_7[1][0]']
#
#  dropout_11 (Dropout)        (None, 8, 32)                0         ['max_pooling1d_11[1][0]']
#
#  layer_normalization (Layer  (None, 8, 32)                64        ['dropout_3[1][0]']
#  Normalization)
#
#  layer_normalization_1 (Lay  (None, 8, 32)                64        ['dropout_7[1][0]']
#  erNormalization)
#
#  layer_normalization_2 (Lay  (None, 8, 32)                64        ['dropout_11[1][0]']
#  erNormalization)
#
#  lstm (LSTM)                 (None, 8, 64)                24832     ['layer_normalization[1][0]']
#
#  lstm_2 (LSTM)               (None, 8, 64)                24832     ['layer_normalization_1[1][0]'
#                                                                     ]
#
#  lstm_4 (LSTM)               (None, 8, 64)                24832     ['layer_normalization_2[1][0]'
#                                                                     ]
#
#  lstm_1 (LSTM)               (None, 8, 64)                33024     ['lstm[1][0]']
#
#  lstm_3 (LSTM)               (None, 8, 64)                33024     ['lstm_2[1][0]']
#
#  lstm_5 (LSTM)               (None, 8, 64)                33024     ['lstm_4[1][0]']
#
#  attention (Attention)       (None, 64)                   72        ['lstm_1[1][0]']
#
#  attention_1 (Attention)     (None, 64)                   72        ['lstm_3[1][0]']
#
#  attention_2 (Attention)     (None, 64)                   72        ['lstm_5[1][0]']
#
#  concatenate_3 (Concatenate  (None, 192)                  0         ['attention[1][0]',
#  )                                                                   'attention_1[1][0]',
#                                                                      'attention_2[1][0]']
#
#  dropout_12 (Dropout)        (None, 192)                  0         ['concatenate_3[1][0]']
#
#  dense (Dense)               (None, 6)                    1158      ['dropout_12[1][0]']
#
#  softmax (Activation)        (None, 6)                    0         ['dense[1][0]']
#
# ==================================================================================================
# Total params: 576318 (2.20 MB)
# Trainable params: 573438 (2.19 MB)
# Non-trainable params: 2880 (11.25 KB)
# __________________________________________________________________________________________________
# Test Accuracy: 0.9589
# Average Accuracy: 0.9709497637218899
# Best Accuracy: 0.9896275997161865
# Last Epoch Accuracy: 0.9894575476646423
# Micro Accuracy: 0.9589
# Macro Accuracy: 0.9596
# Weighted Accuracy: 0.9589
# Precision (Macro): 0.9612312226185327
# Precision (Weighted): 0.9598602206975932
# Precision (Micro): 0.9589412962334578
# Recall (Macro): 0.95957681569461
# Recall (Weighted): 0.9589412962334578
# Recall (Micro): 0.9589412962334578
# F1 Score (Macro): 0.9597842341298833
# F1 Score (Weighted): 0.9587640497960863
# F1 Score (Micro): 0.9589412962334577
# Population Std Dev - True Labels: 1.7400526830680672
# Population Std Dev - Predicted Labels: 1.7437471402776183
# Sample Std Dev - True Labels: 1.7403479826345662
# Sample Std Dev - Predicted Labels: 1.7440430668203137
# _______________________________________________________________
# Metrics for WALKING:
#   True Positives (TP): 479
#   True Negatives (TN): 2445
#   False Positives (FP): 6
#   False Negatives (FN): 17
#
# Metrics for UPSTAIRS:
#   True Positives (TP): 467
#   True Negatives (TN): 2458
#   False Positives (FP): 18
#   False Negatives (FN): 4
#
# Metrics for DOWNSTAIRS:
#   True Positives (TP): 419
#   True Negatives (TN): 2526
#   False Positives (FP): 1
#   False Negatives (FN): 1
#
# Metrics for SITTING:
#   True Positives (TP): 419
#   True Negatives (TN): 2429
#   False Positives (FP): 27
#   False Negatives (FN): 72
#
# Metrics for STANDING:
#   True Positives (TP): 505
#   True Negatives (TN): 2346
#   False Positives (FP): 69
#   False Negatives (FN): 27
#
# Metrics for LAYING:
#   True Positives (TP): 537
#   True Negatives (TN): 2410
#   False Positives (FP): 0
#   False Negatives (FN): 0
#
# Timer stopped at 2024-06-03 16:24:26
# Elapsed time: 518.3857901096344 seconds
